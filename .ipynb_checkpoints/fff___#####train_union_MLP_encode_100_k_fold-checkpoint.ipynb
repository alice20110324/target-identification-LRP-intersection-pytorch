LRP
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
# %matplotlib inline

#from Pytorch-LRP-master import Innvestigator
from innvestigator import InnvestigateModel
#from Pytorch-LRP-master.innvestigator import InnvestigateModel
from utils import Flatten


inn_model = InnvestigateModel(model, lrp_exponent=2,
                              method="e-rule",
                              beta=.5)

model.double()
genes_features=np.array([i for i in range(9)]).reshape(9,1).tolist()
print(genes_features)
for data, target in test_loader:

    data, target = data.to(device), target.to(device)
    print('data:',data.shape)
    batch_size = int(data.size()[0])
    print('batch_size:',batch_size)#=20
    evidence_for_class = []
    # Overlay with noise 
    # data[0] += 0.25 * data[0].max() * torch.Tensor(np.random.randn(28*28).reshape(1, 28, 28))
    model_prediction, true_relevance = inn_model.innvestigate(in_tensor=data)

    for i in range(9):#10类
    # Unfortunately, we had some issue with freeing pytorch memory, therefore 
    # we need to reevaluate the model separately for every class.
        model_prediction, input_relevance_values = inn_model.innvestigate(in_tensor=data, rel_for_class=i)
        evidence_for_class.append(input_relevance_values)
    print('input_relevance_values:',input_relevance_values.shape)
    print('evidence_for_class:',len(evidence_for_class))
    evidence_for_class = np.array([elt.numpy() for elt in evidence_for_class])
    print('evidence_for_class:',evidence_for_class.shape)#[10,20,784]
    for idx, example in enumerate(data):#batch 中的每一个样本
        print('example:',example.shape)
        prediction = np.argmax(model_prediction.cpu().detach(), axis=1)#
        print('prediction[idx]:',prediction[idx])
        #print(evidence_for_class[prediction[idx]][idx])
        fig, axes = plt.subplots(3, 5)
        fig.suptitle("Prediction of model: " + str(prediction[idx]) + "({0:.2f})".format(
            100*float(model_prediction[idx][model_prediction[idx].argmax()].exp()/model_prediction[idx].exp().sum())))
        prediction_value=prediction[idx]
        p_x=model_prediction[idx][model_prediction[idx].argmax()].exp()
        p_sum=model_prediction[idx].exp().sum()
        prediction_score=100*float(model_prediction[idx][model_prediction[idx].argmax()].exp()/model_prediction[idx].exp().sum())
        print('prediction_value:',prediction_value)
        print('prediction_score:',prediction_score)
        if (len(genes_features[idx]))>1:
        
            relevance_score_for_every_pixel=evidence_for_class[prediction[idx]][idx]
            #print('relevance_score_for_every_pixel.shape:',relevance_score_for_every_pixel.tolist())
            relevance_score_for_every_pixel=torch.from_numpy(relevance_score_for_every_pixel)
            index=torch.topk(relevance_score_for_every_pixel,100,largest=True)#基因个数50
            print('pixel_sorted:',index)      
            
            #与存储起来的基因数比较，如果小于30，认为是新的特征，继续加入
            if set(index.indices)&set(prediction[idx][2]) <30:
                genes_features[prediction[idx].append(index)]
        else:
            if prediction_score>95:
                genes_features[prediction[idx].append(prediction_score)]
                relevance_score_for_every_pixel=evidence_for_class[prediction[idx]][idx]
                #print('relevance_score_for_every_pixel.shape:',relevance_score_for_every_pixel.tolist())
                relevance_score_for_every_pixel=torch.from_numpy(relevance_score_for_every_pixel)
                index=torch.topk(relevance_score_for_every_pixel,100,largest=True)#基因个数50
                print('pixel_sorted:',index)      
                genes_features[predictione[idx].append(index)]
        
        
            
        print('分子:',p_x)
        print('分母：',p_sum)
        
        
        
        
        #同一疾病的不同种类 获取不同特征
        #if 
        
        '''
        #写个算法，看多少个像素就能把一个图像全都表达出来
        relevance_score_for_every_pixel=evidence_for_class[prediction[idx]][idx]
        #relevance_score_for_every_pixel.sort()
        row,=relevance_score_for_every_pixel.shape
        num=0
        for i in range(row):
            if relevance_score_for_every_pixel[i,]<0.005:
                evidence_for_class[prediction[idx]][idx][i,]=1
            else:
                num=num+1
        print("num:",num)       
        #print('evi:',evidence_for_class[prediction[idx]][idx])
        vmin = np.percentile(evidence_for_class[:, idx], 50)
        vmax = np.percentile(evidence_for_class[:, idx], 99.9)
        
        axes[0, 2].imshow(example[0])
        
        axes[0, 2].set_title("Input (" + str(int(target[idx]))+ ")")
        #axes[0, 3].imshow(evidence_for_class[prediction[idx]][idx][0], vmin=vmin,
                          #vmax=vmax, cmap="hot")#【0】
        axes[0, 3].imshow(evidence_for_class[prediction[idx]][idx].reshape(28,28), vmin=vmin,
                          vmax=vmax, cmap="hot")
        axes[0, 3].set_title("Pred. Evd.")
        for ax in axes[0]:
            ax.set_axis_off()
        for j, ax in enumerate(axes[1:].flatten()):
            #im = ax.imshow(evidence_for_class[j][idx][0], cmap="hot", vmin=vmin,
                         # vmax=vmax)#【0】。reshape
            im = ax.imshow(evidence_for_class[j][idx].reshape(28,28), cmap="hot", vmin=vmin,
                          vmax=vmax)
            ax.set_axis_off()
            ax.set_title("Evd. " + str(j))
        fig.colorbar(im, ax=axes.ravel().tolist())
        plt.show()
        '''
        
        
    break
        # fig.savefig("./mnist_example{0}.png".format(idx))
print(genes_features)
# Out:
# MLP(
#   (bn0): BatchNorm1d(10477, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=10477, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# [[0], [1], [2], [3], [4], [5], [6], [7], [8]]
# data: torch.Size([16, 10477])
# batch_size: 16
# input_relevance_values: torch.Size([16, 10477])
# evidence_for_class: 9
# evidence_for_class: (9, 16, 10477)
# example: torch.Size([10477])
# prediction[idx]: tensor(0)
# prediction_value: tensor(0)
# prediction_score: 23.803302624280615
# 分子: tensor(2.5232, device='cuda:0', dtype=torch.float64)
# 分母： tensor(10.6003, device='cuda:0', dtype=torch.float64)
# example: torch.Size([10477])
# prediction[idx]: tensor(2)
# prediction_value: tensor(2)
# prediction_score: 25.349532715576274
# 分子: tensor(2.7168, device='cuda:0', dtype=torch.float64)
# 分母： tensor(10.7173, device='cuda:0', dtype=torch.float64)
# example: torch.Size([10477])
# prediction[idx]: tensor(6)
# prediction_value: tensor(6)
# prediction_score: 25.343736815390304
# 分子: tensor(2.7161, device='cuda:0', dtype=torch.float64)
# 分母： tensor(10.7169, device='cuda:0', dtype=torch.float64)
# example: torch.Size([10477])
# prediction[idx]: tensor(4)
# prediction_value: tensor(4)
# prediction_score: 25.360947235740362
# 分子: tensor(2.7183, device='cuda:0', dtype=torch.float64)
# 分母： tensor(10.7183, device='cuda:0', dtype=torch.float64)
# example: torch.Size([10477])
# prediction[idx]: tensor(1)
# prediction_value: tensor(1)
# prediction_score: 24.800405682450062
# 分子: tensor(2.6472, device='cuda:0', dtype=torch.float64)
# 分母： tensor(10.6739, device='cuda:0', dtype=torch.float64)
# example: torch.Size([10477])
# prediction[idx]: tensor(1)
# prediction_value: tensor(1)
# prediction_score: 25.33257895513646
# 分子: tensor(2.7146, device='cuda:0', dtype=torch.float64)
# 分母： tensor(10.7160, device='cuda:0', dtype=torch.float64)
# example: torch.Size([10477])
# prediction[idx]: tensor(3)
# prediction_value: tensor(3)
# prediction_score: 25.358228626959185
# 分子: tensor(2.7179, device='cuda:0', dtype=torch.float64)
# 分母： tensor(10.7180, device='cuda:0', dtype=torch.float64)
# example: torch.Size([10477])
# prediction[idx]: tensor(8)
# prediction_value: tensor(8)
# prediction_score: 25.361104827701958
# 分子: tensor(2.7183, device='cuda:0', dtype=torch.float64)
# 分母： tensor(10.7183, device='cuda:0', dtype=torch.float64)
# example: torch.Size([10477])
# prediction[idx]: tensor(8)
# prediction_value: tensor(8)
# prediction_score: 13.279482648525647
# 分子: tensor(1.3405, device='cuda:0', dtype=torch.float64)
# 分母： tensor(10.0946, device='cuda:0', dtype=torch.float64)
# example: torch.Size([10477])
# prediction[idx]: tensor(2)
# prediction_value: tensor(2)
# prediction_score: 25.350659375953473
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-7b597408fd85> in <module>
#      87         print('prediction_value:',prediction_value)
#      88         print('prediction_score:',prediction_score)
# ---> 89         if (len(genes_features[idx]))>1:
#      90
#      91             relevance_score_for_every_pixel=evidence_for_class[prediction[idx]][idx]
#
# IndexError: list index out of range

# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':1000,
    'linear_hidden':100,#线性模型输出层（隐层个数）
    'embed_input_dim':1001,#embed输入维度
    'embed_dim': 10, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    #'dnn_hidden_units': [100,11],#MLP隐层和输出层
    
    'dnn_hidden_units':[100,9],#MLP隐层
    'num_sparse_features_cols':4224,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 16,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'epoch':1000,
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    #'train_file':'data/xiaoqiu_gene_5000/train/final_5000_encode_100x.csv',
    'train_data':'dataset/qiuguan/encode/encode_1000/train/train_encode_data_1000_new.csv',
    'train_label':'dataset/qiuguan/non_code/train/train_label.csv',
    'guan_test_data':'dataset/qiuguan/non_code/guan_test/guan_test_data.csv',
    'guan_test_label':'dataset/qiuguan/non_code/guan_test/guan_test_label.csv',
    'test_data':'dataset/qiuguan/encode/encode_1000/test/test_encode_data_1000_new.csv',
    'test_label':'dataset/qiuguan/non_code/test/test_labels.csv',
    #'title':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_data.csv',
    'gene_name':'dataset/qiuguan/orign/gene_name.csv',
    'label_name':'dataset/qiuguan/orign/gene_label.csv'
    #'all':''
    #'title':'data/xiaoqiu_gene_5000/train/gene_5000_gene_name.csv',
    #'all':'data/xiaoqiu_gene_5000/train/gene_5000_label_name.csv'
}


import torch

#功能：加载保存到path中的各层参数到神经网络

path='dataset/qiuguan/model_new_K_fold/MLP_encode_100/MLP610.pkl'
import torch.nn as nn
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(10477)
        self.fc1 = nn.Linear(10477, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model = MLP().cuda()
print(model)

#nfm=NFM(nfm_config)
mlp=MLP()
#print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
mlp.load_state_dict(torch.load(path),strict=False)
mlp.cuda()

print(mlp)




mlp_params = list(mlp.named_parameters())
#print(nfm_params)
net=mlp



weight={}
for name,parameters in net.named_parameters():
    print(name,':',parameters.size())
    #names.append(name)
    weight[name]=parameters
#print("weight:",weight)


import pandas as pd 
import numpy as np
disease=pd.read_csv(nfm_config['label_name'],sep=',',header=None)
disease=np.array(disease)
disease=disease[1:,-1]
disease=disease.tolist()
#print(disease)
dis_names=[]
#dis_names.append()

for id in disease:
    if id not in dis_names:
        dis_names.append(id)

print(dis_names)
val=[ i for i in range(nfm_config['n_class'])]
#print(val)

disease_names={}
#disease_names.keys=dis_names
#disease_names.values=val
#disease_names[dis_names]=val
#print(disease_names)
disease_names=dict(zip(dis_names,val))
print(disease_names)




genes=[]
gene_res={}
title=pd.read_csv(nfm_config['gene_name'],sep=',',header=None)
print(title.shape)



def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    n = len(labels)
    #n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output


new_labels=[i for i in range(nfm_config['n_class'])]
new_targets=one_hot_smoothing(new_labels,nfm_config['n_class'])
print(new_targets)

'''
bn0.weight : torch.Size([10477])
bn0.bias : torch.Size([10477])
fc1.weight : torch.Size([2000, 10477])
fc1.bias : torch.Size([2000])
bn1.weight : torch.Size([2000])
bn1.bias : torch.Size([2000])
fc2.weight : torch.Size([100, 2000])
fc2.bias : torch.Size([100])
bn2.weight : torch.Size([100])
bn2.bias : torch.Size([100])
fc3.weight : torch.Size([9, 100])
fc3.bias : torch.Size([9])
bn3.weight : torch.Size([9])
bn3.bias : torch.Size([9])

'''


gene_name=[]
##genes_list=[]
genes=[]
for i in range(nfm_config['n_class']):
    '''
    BN_num.weight : torch.Size([10477])
    BN_num.bias : torch.Size([10477])
    linear_model1.weight : torch.Size([2000, 10477])
    linear_model1.bias : torch.Size([2000])
    BN_linear1.weight : torch.Size([2000])
    BN_linear1.bias : torch.Size([2000])
    linear_model2.weight : torch.Size([100, 2000])
    linear_model2.bias : torch.Size([100])
    BN_linear2.weight : torch.Size([100])
    BN_linear2.bias : torch.Size([100])
    embedding_layers.weight : torch.Size([1001, 10])
    BN_bi.weight : torch.Size([10])
    BN_bi.bias : torch.Size([10])
    dnn_layers.0.weight : torch.Size([100, 110])
    dnn_layers.0.bias : torch.Size([100])
    dnn_layers.1.weight : torch.Size([9, 100])
    dnn_layers.1.bias : torch.Size([9])
    
    
    
    '''
    
    gene=[]
    
    #gene.appenda(i)
    #new_targets=torch.tensor([0, 0, 0, 0, 0, 0, 0, 1])
    new_targets=torch.tensor(new_targets).cuda()
    l1=torch.mv(weight['fc3.weight'].T,(new_targets[i]-weight['fc3.bias']))
    l2=torch.mv(weight['fc2.weight'].T,(l1-weight['fc2.bias']))
    #l2=l2[100:]
    l3=torch.mv(weight['fc1.weight'].T,(l2-weight['fc1.bias']))
    #l4=torch.mv(weight['linear_model1.weight'].T,(l3-weight['linear_model1.bias']))
    #print('l3的权重大小，判断取多少个基因：',l3)#
    #
    
    
    
    #对l3进行排序
    
    
    
    
    top_k=torch.topk(l3,50,largest=True)#基因个数50
    
    print("top_k:",top_k)
    #print(top_k)
    index=top_k.indices
    index=index.tolist()
    #print(index)
    d1=pd.DataFrame(title,columns=index)#
    gene=d1.iloc[1,:]
    gene=gene.tolist()
    #gene.append(dis_names[i])
    genes.append(gene)
    #genes_list.append(gene)
    #print(genes)
    
gene_res=dict(zip(dis_names,genes))
print(gene_res)
#print("genes_list:",genes_list)
genes=np.array(genes)
genes=pd.DataFrame(genes)
print('genes_list:')
#print(genes_list)
genes.to_csv('dataset/qiuguan/results_K_FOLD/MLP_encode_100_genes.csv')
# Out:
# MLP(
#   (bn0): BatchNorm1d(10477, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=10477, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP(
#   (bn0): BatchNorm1d(10477, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=10477, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# bn0.weight : torch.Size([10477])
# bn0.bias : torch.Size([10477])
# fc1.weight : torch.Size([2000, 10477])
# fc1.bias : torch.Size([2000])
# bn1.weight : torch.Size([2000])
# bn1.bias : torch.Size([2000])
# fc2.weight : torch.Size([100, 2000])
# fc2.bias : torch.Size([100])
# bn2.weight : torch.Size([100])
# bn2.bias : torch.Size([100])
# fc3.weight : torch.Size([9, 100])
# fc3.bias : torch.Size([9])
# bn3.weight : torch.Size([9])
# bn3.bias : torch.Size([9])
# ['Con', 'DN', 'FSGS', 'HT', 'IgAN', 'MCD', 'MN', 'RPGN', 'SLE']
# {'Con': 0, 'DN': 1, 'FSGS': 2, 'HT': 3, 'IgAN': 4, 'MCD': 5, 'MN': 6, 'RPGN': 7, 'SLE': 8}
# (2, 10477)
# [[0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.82222223 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.82222223 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.82222223 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.82222223
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.82222223 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]]
# top_k: torch.return_types.topk(
# values=tensor([2.5434, 2.5014, 2.2934, 2.1394, 2.0879, 2.0290, 2.0071, 1.9529, 1.9097,
#         1.8321, 1.8199, 1.7759, 1.6307, 1.6034, 1.6022, 1.4843, 1.4730, 1.4640,
#         1.4079, 1.2625, 1.2511, 1.2497, 1.2408, 1.2147, 1.2070, 1.1914, 1.0975,
#         1.0760, 1.0726, 1.0667, 1.0047, 1.0023, 1.0004, 0.9814, 0.9679, 0.9629,
#         0.9508, 0.9328, 0.9137, 0.8609, 0.8524, 0.8351, 0.8184, 0.7906, 0.7845,
#         0.7693, 0.7593, 0.7561, 0.7557, 0.7556], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([6505, 9131, 1752, 2876, 4223, 6933, 1584, 2575, 2230,  924,  274, 3784,
#         4683, 5587, 9267, 8271, 2739, 9107, 7246,   29, 5141, 6141, 5910, 3395,
#         8445, 6055, 4892, 7374, 9541, 4835, 2632, 9758, 2207, 1658, 6393, 3953,
#         7620, 6288, 5677, 3998, 6908, 2881, 7623,  375, 7821,  438, 8782, 1274,
#         4686, 1667], device='cuda:0'))
# top_k: torch.return_types.topk(
# values=tensor
device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([10018,  6291,  6162,  8913,    55,  9620,  6357,  8782,  1660,  6219,
#          8078,  6790,  3875,    48,  7885,  1987,   524,  2991,  1099,  3053,
#          9107,  8777,  9685,  2237,  3194,   211,  3241,  1022,   226,  4415,
#          8337,  4274,  1626,  9758,  6034,  7746,  2881,  2019,  7246, 10122,
#          8808,   929,  2517,  6933,   695,  9359,  5587,   375,   455,  4988],
#        device='cuda:0'))
# top_k: torch.return_types.topk(
# values=tensor([4.1706, 3.6332, 3.4058, 3.1503, 2.8639, 2.8053, 2.7519, 2.7006, 2.6704,
#         2.5853, 2.5828, 2.5116, 2.4829, 2.4661, 2.4532, 2.3734, 2.2953, 2.2289,
#         2.1850, 2.1511, 2.1322, 2.0894, 2.0629, 2.0439, 2.0304, 1.9651, 1.9506,
#         1.9418, 1.8773, 1.8740, 1.8320, 1.8254, 1.7996, 1.7897, 1.7638, 1.7372,
#         1.7302, 1.6710, 1.6440, 1.6421, 1.6103, 1.6102, 1.6007, 1.5916, 1.5878,
#         1.5624, 1.5568, 1.5400, 1.5306, 1.5119], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([ 4223,  1660,   455,   899,  6357,   481,  6517,  4271,   416,  3724,
#          9737,  4847,  4481,  8782,  4578,  1626,  2207,  7017,  3345,  8253,
#          9758,  1688,  9605,  9086,  2603,  6057,  3242,   524,  8366,  7857,
#          9735,  4274,  2703,  6585,  3194,  9359,   793,  5478,  1315,  8158,
#          6933,  2758,  7885, 10352,  6393,  7962,  1987,  2959,  4892,  6434],
#        device='cuda:0'))
# top_k: torch.return_types.topk(
# values=tensor([8.1230, 5.2645, 5.0275, 4.9192, 4.8516, 4.5197, 4.5156, 4.3053, 4.0439,
#         3.9990, 3.9338, 3.9171, 3.7348, 3.7330, 3.7261, 3.6532, 3.5824, 3.5643,
#         3.4548, 3.3891, 3.1944, 3.1507, 3.1389, 3.1147, 3.0262, 2.9828, 2.8869,
#         2.8610, 2.8357, 2.8127, 2.8099, 2.8001, 2.7741, 2.5652, 2.5603, 2.4841,
#         2.4477, 2.4352, 2.4126, 2.3728, 2.3131, 2.3002, 2.2903, 2.2638, 2.2310,
#         2.2194, 2.1621, 2.1520, 2.1359, 2.0721], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([4223, 2575, 9541, 1688, 6933, 2758,  375, 1274, 1656, 5141, 4271, 7885,
#         9107, 4047, 8782, 5080, 3345, 2739, 1626, 4225, 8192, 9131, 5478, 2394,
#          274, 9735,  813, 3242, 6908, 6214, 6055, 8976, 6880,  924, 8445,  455,
#         2207,   55, 6162, 7368, 6393, 1702,    6, 5495, 3641, 6057, 6551, 7374,
#         6300, 2703], device='cuda:0'))
# {'Con': ['PDK4', 'TFRC', 'CISH', 'ENY2', 'IFI6', 'PPDPF', 'CEBPD', 'DPP4', 'CYP27B1', 'BCR', 'AHCYL1', 'GSTM3', 'KLF6', 'MT1M', 'TMEM100', 'SLC19A2', 'EGLN3', 'TFAM', 'PTP4A1', 'ABCB7', 'MAP3K1', 'NUDT4', 'NFIL3', 'GABARAPL1', 'SLCO4A1', 'NR0B2', 'LIN7A', 'RAB6A', 'TRIM14', 'LDHC', 'DUSP6', 'UBD', 'CYB5R4', 'CGA', 'PAX8', 'HIGD2A', 'RHOB', 'OVOL2', 'MYL7', 'HLA-DQA1', 'PON3', 'EPB41L1', 'RHOBTB3', 'AMDHD2', 'RRAGD', 'ANXA13', 'STAP2', 'CASP6', 'KLF9', 'CHCHD2'], 'DN': ['SPARCL1', 'SLCO4A1', 'CHP2', 'IGKC', 'STIP1', 'FTL', 'CASP6', 'ZNF33B', 'CLSTN3', 'ATF6', 'ATP12A', 'EGLN3', 'BSG', 'HIGD1B', 'CGA', 'PIK3CB', 'TUBA3C', 'TMEM100', 'MAB21L4', 'AGL', 'RPS27L', 'S100A1', 'EIF2AK2', 'TFRC', 'CHP1', 'CGREF1', 'HS3ST1', 'C1orf116', 'IFI6', 'GPC5', 'FMO3', 'DPP4', 'SIGIRR', 'CDC14B', 'ANXA13', 'GLTP', 'ABCB7', 'OXCT1', 'TIMM8B', 'PON3', 'UBD', 'HIRA', 'BCR', 'CTXND1', 'PTP4A1', 'TMPRSS4', 'MAP3K1', 'NCOA2', 'ARSD', 'MPPED2'], 'FSGS': ['POLR1D', 'HOXD10', 'ITCH', 'NEAT1', 'HNRNPH1', 'FUS', 'CFLAR', 'RAB40B', 'AMDHD2', 'TRA2A', 'STAP2', 'ANXA9', 'NR1D2', 'MAB21L4', 'RETSAT', 'C5', 'FKBP5', 'HIGD2A', 'TRIB1', 'EIF2AK2', 'TARS2', 'KCNN2', 'ELP5', 'CYP2E1', 'TFAP2A', 'ADTRP', 'ARL6IP5', 'PLIN3', 'TMEM159', 'CASP8', 'PAX8', 'AHCYL1', 'PAPPA2', 'GUSBP11', 'RBM41', 'DSP', 'PEG10', 'DPP4', 'COX15', 'LAMTOR3', 'CRISPLD2', 'NDUFB5', 'C1orf68', 'EPHX1', 'RPS23', 'PEX6', 'DLK1', 'CASP6', 'NPY', 'RPS14'], 'HT': ['BCAT1', 'IFI6', 'TRIM14', 'NR0B2', 'GADD45GIP1', 'TYMP', 'IGKC', 'SPARCL1', 'DARS2', 'KLF6', 'TFAM', 'GPX2', 'EGLN3', 'AFP', 'COX6B1', 'ADTRP', 'HLA-DQA1', 'FTL', 'SURF1', 'CLSTN3', 'ENPP2', 'CASP6', 'PPDPF', 'OVOL2', 'POLR1D', 'STAP2', 'TIMM8B', 'ATPAF2', 'GABARAPL1', 'GOLGA2P5', 'CEBPD', 'MCUR1', 'TFRC', 'CISH', 'CEP63', 'CERS4', 'ATP6V1F', 'CHM', 'PEX6', 'LETM1', 'ENY2', 'DDX25', 'CGA', 'GUSBP11', 'TENT5C', 'CYB5R4', 'PSPH', 'DPP4', 'RNFT1', 'ACP1'], 'IgAN': ['STAP2', 'ENY2', 'TRIL', 'NUP62CL', 'EXOC5', 'AHCYL1', 'TFAM', 'SUCLG2', 'PPDPF', 'PEG10', 'TMEM100', 'IGKC', 'EPB41L1', 'ID2', 'BCR', 'DARS2', 'NPY', 'TARS2', 'CYB5R4', 'RAB6A', 'MYO15B', 'LIN7A', 'AMDHD2', 'FKBP4', 'LDHC', 'KCNQ1', 'ZNF33B', 'NUDT21', 'PRB3', 'IL17RC', 'TYRP1', 'WARS2', 'POLR1D', 'CD3EAP', 'TRPV5', 'RHBDL1', 'NAP1L1', 'CCDC186', 'AUTS2', 'MAB21L4', 'OVOL2', 'COX15', 'HBB', 'PTP4A1', 'AFP', 'PON3', 'PAX8', 'WASHC3', 'CLSTN3', 'SERPINC1'], 'MCD': ['IFI6', 'HIST1H1C', 'GPC3', 'RRM2', 'HLF', 'MAP3K1', 'CLSTN3', 'RHBDL1', 'CHCHD2', 'DEPTOR', 'SCD', 'TMEM260', 'COMMD10', 'RRAGD', 'PTMS', 'PLIN2', 'LSM8', 'SERPINC1', 'COL4A3BP', 'BICDL1', 'MGLL', 'WASHC3', 'COX5A', 'TFAM', 'TYR', 'TRPS1', 'HIST1H4C', 'CPNE6', 'PRB3', 'MRPL12', 'NUDT4', 'EDAR', 'ENY2', 'IFIT1', 'MRPL19', 'CHP2', 'AUTS2', 'PGGT1B', 'AQP6', 'ITGA6', 'TUBA3C', 'NUDT21', 'OVOL2', 'NPPA', 'NEFH', 'MYL7', 'ELP5', 'PCP4', 'ARSD', 'LAMTOR3'], 'MN': ['WARS2', 'OXCT1', 'NUP62CL', 'SYNJ2BP', 'ABHD2', 'TSKU', 'PAPPA', 'STAP2', 'CGREF1', 'OPA3', 'SERPINA4', 'PLIN3', 'HBB', 'ABCG2', 'S100A1', 'CP', 'AQP1', 'EXOC5', 'C1orf68', 'FAM120A', 'TFAM', 'STAG3', 'TUBA3C', 'CYP2C9', 'FGB', 'ADI1', 'FKBP4', 'BSG', 'ADPRM', 'IRF6', 'SLC2A11', 'IGLV2-14', 'CEP63', 'UBD', 'NPIPB15', 'RORA', 'EPB41L1', 'CRABP1', 'PTP4A1', 'XPNPEP3', 'STK16', 'BDKRB2', 'DNAJC15', 'PPDPF', 'ASXL3', 'TMPRSS4', 'MT1M', 'AMDHD2', 'AOX1', 'LRP5'], 'RPGN': ['IFI6', 'CGREF1', 'AOX1', 'BCAT1', 'PAPPA', 'APBB1IP', 'PDSS1', 'IGKC', 'ANKRD2', 'GPX2', 'TYR', 'LETM1', 'IZUMO4', 'STAP2', 'KCNQ1', 'CEP63', 'CYB5R4', 'PRB3', 'FTL', 'SLC16A1', 'UBD', 'CHM', 'TRPV5', 'TENT5C', 'DSP', 'NR1D2', 'FKBP5', 'AQP1', 'SLC35F6', 'RTN1', 'TYMP', 'IGLV2-14', 'EDNRB', 'PGGT1B', 'FGB', 'TMPRSS4', 'ATPAF2', 'MPDU1', 'CCDC170', 'SH3BP1', 'PPDPF', 'EIF2AK2', 'S100A1', 'ZNF33B', 'PAX8', 'SCGB1D2', 'CP', 'ESRRA', 'LIN7A', 'PCLO'], 'SLE': ['IFI6', 'DPP4', 'TRIM14', 'CHM', 'PPDPF', 'EIF2AK2', 'AMDHD2', 'CASP6', 'CFLAR', 'MAP3K1', 'IGKC', 'S100A1', 'TFAM', 'HNRNPH1', 'STAP2', 'MAB21L4', 'FTL', 'EGLN3', 'CEP63', 'IFIT1', 'SIGIRR', 'TFRC', 'MPDU1', 'DEPTOR', 'AHCYL1', 'TYMP', 'AUTS2', 'FKB ...
# genes_list:
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:203: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
