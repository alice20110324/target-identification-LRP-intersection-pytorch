# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':1000,
    'linear_hidden':100,#线性模型输出层（隐层个数）
    'embed_input_dim':1001,#embed输入维度
    'embed_dim': 50, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    #'dnn_hidden_units': [100,11],#MLP隐层和输出层
    
    'dnn_hidden_units':[100,9],#MLP隐层
    'num_sparse_features_cols':4224,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 24,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'epoch':1000,
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    #'train_file':'data/xiaoqiu_gene_5000/train/final_5000_encode_100x.csv',
    'train_data':'dataset/xiaoguan/RF/RF_for_train/train_class_9/train_aug/train_datas_encode_aug.csv',
    'train_label':'dataset/xiaoguan/RF/RF_for_train/train_class_9/train_aug/train_labels.csv',
    'test_data':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test_aug/test_datas_encode_aug.csv',
    'test_label':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test_aug/test_labels.csv',
    #'title':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_data.csv',
    
    #'all':''
    #'title':'data/xiaoqiu_gene_5000/train/gene_5000_gene_name.csv',
    #'all':'data/xiaoqiu_gene_5000/train/gene_5000_label_name.csv'
}

# %%
#准备训练集

import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter

#import network
import config
import evaluate
import data_utils
import Trainer
#from utils import 
#准备训练集
#from new_dataset_processed import FMData
from dataset_process import FMData
def prepare_dataset(m_data,m_label,batch_size,n_class):
    m_dataset=FMData(m_data,m_label,n_class)
    m_dataloader=data.DataLoader(m_dataset, drop_last=True,batch_size=batch_size,shuffle=True,num_workers=4)
    
    return m_dataset,m_dataloader

# %%
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics
def   train_data(model,train_loader,test_loader,batch_size,model_path):
    #train_accuracy=torchmetrics.Accuracy()
    #test_accuracy=torchmetrics.Accuracy()
    BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    total = 0
    
    #loss_func = torch.nn.BCELoss()
    loss_func=torch.nn.CrossEntropyLoss()
    #loss_func=nn.MultiLabelSoftMarginLoss()
    #loss_func=torch.nn.LogSoftmax()
    num=4
    #model=nn.Softmax(nn.Linear(10149,16)).to(device)
    # 从DataLoader中获取小批量的id以及数据
    for epoch_id in range(1000):
        correct=0
        total=0
        total_test_acc=0
        
        for batch_idx, (x, labels) in enumerate(train_loader):
            x = Variable(x)
            labels = Variable(labels)
            
            
            #x = torch.tensor(x, dtype=torch.float)
            #x=x.clone().detach().requires_grad_(True)
            x=torch.tensor(x,dtype=torch.float)
            labels=torch.tensor(labels,dtype=torch.float)
            x, labels = x.cuda(), labels.cuda()
            labels_int=labels=torch.max(labels,1)[1]
            #labels_int.cuda()
            #print("labels:",labels)
            
            optimizer.zero_grad()
            y_predict = model(x)
            #print("y_predict:",y_predict)
            #loss = loss_func(y_predict.view(-1), labels)
            loss = loss_func(y_predict, labels)
            loss.backward()
            optimizer.step()
            
            loss = loss.item()
            #loss, predicted = self._train_single_batch(x, labels)

            total += loss
            
            
            #predicted = torch.max(y_predict.data,1)
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
            #predicted=predicted.detach().cpu().numpy()
            
            #labels=torch.max(labels,1)
            #print("labels:",labels)
            #labels=labels[1]
            #y_predict=y_predict.cuda()
            #labels=torch.max(labels,1)[1].cuda()
            #labels=labels.detach().cpu().numpy()
            #correct += (predicted == labels).sum()
            #print("correct:",correct)
            #correct=correct[0]
            #print("new_correct:",float(correct))
            #correct=float(correct)   
            #if batch_idx % 10 == 0:
            #print("batch_idx:",batch_idx)
            #print(correct/(BATCH_SIZE*(batch_idx+1)))
            batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
            #print('batch_train_acc:',batch_train_acc)
        #total_train_accuracy=torchmetrics.functional.compute_details()
        #print('total_train_accuracy:',total_train_accuracy)
        for i , (inputs , targets) in enumerate(test_loader):   
            # evaluate the model on the test set   
            #print(\ inputs:\  inputs)   
            #print(\ targets:\  targets)   
            inputs = Variable(inputs)   
            targets = Variable(targets)     
            #x = torch.tensor(x  dtype=torch.float)   
            #x=x.clone().detach().requires_grad_(True)   
            inputs=torch.tensor(inputs ,dtype=torch.float)   
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs , targets = inputs.cuda(),  targets.cuda()   
            yhat = model(inputs)  
            
            #yhat = torch.max(yhat.data,1)[1]
            #yhat=yhat.detach().cpu().numpy()
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
             #predicted = torch.max(y_predict.data,1)[1]
            
            
            targets=torch.max(targets,1)[1]
            #print("labels:",labels)
            #labels=labels[1]
            #targets=targets.detach().cpu().numpy()
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            #print("batch_test_acc:",batch_test_acc)
            total_test_acc+=batch_test_acc
            #total_test_accuracy=torchmetrics.functional.compute_details()
        print('total_test_accuracy:',total_test_acc/(i+1))
        
                    
                    
            
            #model.evaluate()
            #model.eval()
            #train_result = evaluate.metrics(model, train_loader)
            #valid_result = evaluate.metrics(model, valid_loader)
            #est_result = evaluate.metrics(model, test_loader)
            #acturals,predictions,acc_test=evaluate_model(test_loader,model)
            #print("acc_test:  %d  " %(acc_test))
            #print("Train_RMSE: {:.3f}, Valid_RMSE: {:.3f}, Test_RMSE: {:.3f}".format(
            #train_result, valid_result, test_result))
            # print('[Training Epoch: {}] Batch: {}, Loss: {}'.format(epoch_id, batch_id, loss))
        print("Training Epoch: %d, total loss: %f" % (epoch_id, total))
        #print("auc:",roc_auc_score)
    #功能：保存训练完的网络的各层参数（即weights和bias)
    #path='dataset/xiaoguan/RF/RF_for_train/train_class_9/model/gene_4000_NFM.pkl'
        if epoch_id %100==0:
            num=num+1
            path=os.path.join(model_path,'NMF'+str(num)+'.pkl')
            torch.save(model.state_dict(),path)

# %%
train_dataset,train_loader=prepare_dataset(nfm_config['train_data'],nfm_config['train_label'],nfm_config['batch_size'],nfm_config['n_class'])
test_dataset,test_loader=prepare_dataset(nfm_config['test_data'],nfm_config['test_label'],nfm_config['batch_size'],nfm_config['n_class'])
#from MLP import MLP
from new_nfm_network_batch_1 import NFM
#model=MLP(4224,1000,100,9)
model=NFM(nfm_config)
model.cuda()
print("NFM:",model)
train_data(model,train_loader,test_loader,nfm_config['batch_size'],'dataset/xiaoguan/RF/RF_for_train/train_class_9/model/NFM_aug/')
# Out:
# FMData
# FMData
# NFM: NFM(
#   (drop): Dropout(p=0.5, inplace=False)
#   (BN_num): BatchNorm1d(4224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear_model1): Linear(in_features=4224, out_features=1000, bias=True)
#   (BN_linear1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear_model2): Linear(in_features=1000, out_features=100, bias=True)
#   (BN_linear2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (embedding_layers): Embedding(1001, 20)
#   (bi_pooling): BiInteractionPooling()
#   (dropout): Dropout(p=0.3, inplace=False)
#   (BN_bi): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dnn_layers): ModuleList(
#     (0): Linear(in_features=120, out_features=100, bias=True)
#     (1): Linear(in_features=100, out_features=9, bias=True)
#   )
#   (dnn_softmax): Softmax(dim=1)
# )
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:51: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:52: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:103: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:104: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_test_accuracy: tensor(0.1875, device='cuda:0')
# Training Epoch: 0, total loss: 76.141541
# total_test_accuracy: tensor(0.1875, device='cuda:0')
# Training Epoch: 1, total loss: 74.652848
# total_test_accuracy: tensor(0.2917, device='cuda:0')
# Training Epoch: 2, total loss: 73.031699
# total_test_accuracy: tensor(0.2917, device='cuda:0')
# Training Epoch: 3, total loss: 72.219887
# total_test_accuracy: tensor(0.3125, device='cuda:0')
# Training Epoch: 4, total loss: 71.956937
# total_test_accuracy: tensor(0.2708, device='cuda:0')
# Training Epoch: 5, total loss: 71.463739
# total_test_accuracy: tensor(0.2500, device='cuda:0')
# Training Epoch: 6, total loss: 71.512267
# total_test_accuracy: tensor(0.3125, device='cuda:0')
# Training Epoch: 7, total loss: 71.218002
# total_test_accuracy: tensor(0.2500, device='cuda:0')
# Training Epoch: 8, total loss: 70.818869
# total_test_accuracy: tensor(0.2917, device='cuda:0')
# Training Epoch: 9, total loss: 70.754413
# total_test_accuracy: tensor(0.2708, device='cuda:0')
# Training Epoch: 10, total loss: 70.182986
# total_test_accuracy: tensor(0.2292, device='cuda:0')
# Training Epoch: 11, total loss: 70.303214
# total_test_accuracy: tensor(0.3125, device='cuda:0')
# Training Epoch: 12, total loss: 70.057809
# total_test_accuracy: tensor(0.2708, device='cuda:0')
# Training Epoch: 13, total loss: 70.130502
# total_test_accuracy: tensor(0.2500, device='cuda:0')
# Training Epoch: 14, total loss: 69.205890
# total_test_accuracy: tensor(0.3542, device='cuda:0')
# Training Epoch: 15, total loss: 69.804635
# total_test_accuracy: tensor(0.2083, device='cuda:0')
# Training Epoch: 16, total loss: 69.485902
# total_test_accuracy: tensor(0.2292, device='cuda:0')
# Training Epoch: 17, total loss: 69.303700
# total_test_accuracy: tensor(0.2917, device='cuda:0')
# Training Epoch: 18, total loss: 69.338868
# total_test_accuracy: tensor(0.2292, device='cuda:0')
# Training Epoch: 19, total loss: 68.990017
# total_test_accuracy: tensor(0.3333, device='cuda:0')
# Training Epoch: 20, total loss: 68.794405
# total_test_accuracy: tensor(0.2708, device='cuda:0')
# Training Epoch: 21, total loss: 68.337133
# total_test_accuracy: tensor(0.3542, device='cuda:0')
# Training Epoch: 22, total loss: 68.603522
# total_test_accuracy: tensor(0.3333, device='cuda:0')
# Training Epoch: 23, total loss: 67.666728
# total_test_accuracy: tensor(0.2917, device='cuda:0')
# Training Epoch: 24, total loss: 67.944282
# total_test_accuracy: tensor(0.3333, device='cuda:0')
# Training Epoch: 25, total loss: 67.125688
# total_test_accuracy: tensor(0.2500, device='cuda:0')
# Training Epoch: 26, total loss: 67.672829
# total_test_accuracy: tensor(0.4167, device='cuda:0')
# Training Epoch: 27, total loss: 66.954716
# total_test_accuracy: tensor(0.3125, device='cuda:0')
# Training Epoch: 28, total loss: 67.208326
# total_test_accuracy: tensor(0.2708, device='cuda:0')
# Training Epoch:

#net = nn.DataParallel(net)
#net = net.to(device)
model.load_state_dict(torch.load(path),strict=False)
model.cuda()
# Out:
# NFM(
#   (drop): Dropout(p=0.5, inplace=False)
#   (BN_num): BatchNorm1d(4224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear_model1): Linear(in_features=4224, out_features=1000, bias=True)
#   (BN_linear1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear_model2): Linear(in_features=1000, out_features=100, bias=True)
#   (BN_linear2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (embedding_layers): Embedding(1001, 20)
#   (bi_pooling): BiInteractionPooling()
#   (dropout): Dropout(p=0.3, inplace=False)
#   (BN_bi): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dnn_layers): ModuleList(
#     (0): Linear(in_features=120, out_features=100, bias=True)
#     (1): Linear(in_features=100, out_features=9, bias=True)
#   )
#   (dnn_softmax): Softmax(dim=1)
# )
# NFM(
#   (drop): Dropout(p=0.5, inplace=False)
#   (BN_num): BatchNorm1d(4224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear_model1): Linear(in_features=4224, out_features=1000, bias=True)
#   (BN_linear1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear_model2): Linear(in_features=1000, out_features=100, bias=True)
#   (BN_linear2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (embedding_layers): Embedding(1001, 20)
#   (bi_pooling): BiInteractionPooling()
#   (dropout): Dropout(p=0.3, inplace=False)
#   (BN_bi): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dnn_layers): ModuleList(
#     (0): Linear(in_features=120, out_features=100, bias=True)
#     (1): Linear(in_features=100, out_features=9, bias=True)
#   )
#   (dnn_softmax): Softmax(dim=1)
# )

# %%
train_dataset,train_loader=prepare_dataset(nfm_config['train_data'],nfm_config['train_label'],nfm_config['batch_size'],nfm_config['n_class'])
test_dataset,test_loader=prepare_dataset(nfm_config['test_data'],nfm_config['test_label'],nfm_config['batch_size'],nfm_config['n_class'])
#from MLP import MLP
#from new_nfm_network_batch_1 import NFM
#model=MLP(4224,1000,100,9)
#model=NFM(nfm_config)
#model.cuda()
print("NFM:",model)
train_data(model,train_loader,test_loader,nfm_config['batch_size'],'dataset/xiaoguan/RF/RF_for_train/train_class_9/model/NFM_aug/')
# Out:
# FMData
# FMData
# NFM: NFM(
#   (drop): Dropout(p=0.5, inplace=False)
#   (BN_num): BatchNorm1d(4224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear_model1): Linear(in_features=4224, out_features=1000, bias=True)
#   (BN_linear1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear_model2): Linear(in_features=1000, out_features=100, bias=True)
#   (BN_linear2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (embedding_layers): Embedding(1001, 20)
#   (bi_pooling): BiInteractionPooling()
#   (dropout): Dropout(p=0.3, inplace=False)
#   (BN_bi): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dnn_layers): ModuleList(
#     (0): Linear(in_features=120, out_features=100, bias=True)
#     (1): Linear(in_features=100, out_features=9, bias=True)
#   )
#   (dnn_softmax): Softmax(dim=1)
# )
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:51: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:52: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:103: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:104: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_test_accuracy: tensor(0.3542, device='cuda:0')
# Training Epoch: 0, total loss: 62.465085
# total_test_accuracy: tensor(0.3750, device='cuda:0')
# Training Epoch: 1, total loss: 61.561271
# total_test_accuracy: tensor(0.3750, device='cuda:0')
# Training Epoch: 2, total loss: 62.054969
# total_test_accuracy: tensor(0.3542, device='cuda:0')
# Training Epoch: 3, total loss: 61.746159
# total_test_accuracy: tensor(0.3542, device='cuda:0')
# Training Epoch: 4, total loss: 61.495275
# total_test_accuracy: tensor(0.2917, device='cuda:0')
# Training Epoch: 5, total loss: 61.610318
# total_test_accuracy: tensor(0.3333, device='cuda:0')
# Training Epoch: 6, total loss: 61.883663
# total_test_accuracy: tensor(0.3958, device='cuda:0')
# Training Epoch: 7, total loss: 61.289760
# total_test_accuracy: tensor(0.2500, device='cuda:0')
# Training Epoch: 8, total loss: 61.571982
# total_test_accuracy: tensor(0.2708, device='cuda:0')
# Training Epoch: 9, total loss: 61.644091
# total_test_accuracy: tensor(0.3542, device='cuda:0')
# Training Epoch: 10, total loss: 61.659368
# total_test_accuracy: tensor(0.2917, device='cuda:0')
# Training Epoch: 11, total loss: 61.603050
# total_test_accuracy: tensor(0.3333, device='cuda:0')
# Training Epoch: 12, total loss: 61.511923
# total_test_accuracy: tensor(0.3125, device='cuda:0')
# Training Epoch: 13, total loss: 61.587907
# total_test_accuracy: tensor(0.2917, device='cuda:0')
# Training Epoch: 14, total loss: 61.205116
# total_test_accuracy: tensor(0.2917, device='cuda:0')
# Training Epoch: 15, total loss: 60.334761
# total_test_accuracy: tensor(0.3958, device='cuda:0')
# Training Epoch: 16, total loss: 60.795888
# total_test_accuracy: tensor(0.3333, device='cuda:0')
# Training Epoch: 17, total loss: 59.789433
# total_test_accuracy: tensor(0.2917, device='cuda:0')
# Training Epoch: 18, total loss: 60.473181
# total_test_accuracy: tensor(0.3750, device='cuda:0')
# Training Epoch: 19, total loss: 60.597486
# total_test_accuracy: tensor(0.3958, device='cuda:0')
# Training Epoch: 20, total loss: 59.834525
# total_test_accuracy: tensor(0.3958, device='cuda:0')
# Training Epoch: 21, total loss: 58.997797
# total_test_accuracy: tensor(0.4167, device='cuda:0')
# Training Epoch: 22, total loss: 59.575167
# total_test_accuracy: tensor(0.3333, device='cuda:0')
# Training Epoch: 23, total loss: 59.444045
# total_test_accuracy: tensor(0.3125, device='cuda:0')
# Training Epoch: 24, total loss: 59.624219
# total_test_accuracy: tensor(0.3125, device='cuda:0')
# Training Epoch: 25, total loss: 59.541441
# total_test_accuracy: tensor(0.3542, device='cuda:0')
# Training Epoch: 26, total loss: 59.519418
# total_test_accuracy: tensor(0.1875, device='cuda:0')
# Training Epoch: 27, total loss: 58.615794
# total_test_accuracy: tensor(0.3125, device='cuda:0')
# Training Epoch: 28, total loss: 58.797036
# total_test_accuracy: tensor(0.3542, device='cuda:0')
# Training Epoch: 29, total loss: 59.350898
# total_test_accuracy: tensor(0.3125, device='cuda:0')
# Training Epoch: 30, total loss: 59.287661
# total_test_accuracy: tensor(0.4792, device='cuda:0')
# Training Epoch: 31, total loss: 58.448178
# total_test_accuracy: tensor(0.3958, device='cuda:0')
# Training Epoch: