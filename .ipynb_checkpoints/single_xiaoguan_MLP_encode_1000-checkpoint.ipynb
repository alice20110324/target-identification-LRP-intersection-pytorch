# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':12,
    'linear_hidden1':1000,
    'linear_hidden':100,#线性模型输出层（隐层个数）
    'embed_input_dim':1001,#embed输入维度
    'embed_dim': 100, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    #'dnn_hidden_units': [100,11],#MLP隐层和输出层
    
    'dnn_hidden_units':[100,9],#MLP隐层
    'num_sparse_features_cols':4224,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 16,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'epoch':1000,
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    #'train_file':'data/xiaoqiu_gene_5000/train/final_5000_encode_100x.csv',
    'train_data':'dataset/qiuguan/xiaoguan/train_new/train_xiaoguan_all_encode_data_1000_union.csv',
    'train_label':'dataset/qiuguan/xiaoguan/train/train_xiaoguan_labels.csv',
    'guan_test_data':'dataset/qiuguan/non_code/guan_test/guan_test_data.csv',
    'guan_test_label':'dataset/qiuguan/non_code/guan_test/guan_test_label.csv',
    'test_data':'dataset/qiuguan/xiaoguan/test_new/test_xiaoguan_all_encode_data_1000.csv',
    'test_label':'dataset/qiuguan/xiaoguan/test_new/test_label.csv',
    #'title':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_data.csv',
    
    #'all':''
    #'title':'data/xiaoqiu_gene_5000/train/gene_5000_gene_name.csv',
    #'all':'data/xiaoqiu_gene_5000/train/gene_5000_label_name.csv'
}

# %%
#准备训练集

import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter

#import network
import config
import evaluate
import data_utils
import Trainer
#from utils import 
#准备训练集
#from new_dataset_processed import FMData
from dataset_process import FMData
def prepare_dataset(m_data,m_label,batch_size,n_class):
    m_dataset=FMData(m_data,m_label,n_class)
    m_dataloader=data.DataLoader(m_dataset, drop_last=True,batch_size=batch_size,shuffle=True,num_workers=4)
    
    return m_dataset,m_dataloader
# Out:
# [[190 220 490 ... 360 370 420]
#  [110 220 500 ... 340 260 420]
#  [100 300 500 ... 330 350 390]
#  ...
#  [450 360 500 ... 430 360 500]
#  [420 350 530 ... 440 370 500]
#  [420 360 540 ... 430 370 450]]

# %%
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics
def   train_data(model,train_loader,test_loader,batch_size,model_path):
    #train_accuracy=torchmetrics.Accuracy()
    #test_accuracy=torchmetrics.Accuracy()
    BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    total = 0
    
    #loss_func = torch.nn.BCELoss()
    loss_func=torch.nn.CrossEntropyLoss()
    #loss_func=nn.MultiLabelSoftMarginLoss()
    #loss_func=torch.nn.LogSoftmax()
    num=0
    #model=nn.Softmax(nn.Linear(10149,16)).to(device)
    # 从DataLoader中获取小批量的id以及数据
    
    batch_size=0
    for epoch_id in range(1000):
        correct=0
        total=0
        total_test_acc=0
        total_train_accuracy=0
        for batch_idx, (x, labels) in enumerate(train_loader):
            x = Variable(x)
            labels = Variable(labels)
            
            
            #x = torch.tensor(x, dtype=torch.float)
            #x=x.clone().detach().requires_grad_(True)
            x=torch.tensor(x,dtype=torch.float)
            labels=torch.tensor(labels,dtype=torch.float)
            x, labels = x.cuda(), labels.cuda()
            labels_int=labels=torch.max(labels,1)[1]
            #labels_int.cuda()
            #print("labels:",labels)
            
            optimizer.zero_grad()
            y_predict = model(x)
            #print("y_predict:",y_predict)
            #loss = loss_func(y_predict.view(-1), labels)
            loss = loss_func(y_predict, labels)
            loss.backward()
            optimizer.step()
            
            loss = loss.item()
            #loss, predicted = self._train_single_batch(x, labels)

            total += loss
            
            
            #predicted = torch.max(y_predict.data,1)
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
            #predicted=predicted.detach().cpu().numpy()
            
            #labels=torch.max(labels,1)
            #print("labels:",labels)
            #labels=labels[1]
            #y_predict=y_predict.cuda()
            #labels=torch.max(labels,1)[1].cuda()
            #labels=labels.detach().cpu().numpy()
            #correct += (predicted == labels).sum()
            #print("correct:",correct)
            #correct=correct[0]
            #print("new_correct:",float(correct))
            #correct=float(correct)   
            #if batch_idx % 10 == 0:
            #print("batch_idx:",batch_idx)
            #print(correct/(BATCH_SIZE*(batch_idx+1)))
            batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
            #print('batch_train_acc:',batch_train_acc)
            total_train_accuracy+=batch_train_acc
        #total_train_accuracy=torchmetrics.functional.compute_details()
        total_train_accuracy/=(batch_idx+1)
        print('total_train_accuracy:',total_train_accuracy)
        #print('total_train_accuracy:',total_train_accuracy)
        for i , (inputs , targets) in enumerate(test_loader):   
            print("test")
            # evaluate the model on the test set   
            #print(\ inputs:\  inputs)   
            #print(\ targets:\  targets)   
            inputs = Variable(inputs)   
            targets = Variable(targets)     
            #x = torch.tensor(x  dtype=torch.float)   
            #x=x.clone().detach().requires_grad_(True)   
            inputs=torch.tensor(inputs ,dtype=torch.float)   
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs , targets = inputs.cuda(),  targets.cuda()   
            yhat = model(inputs)  
            
            #yhat = torch.max(yhat.data,1)[1]
            #yhat=yhat.detach().cpu().numpy()
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
             #predicted = torch.max(y_predict.data,1)[1]
            
            
            targets=torch.max(targets,1)[1]
            #print("labels:",labels)
            #labels=labels[1]
            #targets=targets.detach().cpu().numpy()
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            #print("batch_test_acc:",batch_test_acc)
            total_test_acc+=batch_test_acc
            #total_test_accuracy=torchmetrics.functional.compute_details()
            batch_size=i
        print('total_test_accuracy:',total_test_acc/(batch_size+1))
        
                    
                    
            
            #model.evaluate()
            #model.eval()
            #train_result = evaluate.metrics(model, train_loader)
            #valid_result = evaluate.metrics(model, valid_loader)
            #est_result = evaluate.metrics(model, test_loader)
            #acturals,predictions,acc_test=evaluate_model(test_loader,model)
            #print("acc_test:  %d  " %(acc_test))
            #print("Train_RMSE: {:.3f}, Valid_RMSE: {:.3f}, Test_RMSE: {:.3f}".format(
            #train_result, valid_result, test_result))
            # print('[Training Epoch: {}] Batch: {}, Loss: {}'.format(epoch_id, batch_id, loss))
        print("Training Epoch: %d, total loss: %f" % (epoch_id, total))
        #print("auc:",roc_auc_score)
    #功能：保存训练完的网络的各层参数（即weights和bias)
    #path='dataset/xiaoguan/RF/RF_for_train/train_class_9/model/gene_4000_NFM.pkl'
        if epoch_id %100==0:
            num=num+1
            path=os.path.join(model_path,'MLP'+str(num)+'.pkl')
            torch.save(model.state_dict(),path)

# %%
train_dataset,train_loader=prepare_dataset(nfm_config['train_data'],nfm_config['train_label'],nfm_config['batch_size'],shuffle=True,nfm_config['n_class'])
test_dataset,test_loader=prepare_dataset(nfm_config['test_data'],nfm_config['test_label'],nfm_config['batch_size'],shuffle=False,nfm_config['n_class'])
from MLP2 import MLP
#from new_nfm_network import NFM
model=MLP(10150,1000,100,12)
#model=NFM(nfm_config)
model.cuda()
print("MLP1:",model)
train_data(model,train_loader,test_loader,nfm_config['batch_size'],'dataset/qiuguan/xiaoguan/model/MLP_encode_1000/')
# Out:
# FMData
# FMData
# MLP1: MLP(
#   (bn0): BatchNorm1d(10150, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=10150, out_features=1000, bias=True)
#   (bn1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=1000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=12, bias=True)
#   (bn3): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.7, inplace=False)
#   (drop2): Dropout(p=0.5, inplace=False)
# )
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.1875, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 0, total loss: 46.317250
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.3092, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 1, total loss: 45.331172
# total_train_accuracy: tensor(0.3586, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 2, total loss: 44.928878
# total_train_accuracy: tensor(0.3684, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 3, total loss: 44.643604
# total_train_accuracy: tensor(0.3947, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 4, total loss: 44.663426
# total_train_accuracy: tensor(0.4046, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 5, total loss: 44.353361
# total_train_accuracy: tensor(0.4013, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 6, total loss: 44.203166
# total_train_accuracy: tensor(0.4112, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 7, total loss: 44.290799
# total_train_accuracy: tensor(0.3914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 8, total loss: 44.188040
# total_train_accuracy: tensor(0.4013, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 9, total loss: 43.998358
# total_train_accuracy: tensor(0.3947, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 10, total loss: 44.319325
# total_train_accuracy: tensor(0.4605, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 11, total loss: 43.793751
# total_train_accuracy: tensor(0.4539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 12, total loss: 43.704900
# total_train_accuracy: tensor(0.4145, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 13, total loss: 43.788505
# total_train_accuracy: tensor(0.4704, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 14, total loss: 43.366239
# total_train_accuracy: tensor(0.4737, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 15, total loss: 43.552448
# total_train_accuracy: tensor(0.4375, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 16, total loss: 43.698663
# total_train_accuracy: tensor(0.4441, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 17, total loss: 43.609637
# total_train_accuracy: tensor(0.4539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 18, total loss: 43.427290
# total_train_accuracy: tensor(0.4671, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 19, total loss: 43.163022
# total_train_accuracy: tensor(0.4901, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 20, total loss: 43.035365
# total_train_accuracy: tensor(0.4868, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 21, total loss: 42.877281
# total_train_accuracy: tensor(0.4868, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 22, total loss: 43.050735
# total_train_accuracy: tensor(0.4836, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 23, total loss: 42.776447
# total_train_accuracy: tensor(0.4770, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 24, total loss: 42.772813
# total_train_accuracy: tensor(0.5296, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 25, total loss: 42.416864
# total_train_accuracy: tensor(0.4474, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 26, total loss: 42.926073
# total_train_accuracy: tensor(0.4901, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 27, total loss: 42.485640
# total_train_accuracy: tensor(0.5099, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 28, total loss: 42.467030
# total_train_accuracy: tensor(0.4901, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 29, total loss: 42.433010
# total_train_accuracy: tensor(0.5099, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 30, total loss: 42.108204
# total_train_accuracy: tensor(0.5000, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 31, total loss: 42.232051
# total_train_accuracy: tensor(0.5066, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 32, total loss: 42.195834
# total_train_accuracy: tensor(0.5000, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 33, total loss: 42.117447
# total_train_accuracy: tensor(0.5197, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 34, total loss: 42.138452
# total_train_accuracy: tensor(0.5329, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 35, total loss: 41.820604
# total_train_accuracy: tensor(0.5099, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 36, total loss: 42.010057
# total_train_accuracy: tensor(0.5428, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 37, total loss: 41.605209
# total_train_accuracy: tensor(0.5526, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 38, total loss: 41.649805
# total_train_accuracy: tensor(0.5132, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 39, total loss: 41.781478
# total_train_accuracy: tensor(0.5099, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 40, total loss: 41.512575
# total_train_accuracy: tensor(0.5658, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 41, total loss: 41.356332
# total_train_accuracy: tensor(0.5658, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 42, total loss: 41.190089
# total_train_accuracy: tensor(0.5362, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 43, total loss: 41.390574
# total_train_accuracy: tensor(0.5888, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 44, total loss: 40.545623
# total_train_accuracy: tensor(0.5526, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 45, total loss: 41.145912
# total_train_accuracy: tensor(0.5724, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 46, total loss: 40.733119
# total_train_accuracy: tensor(0.5855, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 47, total loss: 40.881723
# total_train_accuracy: tensor(0.5954, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 48, total loss: 40.647692
# total_train_accuracy: tensor(0.5592, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 49, total loss: 40.859379
# total_train_accuracy: tensor(0.5461, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 50, total loss: 40.879373
# total_train_accuracy: tensor(0.5789, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 51, total loss: 40.533290
# total_train_accuracy: tensor(0.5592, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 52, total loss: 40.450244
# total_train_accuracy: tensor(0.5724, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 53, total loss: 40.378147
# total_train_accuracy: tensor(0.6151, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 54, total loss: 40.086480
# total_train_accuracy: tensor(0.6151, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 55, total loss: 40.105900
# total_train_accuracy: tensor(0.5888, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 56, total loss: 39.968620
# total_train_accuracy: tensor(0.5789, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 57, total loss: 40.184219
# total_train_accuracy: tensor(0.6250, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 58, total loss: 39.706084
# total_train_accuracy: tensor(0.5954, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 59, total loss: 39.855569
# total_train_accuracy: tensor(0.6382, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 60, total loss: 39.742980
# total_train_accuracy: tensor(0.5789, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 61, total loss: 40.111830
# total_train_accuracy: tensor(0.6382, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 62, total loss: 39.551656
# total_train_accuracy: tensor(0.6250, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 63, total loss: 39.783054
# total_train_accuracy: tensor(0.6217, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 64, total loss: 39.447109
# total_train_accuracy: tensor(0.6579, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 65, total loss: 39.059044
# total_train_accuracy: tensor(0.6941, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 66, total loss: 38.393705
# total_train_accuracy: tensor(0.6053, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 67, total loss: 39.518336
# total_train_accuracy: tensor(0.6678, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 68, total loss: 39.053943
# total_train_accuracy: tensor(0.6250, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 69, total loss: 39.587923
# total_train_accuracy: tensor(0.6118, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 70, total loss: 39.455227
# total_train_accuracy: tensor(0.6612, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 71, total loss: 38.774976
# total_train_accuracy: tensor(0.6875, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 72, total loss: 38.454520
# total_train_accuracy: tensor(0.6678, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 73, total loss: 38.690595
# total_train_accuracy: tensor(0.6349, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 74, total loss: 39.004663
# total_train_accuracy: tensor(0.6842, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 75, total loss: 38.375880
# total_train_accuracy: tensor(0.6743, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 76, total loss: 38.528713
# total_train_accuracy: tensor(0.7171, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 77, total loss: 37.962265
# total_train_accuracy: tensor(0.7039, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 78, total loss: 37.928558
# total_train_accuracy: tensor(0.7072, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 79, total loss: 38.178775
# total_train_accuracy: tensor(0.6842, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 80, total loss: 38.491116
# total_train_accuracy: tensor(0.6842, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 81, total loss: 38.236683
# total_train_accuracy: tensor(0.6908, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 82, total loss: 38.113398
# total_train_accuracy: tensor(0.7204, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 83, total loss: 37.955544
# total_train_accuracy: tensor(0.7632, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 84, total loss: 37.064914
# total_train_accuracy: tensor(0.7039, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 85, total loss: 38.019253
# total_train_accuracy: tensor(0.6842, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 86, total loss: 37.792124
# total_train_accuracy: tensor(0.7039, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 87, total loss: 37.890899
# total_train_accuracy: tensor(0.7171, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 88, total loss: 37.683309
# total_train_accuracy: tensor(0.7303, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 89, total loss: 37.371537
# total_train_accuracy: tensor(0.7533, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 90, total loss: 37.238526
# total_train_accuracy: tensor(0.7664, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 91, total loss: 37.334419
# total_train_accuracy: tensor(0.7368, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 92, total loss: 37.213824
# total_train_accuracy: tensor(0.7500, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 93, total loss: 37.155501
# total_train_accuracy: tensor(0.7533, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 94, total loss: 37.318886
# total_train_accuracy: tensor(0.7862, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 95, total loss: 36.864831
# total_train_accuracy: tensor(0.7730, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 96, total loss: 36.866271
# total_train_accuracy: tensor(0.7862, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 97, total loss: 36.450284
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 98, total loss: 36.578935
# total_train_accuracy: tensor(0.7862, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 99, total loss: 36.716146
# total_train_accuracy: tensor(0.7697, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 100, total loss: 36.811164
# total_train_accuracy: tensor(0.7928, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 101, total loss: 36.458445
# total_train_accuracy: tensor(0.7928, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 102, total loss: 36.746138
# total_train_accuracy: tensor(0.7796, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 103, total loss: 36.333438
# total_train_accuracy: tensor(0.8059, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 104, total loss: 36.220259
# total_train_accuracy: tensor(0.7928, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 105, total loss: 36.447588
# total_train_accuracy: tensor(0.7961, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 106, total loss: 36.335938
# total_train_accuracy: tensor(0.7993, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 107, total loss: 36.034693
# total_train_accuracy: tensor(0.8289, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 108, total loss: 35.770852
# total_train_accuracy: tensor(0.7961, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 109, total loss: 36.563668
# total_train_accuracy: tensor(0.8289, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 110, total loss: 35.885099
# total_train_accuracy: tensor(0.8026, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 111, total loss: 36.177091
# total_train_accuracy: tensor(0.8191, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 112, total loss: 36.033545
# total_train_accuracy: tensor(0.8388, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 113, total loss: 35.550325
# total_train_accuracy: tensor(0.8322, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 114, total loss: 35.635281
# total_train_accuracy: tensor(0.8355, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 115, total loss: 35.588724
# total_train_accuracy: tensor(0.7862, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 116, total loss: 36.325141
# total_train_accuracy: tensor(0.8158, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 117, total loss: 35.788826
# total_train_accuracy: tensor(0.8191, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 118, total loss: 35.493678
# total_train_accuracy: tensor(0.8651, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 119, total loss: 35.345129
# total_train_accuracy: tensor(0.8355, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 120, total loss: 35.571194
# total_train_accuracy: tensor(0.8388, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 121, total loss: 35.500200
# total_train_accuracy: tensor(0.7928, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 122, total loss: 36.070448
# total_train_accuracy: tensor(0.8586, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 123, total loss: 35.433592
# total_train_accuracy: tensor(0.8421, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 124, total loss: 35.370762
# total_train_accuracy: tensor(0.8553, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 125, total loss: 35.231168
# total_train_accuracy: tensor(0.8322, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 126, total loss: 35.595450
# total_train_accuracy: tensor(0.8586, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 127, total loss: 34.968595
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 128, total loss: 35.660050
# total_train_accuracy: tensor(0.8454, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 129, total loss: 35.240705
# total_train_accuracy: tensor(0.8224, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 130, total loss: 35.467000
# total_train_accuracy: tensor(0.8553, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 131, total loss: 35.270853
# total_train_accuracy: tensor(0.8553, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 132, total loss: 35.156534
# total_train_accuracy: tensor(0.8092, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 133, total loss: 35.803755
# total_train_accuracy: tensor(0.8421, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 134, total loss: 35.527873
# total_train_accuracy: tensor(0.8224, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 135, total loss: 35.042478
# total_train_accuracy: tensor(0.8520, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 136, total loss: 35.276438
# total_train_accuracy: tensor(0.8355, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 137, total loss: 35.362428
# total_train_accuracy: tensor(0.8224, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 138, total loss: 35.548664
# total_train_accuracy: tensor(0.8322, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 139, total loss: 35.311194
# total_train_accuracy: tensor(0.8487, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 140, total loss: 34.899666
# total_train_accuracy: tensor(0.8651, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 141, total loss: 34.890952
# total_train_accuracy: tensor(0.8684, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 142, total loss: 34.866993
# total_train_accuracy: tensor(0.8322, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 143, total loss: 35.336509
# total_train_accuracy: tensor(0.8586, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 144, total loss: 34.841771
# total_train_accuracy: tensor(0.8651, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 145, total loss: 34.896466
# total_train_accuracy: tensor(0.8355, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 146, total loss: 35.086894
# total_train_accuracy: tensor(0.8783, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 147, total loss: 34.130648
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 148, total loss: 34.362304
# total_train_accuracy: tensor(0.8586, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 149, total loss: 35.178764
# total_train_accuracy: tensor(0.8355, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 150, total loss: 35.296224
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 151, total loss: 34.253737
# total_train_accuracy: tensor(0.8553, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 152, total loss: 34.710010
# total_train_accuracy: tensor(0.8421, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 153, total loss: 35.294863
# total_train_accuracy: tensor(0.8158, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 154, total loss: 35.292637
# total_train_accuracy: tensor(0.8421, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 155, total loss: 35.152664
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 156, total loss: 34.579613
# total_train_accuracy: tensor(0.8520, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 157, total loss: 34.792943
# total_train_accuracy: tensor(0.8980, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 158, total loss: 34.202561
# total_train_accuracy: tensor(0.8947, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 159, total loss: 34.357866
# total_train_accuracy: tensor(0.8980, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 160, total loss: 34.308510
# total_train_accuracy: tensor(0.8783, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 161, total loss: 34.459400
# total_train_accuracy: tensor(0.9013, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 162, total loss: 34.142820
# total_train_accuracy: tensor(0.8651, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 163, total loss: 34.694303
# total_train_accuracy: tensor(0.8618, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 164, total loss: 34.714588
# total_train_accuracy: tensor(0.8717, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 165, total loss: 34.371499
# total_train_accuracy: tensor(0.8684, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 166, total loss: 34.996770
# total_train_accuracy: tensor(0.8487, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 167, total loss: 34.933054
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 168, total loss: 34.292323
# total_train_accuracy: tensor(0.8618, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 169, total loss: 34.553991
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 170, total loss: 34.302891
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 171, total loss: 34.274672
# total_train_accuracy: tensor(0.8783, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 172, total loss: 34.578425
# total_train_accuracy: tensor(0.9046, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 173, total loss: 33.839628
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 174, total loss: 34.347268
# total_train_accuracy: tensor(0.8586, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 175, total loss: 34.586659
# total_train_accuracy: tensor(0.8717, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 176, total loss: 34.286878
# total_train_accuracy: tensor(0.8947, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 177, total loss: 34.333058
# total_train_accuracy: tensor(0.8684, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 178, total loss: 34.342140
# total_train_accuracy: tensor(0.8454, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 179, total loss: 34.843651
# total_train_accuracy: tensor(0.8717, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 180, total loss: 34.432603
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 181, total loss: 34.000373
# total_train_accuracy: tensor(0.8520, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 182, total loss: 34.448805
# total_train_accuracy: tensor(0.8717, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 183, total loss: 34.440918
# total_train_accuracy: tensor(0.8783, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 184, total loss: 34.281605
# total_train_accuracy: tensor(0.8816, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 185, total loss: 34.188256
# total_train_accuracy: tensor(0.9112, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 186, total loss: 33.851123
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 187, total loss: 34.184789
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 188, total loss: 34.217509
# total_train_accuracy: tensor(0.8783, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 189, total loss: 34.265405
# total_train_accuracy: tensor(0.9243, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 190, total loss: 33.580888
# total_train_accuracy: tensor(0.9178, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 191, total loss: 33.616377
# total_train_accuracy: tensor(0.8684, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 192, total loss: 33.994945
# total_train_accuracy: tensor(0.8947, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 193, total loss: 33.927472
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 194, total loss: 34.134583
# total_train_accuracy: tensor(0.9079, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 195, total loss: 33.901740
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 196, total loss: 34.009962
# total_train_accuracy: tensor(0.9178, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 197, total loss: 33.969721
# total_train_accuracy: tensor(0.8816, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 198, total loss: 34.211586
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 199, total loss: 33.965075
# total_train_accuracy: tensor(0.9079, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 200, total loss: 33.667095
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 201, total loss: 34.068650
# total_train_accuracy: tensor(0.8684, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 202, total loss: 34.235933
# total_train_accuracy: tensor(0.9046, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 203, total loss: 33.741187
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 204, total loss: 33.815094
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 205, total loss: 34.107931
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 206, total loss: 34.136499
# total_train_accuracy: tensor(0.8849, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 207, total loss: 34.173413
# total_train_accuracy: tensor(0.8717, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 208, total loss: 34.333214
# total_train_accuracy: tensor(0.9145, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 209, total loss: 33.579919
# total_train_accuracy: tensor(0.9243, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 210, total loss: 33.351439
# total_train_accuracy: tensor(0.8849, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 211, total loss: 34.117917
# total_train_accuracy: tensor(0.8980, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 212, total loss: 33.961774
# total_train_accuracy: tensor(0.9145, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 213, total loss: 33.662984
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 214, total loss: 33.692862
# total_train_accuracy: tensor(0.9013, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 215, total loss: 33.630366
# total_train_accuracy: tensor(0.8947, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 216, total loss: 33.700290
# total_train_accuracy: tensor(0.9013, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 217, total loss: 33.835588
# total_train_accuracy: tensor(0.9112, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 218, total loss: 33.528662
# total_train_accuracy: tensor(0.9079, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 219, total loss: 33.514089
# total_train_accuracy: tensor(0.9145, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 220, total loss: 33.667286
# total_train_accuracy: tensor(0.9046, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0156, device='cuda:0')
# Training Epoch: 221, total loss: 33.725392
# total_train_accuracy: tensor(0.8947, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 222, total loss: 33.720397
# total_train_accuracy: tensor(0.9145, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 223, total loss: 33.253003
# total_train_accuracy: tensor(0.9013, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1406, device='cuda:0')
# Training Epoch: 224, total loss: 33.952819
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 225, total loss: 33.882257
# total_train_accuracy: tensor(0.8947, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 226, total loss: 33.550240
# total_train_accuracy: tensor(0.9112, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 227, total loss: 33.898960
# total_train_accuracy: tensor(0.9046, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 228, total loss: 33.394071
# total_train_accuracy: tensor(0.9178, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 229, total loss: 33.200154
# total_train_accuracy: tensor(0.9408, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 230, total loss: 32.957106
# total_train_accuracy: tensor(0.9145, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 231, total loss: 33.752712
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 232, total loss: 34.014968
# total_train_accuracy: tensor(0.9211, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 233, total loss: 33.332832
# total_train_accuracy: tensor(0.9243, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 234, total loss: 33.256507
# total_train_accuracy: tensor(0.9178, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 235, total loss: 33.353436
# total_train_accuracy: tensor(0.9046, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 236, total loss: 33.552284
# total_train_accuracy: tensor(0.9112, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 237, total loss: 33.571402
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 238, total loss: 33.785892
# total_train_accuracy: tensor(0.8947, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 239, total loss: 33.572095
# total_train_accuracy: tensor(0.8980, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 240, total loss: 33.684819
# total_train_accuracy: tensor(0.9013, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 241, total loss: 33.580305
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 242, total loss: 33.656259
# total_train_accuracy: tensor(0.8914, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 243, total loss: 33.803777
# total_train_accuracy: tensor(0.9013, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 244, total loss: 33.637899
# total_train_accuracy: tensor(0.9178, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 245, total loss: 33.409438
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 246, total loss: 33.796302
# total_train_accuracy: tensor(0.9079, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 247, total loss: 33.339296
# total_train_accuracy: tensor(0.8980, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 248, total loss: 33.765315
# total_train_accuracy: tensor(0.9276, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 249, total loss: 33.296589
# total_train_accuracy: tensor(0.9211, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 250, total loss: 33.148124
# total_train_accuracy: tensor(0.8980, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 251, total loss: 33.333741
# total_train_accuracy: tensor(0.9211, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 252, total loss: 33.167747
# total_train_accuracy: tensor(0.8947, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 253, total loss: 33.723754
# total_train_accuracy: tensor(0.9243, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 254, total loss: 33.583792
# total_train_accuracy: tensor(0.9408, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 255, total loss: 33.149907
# total_train_accuracy: tensor(0.9211, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 256, total loss: 32.950593
# total_train_accuracy: tensor(0.8947, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 257, total loss: 33.648758
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 258, total loss: 32.975821
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 259, total loss: 33.975326
# total_train_accuracy: tensor(0.9243, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 260, total loss: 33.190339
# total_train_accuracy: tensor(0.9243, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 261, total loss: 32.885043
# total_train_accuracy: tensor(0.9046, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 262, total loss: 33.807218
# total_train_accuracy: tensor(0.9046, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 263, total loss: 33.540464
# total_train_accuracy: tensor(0.8849, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 264, total loss: 33.494028
# total_train_accuracy: tensor(0.9243, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 265, total loss: 33.177603
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 266, total loss: 32.937156
# total_train_accuracy: tensor(0.9112, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 267, total loss: 33.168926
# total_train_accuracy: tensor(0.9276, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 268, total loss: 32.834528
# total_train_accuracy: tensor(0.9211, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 269, total loss: 33.106801
# total_train_accuracy: tensor(0.9079, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 270, total loss: 33.316355
# total_train_accuracy: tensor(0.9145, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 271, total loss: 33.079641
# total_train_accuracy: tensor(0.9112, device='cuda:0')
# test
# test
# test
# test
# ...
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 906, total loss: 31.968890
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 907, total loss: 31.874045
# total_train_accuracy: tensor(0.9803, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 908, total loss: 31.384145
# total_train_accuracy: tensor(0.9605, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 909, total loss: 31.826310
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 910, total loss: 31.696115
# total_train_accuracy: tensor(0.9737, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 911, total loss: 31.671914
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 912, total loss: 31.937738
# total_train_accuracy: tensor(0.9474, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 913, total loss: 32.001428
# total_train_accuracy: tensor(0.9507, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 914, total loss: 32.031197
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 915, total loss: 31.739779
# total_train_accuracy: tensor(0.9671, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 916, total loss: 31.659036
# total_train_accuracy: tensor(0.9507, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 917, total loss: 32.001389
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 918, total loss: 32.339029
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 919, total loss: 31.991697
# total_train_accuracy: tensor(0.9342, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 920, total loss: 32.299484
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 921, total loss: 31.873232
# total_train_accuracy: tensor(0.9572, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 922, total loss: 31.921990
# total_train_accuracy: tensor(0.9605, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 923, total loss: 31.859440
# total_train_accuracy: tensor(0.9441, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 924, total loss: 32.263270
# total_train_accuracy: tensor(0.9605, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 925, total loss: 31.976099
# total_train_accuracy: tensor(0.9276, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 926, total loss: 32.310125
# total_train_accuracy: tensor(0.9572, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 927, total loss: 31.747455
# total_train_accuracy: tensor(0.9671, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 928, total loss: 31.867042
# total_train_accuracy: tensor(0.9507, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 929, total loss: 31.902345
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 930, total loss: 32.159335
# total_train_accuracy: tensor(0.9507, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 931, total loss: 32.082308
# total_train_accuracy: tensor(0.9770, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 932, total loss: 31.652064
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 933, total loss: 32.234470
# total_train_accuracy: tensor(0.9342, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 934, total loss: 32.221823
# total_train_accuracy: tensor(0.9211, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 935, total loss: 32.577950
# total_train_accuracy: tensor(0.9507, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 936, total loss: 32.048266
# total_train_accuracy: tensor(0.9408, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 937, total loss: 32.094673
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 938, total loss: 32.010231
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 939, total loss: 31.925863
# total_train_accuracy: tensor(0.9704, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 940, total loss: 31.650455
# total_train_accuracy: tensor(0.9605, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 941, total loss: 31.786020
# total_train_accuracy: tensor(0.9572, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 942, total loss: 32.026146
# total_train_accuracy: tensor(0.9342, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 943, total loss: 32.266283
# total_train_accuracy: tensor(0.9342, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 944, total loss: 32.257546
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 945, total loss: 31.962335
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 946, total loss: 32.191121
# total_train_accuracy: tensor(0.9572, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 947, total loss: 32.008038
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 948, total loss: 31.944047
# total_train_accuracy: tensor(0.9605, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 949, total loss: 31.818538
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 950, total loss: 31.744860
# total_train_accuracy: tensor(0.9704, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 951, total loss: 31.625057
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 952, total loss: 31.824906
# total_train_accuracy: tensor(0.9276, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 953, total loss: 32.383639
# total_train_accuracy: tensor(0.9309, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 954, total loss: 32.404757
# total_train_accuracy: tensor(0.9474, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 955, total loss: 32.112976
# total_train_accuracy: tensor(0.9671, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 956, total loss: 31.836674
# total_train_accuracy: tensor(0.9572, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 957, total loss: 31.896325
# total_train_accuracy: tensor(0.9737, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 958, total loss: 31.554282
# total_train_accuracy: tensor(0.9408, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 959, total loss: 32.186567
# total_train_accuracy: tensor(0.9243, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 960, total loss: 32.402231
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 961, total loss: 31.773320
# total_train_accuracy: tensor(0.9605, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 962, total loss: 31.935356
# total_train_accuracy: tensor(0.9342, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 963, total loss: 32.457914
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1094, device='cuda:0')
# Training Epoch: 964, total loss: 31.891750
# total_train_accuracy: tensor(0.9605, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 965, total loss: 31.961159
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 966, total loss: 31.707740
# total_train_accuracy: tensor(0.9770, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 967, total loss: 31.640734
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 968, total loss: 31.989462
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 969, total loss: 32.158319
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 970, total loss: 31.954349
# total_train_accuracy: tensor(0.9605, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 971, total loss: 31.851671
# total_train_accuracy: tensor(0.9342, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0156, device='cuda:0')
# Training Epoch: 972, total loss: 32.325884
# total_train_accuracy: tensor(0.9572, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 973, total loss: 32.029442
# total_train_accuracy: tensor(0.9507, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 974, total loss: 32.055208
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 975, total loss: 32.000188
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 976, total loss: 32.010220
# total_train_accuracy: tensor(0.9507, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 977, total loss: 31.898769
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 978, total loss: 31.796907
# total_train_accuracy: tensor(0.9342, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 979, total loss: 32.341200
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 980, total loss: 31.844485
# total_train_accuracy: tensor(0.9342, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 981, total loss: 32.365642
# total_train_accuracy: tensor(0.9638, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 982, total loss: 31.903603
# total_train_accuracy: tensor(0.9770, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 983, total loss: 31.505387
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 984, total loss: 32.072292
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 985, total loss: 31.879180
# total_train_accuracy: tensor(0.9704, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 986, total loss: 31.769043
# total_train_accuracy: tensor(0.9605, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 987, total loss: 32.089690
# total_train_accuracy: tensor(0.9671, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 988, total loss: 31.799359
# total_train_accuracy: tensor(0.9572, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0469, device='cuda:0')
# Training Epoch: 989, total loss: 31.902714
# total_train_accuracy: tensor(0.9474, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 990, total loss: 31.881495
# total_train_accuracy: tensor(0.9737, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 991, total loss: 31.618484
# total_train_accuracy: tensor(0.9605, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 992, total loss: 31.801036
# total_train_accuracy: tensor(0.9507, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 993, total loss: 32.091960
# total_train_accuracy: tensor(0.9671, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 994, total loss: 31.713083
# total_train_accuracy: tensor(0.9572, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 995, total loss: 31.912480
# total_train_accuracy: tensor(0.9671, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 996, total loss: 31.785918
# total_train_accuracy: tensor(0.9408, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 997, total loss: 32.153899
# total_train_accuracy: tensor(0.9441, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0781, device='cuda:0')
# Training Epoch: 998, total loss: 32.241976
# total_train_accuracy: tensor(0.9539, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 999, total loss: 31.757038
