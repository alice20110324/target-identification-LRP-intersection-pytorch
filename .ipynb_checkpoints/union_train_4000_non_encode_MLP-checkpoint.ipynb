# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':1000,
    'linear_hidden':100,#线性模型输出层（隐层个数）
    'embed_input_dim':1001,#embed输入维度
    'embed_dim': 100, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    #'dnn_hidden_units': [100,11],#MLP隐层和输出层
    
    'dnn_hidden_units':[100,9],#MLP隐层
    'num_sparse_features_cols':4224,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 16,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'epoch':1000,
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    #'train_file':'data/xiaoqiu_gene_5000/train/final_5000_encode_100x.csv',
    'train_data':'dataset/qiuguan/non_code/train/train_data.csv',
    'train_label':'dataset/qiuguan/non_code/train/train_label.csv',
    #'guan_test_data':'dataset/qiuguan/non_code/guan_test/guan_test_data.csv',
    #'guan_test_label':'dataset/qiuguan/non_code/guan_test/guan_test_label.csv',
    #'test_data':'dataset/qiuguan/non_code/test/test_datas.csv',
    'test_label':'dataset/qiuguan/non_code/test/test_labels.csv',
    'title':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_data.csv',
    #'train_data':'dataset/new_transfer/qiuguan/train/train_data.csv',
    #'train_label':'dataset/new_transfer/qiuguan/train/train_label.csv',
    # 'guan_test_data':'dataset/qiuguan/non_code/guan_test/guan_test_data.csv',
    #'guan_test_label':'dataset/qiuguan/non_code/guan_test/guan_test_label.csv',
    #'test_data':'dataset/new_transfer/qiuguan/test/test_data.csv',
    #'test_label':'dataset/new_transfer/qiuguan/test/test_label.csv'
    #'all':''
    #'title':'data/xiaoqiu_gene_5000/train/gene_5000_gene_name.csv',
    #'all':'data/xiaoqiu_gene_5000/train/gene_5000_label_name.csv'
}

# %%
#准备训练集

import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter

#import network
import config
import evaluate
import data_utils
import Trainer
#from utils import 
#准备训练集
#from new_dataset_processed import FMData
from dataset_process import FMData
def prepare_dataset(m_data,m_label,batch_size,n_class):
    m_dataset=FMData(m_data,m_label,n_class)
    m_dataloader=data.DataLoader(m_dataset, drop_last=True,batch_size=batch_size,shuffle=True,num_workers=4)
    
    return m_dataset,m_dataloader
# Out:
# [[190 220 490 ... 360 370 420]
#  [110 220 500 ... 340 260 420]
#  [100 300 500 ... 330 350 390]
#  ...
#  [450 360 500 ... 430 360 500]
#  [420 350 530 ... 440 370 500]
#  [420 360 540 ... 430 370 450]]

# %%
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics
def   train_data(model,train_loader,test_loader,batch_size,model_path):
    #train_accuracy=torchmetrics.Accuracy()
    #test_accuracy=torchmetrics.Accuracy()
    BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    total = 0
    
    #loss_func = torch.nn.BCELoss()
    loss_func=torch.nn.CrossEntropyLoss()
    #loss_func=nn.MultiLabelSoftMarginLoss()
    #loss_func=torch.nn.LogSoftmax()
    num=0
    #model=nn.Softmax(nn.Linear(10149,16)).to(device)
    # 从DataLoader中获取小批量的id以及数据
    
    batch_size=0
    for epoch_id in range(1000):
        correct=0
        total=0
        total_test_acc=0
        total_train_accuracy=0
        for batch_idx, (x, labels) in enumerate(train_loader):
            x = Variable(x)
            labels = Variable(labels)
            
            
            #x = torch.tensor(x, dtype=torch.float)
            #x=x.clone().detach().requires_grad_(True)
            x=torch.tensor(x,dtype=torch.float)
            labels=torch.tensor(labels,dtype=torch.float)
            x, labels = x.cuda(), labels.cuda()
            labels_int=labels=torch.max(labels,1)[1]
            #labels_int.cuda()
            #print("labels:",labels)
            
            optimizer.zero_grad()
            y_predict = model(x)
            #print("y_predict:",y_predict)
            #loss = loss_func(y_predict.view(-1), labels)
            loss = loss_func(y_predict, labels)
            loss.backward()
            optimizer.step()
            
            loss = loss.item()
            #loss, predicted = self._train_single_batch(x, labels)

            total += loss
            
            
            #predicted = torch.max(y_predict.data,1)
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
            #predicted=predicted.detach().cpu().numpy()
            
            #labels=torch.max(labels,1)
            #print("labels:",labels)
            #labels=labels[1]
            #y_predict=y_predict.cuda()
            #labels=torch.max(labels,1)[1].cuda()
            #labels=labels.detach().cpu().numpy()
            #correct += (predicted == labels).sum()
            #print("correct:",correct)
            #correct=correct[0]
            #print("new_correct:",float(correct))
            #correct=float(correct)   
            #if batch_idx % 10 == 0:
            #print("batch_idx:",batch_idx)
            #print(correct/(BATCH_SIZE*(batch_idx+1)))
            batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
            #print('batch_train_acc:',batch_train_acc)
            total_train_accuracy+=batch_train_acc
        #total_train_accuracy=torchmetrics.functional.compute_details()
        total_train_accuracy/=(batch_idx+1)
        print('total_train_accuracy:',total_train_accuracy)
        #print('total_train_accuracy:',total_train_accuracy)
        for i , (inputs , targets) in enumerate(test_loader):   
            print("test")
            # evaluate the model on the test set   
            #print(\ inputs:\  inputs)   
            #print(\ targets:\  targets)   
            inputs = Variable(inputs)   
            targets = Variable(targets)     
            #x = torch.tensor(x  dtype=torch.float)   
            #x=x.clone().detach().requires_grad_(True)   
            inputs=torch.tensor(inputs ,dtype=torch.float)   
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs , targets = inputs.cuda(),  targets.cuda()   
            yhat = model(inputs)  
            
            #yhat = torch.max(yhat.data,1)[1]
            #yhat=yhat.detach().cpu().numpy()
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
             #predicted = torch.max(y_predict.data,1)[1]
            
            
            targets=torch.max(targets,1)[1]
            #print("labels:",labels)
            #labels=labels[1]
            #targets=targets.detach().cpu().numpy()
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            #print("batch_test_acc:",batch_test_acc)
            total_test_acc+=batch_test_acc
            #total_test_accuracy=torchmetrics.functional.compute_details()
            batch_size=i
        print('total_test_accuracy:',total_test_acc/(batch_size+1))
        
                    
                    
            
            #model.evaluate()
            #model.eval()
            #train_result = evaluate.metrics(model, train_loader)
            #valid_result = evaluate.metrics(model, valid_loader)
            #est_result = evaluate.metrics(model, test_loader)
            #acturals,predictions,acc_test=evaluate_model(test_loader,model)
            #print("acc_test:  %d  " %(acc_test))
            #print("Train_RMSE: {:.3f}, Valid_RMSE: {:.3f}, Test_RMSE: {:.3f}".format(
            #train_result, valid_result, test_result))
            # print('[Training Epoch: {}] Batch: {}, Loss: {}'.format(epoch_id, batch_id, loss))
        print("Training Epoch: %d, total loss: %f" % (epoch_id, total))
        #print("auc:",roc_auc_score)
    #功能：保存训练完的网络的各层参数（即weights和bias)
    #path='dataset/xiaoguan/RF/RF_for_train/train_class_9/model/gene_4000_NFM.pkl'
        if epoch_id %100==0:
            num=num+1
            path=os.path.join(model_path,'MLP'+str(num)+'.pkl')
            torch.save(model.state_dict(),path)

# %%
train_dataset,train_loader=prepare_dataset(nfm_config['train_data'],nfm_config['train_label'],nfm_config['batch_size'],nfm_config['n_class'])
test_dataset,test_loader=prepare_dataset(nfm_config['test_data'],nfm_config['test_label'],nfm_config['batch_size'],nfm_config['n_class'])
from MLP1 import MLP
#from new_nfm_network import NFM
model=MLP(8904,1000,100,9)
#model=NFM(nfm_config)
model.cuda()
print("MLP1:",model)
train_data(model,train_loader,test_loader,nfm_config['batch_size'],'dataset/qiuguan/model/MLP_non_encode/')
# Out:
# FMData
# FMData
# MLP1: MLP(
#   (bn0): BatchNorm1d(8904, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=8904, out_features=1000, bias=True)
#   (bn1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=1000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 0, total loss: nan
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 1, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 2, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 3, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 4, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 5, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 6, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 7, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 8, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 9, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 10, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 11, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 12, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 13, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 14, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 15, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 16, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 17, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 18, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 19, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 20, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 21, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 22, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 23, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 24, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 25, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 26, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 27, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 28, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 29, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 30, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 31, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 32, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 33, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 34, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 35, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 36, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 37, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 38, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 39, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 40, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 41, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 42, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 43, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 44, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 45, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 46, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 47, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 48, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 49, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 50, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 51, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 52, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 53, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 54, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 55, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 56, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 57, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 58, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 59, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 60, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 61, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 62, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 63, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 64, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 65, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 66, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 67, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 68, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 69, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 70, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 71, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 72, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 73, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 74, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 75, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 76, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 77, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 78, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 79, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 80, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 81, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 82, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 83, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 84, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 85, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 86, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 87, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 88, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 89, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 90, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 91, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 92, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 93, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 94, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 95, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 96, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 97, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 98, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 99, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 100, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 101, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 102, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 103, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 104, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 105, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 106, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 107, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 108, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 109, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 110, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 111, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 112, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 113, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 114, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 115, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 116, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 117, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 118, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 119, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 120, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 121, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 122, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 123, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 124, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 125, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 126, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 127, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 128, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 129, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 130, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 131, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 132, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 133, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 134, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 135, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 136, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 137, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 138, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 139, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 140, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 141, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 142, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 143, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 144, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 145, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 146, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 147, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 148, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 149, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 150, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 151, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 152, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 153, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 154, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 155, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 156, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 157, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 158, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 159, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 160, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 161, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 162, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 163, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 164, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 165, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 166, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 167, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 168, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 169, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 170, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 171, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 172, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 173, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 174, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 175, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 176, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 177, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 178, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 179, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 180, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 181, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 182, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 183, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 184, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 185, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 186, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 187, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 188, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 189, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 190, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 191, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 192, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 193, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 194, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 195, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 196, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 197, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 198, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 199, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 200, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 201, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 202, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 203, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 204, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 205, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 206, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 207, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 208, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 209, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 210, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 211, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 212, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 213, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 214, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 215, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 216, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 217, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 218, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 219, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 220, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 221, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 222, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 223, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 224, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 225, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 226, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 227, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 228, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 229, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 230, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 231, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 232, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 233, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 234, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 235, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 236, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 237, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 238, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 239, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 240, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 241, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 242, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 243, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 244, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 245, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 246, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 247, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 248, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 249, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 250, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 251, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 252, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 253, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 254, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 255, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 256, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 257, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 258, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 259, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 260, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 261, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 262, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 263, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 264, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 265, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 266, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 267, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 268, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 269, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 270, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 271, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 272, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 273, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 274, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 275, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 276, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 277, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 278, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 279, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 280, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 281, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 282, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 283, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 284, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 285, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 286, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 287, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 288, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 289, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 290, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 291, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 292, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 293, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 294, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 295, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 296, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 297, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0312, device='cuda:0')
# Training Epoch: 298, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 299, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 300, total loss: nan
# ...
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 515, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 516, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 517, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 518, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 519, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 520, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 521, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 522, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 523, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 524, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 525, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 526, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 527, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 528, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 529, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 530, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 531, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 532, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 533, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 534, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 535, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 536, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 537, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 538, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 539, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 540, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 541, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 542, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 543, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 544, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 545, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 546, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 547, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 548, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 549, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 550, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 551, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 552, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 553, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 554, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 555, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 556, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 557, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 558, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 559, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 560, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 561, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 562, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 563, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 564, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 565, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 566, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 567, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 568, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 569, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 570, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0625, device='cuda:0')
# Training Epoch: 571, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 572, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 573, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 574, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 575, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 576, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 577, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 578, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 579, total loss: nan
# total_train_accuracy: tensor(0.0594, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 580, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 581, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 582, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 583, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 584, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 585, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 586, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 587, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.0938, device='cuda:0')
# Training Epoch: 588, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1250, device='cuda:0')
# Training Epoch: 589, total loss: nan
# total_train_accuracy: tensor(0.0609, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.1562, device='cuda:0')
# Training Epoch: 590, total loss: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e8934b1dd26c> in <module>
#       7 model.cuda()
#       8 print("MLP1:",model)
# ----> 9 train_data(model,train_loader,test_loader,nfm_config['batch_size'],'dataset/qiuguan/model/MLP_non_encode/')
#
# <ipython-input-3-33bbfac7d3d0> in train_data(model, train_loader, test_loader, batch_size, model_path)
#      44         total_test_acc=0
#      45         total_train_accuracy=0
# ---> 46         for batch_idx, (x, labels) in enumerate(train_loader):
#      47             x = Variable(x)
#      48             labels = Variable(labels)
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1184
#    1185             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186             idx, data = self._get_data()
#    1187             self._tasks_outstanding -= 1
#    1188             if self._dataset_kind == _DatasetKind.Iterable:
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1150         else:
#    1151             while True:
# -> 1152                 success, data = self._try_get_data()
#    1153                 if success:
#    1154                     return data
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     988         #   (bool: whether successfully get data, any: data if successful else None)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#     992         except Exception as e:
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/multiprocessing/queues.py in get(self, block, timeout)
#     111                 self._rlock.release()
#     112         # unserialize the data after having released the lock
# --> 113         return _ForkingPickler.loads(res)
#     114
#     115     def qsize(self):
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/torch/multiprocessing/reductions.py in rebuild_storage_fd(cls, df, size)
#     287
#     288 def rebuild_storage_fd(cls, df, size):
# --> 289     fd = df.detach()
#     290     try:
#     291         storage = storage_from_cache(cls, fd_id(fd))
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/multiprocessing/resource_sharer.py in detach(self)
#      55         def detach(self):
#      56             '''Get the fd.  This should only be called once.'''
# ---> 57             with _resource_sharer.get_connection(self._id) as conn:
#      58                 return reduction.recv_handle(conn)
#      59
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/multiprocessing/resource_sharer.py in get_connection(ident)
#      86         address, key = ident
#      87         c = Client(address, authkey=process.current_process().authkey)
# ---> 88         c.send((key, os.getpid()))
#      89         return c
#      90
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/multiprocessing/connection.py in send(self, obj)
#     204         self._check_closed()
#     205         self._check_writable()
# --> 206         self._send_bytes(_ForkingPickler.dumps(obj))
#     207
#     208     def recv_bytes(self, maxlength=None):
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/multiprocessing/connection.py in _send_bytes(self, buf)
#     402             # Also note we want to avoid sending a 0-length buffer separately,
#     403             # to avoid "broken pipe" errors if the other end closed the pipe.
# --> 404             self._send(header + buf)
#     405
#     406     def _recv_bytes(self, maxsize=None):
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/multiprocessing/connection.py in _send(self, buf, write)
#     366         remaining = len(buf)
#     367         while True:
# --> 368             n = write(self._handle, buf)
#     369             remaining -= n
#     370             if remaining == 0:
#
# KeyboardInterrupt:

# %%
##测试集
#from new_nfm_network import NFM
#加载模型
from MLP import MLP
model=MLP(10477,1000,100,9)
#model.cuda()
path='dataset/qiuguan/model/MLP_non_encode/MLP11.pkl'
#nfm = NFM(nfm_config).cuda()
net=model.cuda()
#net=nfm
print(net)
#net = nn.DataParallel(net)
#net = net.to(device)
net.load_state_dict(torch.load(path),strict=False)
net.cuda()

optimizer = torch.optim.Adam(net.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
total = 0
#loss_func = torch.nn.BCELoss()
loss_func=torch.nn.CrossEntropyLoss()
# Out:
# MLP(
#   (fc1): Linear(in_features=10477, out_features=1000, bias=True)
#   (bn1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=1000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )

# %%
train_dataset,train_loader=prepare_dataset(nfm_config['train_data'],nfm_config['train_label'],nfm_config['batch_size'],nfm_config['n_class'])
test_dataset,test_loader=prepare_dataset(nfm_config['test_data'],nfm_config['test_label'],nfm_config['batch_size'],nfm_config['n_class'])
#from MLP import MLP
#from new_nfm_network import NFM
#model=MLP(10477,1000,100,9)
#model=NFM(nfm_config)
#model.cuda()
#print("MLP:",model)
train_data(net,train_loader,test_loader,nfm_config['batch_size'],'dataset/qiuguan/model/MLP_non_encode/')
# Out:
# FMData
# FMData
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# test
# test
# total_test_accuracy: tensor(0.7188, device='cuda:0')
# Training Epoch: 0, total loss: 67.490138
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:106: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 1, total loss: 66.274198
# test
# test
# total_test_accuracy: tensor(0.7812, device='cuda:0')
# Training Epoch: 2, total loss: 66.526301
# test
# test
# total_test_accuracy: tensor(0.8438, device='cuda:0')
# Training Epoch: 3, total loss: 67.059903
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 4, total loss: 67.339256
# test
# test
# total_test_accuracy: tensor(0.7812, device='cuda:0')
# Training Epoch: 5, total loss: 67.632156
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 6, total loss: 67.120770
# test
# test
# total_test_accuracy: tensor(0.7812, device='cuda:0')
# Training Epoch: 7, total loss: 68.283451
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 8, total loss: 67.675528
# test
# test
# total_test_accuracy: tensor(0.8438, device='cuda:0')
# Training Epoch: 9, total loss: 68.084343
# test
# test
# total_test_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 10, total loss: 67.330729
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 11, total loss: 67.590849
# test
# test
# total_test_accuracy: tensor(0.7812, device='cuda:0')
# Training Epoch: 12, total loss: 66.867933
# test
# test
# total_test_accuracy: tensor(0.7188, device='cuda:0')
# Training Epoch: 13, total loss: 69.412908
# test
# test
# total_test_accuracy: tensor(0.8438, device='cuda:0')
# Training Epoch: 14, total loss: 69.406021
# test
# test
# total_test_accuracy: tensor(0.7500, device='cuda:0')
# Training Epoch: 15, total loss: 68.460744
# test
# test
# total_test_accuracy: tensor(0.8438, device='cuda:0')
# Training Epoch: 16, total loss: 68.713422
# test
# test
# total_test_accuracy: tensor(0.7812, device='cuda:0')
# Training Epoch: 17, total loss: 68.155463
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 18, total loss: 68.111383
# test
# test
# total_test_accuracy: tensor(0.7812, device='cuda:0')
# Training Epoch: 19, total loss: 67.757988
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 20, total loss: 68.512943
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 21, total loss: 68.488360
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 22, total loss: 67.729794
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 23, total loss: 67.490696
# test
# test
# total_test_accuracy: tensor(0.6875, device='cuda:0')
# Training Epoch: 24, total loss: 68.150457
# test
# test
# total_test_accuracy: tensor(0.7500, device='cuda:0')
# Training Epoch: 25, total loss: 67.159769
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 26, total loss: 67.595575
# test
# test
# total_test_accuracy: tensor(0.7188, device='cuda:0')
# Training Epoch: 27, total loss: 67.719932
# test
# test
# total_test_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 28, total loss: 68.294475
# test
# test
# total_test_accuracy: tensor(0.8438, device='cuda:0')
# Training Epoch: 29, total loss: 68.958349
# test
# test
# total_test_accuracy: tensor(0.7812, device='cuda:0')
# Training Epoch: 30, total loss: 68.397987
# test
# test
# total_test_accuracy: tensor(0.7188, device='cuda:0')
# Training Epoch: 31, total loss: 68.553979
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 32, total loss: 68.373916
# test
# test
# total_test_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch:
# total_train_accuracy: tensor(0.9766, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 963, total loss: 56.349368
# total_train_accuracy: tensor(0.9641, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 964, total loss: 56.979112
# total_train_accuracy: tensor(0.9922, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 965, total loss: 55.725218
# total_train_accuracy: tensor(0.9734, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 966, total loss: 56.249928
# total_train_accuracy: tensor(0.9766, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 967, total loss: 56.305813
# total_train_accuracy: tensor(0.9766, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 968, total loss: 56.308202
# total_train_accuracy: tensor(0.9641, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 969, total loss: 56.720373
# total_train_accuracy: tensor(0.9766, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 970, total loss: 56.224346
# total_train_accuracy: tensor(0.9766, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 971, total loss: 56.374617
# total_train_accuracy: tensor(0.9703, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 972, total loss: 56.590591
# total_train_accuracy: tensor(0.9719, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 973, total loss: 56.453881
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 974, total loss: 56.493674
# total_train_accuracy: tensor(0.9828, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 975, total loss: 56.063935
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 976, total loss: 56.527608
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9062, device='cuda:0')
# Training Epoch: 977, total loss: 56.506196
# total_train_accuracy: tensor(0.9656, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 978, total loss: 56.630692
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 979, total loss: 56.455998
# total_train_accuracy: tensor(0.9797, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 980, total loss: 56.230777
# total_train_accuracy: tensor(0.9703, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 981, total loss: 56.410393
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 982, total loss: 56.779501
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 983, total loss: 56.410500
# total_train_accuracy: tensor(0.9828, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 984, total loss: 56.144659
# total_train_accuracy: tensor(0.9766, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 985, total loss: 56.161923
# total_train_accuracy: tensor(0.9781, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 986, total loss: 56.241165
# total_train_accuracy: tensor(0.9719, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 987, total loss: 56.287408
# total_train_accuracy: tensor(0.9734, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 988, total loss: 56.288880
# total_train_accuracy: tensor(0.9781, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 989, total loss: 56.182501
# total_train_accuracy: tensor(0.9766, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 990, total loss: 56.166801
# total_train_accuracy: tensor(0.9812, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 991, total loss: 56.087666
# total_train_accuracy: tensor(0.9859, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 992, total loss: 56.047644
# total_train_accuracy: tensor(0.9703, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 993, total loss: 56.317502
# total_train_accuracy: tensor(0.9656, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 994, total loss: 56.625771
# total_train_accuracy: tensor(0.9734, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 995, total loss: 56.312184
# total_train_accuracy: tensor(0.9781, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 996, total loss: 56.344034
# total_train_accuracy: tensor(0.9812, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 997, total loss: 56.029960
# total_train_accuracy: tensor(0.9781, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 998, total loss: 56.060200
# total_train_accuracy: tensor(0.9766, device='cuda:0')
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# Training Epoch: 999, total loss: 56.298222

# %%
train_dataset,train_loader=prepare_dataset(nfm_config['train_data'],nfm_config['train_label'],nfm_config['batch_size'],nfm_config['n_class'])
test_dataset,test_loader=prepare_dataset(nfm_config['guan_test_data'],nfm_config['guan_test_label'],nfm_config['batch_size'],nfm_config['n_class'])
from MLP1 import MLP
#from new_nfm_network import NFM
model=MLP(10477,1000,100,9)
#model=NFM(nfm_config)
model.cuda()
print("MLP1:",model)
train_data(model,train_loader,test_loader,nfm_config['batch_size'],'dataset/qiuguan/model/MLP_non_encode_guan_test/')
# Out:
# FMData
# FMData
# MLP1: MLP(
#   (bn0): BatchNorm1d(10477, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=10477, out_features=1000, bias=True)
#   (bn1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=1000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.1297, device='cuda:0')
# test
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-32dc7b90e9e4> in <module>
#       7 model.cuda()
#       8 print("MLP1:",model)
# ----> 9 train_data(model,train_loader,test_loader,nfm_config['batch_size'],'dataset/qiuguan/model/MLP_non_encode_guan_test/')
#
# <ipython-input-8-8648f8a97dcd> in train_data(model, train_loader, test_loader, batch_size, model_path)
#     110             targets=torch.tensor(targets ,dtype=torch.float)
#     111             inputs , targets = inputs.cuda(),  targets.cuda()
# --> 112             yhat = model(inputs)
#     113
#     114             #yhat = torch.max(yhat.data,1)[1]
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/NFM-pyorch-master/NFM-pyorch-master/MLP1.py in forward(self, x)
#      39     def forward(self, x):
#      40         #print("inputs.lenth:",inputs)
# ---> 41         x=self.bn0(x)
#      42         x = F.relu(self.drop(self.bn1(self.fc1(x))))
#      43         x = F.relu(self.drop(self.bn2(self.fc2(x))))
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#     177             bn_training,
#     178             exponential_average_factor,
# --> 179             self.eps,
#     180         )
#     181
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2281
#    2282     return torch.batch_norm(
# -> 2283         input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2284     )
#    2285
#
# RuntimeError: running_mean should contain 10578 elements not 10477
