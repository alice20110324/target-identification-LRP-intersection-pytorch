# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':2000,
    #'linear_hidden':100,#线性模型输出层（隐层个数）
    #'embed_input_dim':1001,#embed输入维度
    #'embed_dim': 100, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    #'dnn_hidden_units': [100,11],#MLP隐层和输出层
    
    'dnn_hidden_units':[100,9],#MLP隐层
    'num_sparse_features_cols':10477,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 16,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'epoch':1000,
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    #'train_file':'data/xiaoqiu_gene_5000/train/final_5000_encode_100x.csv',
    #'train_data':'dataset/qiuguan/encode/encode_1000/train/train_encode_data_1000_new.csv',
    #'train_label':'dataset/qiuguan/non_code/train/train_label.csv',
    #'guan_test_data':'dataset/qiuguan/non_code/guan_test/guan_test_data.csv',
    #'guan_test_label':'dataset/qiuguan/non_code/guan_test/guan_test_label.csv',
    #'test_data':'dataset/qiuguan/encode/encode_1000/test/test_encode_data_1000_new.csv',
    #'test_label':'dataset/qiuguan/non_code/test/test_labels.csv',
    #'title':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_data.csv',
    
    #'all':''
    #'title':'data/xiaoqiu_gene_5000/train/gene_5000_gene_name.csv',
    #'all':'data/xiaoqiu_gene_5000/train/gene_5000_label_name.csv'
}

#model definition
import torch.nn as nn
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(3300)
        self.fc1 = nn.Linear(3300, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model = MLP().cuda()
print(model)

class MLP1(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(237)
        self.fc1 = nn.Linear(237, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model1 = MLP1().cuda()
print(model1)
class MLP2(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(90)
        self.fc1 = nn.Linear(90, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model2 = MLP2().cuda()
print(model2)


class MLP3(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(99)
        self.fc1 = nn.Linear(99, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model3 = MLP3().cuda()
print(model3)
class MLP4(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(81)
        self.fc1 = nn.Linear(81, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model4 = MLP4().cuda()
print(model4)

class MLP5(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(69)
        self.fc1 = nn.Linear(69, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model5 = MLP5().cuda()
print(model5)

class MLP6(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(119)
        self.fc1 = nn.Linear(119, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model6 = MLP6().cuda()
print(model6)

class MLP7(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(86)
        self.fc1 = nn.Linear(86, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model7 = MLP7().cuda()
print(model7)

class MLP8(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(9)
        self.fc1 = nn.Linear(9, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model8 = MLP8().cuda()
print(model8)

class MLP9(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(101)
        self.fc1 = nn.Linear(101, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model9 = MLP9().cuda()
print(model9)


class MLP10(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(74)
        self.fc1 = nn.Linear(74, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model10 = MLP10().cuda()
print(model10)


class MLP11(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(78)
        self.fc1 = nn.Linear(78, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model11 = MLP11().cuda()
print(model11)

class MLP12(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(101)
        self.fc1 = nn.Linear(101, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model12 = MLP12().cuda()
print(model12)

class MLP13(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(70)
        self.fc1 = nn.Linear(70, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model13 = MLP13().cuda()
print(model13)

class MLP14(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(118)
        self.fc1 = nn.Linear(118, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model14 = MLP14().cuda()
print(model14)
class MLP15(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(124)
        self.fc1 = nn.Linear(124, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model15 = MLP15().cuda()
print(model15)
class MLP16(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(138)
        self.fc1 = nn.Linear(138, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model16 = MLP16().cuda()
print(model16)
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import torch.nn.functional as F  # 激励函数的库
#import network
import config
import evaluate
import data_utils
#import Trainer



def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    #n = len(labels)
    n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output

def one_hot(labels, classes):
    n = len(labels)
    #eoff = label_smoothing / classes
    output = np.zeros((n, classes), dtype=np.float32)
    for row, label in enumerate(labels):
        output[row, label] = 1
        #print("row:",row,"label:",label)
    return output


def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    #n = len(labels)
    n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output

def one_hot(labels, classes):
    n = len(labels)
    #eoff = label_smoothing / classes
    output = np.zeros((n, classes), dtype=np.float32)
    for row, label in enumerate(labels):
        output[row, label] = 1
        #print("row:",row,"label:",label)
    return output



class KZDatasetPredict(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, df_list):
    
       
        self.data_info = self.get_data_info(df_list)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data,label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data,label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,df_list):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        print('data_info:',df_list[-1])
        #df=pd.read_csv(csv_path,sep=',')
        #df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        label=int(df_list[-1])
        labels.append(label)
        print('labels:',labels)
        data=df_list[:-1]
        #df_np=np.array(df_list)
        #print(rows,cols)
        
        #print('labels:',labels)
        labels=np.array(labels)
        print('labels.shape:',labels.shape)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        
           
        
        data=np.array(data)#
            
            
            
            
            
            
            
            
        data=torch.from_numpy(data)#
            
        labels=torch.from_numpy(labels)#
        #bi_data=embding_process(nfm_config,data)
        #print("bi_data.shape:",bi_data.shape)
            
            
        data_info.append((data,label))
        return data_info
class KZDatasetTest(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, csv_path):
    
       
        self.data_info = self.get_data_info(csv_path)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]
            data=data.astype(float)#
            data=np.array(data)#
            
            label=labels[i]
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            label=torch.from_numpy(label)#
            
            
            data_info.append((data,label))
        return data_info
import torch
import torch.nn as nn
from torch.utils.data.dataset import *
from PIL import Image
from torch.nn import functional as F
import random
from sklearn.model_selection import train_test_split
import ast
import torchvision


        

class KZDataset(Dataset):
    def __init__(self, csv_path, K,n_class,ki=0, typ='train', transform=None, rand=False):
       
        self.all_data_info = self.get_data_info(csv_path)
        
        if rand:
            random.seed(1)
            random.shuffle(self.all_data_info)
        leng = len(self.all_data_info)
        every_z_len = leng // K
        if typ == 'val':
            self.data_info = self.all_data_info[every_z_len * ki : every_z_len * (ki+1)]
        elif typ == 'train':
            self.data_info = self.all_data_info[: every_z_len * ki] + self.all_data_info[every_z_len * (ki+1) :]
            
        self.transform = transform
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, label

    def __len__(self):
        return len(self.data_info)
    
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        
        print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]
            data=data.astype(float)#
            data=np.array(data)#
            
            label=labels[i]
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            label=torch.from_numpy(label)#
            
            
            data_info.append((data,label))
        return data_info
            
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics

from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics


def train_epoch(model,train_loader,batch_size,optimizer,loss_func):
    BATCH_SIZE=batch_size
    total = 0
    correct=0
    total_loss=0
    #
    model.train()
    total_train_accuracy=0  
    for batch_idx, (x, labels) in enumerate(train_loader):
            
        labels = Variable(labels)
        x = Variable(x)
            
            
        x=torch.tensor(x,dtype=torch.float)
        labels=torch.tensor(labels,dtype=torch.float)
        x, labels = x.cuda(), labels.cuda()
        labels_int=labels=torch.max(labels,1)[1]
            
            
        optimizer.zero_grad()
        y_predict = model(x)
            
        loss = loss_func(y_predict, labels)
        loss.backward()
        optimizer.step()
            
        loss = loss.item()
           

        total_loss += loss
            
            
            
        batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
        total_train_accuracy+=batch_train_acc
            
    total_train_accuracy/=(batch_idx+1)
    print('total_train_accuracy:',total_train_accuracy)
    print("Training Epoch: %d, total loss: %f" % (epoch_id, total_loss))
    return total_loss,total_train_accuracy

def val_epoch(model,test_loader,batch_size,optimizer): 
    batch_size_num=0
    total_test_acc=0
    model.eval()
    for i , (inputs , targets) in enumerate(test_loader):   
            print("test")
            
            inputs = Variable(inputs)   
            targets = Variable(targets)     
           
            inputs=torch.tensor(inputs ,dtype=torch.float)   
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs , targets = inputs.cuda(),  targets.cuda()   
            yhat = model(inputs)  
            
            
            
            targets=torch.max(targets,1)[1]
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            
            total_test_acc+=batch_test_acc
            
            batch_size_num=i
    total_test_acc/=(batch_size_num+1)
        ###print('total_test_accuracy:',total_test_acc/(batch_size+1))
    print('total_test_accuracy:',total_test_acc)
        
                    
                    
            
            
    
        
   
    
    return total_test_acc


import numpy as np
import math
import matplotlib.pyplot as plt

def plotLoss(loss,epoch):
    plt.rcParams['font.sans-serif']=['SimHei']
    plt.rcParams['axes.unicode_minus'] = False
    plt.figure(figsize=(8, 5))
    x=[i for i in range(epoch)]
    #acc_train=acc_train.cpu()
    #acc_test=acc_test.cpu()
    plt.plot(x, loss, 'r-', mec='k', label='Logistic Loss', lw=2)
    #plt.plot(x,acc_train,'b-',mec='k',label='accuracy Train',lw=2)
    #plt.plot(x,acc_test,'g-',mec='k',label='accuracy Test',lw=2)
    #plt.plot(x, y_01, 'g-', mec='k', label='0/1 Loss', lw=2)
    #plt.plot(x, y_hinge, 'b-',mec='k', label='Hinge Loss', lw=2)
    #plt.plot(x, boost, 'm--',mec='k', label='Adaboost Loss',lw=2)
    plt.grid(True, ls='--')
    plt.legend(loc='upper right')
    plt.title('损失函数')
    plt.show()
# Out:
# MLP(
#   (bn0): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=3300, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP1(
#   (bn0): BatchNorm1d(237, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=237, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP2(
#   (bn0): BatchNorm1d(90, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=90, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP3(
#   (bn0): BatchNorm1d(99, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=99, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP4(
#   (bn0): BatchNorm1d(81, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=81, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP5(
#   (bn0): BatchNorm1d(69, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=69, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP6(
#   (bn0): BatchNorm1d(119, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=119, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP7(
#   (bn0): BatchNorm1d(86, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=86, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP8(
#   (bn0): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=9, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP9(
#   (bn0): BatchNorm1d(101, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=101, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP10(
#   (bn0): BatchNorm1d(74, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=74, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP11(
#   (bn0): BatchNorm1d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=78, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP12(
#   (bn0): BatchNorm1d(101, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=101, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP13(
#   (bn0): BatchNorm1d(70, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=70, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP14(
#   (bn0): BatchNorm1d(118, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=118, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP15(
#   (bn0): BatchNorm1d(124, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=124, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP16(
#   (bn0): BatchNorm1d(138, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=138, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )

# %%
#for 20_genes
import pandas as pd 
import numpy as np
mlp_20_path='results_genes/ConvAttMLP/contri_30_names_df.csv'
nfm_layer_20_path='results_genes/NFM_layer_2/contri_30_names_df.csv'


mlp_20_df=pd.read_csv(mlp_20_path,sep=',')
nfm_layer_20_df=pd.read_csv(nfm_layer_20_path,sep=',')

#print(mlp_20_df)
mlp_20_df=mlp_20_df.iloc[:,1:]
nfm_layer_20_df=nfm_layer_20_df.iloc[:,1:]
#print(mlp_20_df.shape)
mlp_20_np=np.array(mlp_20_df)
nfm_layer_20_np=np.array(nfm_layer_20_df)

#print(mlp_20_np)


import csv
csv_filename = "results_genes/intersections/ConvAttMLP_NFM_intersecions_30_df.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    #writer.writerow(result_list)

    #intersections_20_list=[]
    for i in range(9):
        mlp_data=mlp_20_np[i,:].tolist()
        nfm_data=nfm_layer_20_np[i,:].tolist()
    
        # 将列表转换为集合
        mlp_set = set(mlp_data)
        nfm_set = set(nfm_data)

        # 求交集
        intersection = mlp_set.intersection(nfm_set)

        # 将交集转换回列表
        intersection_list = list(intersection)
        print('intersecion_list:',intersection_list)
        writer.writerow(intersection_list)
        #intersections_20_list.append(intersection_list)
#print('len:',len(intersections_20_list))    
file.close()    
#intersections_20_np=np.array(intersections_20_list)  
#intersections_20_df=pd.DataFrame(intersections_20_np)
#intersections_20_df.to_csv('results_genes/intersections/intersecions_20_df.csv')
# Out:
# intersecion_list: ['CYP39A1', 'GDF15', 'PTP4A1', 'ADPRM', 'ZNRF4', 'KLF6', 'IFI6', 'AHCYL1', 'EEF1AKMT3', 'DUSP6', 'TMEM100', 'LYPLA1', 'CHCHD3', 'ABCB7', 'ZNF195', 'IFI44L', 'NR0B2', 'PCK1', 'RHOB', 'CEBPB', 'MT2A', 'NUDT4']
# intersecion_list: ['CYP2J2', 'LGMN', 'ATP6V0E2', 'IFI6', 'VAMP8', 'NDUFA13', 'MS4A4A', 'TUBB2B', 'TMEM100', 'FCGBP', 'CTSG', 'RGS5', 'RPS27L', 'CHODL', 'TESC', 'LHPP', 'ZNHIT1', 'AGL', 'CPVL', 'CHP1', 'TYR', 'UQCR10']
# intersecion_list: ['TFAP2A', 'EPM2AIP1', 'NEAT1', 'CFLAR', 'TRA2A', 'VTCN1', 'TUBA4B', 'METTL9', 'MEST', 'FOS', 'CTTN', 'VDR', 'NR1D2', 'ISCU', 'ACTA2', 'NDUFA13', 'ACP6', 'ACVR1B', 'COX15']
# intersecion_list: ['ABCB4', 'RHOB', 'UQCR10', 'TESC', 'MNX1', 'ZNF593', 'TRIM14', 'KLF6', 'IFI6', 'ELF3', 'TYMP', 'VAMP8', 'BHLHE40', 'SLC3A2', 'FST', 'KLF9', 'COX8A', 'ATP6V1F']
# intersecion_list: ['TMEM100', 'NONO', 'PEG10', 'LYPLA1', 'FCGBP', 'WDR12', 'RPL38', 'AFP', 'RHBDL1', 'NUDT4', 'ECH1', 'ITGB3BP', 'VAMP8', 'LARP1', 'CPVL', 'WASHC3', 'COX15', 'FKBP4']
# intersecion_list: ['RRM2', 'LIPC', 'LGMN', 'CHCHD3', 'PTMS', 'MRPL44', 'UBXN8', 'LHX1', 'HP', 'PAFAH1B3', 'ATP5IF1', 'COL4A3BP', 'IFI6', 'OVOL2', 'MRPS16', 'ITGB3BP', 'DEPTOR', 'IFIT1', 'ADM2', 'EPM2AIP1']
# intersecion_list: ['ABHD2', 'RPA3', 'PTP4A1', 'PLIN3', 'LLGL2', 'NDUFB1', 'ABCB7', 'WASHC4', 'RGN', 'SERPINF1', 'ABCD3', 'HKDC1', 'OSBPL1A', 'BDKRB2', 'ABLIM1', 'ZNHIT1', 'UCHL1', 'NUDT4', 'COL4A3BP', 'ACAD10', 'SPI1', 'ADI1', 'OXCT1', 'PLEKHA5', 'CAMLG']
# intersecion_list: ['PDK3', 'IFI6', 'ANKRD2', 'BCCIP', 'TTC1', 'SH3BP2', 'UGDH', 'OLFML3', 'CGREF1', 'GPX3', 'KLF9', 'CD163', 'IGLV2-14', 'ABCC3', 'GPX2', 'IFI44L', 'ALB', 'LHPP', 'ATP6V1F', 'CFB', 'MT2A', 'PPP6R1']
# intersecion_list: ['ZNF195', 'TFAM', 'LGMN', 'IFI44L', 'ABLIM1', 'ALB', 'COX5B', 'OLFML3', 'DEPTOR', 'TRIM14', 'IFI6', 'MRPS16', 'VAMP8', 'IFIT1', 'GPX3', 'NDUFA13', 'MS4A4A', 'HERC5', 'MAP3K1']

# %%
#compute unions for  the intersections_20_df of every class 
#intersections_20_df=pd.read_csv('results_genes/intersections/intersecions_20_df.csv',sep=',')
#from chartGPT of the following code
#intersections_20_df=intersections_20_df.iloc[:,1:]
#print(intersections_20_df)
#intersections_20_np=np.array(intersections_20_df)


result = set()
import csv
csv_filename = "results_genes/intersections/ConvAttMLP_NFM_intersecions_30_df.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='r', newline='') as csvfile:
    csv_reader = csv.reader(csvfile)
    # 逐行读取数据
    for row in csv_reader:
        row_set=set(row)
        result=result.union(row_set)
        
        

# 或者使用集合的union方法的更简洁写法，使用集合解析
# result = set().union(*list_of_lists)

# 或者使用 | 运算符
# result = set().union(*list_of_lists)

# 将结果转回列表
result_list = list(result)

print(len(result_list))

import csv
csv_filename = "results_genes/intersections/ConvAttMLP_NFM_genes_intersections_30.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    writer.writerow(result_list)

#这将输出所有列表的并集，不包含重复的元素。在这个例子中，结果会是 [1, 2, 3, 4, 5, 6, 7]。你可以根据你的实际需求将这个结果转换为列表或者保留为集合，具体取决于你的应用场景。
#抽取训练集和测试集中的数据

#生成新选取元素的数据集
train_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/train_val_info.csv'
test_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info.csv'

train_df=pd.read_csv(train_path,sep=',')


train_df=train_df.iloc[:,1:]


columns=result_list
columns.append('label')
print('columns:',columns)


train_df2=train_df[columns]
print(train_df2.shape)
train_df2.to_csv('results_genes/intersections/dataset/30_ConvAttMLP_NFM_train_val_info.csv')


test_df=pd.read_csv(test_path,sep=',')

test_df=test_df.iloc[:,1:]



test_df=test_df[columns]
print(test_df.shape)
test_df.to_csv('results_genes/intersections/dataset/30_ConvAttMLP_NFM_test_info.csv')
# Out:
# 138
# columns: ['RPA3', 'NONO', 'ADPRM', 'LGMN', 'ATP5IF1', 'KLF6', 'TRIM14', 'ANKRD2', 'IFIT1', 'TMEM100', 'RRM2', 'LYPLA1', 'ABCB7', 'MRPS16', 'VDR', 'GPX3', 'ISCU', 'RGS5', 'RPS27L', 'COX15', 'IGLV2-14', 'ABCD3', 'IFI44L', 'OSBPL1A', 'OVOL2', 'LHPP', 'NR0B2', 'CFB', 'MAP3K1', 'ABLIM1', 'UCHL1', 'ECH1', 'SPI1', 'TYMP', 'CPVL', 'TYR', 'ABCB4', 'CFLAR', 'MRPL44', 'IFI6', 'BCCIP', 'ELF3', 'PLIN3', 'LLGL2', 'DUSP6', 'ACVR1B', 'NDUFB1', 'FCGBP', 'RPL38', 'CTSG', 'CHODL', 'HKDC1', 'GPX2', 'TESC', 'LARP1', 'ACTA2', 'CEBPB', 'ZNHIT1', 'VTCN1', 'NUDT4', 'COL4A3BP', 'MEST', 'CTTN', 'ADM2', 'PPP6R1', 'PLEKHA5', 'NR1D2', 'CAMLG', 'ABHD2', 'CYP2J2', 'GDF15', 'ATP6V0E2', 'PDK3', 'RHBDL1', 'AHCYL1', 'VAMP8', 'EEF1AKMT3', 'TTC1', 'MS4A4A', 'TUBB2B', 'SH3BP2', 'UGDH', 'PTMS', 'LHX1', 'OLFML3', 'CGREF1', 'CD163', 'HERC5', 'ZNF195', 'PEG10', 'HP', 'COX5B', 'TUBA4B', 'PCK1', 'ATP6V1F', 'WASHC3', 'BDKRB2', 'EPM2AIP1', 'PAFAH1B3', 'AFP', 'AGL', 'BHLHE40', 'SLC3A2', 'ADI1', 'UQCR10', 'OXCT1', 'TFAM', 'CYP39A1', 'PTP4A1', 'UBXN8', 'ZNRF4', 'FOS', 'NDUFA13', 'ACP6', 'FKBP4', 'NEAT1', 'CHCHD3', 'TRA2A', 'WASHC4', 'RGN', 'FST', 'KLF9', 'SERPINF1', 'ABCC3', 'LIPC', 'MNX1', 'ZNF593', 'ALB', 'ITGB3BP', 'RHOB', 'COX8A', 'TFAP2A', 'MT2A', 'WDR12', 'METTL9', 'DEPTOR', 'ACAD10', 'CHP1', 'label']
# (549, 139)
# (138, 139)

# %%
#train model with new features of 94
model=model16
K=10
test_metrics=[]
train_loss_total_list=[]
for ki in range(K):
    trainset = KZDataset(csv_path='results_genes/intersections/dataset/30_ConvAttMLP_NFM_train_val_info.csv',K=K, n_class=nfm_config['n_class'],ki=ki,  typ='train', transform=None, rand=True)
    valset = KZDataset(csv_path='results_genes/intersections/dataset/30_ConvAttMLP_NFM_train_val_info.csv', K=K,n_class=nfm_config['n_class'],ki=ki,  typ='val', transform=None, rand=True)
    train_loader = data.DataLoader(
         dataset=trainset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size'],
         shuffle=True)
    val_loader = data.DataLoader(
         dataset=valset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
    
    model_path='results_genes/intersections/models/30_ConvAttMLP_NFM/'
    #BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    #total = 0
    
    
    loss_func=torch.nn.CrossEntropyLoss()
    
    num=0
   
    
    epoches=101
    for epoch_id in range(epoches):
          
        
        
        train_loss_total,acc_train=train_epoch(model,train_loader,nfm_config['batch_size'],optimizer,loss_func)
        train_loss_total_list.append(train_loss_total)#
        if epoch_id %20==0:
            num=num+1
            #path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pkl')
            #torch.save(model.state_dict(),path)
            # 保存模型
            
            path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pt')##################pt
            torch.save(model.state_dict(),path)
            #torch.save(model.state_dict(),path)
    print("the ",ki," epoch ends")
    plotLoss(train_loss_total_list,epoches)
    train_loss_total_list=[]
    acc_test=val_epoch(model,val_loader,nfm_config['batch_size'],optimizer)
    print("acc_test_each_k:",acc_test)
    test_metrics.append(acc_test)

print(test_metrics)
#test_metrics=test_metrics.tolist()
test_metrics=[x.cpu().detach().numpy() for x in test_metrics]
print(test_metrics)
acc_test_metrics=np.mean(test_metrics) 
print("acc_test_metrics:",acc_test_metrics)
# Out:
# 549 139
# 549 139
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:730: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:731: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.2792, device='cuda:0')
# Training Epoch: 0, total loss: 63.836004
# total_train_accuracy: tensor(0.4896, device='cuda:0')
# Training Epoch: 1, total loss: 60.737590
# total_train_accuracy: tensor(0.6104, device='cuda:0')
# Training Epoch: 2, total loss: 58.790243
# total_train_accuracy: tensor(0.6604, device='cuda:0')
# Training Epoch: 3, total loss: 57.881723
# total_train_accuracy: tensor(0.7417, device='cuda:0')
# Training Epoch: 4, total loss: 56.624464
# total_train_accuracy: tensor(0.7125, device='cuda:0')
# Training Epoch: 5, total loss: 56.155728
# total_train_accuracy: tensor(0.7396, device='cuda:0')
# Training Epoch: 6, total loss: 55.306740
# total_train_accuracy: tensor(0.7813, device='cuda:0')
# Training Epoch: 7, total loss: 54.851019
# total_train_accuracy: tensor(0.7833, device='cuda:0')
# Training Epoch: 8, total loss: 54.227493
# total_train_accuracy: tensor(0.7896, device='cuda:0')
# Training Epoch: 9, total loss: 53.765892
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 10, total loss: 53.285110
# total_train_accuracy: tensor(0.8313, device='cuda:0')
# Training Epoch: 11, total loss: 52.737956
# total_train_accuracy: tensor(0.8208, device='cuda:0')
# Training Epoch: 12, total loss: 52.477382
# total_train_accuracy: tensor(0.8313, device='cuda:0')
# Training Epoch: 13, total loss: 52.348982
# total_train_accuracy: tensor(0.8646, device='cuda:0')
# Training Epoch: 14, total loss: 51.866582
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 15, total loss: 51.791673
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 16, total loss: 51.989452
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 17, total loss: 51.032694
# total_train_accuracy: tensor(0.8417, device='cuda:0')
# Training Epoch: 18, total loss: 51.303891
# total_train_accuracy: tensor(0.8354, device='cuda:0')
# Training Epoch: 19, total loss: 50.991858
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 20, total loss: 50.836045
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 21, total loss: 50.474198
# total_train_accuracy: tensor(0.8729, device='cuda:0')
# Training Epoch: 22, total loss: 50.021006
# total_train_accuracy: tensor(0.8542, device='cuda:0')
# Training Epoch: 23, total loss: 50.740155
# total_train_accuracy: tensor(0.8625, device='cuda:0')
# Training Epoch: 24, total loss: 49.985590
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 25, total loss: 49.437674
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 26, total loss: 49.294099
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 27, total loss: 49.601306
# total_train_accuracy: tensor(0.8813, device='cuda:0')
# Training Epoch: 28, total loss: 49.531163
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 29, total loss: 49.164480
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 30, total loss: 48.864197
# total_train_accuracy: tensor(0.8813, device='cuda:0')
# Training Epoch: 31, total loss: 48.894689
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# Training Epoch: 32, total loss: 48.350634
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 33, total loss: 48.505875
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 34, total loss: 48.508114
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 35, total loss: 48.222922
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 36, total loss: 48.401321
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 37, total loss: 47.532239
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 38, total loss: 48.031599
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 39, total loss: 48.479150
# total_train_accuracy: tensor(0.9063, device='cuda:0')
# Training Epoch: 40, total loss: 48.023502
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 41, total loss: 47.496875
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 42, total loss: 47.774884
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 43, total loss: 48.263419
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 44, total loss: 48.378946
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 45, total loss: 47.289993
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 46, total loss: 47.453733
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 47, total loss: 47.329303
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 48, total loss: 47.209707
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 49, total loss: 47.026332
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 50, total loss: 47.512943
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 51, total loss: 47.466766
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 52, total loss: 47.477269
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 53, total loss: 47.147629
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 54, total loss: 47.288468
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 55, total loss: 47.536680
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 56, total loss: 46.349985
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 57, total loss: 46.170507
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 58, total loss: 46.393592
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 59, total loss: 46.760556
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 60, total loss: 46.757149
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 61, total loss: 47.426737
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 62, total loss: 46.200714
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 63, total loss: 46.447650
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 64, total loss: 45.961694
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 65, total loss: 46.039152
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 66, total loss: 45.780616
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 67, total loss: 46.181945
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 68, total loss: 46.116817
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 69, total loss: 46.380123
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 70, total loss: 46.224863
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 71, total loss: 45.993051
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 72, total loss: 46.168734
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 73, total loss: 45.543346
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 74, total loss: 46.271772
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 75, total loss: 46.037186
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 76, total loss: 45.625094
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 77, total loss: 45.549587
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 78, total loss: 45.568447
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 79, total loss: 45.135525
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 80, total loss: 46.001266
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 81, total loss: 45.871556
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 82, total loss: 45.846087
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 83, total loss: 45.466031
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 84, total loss: 45.649627
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 85, total loss: 45.743590
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 86, total loss: 45.763479
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 87, total loss: 45.188186
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 88, total loss: 45.006296
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 89, total loss: 45.079023
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 90, total loss: 44.952655
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 91, total loss: 45.466399
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 92, total loss: 45.270471
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 93, total loss: 44.718571
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 94, total loss: 45.146549
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 95, total loss: 45.613015
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 96, total loss: 45.090813
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 97, total loss: 45.101975
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 98, total loss: 45.396108
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 99, total loss: 45.217638
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 100, total loss: 45.365750
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# the  0  epoch ends
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:768: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:769: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# test
# test
# test
# total_test_accuracy: tensor(0.8542, device='cuda:0')
# acc_test_each_k: tensor(0.8542, device='cuda:0')
# 549 139
# 549 139
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 0, total loss: 44.885800
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 1, total loss: 45.756955
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 2, total loss: 45.947519
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 3, total loss: 45.246875
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 4, total loss: 45.236319
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 5, total loss: 44.924021
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 6, total loss: 44.699186
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 7, total loss: 45.060806
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 8, total loss: 44.684599
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 9, total loss: 44.459045
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 10, total loss: 45.139711
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 11, total loss: 44.695126
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 12, total loss: 44.335179
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 13, total loss: 44.865840
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 14, total loss: 44.328118
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 15, total loss: 44.976815
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 16, total loss: 44.576017
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 17, total loss: 44.809254
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 18, total loss: 44.815131
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 19, total loss: 44.670382
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 20, total loss: 44.513006
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 21, total loss: 44.782677
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 22, total loss: 44.464874
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 23, total loss: 44.077380
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 24, total loss: 44.142648
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 25, total loss: 43.880261
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 26, total loss: 44.297585
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 27, total loss: 44.436541
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 28, total loss: 44.974964
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 29, total loss: 44.166131
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 30, total loss: 44.440851
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 31, total loss: 44.808046
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 32, total loss: 44.075831
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 33, total loss: 44.255303
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 34, total loss: 44.349429
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 35, total loss: 44.244980
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 36, total loss: 44.580662
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 37, total loss: 43.811493
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 38, total loss: 44.365859
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 39, total loss: 44.668528
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 40, total loss: 44.043717
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 41, total loss: 44.250104
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 42, total loss: 44.202365
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 43, total loss: 44.321821
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 44, total loss: 43.653707
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 45, total loss: 43.944122
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 46, total loss: 43.897712
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 47, total loss: 44.182025
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 48, total loss: 43.898130
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 49, total loss: 44.350617
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 50, total loss: 43.829994
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 51, total loss: 43.798318
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 52, total loss: 44.505275
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 53, total loss: 43.558307
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 54, total loss: 44.099925
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 55, total loss: 44.862625
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 56, total loss: 43.934017
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 57, total loss: 43.568061
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 58, total loss: 44.328969
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 59, total loss: 43.623488
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 60, total loss: 43.825394
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 61, total loss: 44.728725
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 62, total loss: 43.937302
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 63, total loss: 44.153861
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 64, total loss: 43.485169
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 65, total loss: 44.096081
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 66, total loss: 43.625408
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 67, total loss: 44.185013
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 68, total loss: 43.800892
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 69, total loss: 43.458793
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 70, total loss: 44.143761
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 71, total loss: 43.597237
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 72, total loss: 43.846487
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 73, total loss: 43.803898
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 74, total loss: 43.357505
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 75, total loss: 43.606955
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 76, total loss: 43.372571
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 77, total loss: 43.720264
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 78, total loss: 43.906073
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 79, total loss: 43.489422
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 80, total loss: 43.529093
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 81, total loss: 43.278524
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 82, total loss: 43.659899
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 83, total loss: 43.807391
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 84, total loss: 43.512966
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 85, total loss: 43.427257
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 86, total loss: 43.485378
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 87, total loss: 44.080699
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 88, total loss: 43.599121
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 89, total loss: 44.152771
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 90, total loss: 44.045314
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 91, total loss: 44.220680
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 92, total loss: 43.786622
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 93, total loss: 43.587224
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 94, total loss: 43.749156
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 95, total loss: 43.515963
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 96, total loss: 43.250998
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 97, total loss: 43.674004
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 98, total loss: 43.348506
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 99, total loss: 43.530384
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 100, total loss: 43.690285
# the  1  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(0.9583, device='cuda:0')
# acc_test_each_k: tensor(0.9583, device='cuda:0')
# 549 139
# 549 139
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 0, total loss: 43.863494
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 1, total loss: 43.928182
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 2, total loss: 43.452299
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 3, total loss: 43.888101
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 4, total loss: 43.232640
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 5, total loss: 43.606970
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 6, total loss: 43.663814
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 7, total loss: 43.634862
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 8, total loss: 43.611036
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 9, total loss: 43.878594
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 10, total loss: 43.537880
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 11, total loss: 43.456887
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 12, total loss: 44.083301
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 13, total loss: 43.461024
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 14, total loss: 43.800679
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 15, total loss: 43.368232
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 16, total loss: 43.054701
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 17, total loss: 43.272520
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 18, total loss: 43.617499
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 19, total loss: 43.369385
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 20, total loss: 43.344844
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 21, total loss: 43.161055
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 22, total loss: 43.328985
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 23, total loss: 43.277332
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 24, total loss: 43.286991
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 25, total loss: 42.986284
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 26, total loss: 43.300398
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 27, total loss: 43.252210
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 28, total loss: 42.940913
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 29, total loss: 42.948061
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 30, total loss: 43.589079
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 31, total loss: 43.330877
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 32, total loss: 43.371515
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 33, total loss: 43.122759
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 34, total loss: 43.072567
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 35, total loss: 42.943437
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 36, total loss: 43.348846
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 37, total loss: 43.269176
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 38, total loss: 42.898690
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 39, total loss: 43.708645
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 40, total loss: 43.041009
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 41, total loss: 43.285826
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 42, total loss: 43.510294
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 43, total loss: 43.177044
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 44, total loss: 42.705563
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 45, total loss: 43.562292
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 46, total loss: 43.111395
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 47, total loss: 43.549505
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 48, total loss: 42.982353
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 49, total loss: 43.378901
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 50, total loss: 43.092340
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 51, total loss: 42.911283
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 52, total loss: 43.022625
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 53, total loss: 42.970387
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 54, total loss: 42.983387
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 55, total loss: 43.205027
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 56, total loss: 43.327434
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 57, total loss: 43.094757
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 58, total loss: 43.254459
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 59, total loss: 43.564921
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 60, total loss: 42.913468
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 61, total loss: 42.722825
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 62, total loss: 42.595440
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 63, total loss: 42.991280
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 64, total loss: 43.024589
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 65, total loss: 43.044577
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 66, total loss: 42.954663
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 67, total loss: 43.196727
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 68, total loss: 43.482516
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 69, total loss: 42.868572
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 70, total loss: 42.929085
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 71, total loss: 43.149468
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 72, total loss: 42.768028
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 73, total loss: 42.970460
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 74, total loss: 42.931328
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 75, total loss: 42.762817
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 76, total loss: 42.585233
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 77, total loss: 43.262311
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 78, total loss: 43.156889
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 79, total loss: 43.002108
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 80, total loss: 43.251029
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 81, total loss: 42.990116
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 82, total loss: 43.110884
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 83, total loss: 42.610962
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 84, total loss: 42.964689
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 85, total loss: 43.142025
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 86, total loss: 42.585987
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 87, total loss: 42.651963
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 88, total loss: 43.253372
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 89, total loss: 42.940645
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 90, total loss: 42.536845
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 91, total loss: 43.045312
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 92, total loss: 42.711622
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 93, total loss: 42.452914
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 94, total loss: 42.684266
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 95, total loss: 42.986345
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 96, total loss: 43.040432
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 97, total loss: 43.074538
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 98, total loss: 43.337656
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 99, total loss: 43.078092
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 100, total loss: 43.090644
# the  2  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# acc_test_each_k: tensor(1., device='cuda:0')
# 549 139
# 549 139
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 0, total loss: 43.601452
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 1, total loss: 42.887780
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 2, total loss: 42.756983
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 3, total loss: 42.918811
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 4, total loss: 43.054065
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 5, total loss: 43.341927
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 6, total loss: 43.253252
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 7, total loss: 43.245312
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 8, total loss: 42.644055
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 9, total loss: 42.925472
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 10, total loss: 43.085985
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 11, total loss: 42.787001
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 12, total loss: 43.075731
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 13, total loss: 43.218782
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 14, total loss: 42.963966
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 15, total loss: 42.902521
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 16, total loss: 42.632210
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 17, total loss: 43.200775
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 18, total loss: 43.688989
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 19, total loss: 42.909182
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 20, total loss: 42.865696
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 21, total loss: 43.190105
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 22, total loss: 43.006088
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 23, total loss: 42.901345
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 24, total loss: 42.856650
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 25, total loss: 43.155390
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 26, total loss: 43.109094
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 27, total loss: 42.904826
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 28, total loss: 42.861644
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 29, total loss: 43.217337
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 30, total loss: 42.715944
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 31, total loss: 42.930992
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 32, total loss: 42.859591
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 33, total loss: 42.461488
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 34, total loss: 42.626123
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 35, total loss: 43.172181
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 36, total loss: 43.330752
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 37, total loss: 43.155120
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 38, total loss: 42.882926
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 39, total loss: 42.390940
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 40, total loss: 43.059670
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 41, total loss: 42.602179
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 42, total loss: 43.016396
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 43, total loss: 42.588442
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 44, total loss: 43.086534
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 45, total loss: 42.779312
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 46, total loss: 43.003975
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 47, total loss: 43.041121
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 48, total loss: 42.915094
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 49, total loss: 42.812099
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 50, total loss: 42.534242
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 51, total loss: 42.750844
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 52, total loss: 42.916889
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 53, total loss: 42.984311
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 54, total loss: 42.810793
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 55, total loss: 42.710820
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 56, total loss: 42.517480
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 57, total loss: 42.477620
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 58, total loss: 42.683688
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 59, total loss: 42.881541
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 60, total loss: 42.668245
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 61, total loss: 42.632688
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 62, total loss: 42.891420
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 63, total loss: 43.144710
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 64, total loss: 42.813410
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 65, total loss: 43.275130
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 66, total loss: 42.392359
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 67, total loss: 42.844235
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 68, total loss: 42.907965
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 69, total loss: 42.662801
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 70, total loss: 42.938714
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 71, total loss: 42.599571
# total_train_accuracy: tensor(0.9938, device='cuda:0')
# Training Epoch: 72, total loss: 41.935490
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 73, total loss: 43.347928
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 74, total loss: 42.532938
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 75, total loss: 42.627133
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 76, total loss: 42.812809
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 77, total loss: 42.781128
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 78, total loss: 42.939955
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 79, total loss: 43.081637
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 80, total loss: 42.474148
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 81, total loss: 43.027052
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 82, total loss: 42.717118
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 83, total loss: 42.729025
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 84, total loss: 42.567961
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 85, total loss: 43.201666
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 86, total loss: 42.658870
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 87, total loss: 42.746026
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 88, total loss: 42.692019
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 89, total loss: 42.377096
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 90, total loss: 43.073119
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 91, total loss: 42.503732
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 92, total loss: 42.389344
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 93, total loss: 42.499671
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 94, total loss: 42.428890
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 95, total loss: 42.846212
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 96, total loss: 42.816520
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 97, total loss: 42.387317
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 98, total loss: 42.580556
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 99, total loss: 42.418514
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 100, total loss: 42.357529
# the  3  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(0.9583, device='cuda:0')
# acc_test_each_k: tensor(0.9583, device='cuda:0')
# 549 139
# 549 139
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 0, total loss: 43.009287
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 1, total loss: 42.778385
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 2, total loss: 42.353545
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 3, total loss: 42.903071
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 4, total loss: 42.998832
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 5, total loss: 43.025104
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 6, total loss: 43.352180
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 7, total loss: 42.725364
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 8, total loss: 42.578678
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 9, total loss: 43.045590
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 10, total loss: 42.566612
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 11, total loss: 42.799646
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 12, total loss: 42.336201
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 13, total loss: 42.576689
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 14, total loss: 42.472450
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 15, total loss: 42.425081
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 16, total loss: 42.618149
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 17, total loss: 42.574321
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 18, total loss: 42.665360
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 19, total loss: 42.588363
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 20, total loss: 42.837185
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 21, total loss: 42.557818
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 22, total loss: 43.097855
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 23, total loss: 43.032026
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 24, total loss: 42.731136
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 25, total loss: 42.683739
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 26, total loss: 43.016053
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 27, total loss: 42.831024
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 28, total loss: 42.450816
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 29, total loss: 43.088703
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 30, total loss: 42.423708
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 31, total loss: 42.654030
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 32, total loss: 42.777163
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 33, total loss: 42.368878
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 34, total loss: 42.560943
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 35, total loss: 42.646438
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 36, total loss: 42.421726
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 37, total loss: 42.307070
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 38, total loss: 42.801286
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 39, total loss: 42.727722
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 40, total loss: 42.335903
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 41, total loss: 42.893078
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 42, total loss: 43.186357
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 43, total loss: 42.915489
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 44, total loss: 42.896774
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 45, total loss: 42.484996
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 46, total loss: 42.546938
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 47, total loss: 42.733176
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 48, total loss: 42.676232
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 49, total loss: 43.108518
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 50, total loss: 42.519911
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 51, total loss: 42.221107
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 52, total loss: 42.699250
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 53, total loss: 42.753724
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 54, total loss: 42.913983
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 55, total loss: 42.457885
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 56, total loss: 42.985419
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 57, total loss: 42.849896
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 58, total loss: 42.449789
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 59, total loss: 42.514318
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 60, total loss: 42.441135
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 61, total loss: 42.849638
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 62, total loss: 42.711518
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 63, total loss: 42.609358
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 64, total loss: 42.490843
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 65, total loss: 42.360304
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 66, total loss: 42.366915
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 67, total loss: 42.418699
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 68, total loss: 42.749206
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 69, total loss: 43.512480
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 70, total loss: 42.751262
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 71, total loss: 42.532521
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 72, total loss: 42.556387

# %%
import torch

#功能：加载保存到path中的各层参数到神经网络

#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP610.pkl'
#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP9110.pkl'
path='results_genes/intersections/models/30_MLP_NFM/MLP610.pt'
#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP10910.pkl'
#nfm=NFM(nfm_config)
mlp=MLP15()
#print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
mlp.load_state_dict(torch.load(path),strict=False)
mlp.cuda()

print(mlp)




mlp_params = list(mlp.named_parameters())
#print(nfm_params)
net=mlp


testset = KZDatasetTest(csv_path='results_genes/intersections/dataset/30_MLP_NFM_test_info.csv')
   
test_loader = data.DataLoader(
         dataset=testset,
         #transform=torchvision.transforms.ToTensor(),
         
         batch_size=nfm_config['batch_size']
        
     )
#———————————————— 
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/jclian91/article/details/121708431# 
from torch.autograd import Variable 
from torch.utils.data import DataLoader 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import accuracy_score 
 
def evaluate_model(test_dl, model): 
    model.eval()#测试数据稳定
    predictions, actuals = [], [] 
    for i, (inputs, targets) in enumerate(test_dl): 
        # evaluate the model on the test set 
        #print(\ inputs:\ ,inputs) 
        #print(\ targets:\ ,targets) 
        inputs = Variable(inputs) 
        targets = Variable(targets) 
                 
                 
        #x = torch.tensor(x, dtype=torch.float) 
        #x=x.clone().detach().requires_grad_(True) 
        inputs=torch.tensor(inputs,dtype=torch.float) 
        targets=torch.tensor(targets,dtype=torch.float) 
        inputs, targets = inputs.cuda(), targets.cuda() 
        yhat = model(inputs) 
        yhat=(yhat==torch.max(yhat,1,keepdim=True)[0]).to(dtype=torch.int32)
        # retrieve numpy array 
        #yhat = yhat.detach().numpy() 
        yhat = yhat.detach().cpu().numpy()#转换到cpu 
        # yhat=yhat.argmax(axis=1) 
        #print(yhat:\ ,yhat) 
        #print('yhat.shape:',yhat.shape) 
        actual = targets.detach().cpu().numpy() 
        actual=actual.round() 
        #print(\ actual:\ ,actual) 
        #print('actual.shape:',actual.shape
        #predictions.appe) 
        #actual = actual.reshape(-1, 1) 
        # round to class values 
        yhat = yhat.round() 
        # store nd(yhat) 
        actuals.append(actual) 
        predictions.append(yhat)
    #print("prediction:" ,predictions) 
    #print("actuals:",actuals) 
    predictions, actuals = np.vstack(predictions), np.vstack(actuals) 
    #print("prediction:" ,predictions) 
    #print("actuals:" ,actuals) 
    # calculate accuracy 
    acc_test = accuracy_score(actuals, predictions) 
    return  actuals, predictions,acc_test 

import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 
target_list=actuals 
pred_list=predictions 
      
y_true=target_list 
y_pred=pred_list 
      
f1=f1_score(y_true=target_list, y_pred=pred_list, average='macro') # 也可以指定micro模式 
acc_score=accuracy_score(y_true=target_list, y_pred=pred_list) 
rec_score=recall_score(y_true=target_list,y_pred=pred_list,average='macro') # 也可以指定micro模式 
pre_recall=precision_score(y_true=target_list,y_pred=pred_list,average='macro') 
print("f1_score:  %.4f" ,f1) 
print("accuracy_score:" ,acc_score) 
print("recall_score:",rec_score) 
print("pre_recall:" ,pre_recall)



auc_curve = roc_auc_score(y_true, y_pred, multi_class='ovo')
#———————————————— 
#版权声明：本文为CSDN博主「农民小飞侠」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/w5688414/article/details/106595892 
PM_y=y_pred 
true_y=y_true 
n_classes=PM_y.shape[1] 
      
print("n_classes:",n_classes) 
fpr = dict() 
tpr = dict() 
roc_auc = dict() 
for i in range(n_classes): 
    fpr[i], tpr[i], _ = roc_curve(true_y[:, i], PM_y[:, i]) 
    roc_auc[i] = auc(fpr[i], tpr[i]) 
    #print(i) 
    #print(fpr) 
    #print(tpr) 
    
    
    
#计算macro auc 
from scipy import interp 
# First aggregate all false positive rates 
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)])) 
       
# Then interpolate all ROC curves at this points 
mean_tpr = np.zeros_like(all_fpr) 
for i in range(n_classes): 
    mean_tpr += interp(all_fpr, fpr[i], tpr[i]) 
       
    # Finally average it and compute AUC 
    mean_tpr /= n_classes 
       
    fpr["macro"] = all_fpr 
    tpr["macro"] = mean_tpr 
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    
    
    
#画图 
      
import matplotlib.pyplot as plt 
from itertools import cycle 
from matplotlib.ticker import FuncFormatter 
lw = 2 
# Plot all ROC curves 
plt.figure() 
labels=['Con(0)','DN(1)','FSGS(2)','HT(3)','IgA(4)','MCD(5)','MGN(6)','RPGN(7)','SLE(8)'] 

'''
plt.plot(fpr["macro"], tpr["macro"], 
              label='macro-average ROC curve (area = {0:0.4f})' 
                    ''.format(roc_auc["macro"]), 
              color='navy', linestyle=':', linewidth=4) 
'''

       
colors = cycle(['aqua', 'darkorange', 'cornflowerblue','blue','yellow','burlywood','cornsilk','darkblue','goldenrod','greenyellow','maroon']) 
for i, color in zip(range(n_classes), colors): 
    plt.plot(fpr[i], tpr[i], color=color, lw=lw, 
                  label=labels[i]+'(area = {0:0.4f})'.format(roc_auc[i])) 
       
    plt.plot([0, 1], [0, 1], 'k--', lw=lw) 
    plt.xlim([0.0, 1.0]) 
    plt.ylim([0.0, 1.05]) 
      
      
    plt.xlabel('1-Specificity (%)') 
    plt.ylabel('Sensitivity (%)') 
    #plt.title('testing on kidney tubules with F800 without augment') 
    plt.title('evaluation with MLP model on top 20 genes\n  based on mean of samples predicted correctly')   

        
def to_percent(temp, position): 
    return '%1.0f'%(100*temp) 
      
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.legend(loc="lower right" ) 
      
plt.show()
