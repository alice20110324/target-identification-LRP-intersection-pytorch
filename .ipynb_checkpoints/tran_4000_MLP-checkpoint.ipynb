# %%
import torch  as pt
from torch import nn
import torch.nn.functional as F  # 激励函数的库
from torchvision import datasets
import torchvision.transforms as transforms
import numpy as np

# %%
import torch
#import Trainer

import torch.utils.data as Data
#from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':1000,
    'linear_hidden':100,#线性模型输出层（隐层个数）
    'embed_input_dim':1001,#embed输入维度
    'embed_dim': 100, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    #'dnn_hidden_units': [100,11],#MLP隐层和输出层
    
    'dnn_hidden_units':[100,9],#MLP隐层
    'num_sparse_features_cols':5510,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.3,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 100,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    'train_non_em':'data/data/guan/gene_4000/other/train_4000_data.csv',
    'train_file':'data/xiaoqiu_gene_5000/train/final_5000_encode_100x.csv',
    'label_file':'data/data/guan/gene_4000/other/train_4000_label.csv',
   # 'test_file':'data/frappe/gene_4000/test/test_file.csv',
   # 'test_label':'data/frappe/gene_4000/test/test_label.csv',
    'title':'data/data/guan/gene_4000/gene_4000_title.csv',
    'all':'data/data/guan/gene_4000/gene_4000_search.csv'

}

# %%
#model definition
class MLP(nn.Module):
    def __init__(self):
        super().__init__()

        self.fc1 = nn.Linear(4078, 1000)
        self.bn1= nn.BatchNorm1d(1000)
        self.fc2 = nn.Linear(1000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3 = nn.Linear(100, 9)
        self.bn3=nn.BatchNorm1d(9)
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model = MLP().cuda()
print(model)
# Out:
# MLP(
#   (fc1): Linear(in_features=4078, out_features=1000, bias=True)
#   (bn1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=1000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )

# %%
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn

# %%
def one_hot(labels, classes, label_smoothing=0.2):
    n = len(labels)
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        print("row:",row,"label:",label)
    return output


class FMData(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, file,label_file, n_class):
        super(FMData, self).__init__()
        self.label = []
        self.features = []
        #self.feature_values = []
        
        features=[]
        #feature_map.keys()
        #self.features=np.array(feature_map)
        #feature_map
        #file="data/frappe/c_df_v_fff2000.csv"
        #num = len(features)
        fd=pd.read_csv(file,sep=',')
        #nrow=fd.shape[0]
        #ncol=fd.shape[1]
        n_fd=np.array(fd,dtype=np.float32)
        #print(n_fd)
        #n_fd=n_fd[:,1:]
        
        """
        for i, item in enumerate(n_fd):
            u=[feature_map[x] for x in item]
            features.append(u)
        """
        
        self.features=np.array(n_fd)
        #self.features=self.features
        
        
        nrow,ncol=n_fd.shape
        #ncol=10150
        #feature_v=[]
        """
            feature_v=[1 for i in range(ncol)]
            #print(feature_v)
            #feature_values=[feature_v for j in range(nrow)]

            for item in range(nrow):
            feature_values.append(feature_v)
        """

        #feature_v=[[1 for i in range(ncol)] for i in range(nrow)]
        #self.feature_values=np.array(feature_v)
        #print(feature_value)
        #self.feature_values=feature_value.tolist()
        #feature_map,lenth=map_features()
        #raw = [item for item in  enumerate(n_fd)]
        #print(raw)
        #raw=raw.tolist()
        
        #label_file=[]
        label_fd=pd.read_csv(label_file,sep=',')
        #print(features)
        #print(label_fd)
        #label=pd.get_dummies(label_fd)
        label=np.array(label_fd)
        #label=label[:,1:]
        label=one_hot(label,n_class)
        #label=F.one_hot(tensor, num_classes=- 1) 
        self.label=label
        print("label:",label)
        print("features:",self.features)
        print("label.shape:",self.label.shape)
        print("features.shape:",self.features.shape)
        #print(label)
        # convert labels
        """if config.loss_type == 'square_loss':
            self.label.append(np.float32(items[0]))
        else: # log_loss
            label = 1 if float(items[0]) > 0 else 0
            self.label.append(label)
        """
        
        """
        assert all(len(item) == len(self.features[0]
            ) for item in self.features), 'features are of different length'
        """
        #print(len(self.features))
        #print(len(self.feature_values))
        #print(len(self.label))

    def __len__(self):
        return len(self.label)

    def __getitem__(self, idx):
        label = self.label[idx]
        features = self.features[idx]
        #feature_values = self.feature_values[idx]
        #return features, feature_values, label
        return features,label

# %%
import pandas as pd
from torch import optim, nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset



train_dataset = FMData(nfm_config['train_non_em'],nfm_config['label_file'],nfm_config['n_class'])
train_loader = data.DataLoader(train_dataset, drop_last=True,batch_size=100,shuffle=True, num_workers=4)#batchsize必须小于测试机总数，否则测试时报错
# Out:
# row: 0 label: [0]
# row: 1 label: [0]
# row: 2 label: [0]
# row: 3 label: [0]
# row: 4 label: [0]
# row: 5 label: [0]
# row: 6 label: [0]
# row: 7 label: [0]
# row: 8 label: [0]
# row: 9 label: [0]
# row: 10 label: [0]
# row: 11 label: [0]
# row: 12 label: [0]
# row: 13 label: [0]
# row: 14 label: [0]
# row: 15 label: [0]
# row: 16 label: [0]
# row: 17 label: [0]
# row: 18 label: [0]
# row: 19 label: [0]
# row: 20 label: [0]
# row: 21 label: [0]
# row: 22 label: [0]
# row: 23 label: [0]
# row: 24 label: [0]
# row: 25 label: [0]
# row: 26 label: [0]
# row: 27 label: [0]
# row: 28 label: [0]
# row: 29 label: [0]
# row: 30 label: [0]
# row: 31 label: [0]
# row: 32 label: [0]
# row: 33 label: [0]
# row: 34 label: [0]
# row: 35 label: [0]
# row: 36 label: [0]
# row: 37 label: [0]
# row: 38 label: [0]
# row: 39 label: [0]
# row: 40 label: [0]
# row: 41 label: [0]
# row: 42 label: [0]
# row: 43 label: [0]
# row: 44 label: [0]
# row: 45 label: [0]
# row: 46 label: [0]
# row: 47 label: [0]
# row: 48 label: [0]
# row: 49 label: [0]
# row: 50 label: [0]
# row: 51 label: [0]
# row: 52 label: [0]
# row: 53 label: [0]
# row: 54 label: [0]
# row: 55 label: [0]
# row: 56 label: [1]
# row: 57 label: [1]
# row: 58 label: [1]
# row: 59 label: [1]
# row: 60 label: [1]
# row: 61 label: [1]
# row: 62 label: [1]
# row: 63 label: [1]
# row: 64 label: [1]
# row: 65 label: [1]
# row: 66 label: [1]
# row: 67 label: [1]
# row: 68 label: [1]
# row: 69 label: [1]
# row: 70 label: [1]
# row: 71 label: [1]
# row: 72 label: [1]
# row: 73 label: [1]
# row: 74 label: [1]
# row: 75 label: [1]
# row: 76 label: [1]
# row: 77 label: [1]
# row: 78 label: [1]
# row: 79 label: [1]
# row: 80 label: [1]
# row: 81 label: [1]
# row: 82 label: [1]
# row: 83 label: [1]
# row: 84 label: [1]
# row: 85 label: [1]
# row: 86 label: [1]
# row: 87 label: [1]
# row: 88 label: [1]
# row: 89 label: [1]
# row: 90 label: [1]
# row: 91 label: [1]
# row: 92 label: [1]
# row: 93 label: [1]
# row: 94 label: [1]
# row: 95 label: [1]
# row: 96 label: [1]
# row: 97 label: [1]
# row: 98 label: [1]
# row: 99 label: [1]
# row: 100 label: [1]
# row: 101 label: [1]
# row: 102 label: [1]
# row: 103 label: [1]
# row: 104 label: [1]
# row: 105 label: [1]
# row: 106 label: [1]
# row: 107 label: [1]
# row: 108 label: [1]
# row: 109 label: [1]
# row: 110 label: [1]
# row: 111 label: [1]
# row: 112 label: [1]
# row: 113 label: [2]
# row: 114 label: [2]
# row: 115 label: [2]
# row: 116 label: [2]
# row: 117 label: [2]
# row: 118 label: [2]
# row: 119 label: [2]
# row: 120 label: [2]
# row: 121 label: [2]
# row: 122 label: [2]
# row: 123 label: [2]
# row: 124 label: [2]
# row: 125 label: [2]
# row: 126 label: [2]
# row: 127 label: [2]
# row: 128 label: [2]
# row: 129 label: [2]
# row: 130 label: [2]
# row: 131 label: [2]
# row: 265 label: [4]
# row: 266 label: [4]
# row: 267 label: [4]
# row: 268 label: [4]
# row: 269 label: [4]
# row: 270 label: [4]
# row: 271 label: [4]
# row: 272 label: [4]
# row: 273 label: [4]
# row: 274 label: [4]
# row: 275 label: [4]
# row: 276 label: [4]
# row: 277 label: [4]
# row: 278 label: [4]
# row: 279 label: [4]
# row: 280 label: [4]
# row: 281 label: [4]
# row: 282 label: [4]
# row: 283 label: [4]
# row: 284 label: [4]
# row: 285 label: [4]
# row: 286 label: [4]
# row: 287 label: [4]
# row: 288 label: [4]
# row: 289 label: [4]
# row: 290 label: [4]
# row: 291 label: [4]
# row: 292 label: [4]
# row: 293 label: [4]
# row: 294 label: [4]
# row: 295 label: [4]
# row: 296 label: [4]
# row: 297 label: [4]
# row: 298 label: [4]
# row: 299 label: [4]
# row: 300 label: [4]
# row: 301 label: [4]
# row: 302 label: [4]
# row: 303 label: [4]
# row: 304 label: [4]
# row: 305 label: [4]
# row: 306 label: [4]
# row: 307 label: [4]
# row: 308 label: [4]
# row: 309 label: [4]
# row: 310 label: [4]
# row: 311 label: [4]
# row: 312 label: [4]
# row: 313 label: [4]
# row: 314 label: [4]
# row: 315 label: [4]
# row: 316 label: [4]
# row: 317 label: [4]
# row: 318 label: [4]
# row: 319 label: [4]
# row: 320 label: [4]
# row: 321 label: [4]
# row: 322 label: [4]
# row: 323 label: [4]
# row: 324 label: [4]
# row: 325 label: [4]
# row: 326 label: [5]
# row: 327 label: [5]
# row: 328 label: [5]
# row: 329 label: [5]
# row: 330 label: [5]
# row: 331 label: [5]
# row: 332 label: [5]
# row: 333 label: [5]
# row: 334 label: [5]
# row: 335 label: [5]
# row: 336 label: [5]
# row: 337 label: [5]
# row: 338 label: [5]
# row: 339 label: [5]
# row: 340 label: [5]
# row: 341 label: [5]
# row: 342 label: [5]
# row: 343 label: [5]
# row: 344 label: [5]
# row: 345 label: [5]
# row: 346 label: [5]
# row: 347 label: [5]
# row: 348 label: [5]
# row: 349 label: [5]
# row: 350 label: [5]
# row: 351 label: [5]
# row: 352 label: [5]
# row: 353 label: [5]
# row: 354 label: [5]
# row: 355 label: [5]
# row: 356 label: [5]
# row: 357 label: [5]
# row: 358 label: [6]
# row: 359 label: [6]
# row: 360 label: [6]
# row: 361 label: [6]
# row: 362 label: [6]
# row: 363 label: [6]
# row: 364 label: [6]
# row: 365 label: [6]
# row: 366 label: [6]
# row: 367 label: [6]
# row: 368 label: [6]
# row: 369 label: [6]
# row: 370 label: [6]
# row: 371 label: [6]
# row: 372 label: [6]
# row: 373 label: [6]
# row: 374 label: [6]
# row: 375 label: [6]
# row: 376 label: [6]
# row: 377 label: [6]
# row: 378 label: [6]
# row: 379 label: [6]
# row: 380 label: [6]
# row: 381 label: [6]
# row: 382 label: [6]
# row: 383 label: [6]
# row: 384 label: [6]
# row: 385 label: [6]
# row: 386 label: [6]
# row: 387 label: [6]
# row: 388 label: [6]
# row: 389 label: [6]
# row: 390 label: [6]
# row: 391 label: [6]
# row: 392 label: [6]
# row: 393 label: [6]
# row: 394 label: [6]
# row: 395 label: [6]
# row: 396 label: [6]
# row: 530 label: [6]
# row: 531 label: [6]
# row: 532 label: [6]
# row: 533 label: [6]
# row: 534 label: [6]
# row: 535 label: [6]
# row: 536 label: [7]
# row: 537 label: [7]
# row: 538 label: [7]
# row: 539 label: [7]
# row: 540 label: [7]
# row: 541 label: [7]
# row: 542 label: [7]
# row: 543 label: [7]
# row: 544 label: [7]
# row: 545 label: [7]
# row: 546 label: [7]
# row: 547 label: [7]
# row: 548 label: [7]
# row: 549 label: [7]
# row: 550 label: [7]
# row: 551 label: [7]
# row: 552 label: [7]
# row: 553 label: [7]
# row: 554 label: [7]
# row: 555 label: [7]
# row: 556 label: [7]
# row: 557 label: [7]
# row: 558 label: [7]
# row: 559 label: [7]
# row: 560 label: [7]
# row: 561 label: [7]
# row: 562 label: [7]
# row: 563 label: [7]
# row: 564 label: [7]
# row: 565 label: [7]
# row: 566 label: [7]
# row: 567 label: [7]
# row: 568 label: [7]
# row: 569 label: [7]
# row: 570 label: [7]
# row: 571 label: [7]
# row: 572 label: [7]
# row: 573 label: [7]
# row: 574 label: [7]
# row: 575 label: [7]
# row: 576 label: [7]
# row: 577 label: [8]
# row: 578 label: [8]
# row: 579 label: [8]
# row: 580 label: [8]
# row: 581 label: [8]
# row: 582 label: [8]
# row: 583 label: [8]
# row: 584 label: [8]
# row: 585 label: [8]
# row: 586 label: [8]
# row: 587 label: [8]
# row: 588 label: [8]
# row: 589 label: [8]
# row: 590 label: [8]
# row: 591 label: [8]
# row: 592 label: [8]
# row: 593 label: [8]
# row: 594 label: [8]
# row: 595 label: [8]
# row: 596 label: [8]
# row: 597 label: [8]
# row: 598 label: [8]
# row: 599 label: [8]
# row: 600 label: [8]
# row: 601 label: [8]
# row: 602 label: [8]
# row: 603 label: [8]
# row: 604 label: [8]
# row: 605 label: [8]
# row: 606 label: [8]
# row: 607 label: [8]
# row: 608 label: [8]
# row: 609 label: [8]
# row: 610 label: [8]
# row: 611 label: [8]
# row: 612 label: [8]
# row: 613 label: [8]
# row: 614 label: [8]
# row: 615 label: [8]
# row: 616 label: [8]
# row: 617 label: [8]
# row: 618 label: [8]
# row: 619 label: [8]
# row: 620 label: [8]
# row: 621 label: [8]
# row: 622 label: [8]
# row: 623 label: [8]
# row: 624 label: [8]
# row: 625 label: [8]
# row: 626 label: [8]
# row: 627 label: [8]
# row: 628 label: [8]
# row: 629 label: [8]
# row: 630 label: [8]
# row: 631 label: [8]
# row: 632 label: [8]
# row: 633 label: [8]
# row: 634 label: [8]
# row: 635 label: [8]
# row: 636 label: [8]
# row: 637 label: [8]
# row: 638 label: [8]
# row: 639 label: [8]
# row: 640 label: [8]
# row: 641 label: [8]
# row: 642 label: [8]
# row: 643 label: [8]
# row: 644 label: [8]
# row: 645 label: [8]
# row: 646 label: [8]
# row: 647 label: [8]
# row: 648 label: [8]
# row: 649 label: [8]
# row: 650 label: [8]
# row: 651 label: [8]
# row: 652 label: [8]
# row: 653 label: [8]
# row: 654 label: [8]
# row: 655 label: [8]
# row: 656 label: [8]
# row: 657 label: [8]
# row: 658 label: [8]
# row: 659 label: [8]
# row: 660 label: [8]
# row: 661 label: [8]
# row: 662 label: [8]
# row: 663 label: [8]
# row: 664 label: [8]
# row: 665 label: [8]
# row: 666 label: [8]
# row: 667 label: [8]
# row: 668 label: [8]
# row: 669 label: [8]
# row: 670 label: [8]
# row: 671 label: [8]
# row: 672 label: [8]
# row: 673 label: [8]
# row: 674 label: [8]
# row: 675 label: [8]
# row: 676 label: [8]
# label: [[0.82222223 0.02222222 0.02222222 ... 0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 ... 0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 ... 0.02222222 0.02222222 0.02222222]
#  ...
#  [0.02222222 0.02222222 0.02222222 ... 0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 ... 0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 ... 0.02222222 0.02222222 0.82222223]]
# features: [[4.7811794  4.737805   6.518972   ... 4.124207   3.3757224  3.743601  ]
#  [4.8956285  4.734086   6.3989453  ... 4.4044714  3.4487958  3.8384867 ]
#  [4.7824674  4.903336   6.007603   ... 4.119987   3.2554233  3.8842363 ]
#  ...
#  [0.967576   4.7495785  5.130435   ... 1.4670559  4.618006   4.2568536 ]
#  [0.79348546 4.2378964  5.6804132  ... 0.88762164 3.8151276  4.821592  ]
#  [0.80465436 4.9622746  6.273483   ... 1.3759555  3.472857   4.4079385 ]]
# label.shape: (677, 9)
# features.shape: (677, 4078)

# %%
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
import torch
#from nfm_network import NFM
if __name__ == "__main__":
    ####################################################################################
    # NFM 模型
    ####################################################################################
    BATCH_SIZE=100
   
    """
    training_data, training_label, dense_features_col, sparse_features_col = getTrainData(nfm_config['train_file'], nfm_config['fea_file'])
    train_dataset = Data.TensorDataset(torch.tensor(training_data).float(), torch.tensor(training_label).float())

    test_data = getTestData(nfm_config['test_file'])
    test_dataset = Data.TensorDataset(torch.tensor(test_data).float())
    
    test_data = getTestData(nfm_config['test_file'])
    test_dataset = Data.TensorDataset(torch.tensor(test_data).float())

    """
    #device = torch.device('cuda:0')
    #epoch=0
    
    #model=nn.Linear(10149,16).to(device)
    #model=nn.Linear(10149,16)
    #model=nn.ReLU(nn.Linear(10149,16))#RuntimeError: all elements of input should be between 0 and 1
    #print('model:',model)
    #nfm = MLP(nfm_config).cuda()#加了device防止出现GPU CPU两种设备的错误提示
    #print("nfm:",nfm)
    #print(nfm)
    #nfm.train()
    #u=nfm.parameters()
    #print(u)
    #optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    optimizer.zero_grad()
    total = 0
    #loss_func = torch.nn.BCELoss()
    loss_func=torch.nn.CrossEntropyLoss()
    #loss_func=torch.nn.LogSoftmax()
    
    #model=nn.Softmax(nn.Linear(10149,16)).to(device)
    # 从DataLoader中获取小批量的id以及数据
    for epoch_id in range(200):
        correct=0
        total=0
        for batch_idx, (x, labels) in enumerate(train_loader):
            #print("x:",x)
            #print("labels:",labels)
            x = Variable(x)
            labels = Variable(labels)
            
            
            #x = torch.tensor(x, dtype=torch.float)
            #x=x.clone().detach().requires_grad_(True)
            #x=torch.tensor(x,dtype=torch.float)
            x=x.clone().detach().requires_grad_(True)
            #labels=torch.tensor(labels,dtype=torch.float)
            labels=labels.clone().detach().requires_grad_(True)
            x, labels = x.cuda(), labels.cuda()
            
            
            optimizer.zero_grad()
            y_predict = model(x)
            #loss = loss_func(y_predict.view(-1), labels)
            loss = loss_func(y_predict, labels)
            loss.backward()
            optimizer.step()

            loss = loss.item()
            #loss, predicted = self._train_single_batch(x, labels)

            total += loss
            
            
            
            predicted = torch.max(y_predict.data,1)
            #print("predicted:",predicted)
            predicted = torch.max(y_predict.data,1)[1]
            
            
            labels=torch.max(labels,1)
            #print("labels:",labels)
            labels=labels[1]
            
            correct += (predicted == labels).sum()
            #print("correct:",correct)
            #correct=correct[0]
            #print("new_correct:",float(correct))
            #correct=float(correct)   
            #if batch_idx % 10 == 0:
            #print(correct/(BATCH_SIZE*(batch_idx+1)))
            accuracy=correct/((BATCH_SIZE)*(batch_idx+1))
            """
            #y_predict.detach().numpy()
            pred = y_predict
            print("pred:",pred.shape)
            y=labels.clone().detach().requires_grad_(True)
            print("y:",y.shape)
            #y=labels.data.cpu().numpy()
            #y = labels.detach().numpy()
            roc_auc_score(y, pred)
            """
           
            # print('[Training Epoch: {}] Batch: {}, Loss: {}'.format(epoch_id, batch_id, loss))
        print("Training Epoch: %d, total loss: %f, accuracy: %f" % (epoch_id, total,accuracy))
        #print("auc:",roc_auc_score)
path='data/data/guan/gene_4000/models/new_model_param_geng_MLP_non_em_4000_with_smoothing.pkl'
torch.save(model.state_dict(),path)
# Out:
# Training Epoch: 0, total loss: nan, accuracy: 0.076667
# Training Epoch: 1, total loss: nan, accuracy: 0.076667
# Training Epoch: 2, total loss: nan, accuracy: 0.085000
# Training Epoch: 3, total loss: nan, accuracy: 0.081667
# Training Epoch: 4, total loss: nan, accuracy: 0.080000
# Training Epoch: 5, total loss: nan, accuracy: 0.076667
# Training Epoch: 6, total loss: nan, accuracy: 0.080000
# Training Epoch: 7, total loss: nan, accuracy: 0.078333
# Training Epoch: 8, total loss: nan, accuracy: 0.083333
# Training Epoch: 9, total loss: nan, accuracy: 0.083333
# Training Epoch: 10, total loss: nan, accuracy: 0.081667
# Training Epoch: 11, total loss: nan, accuracy: 0.078333
# Training Epoch: 12, total loss: nan, accuracy: 0.085000
# Training Epoch: 13, total loss: nan, accuracy: 0.081667
# Training Epoch: 14, total loss: nan, accuracy: 0.078333
# Training Epoch: 15, total loss: nan, accuracy: 0.081667
# Training Epoch: 16, total loss: nan, accuracy: 0.076667
# Training Epoch: 17, total loss: nan, accuracy: 0.075000
# Training Epoch: 18, total loss: nan, accuracy: 0.086667
# Training Epoch: 19, total loss: nan, accuracy: 0.081667
# Training Epoch: 20, total loss: nan, accuracy: 0.083333
# Training Epoch: 21, total loss: nan, accuracy: 0.086667
# Training Epoch: 22, total loss: nan, accuracy: 0.081667
# Training Epoch: 23, total loss: nan, accuracy: 0.081667
# Training Epoch: 24, total loss: nan, accuracy: 0.080000
# Training Epoch: 25, total loss: nan, accuracy: 0.083333
# Training Epoch: 26, total loss: nan, accuracy: 0.080000
# Training Epoch: 27, total loss: nan, accuracy: 0.081667
# Training Epoch: 28, total loss: nan, accuracy: 0.083333
# Training Epoch: 29, total loss: nan, accuracy: 0.081667
# Training Epoch: 30, total loss: nan, accuracy: 0.075000
# Training Epoch: 31, total loss: nan, accuracy: 0.083333
# Training Epoch: 32, total loss: nan, accuracy: 0.086667
# Training Epoch: 33, total loss: nan, accuracy: 0.086667
# Training Epoch: 34, total loss: nan, accuracy: 0.083333
