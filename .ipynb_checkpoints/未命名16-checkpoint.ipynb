# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':11,
    'linear_hidden1':1000,
    'linear_hidden':100,#线性模型输出层（隐层个数）
    'embed_input_dim':1001,#embed输入维度
    #'embed_dim': 100, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    'embed_dim': 4077, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    'dnn_hidden_units': [1000,100,11],#MLP隐层和输出层
    #'dnn_hidden_units': [11],#MLP隐层和输出层
    'num_sparse_features_cols':4077,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.3,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 100,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    'train_file':'data/frappe/gene_4000/gene_4000_encode.csv',
    'label_file':'data/frappe/gene_4000/label.csv',
    'test_file':'data/frappe/gene_4000/test/test_file.csv',
    'test_label':'data/frappe/gene_4000/test/test_label.csv'
}

# %%
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter

#import network
import config
import evaluate
import data_utils
import Trainer
#from utils import

# %%
#from new_dataset_processed import FMData
from dataset_process import FMData

#train_dataset = FMData(config.train_libfm,config.train_label,nfm_config['n_class'])
train_dataset = FMData(nfm_config['train_file'],nfm_config['label_file'],nfm_config['n_class'])
train_loader = data.DataLoader(train_dataset, drop_last=True,batch_size=100,shuffle=True, num_workers=4)

#validate_dataset = FMData(config.valid_libfm,config.valid_label)
#validate_loader = data.DataLoader(train_dataset, drop_last=True,batch_size=100,shuffle=True, num_workers=4)

#test_dataset = FMData(config.test_libfm,config.test_label)
#test_loader = data.DataLoader(test_dataset, drop_last=True,batch_size=100,shuffle=True, num_workers=4)
# Out:
# [[190 220 490 ... 360 370 420]
#  [110 220 500 ... 340 260 420]
#  [100 300 500 ... 330 350 390]
#  ...
#  [450 360 500 ... 430 360 500]
#  [420 350 530 ... 440 370 500]
#  [420 360 540 ... 430 370 450]]
# row: 0 label: [0]
# row: 1 label: [0]
# row: 2 label: [0]
# row: 3 label: [0]
# row: 4 label: [0]
# row: 5 label: [0]
# row: 6 label: [0]
# row: 7 label: [0]
# row: 8 label: [0]
# row: 9 label: [0]
# row: 10 label: [0]
# row: 11 label: [0]
# row: 12 label: [0]
# row: 13 label: [0]
# row: 14 label: [0]
# row: 15 label: [0]
# row: 16 label: [0]
# row: 17 label: [0]
# row: 18 label: [0]
# row: 19 label: [0]
# row: 20 label: [0]
# row: 21 label: [0]
# row: 22 label: [0]
# row: 23 label: [0]
# row: 24 label: [0]
# row: 25 label: [0]
# row: 26 label: [0]
# row: 27 label: [0]
# row: 28 label: [0]
# row: 29 label: [0]
# row: 30 label: [0]
# row: 31 label: [0]
# row: 32 label: [0]
# row: 33 label: [0]
# row: 34 label: [0]
# row: 35 label: [0]
# row: 36 label: [0]
# row: 37 label: [0]
# row: 38 label: [0]
# row: 39 label: [0]
# row: 40 label: [0]
# row: 41 label: [0]
# row: 42 label: [0]
# row: 43 label: [0]
# row: 44 label: [0]
# row: 45 label: [0]
# row: 46 label: [0]
# row: 47 label: [0]
# row: 48 label: [0]
# row: 49 label: [0]
# row: 50 label: [0]
# row: 51 label: [0]
# row: 52 label: [0]
# row: 53 label: [0]
# row: 54 label: [0]
# row: 55 label: [0]
# row: 56 label: [0]
# row: 57 label: [1]
# row: 58 label: [1]
# row: 59 label: [1]
# row: 60 label: [1]
# row: 61 label: [1]
# row: 62 label: [1]
# row: 63 label: [1]
# row: 64 label: [1]
# row: 65 label: [1]
# row: 66 label: [1]
# row: 67 label: [1]
# row: 68 label: [1]
# row: 69 label: [1]
# row: 70 label: [1]
# row: 71 label: [1]
# row: 72 label: [1]
# row: 73 label: [1]
# row: 74 label: [1]
# row: 209 label: [3]
# row: 210 label: [3]
# row: 211 label: [3]
# row: 212 label: [3]
# row: 213 label: [3]
# row: 214 label: [3]
# row: 215 label: [3]
# row: 216 label: [3]
# row: 217 label: [3]
# row: 218 label: [3]
# row: 219 label: [3]
# row: 220 label: [3]
# row: 221 label: [3]
# row: 222 label: [3]
# row: 223 label: [3]
# row: 224 label: [3]
# row: 225 label: [3]
# row: 226 label: [3]
# row: 227 label: [3]
# row: 228 label: [3]
# row: 229 label: [3]
# row: 230 label: [3]
# row: 231 label: [3]
# row: 232 label: [3]
# row: 233 label: [3]
# row: 234 label: [3]
# row: 235 label: [3]
# row: 236 label: [3]
# row: 237 label: [3]
# row: 238 label: [3]
# row: 239 label: [3]
# row: 240 label: [3]
# row: 241 label: [3]
# row: 242 label: [3]
# row: 243 label: [3]
# row: 244 label: [3]
# row: 245 label: [3]
# row: 246 label: [3]
# row: 247 label: [3]
# row: 248 label: [3]
# row: 249 label: [3]
# row: 250 label: [3]
# row: 251 label: [4]
# row: 252 label: [4]
# row: 253 label: [4]
# row: 254 label: [4]
# row: 255 label: [4]
# row: 256 label: [4]
# row: 257 label: [4]
# row: 258 label: [4]
# row: 259 label: [4]
# row: 260 label: [4]
# row: 261 label: [4]
# row: 262 label: [4]
# row: 263 label: [4]
# row: 264 label: [4]
# row: 265 label: [4]
# row: 266 label: [4]
# row: 267 label: [4]
# row: 268 label: [4]
# row: 269 label: [4]
# row: 270 label: [4]
# row: 271 label: [4]
# row: 272 label: [4]
# row: 273 label: [4]
# row: 274 label: [4]
# row: 275 label: [4]
# row: 276 label: [4]
# row: 277 label: [4]
# row: 278 label: [4]
# row: 279 label: [4]
# row: 280 label: [4]
# row: 281 label: [4]
# row: 282 label: [4]
# row: 283 label: [4]
# row: 284 label: [4]
# row: 285 label: [4]
# row: 286 label: [4]
# row: 287 label: [4]
# row: 288 label: [4]
# row: 289 label: [4]
# row: 290 label: [4]
# row: 291 label: [4]
# row: 292 label: [4]
# row: 293 label: [4]
# row: 294 label: [4]
# row: 295 label: [4]
# row: 296 label: [4]
# row: 297 label: [4]
# row: 298 label: [4]
# row: 299 label: [4]
# row: 300 label: [4]
# row: 301 label: [4]
# row: 302 label: [4]
# row: 303 label: [4]
# row: 304 label: [4]
# row: 305 label: [4]
# row: 306 label: [4]
# row: 307 label: [4]
# row: 308 label: [5]
# row: 309 label: [5]
# row: 310 label: [5]
# row: 311 label: [5]
# row: 312 label: [5]
# row: 313 label: [5]
# row: 314 label: [5]
# row: 315 label: [5]
# row: 316 label: [5]
# row: 317 label: [5]
# row: 318 label: [5]
# row: 319 label: [5]
# row: 320 label: [5]
# row: 321 label: [5]
# row: 322 label: [5]
# row: 323 label: [5]
# row: 324 label: [5]
# row: 325 label: [5]
# row: 326 label: [5]
# row: 327 label: [5]
# row: 328 label: [5]
# row: 329 label: [5]
# row: 330 label: [5]
# row: 331 label: [5]
# row: 332 label: [5]
# row: 333 label: [5]
# row: 334 label: [5]
# row: 335 label: [5]
# row: 336 label: [5]
# row: 337 label: [5]
# row: 338 label: [5]
# row: 339 label: [5]
# row: 340 label: [5]
# row: 341 label: [5]
# row: 609 label: [8]
# row: 610 label: [8]
# row: 611 label: [8]
# row: 612 label: [8]
# row: 613 label: [8]
# row: 614 label: [8]
# row: 615 label: [8]
# row: 616 label: [8]
# row: 617 label: [8]
# row: 618 label: [8]
# row: 619 label: [9]
# row: 620 label: [9]
# row: 621 label: [9]
# row: 622 label: [9]
# row: 623 label: [9]
# row: 624 label: [9]
# row: 625 label: [9]
# row: 626 label: [9]
# row: 627 label: [9]
# row: 628 label: [9]
# row: 629 label: [9]
# row: 630 label: [9]
# row: 631 label: [9]
# row: 632 label: [9]
# row: 633 label: [9]
# row: 634 label: [9]
# row: 635 label: [9]
# row: 636 label: [9]
# row: 637 label: [9]
# row: 638 label: [9]
# row: 639 label: [9]
# row: 640 label: [9]
# row: 641 label: [9]
# row: 642 label: [9]
# row: 643 label: [9]
# row: 644 label: [9]
# row: 645 label: [9]
# row: 646 label: [9]
# row: 647 label: [9]
# row: 648 label: [9]
# row: 649 label: [9]
# row: 650 label: [9]
# row: 651 label: [9]
# row: 652 label: [9]
# row: 653 label: [9]
# row: 654 label: [9]
# row: 655 label: [9]
# row: 656 label: [9]
# row: 657 label: [9]
# row: 658 label: [9]
# row: 659 label: [9]
# row: 660 label: [10]
# row: 661 label: [10]
# row: 662 label: [10]
# row: 663 label: [10]
# row: 664 label: [10]
# row: 665 label: [10]
# row: 666 label: [10]
# row: 667 label: [10]
# row: 668 label: [10]
# row: 669 label: [10]
# row: 670 label: [10]
# row: 671 label: [10]
# row: 672 label: [10]
# row: 673 label: [10]
# row: 674 label: [10]
# row: 675 label: [10]
# row: 676 label: [10]
# row: 677 label: [10]
# row: 678 label: [10]
# row: 679 label: [10]
# row: 680 label: [10]
# row: 681 label: [10]
# row: 682 label: [10]
# row: 683 label: [10]
# row: 684 label: [10]
# row: 685 label: [10]
# row: 686 label: [10]
# row: 687 label: [10]
# row: 688 label: [10]
# row: 689 label: [10]
# row: 690 label: [10]
# row: 691 label: [10]
# row: 692 label: [10]
# row: 693 label: [10]
# row: 694 label: [10]
# row: 695 label: [10]
# row: 696 label: [10]
# row: 697 label: [10]
# row: 698 label: [10]
# row: 699 label: [10]
# row: 700 label: [10]
# row: 701 label: [10]
# row: 702 label: [10]
# row: 703 label: [10]
# row: 704 label: [10]
# row: 705 label: [10]
# row: 706 label: [10]
# row: 707 label: [10]
# row: 708 label: [10]
# row: 709 label: [10]
# row: 710 label: [10]
# row: 711 label: [10]
# row: 712 label: [10]
# row: 713 label: [10]
# row: 714 label: [10]
# row: 715 label: [10]
# row: 716 label: [10]
# row: 717 label: [10]
# row: 718 label: [10]
# row: 719 label: [10]
# row: 720 label: [10]
# row: 721 label: [10]
# row: 722 label: [10]
# row: 723 label: [10]
# row: 724 label: [10]
# row: 725 label: [10]
# row: 726 label: [10]
# row: 727 label: [10]
# row: 728 label: [10]
# row: 729 label: [10]
# row: 730 label: [10]
# row: 731 label: [10]
# row: 732 label: [10]
# row: 733 label: [10]
# row: 734 label: [10]
# row: 735 label: [10]
# row: 736 label: [10]
# row: 737 label: [10]
# row: 738 label: [10]
# row: 739 label: [10]
# row: 740 label: [10]
# row: 741 label: [10]
# row: 742 label: [10]
# row: 743 label: [10]
# row: 744 label: [10]
# row: 745 label: [10]
# row: 746 label: [10]
# row: 747 label: [10]
# row: 748 label: [10]
# row: 749 label: [10]
# row: 750 label: [10]
# row: 751 label: [10]
# row: 752 label: [10]
# row: 753 label: [10]
# row: 754 label: [10]
# row: 755 label: [10]
# row: 756 label: [10]
# row: 757 label: [10]
# row: 758 label: [10]
# row: 759 label: [10]
# label: [[0.8181818  0.01818182 0.01818182 ... 0.01818182 0.01818182 0.01818182]
#  [0.8181818  0.01818182 0.01818182 ... 0.01818182 0.01818182 0.01818182]
#  [0.8181818  0.01818182 0.01818182 ... 0.01818182 0.01818182 0.01818182]
#  ...
#  [0.01818182 0.01818182 0.01818182 ... 0.01818182 0.01818182 0.8181818 ]
#  [0.01818182 0.01818182 0.01818182 ... 0.01818182 0.01818182 0.8181818 ]
#  [0.01818182 0.01818182 0.01818182 ... 0.01818182 0.01818182 0.8181818 ]]
# features: [[33 34 46 ... 28 27 29]
#  [36 35 47 ... 31 26 29]
#  [36 35 46 ... 33 27 29]
#  ...
#  [10 36 38 ... 14 35 32]
#  [ 9 32 42 ... 10 29 36]
#  [ 9 37 46 ... 13 27 33]]

# %%
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
#from new_nfm_network import NFM
from nfm_network_non_embed import NFM
if __name__ == "__main__":
    ####################################################################################
    # NFM 模型
    ####################################################################################
    BATCH_SIZE=100
    """
    training_data, training_label, dense_features_col, sparse_features_col = getTrainData(nfm_config['train_file'], nfm_config['fea_file'])
    train_dataset = Data.TensorDataset(torch.tensor(training_data).float(), torch.tensor(training_label).float())

    test_data = getTestData(nfm_config['test_file'])
    test_dataset = Data.TensorDataset(torch.tensor(test_data).float())
    
    test_data = getTestData(nfm_config['test_file'])
    test_dataset = Data.TensorDataset(torch.tensor(test_data).float())

    """
    #device = torch.device('cuda:0')
    #epoch=0
    
    #model=nn.Linear(10149,16).to(device)
    #model=nn.Linear(10149,16)
    #model=nn.ReLU(nn.Linear(10149,16))#RuntimeError: all elements of input should be between 0 and 1
    #print('model:',model)
    nfm = NFM(nfm_config).cuda()#加了device防止出现GPU CPU两种设备的错误提示
    print("nfm:",nfm)
    #print(nfm)
    #nfm.train()
    #u=nfm.parameters()
    #print(u)
    #optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    optimizer = torch.optim.Adam(nfm.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    total = 0
    #loss_func = torch.nn.BCELoss()
    loss_func=torch.nn.CrossEntropyLoss()
    #loss_func=torch.nn.LogSoftmax()
    
    #model=nn.Softmax(nn.Linear(10149,16)).to(device)
    # 从DataLoader中获取小批量的id以及数据
    for epoch_id in range(1000):
        correct=0
        total=0
        for batch_idx, (x, labels) in enumerate(train_loader):
            x = Variable(x)
            labels = Variable(labels)
            
            
            #x = torch.tensor(x, dtype=torch.float)
            #x=x.clone().detach().requires_grad_(True)
            x=torch.tensor(x,dtype=torch.float)
            labels=torch.tensor(labels,dtype=torch.float)
            x, labels = x.cuda(), labels.cuda()
            
            print("labels:",labels)
            
            optimizer.zero_grad()
            y_predict = nfm(x)
            print("y_predict:",y_predict)
            #loss = loss_func(y_predict.view(-1), labels)
            loss = loss_func(y_predict, labels)
            loss.backward()
            optimizer.step()
            
            loss = loss.item()
            #loss, predicted = self._train_single_batch(x, labels)

            total += loss
            
            
            
            predicted = torch.max(y_predict.data,1)
            #print("predicted:",predicted)
            predicted = torch.max(y_predict.data,1)[1]
            
            
            labels=torch.max(labels,1)
            #print("labels:",labels)
            labels=labels[1]
            
            correct += (predicted == labels).sum()
            #print("correct:",correct)
            #correct=correct[0]
            print("new_correct:",float(correct))
            correct=float(correct)   
            #if batch_idx % 10 == 0:
            print("batch_idx:",batch_idx)
            print(correct/(BATCH_SIZE*(batch_idx+1)))
            
            """
            #y_predict.detach().numpy()
            pred = y_predict
            print("pred:",pred.shape)
            y=labels.clone().detach().requires_grad_(True)
            print("y:",y.shape)
            #y=labels.data.cpu().numpy()
            #y = labels.detach().numpy()
            roc_auc_score(y, pred)
            """
           
            # print('[Training Epoch: {}] Batch: {}, Loss: {}'.format(epoch_id, batch_id, loss))
        print("Training Epoch: %d, total loss: %f" % (epoch_id, total))
        #print("auc:",roc_auc_score)
#功能：保存训练完的网络的各层参数（即weights和bias)
path='data/frappe/model/new_model_param_gene_4000.pkl'
torch.save(nfm.state_dict(),path)
# Out:
# nfm: NFM(
#   (drop): Dropout(p=0.7, inplace=False)
#   (linear_model): Linear(in_features=4077, out_features=100, bias=True)
#   (BN_linear): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bi_pooling): BiInteractionPooling()
#   (dropout): Dropout(p=0.3, inplace=False)
#   (BN_bi): BatchNorm1d(4077, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dnn_layers): ModuleList(
#     (0): Linear(in_features=4177, out_features=1000, bias=True)
#     (1): Linear(in_features=1000, out_features=100, bias=True)
#     (2): Linear(in_features=100, out_features=11, bias=True)
#   )
#   (dnn_softmax): Softmax(dim=1)
# )
# labels: tensor([[0.8182, 0.0182, 0.0182,  ..., 0.0182, 0.0182, 0.0182],
#         [0.0182, 0.0182, 0.0182,  ..., 0.0182, 0.0182, 0.8182],
#         [0.0182, 0.0182, 0.0182,  ..., 0.0182, 0.0182, 0.0182],
#         ...,
#         [0.0182, 0.0182, 0.0182,  ..., 0.8182, 0.0182, 0.0182],
#         [0.0182, 0.0182, 0.0182,  ..., 0.8182, 0.0182, 0.0182],
#         [0.0182, 0.0182, 0.0182,  ..., 0.8182, 0.0182, 0.0182]],
#        device='cuda:0')
# linear_output: tensor([[ -6.7100,  41.7650, -29.0571,  ...,  22.0551,  43.9981,  32.7506],
#         [-12.1801,  39.9888, -27.8847,  ...,  21.3014,  29.0353,  26.4453],
#         [-10.2936,  36.2905, -22.8994,  ...,  20.6690,  34.5542,  28.3138],
#         ...,
#         [-11.7070,  39.0614, -23.7832,  ...,  21.4648,  35.9182,  26.0499],
#         [-11.1806,  39.0967, -22.8235,  ...,  21.3718,  32.0413,  26.0543],
#         [ -8.1210,  37.8747, -25.0760,  ...,  19.0994,  35.2546,  28.2821]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/ipykernel_launcher.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/ipykernel_launcher.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-e7a51e8a1350> in <module>
#      59
#      60             optimizer.zero_grad()
# ---> 61             y_predict = nfm(x)
#      62             print("y_predict:",y_predict)
#      63             #loss = loss_func(y_predict.view(-1), labels)
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/NFM-pyorch-master/NFM-pyorch-master/nfm_network_non_embed.py in forward(self, x)
#     103
#     104         #fm_input=[sparse_inputs[:, i] for i in range(sparse_inputs.shape[1])]
# --> 105         fm_input=sparse_inputs
#     106         #fm_input=fm_input.view(-1,self.num_sparse_feature,self.__config['embed_dim'])
#     107
#
# RuntimeError: shape '[-1, 4077, 4077]' is invalid for input of size 407700
