# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':800,#线性模型输出层（隐层个数）
    'embed_input_dim':20,#embed输入维度
    'embed_dim': 10, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    'dnn_hidden_units': [50,9],#MLP隐层和输出层
    'num_sparse_features_cols':3300,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 24,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'train_label': 'dataset/gene_247/train/guan_train_label.csv',
    'train_data':'dataset/gene_247/train/guan_train_data.csv',
    'test_label':'dataset/gene_247/test/qiu_test_label.csv',
    'test_data':'dataset/gene_247/test/qiu_test_data.csv',
    'gene_name':'dataset/qiuguan/origin_800/gene_name.csv',
    'label_name':'dataset/qiuguan/origin_800/gene_label.csv'
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
}


import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import torch.nn.functional as F  # 激励函数的库
#import network
import config
import evaluate
import data_utils
#import Trainer



def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    #n = len(labels)
    n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output

def one_hot(labels, classes):
    n = len(labels)
    #eoff = label_smoothing / classes
    output = np.zeros((n, classes), dtype=np.float32)
    for row, label in enumerate(labels):
        output[row, label] = 1
        #print("row:",row,"label:",label)
    return output

class KZDatasetPredict(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, csv_path):
    
       
        self.data_info = self.get_data_info(csv_path)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, bi_data,label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, bi_data,label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,df_list):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        
        #df=pd.read_csv(csv_path,sep=',')
        #df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        labels=df_list[-1]
        data=df_list[:-1]
        #df_np=np.array(df_list)
        #print(rows,cols)
        
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        
           
        
        data=np.array(data)#
            
            
            
            
            
            
            
            
        data=torch.from_numpy(data)#
            
        labels=torch.from_numpy(labels)#
        bi_data=embding_process(nfm_config,data)
        #print("bi_data.shape:",bi_data.shape)
            
            
        data_info.append(data,bi_data,label)
        return data_info
    
class KZDatasetTest(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, csv_path):
    
       
        self.data_info = self.get_data_info(csv_path)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, bi_data,label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, bi_data,label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        #print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]#data
            data=data.astype(float)#
            data=np.array(data)#
            
            
            #data=torch.from_numpy(data)
            
            
            
            
            label=labels[i]#label
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            #print("data.shape:",data.shape)
            label=torch.from_numpy(label)#
            bi_data=embding_process(nfm_config,data)
            #print("bi_data.shape:",bi_data.shape)
            
            
            data_info.append((data,bi_data,label))
        return data_info
    
    
    
import torch
import torch.nn as nn
from torch.utils.data.dataset import *
from PIL import Image
from torch.nn import functional as F
import random
from sklearn.model_selection import train_test_split
import ast
import torchvision


        

class KZDataset(Dataset):
    def __init__(self, csv_path, K,n_class,ki=0, typ='train', transform=None, rand=False):
        
        self.all_data_info = self.get_data_info(csv_path)
        
        if rand:
            random.seed(1)
            random.shuffle(self.all_data_info)
        leng = len(self.all_data_info)
        every_z_len = leng // K
        if typ == 'val':
            self.data_info = self.all_data_info[every_z_len * ki : every_z_len * (ki+1)]
        elif typ == 'train':
            self.data_info = self.all_data_info[: every_z_len * ki] + self.all_data_info[every_z_len * (ki+1) :]
            
        self.transform = transform
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, bi_data,label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, bi_data,label

    def __len__(self):
        return len(self.data_info)
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        #print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]#data
            data=data.astype(float)#
            data=np.array(data)#
            
            
            #data=torch.from_numpy(data)
            
            
            
            
            label=labels[i]#label
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            #print("data.shape:",data.shape)
            label=torch.from_numpy(label)#
            bi_data=embding_process(nfm_config,data)
            #print("bi_data.shape:",bi_data.shape)
           
            
            data_info.append((data,bi_data,label))
        return data_info
            

import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn


import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics
#import network
import config
import evaluate
import data_utils
import Trainer
#from utils import 
#准备训练集
#from new_dataset_processed import FMData
#from dataset_process import FMData
def train_epoch(model,train_loader,batch_size,optimizer,loss_func):
    BATCH_SIZE=batch_size
    total = 0
    correct=0
    total_loss=0
    #
    total_train_accuracy=0  
    model.train()
    for batch_idx, (x, bi_x,labels) in enumerate(train_loader):
            
        x = Variable(x)
        bi_x=Variable(bi_x)
        labels = Variable(labels)
            
            
        #x = torch.tensor(x, dtype=torch.float)
        #x=x.clone().detach().requires_grad_(True)
        x=torch.tensor(x,dtype=torch.float)
        bi_x=torch.tensor(bi_x,dtype=torch.long)
        labels=torch.tensor(labels,dtype=torch.float)
        x, bi_x,labels = x.cuda(), bi_x.cuda(),labels.cuda()
        labels_int=labels=torch.max(labels,1)[1]
            
        optimizer.zero_grad()
        y_predict = model(x,bi_x)
            
        loss = loss_func(y_predict, labels)
        loss.backward()
        optimizer.step()
            
        loss = loss.item()
           

        total_loss += loss
            
            
            
        batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
        total_train_accuracy+=batch_train_acc
            
    total_train_accuracy/=(batch_idx+1)
    print('total_train_accuracy:',total_train_accuracy)
    print("Training Epoch: %d, total loss: %f" % (epoch_id, total_loss))
    return total_loss,total_train_accuracy



def val_epoch(model,test_loader,batch_size,optimizer): 
    batch_size_num=0
    total_test_acc=0
    model.eval()
    for i , (inputs ,bi_inputs, targets) in enumerate(test_loader):   
            print("test")
            # evaluate the model on the test set   
            #print(\ inputs:\  inputs)   
            #print(\ targets:\  targets)   
            inputs = Variable(inputs)   
            bi_inputs=Variable(bi_inputs)
            targets = Variable(targets)     
            #x = torch.tensor(x  dtype=torch.float)   
            #x=x.clone().detach().requires_grad_(True)   
            inputs=torch.tensor(inputs ,dtype=torch.float)  
            bi_inputs=torch.tensor(bi_inputs,dtype=torch.float)
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs ,bi_inputs,targets = inputs.cuda(),bi_inputs.cuda(), targets.cuda()   
            yhat = model(inputs,bi_inputs)   
            
            
            
            targets=torch.max(targets,1)[1]
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            
            total_test_acc+=batch_test_acc
            
            batch_size_num=i
    total_test_acc/=(batch_size_num+1)
        ###print('total_test_accuracy:',total_test_acc/(batch_size+1))
    print('total_test_accuracy:',total_test_acc)
        
    return total_test_acc




import torch.nn as nn
class BiInteractionPooling(nn.Module):
    """Bi-Interaction Layer used in Neural FM,compress the
      pairwise element-wise product of features into one single vector.
      Input shape
        - A 3D tensor with shape:``(batch_size,field_size,embedding_size)``.
      Output shape
    http://127.0.0.1:3000/notebooks/NFM-pyorch-master/NFM-pyorch-master/%E6%9C%AA%E5%91%BD%E5%90%8D5.ipynb?kernel_name=python3#    - 3D tensor with shape: ``(batch_size,1,embedding_size)``.
    """
    def __init__(self):
        super(BiInteractionPooling, self).__init__()

    def forward(self, inputs):
        concated_embeds_value = inputs
        square_of_sum = torch.pow(
            torch.sum(concated_embeds_value, dim=1, keepdim=True), 2)
        sum_of_square = torch.sum(
            concated_embeds_value * concated_embeds_value, dim=1, keepdim=True)
        cross_term = 0.5 * (square_of_sum - sum_of_square)
        return cross_term

import torch.nn as nn
class BiInteractionPooling(nn.Module):
    """Bi-Interaction Layer used in Neural FM,compress the
      pairwise element-wise product of features into one single vector.
      Input shape
        - A 3D tensor with shape:``(batch_size,field_size,embedding_size)``.
      Output shape
    http://127.0.0.1:3000/notebooks/NFM-pyorch-master/NFM-pyorch-master/%E6%9C%AA%E5%91%BD%E5%90%8D5.ipynb?kernel_name=python3#    - 3D tensor with shape: ``(batch_size,1,embedding_size)``.
    """
    def __init__(self):
        super(BiInteractionPooling, self).__init__()

    def forward(self, inputs):
        concated_embeds_value = inputs
        #print("bi_interaction compute:")
        #print("inputs:",inputs.shape)
        square_of_sum = torch.pow(
            torch.sum(concated_embeds_value, dim=1, keepdim=True), 2)
        #print("square_of_sum：",square_of_sum.shape)
        sum_of_square = torch.sum(
            concated_embeds_value * concated_embeds_value, dim=1, keepdim=True)
        #print("sum_of_square:",sum_of_square.shape)
        cross_term = 0.5 * (square_of_sum - sum_of_square)
        #print("cross_term:",cross_term.shape)
        return cross_term
    
    
def embding_process(config,sparse_inputs):
    #sparse_inputs=torch.tensor(sparse_inputs)
    #sparse_inputs=torch.tensor(sparse_inputs,dtype=torch.int8)
    sparse_inputs=sparse_inputs.int()
    embedding_layers=nn.Embedding(config['embed_input_dim'],config['embed_dim'])
    #print("sparse_inputs:",sparse_inputs.shape)   
    # B-Interaction 层
    bi_pooling = BiInteractionPooling()
    bi_dropout = config['bi_dropout']
    if bi_dropout > 0:
        dropout = nn.Dropout(bi_dropout)
            
    num_sparse_feature=config['num_sparse_features_cols']
    
   
    
    
    
    
        
        
    sparse_embeds = embedding_layers(sparse_inputs) 
    #sparse_embeds=np.array(sparse_embeds)
    #print('sparse_embeds.shape:',sparse_embeds.shape)
    sparse_embeds=sparse_embeds.detach().numpy()
    sparse_embeds=sparse_embeds.T
    sparse_embeds=torch.from_numpy(sparse_embeds)
    #sparse_embeds =[ torch.cat((sparse_embeds[i]), axis=0) for i  in range(sparse_embeds.shape[0])]
    #print("sparse_embeds:",sparse_embeds)
    #print("sparse_numpy.T.shape:",sparse_embeds.shape)
    
    #BN_bi = nn.BatchNorm1d(config['embed_dim'])
    # 送入B-Interaction层
    #fm_input = sparse_embeds.view(-1, num_sparse_feature, config['embed_dim'])#整理成n行m列
    fm_input=sparse_embeds
    # print(fm_input)
    # print(fm_input.shape)
    #print("fm_input:",fm_input)

    bi_out = bi_pooling(fm_input)
    
    #print("bi_out.shape:",bi_out.shape)
    bi_out=bi_out.detach().numpy()
    bi_out=bi_out.T
    bi_out=torch.from_numpy(bi_out)
    #print("bi_out.T.shape:",bi_out.shape)
    
    bi_out = bi_out.view(-1)###
    if bi_dropout:
        bi_out = dropout(bi_out)
    #bi_out = bi_out.unsqueeze(0)
    #
    #print("bi_out_view.shape:",bi_out.shape)
    #bi_out=BN_bi(bi_out)########
    
    
    return bi_out


import torch
import torch.nn as nn
from basemodel import BaseModel
import torch.nn.functional as F



    



class NFM(BaseModel):
    def __init__(self, config, dense_features_cols=[]):#=[]为新增
    #def __init__(self, config, dense_features_cols, sparse_features_cols):
        super(NFM, self).__init__(config)
        # 稠密和稀疏特征的数量
        #self.num_dense_feature = dense_features_cols.__len__()
        self.num_dense_feature = 0#修改
        self.num_sparse_feature = config['num_sparse_features_cols']
        #self.num_sparse_feature = 0##修改
        self.__config=config
        
        self.bi_BN=nn.BatchNorm1d(nfm_config['embed_dim'])
        
        self.BN_num=nn.BatchNorm1d(self.num_sparse_feature)
        self.linear1=nn.Linear(config['num_sparse_features_cols'],config['linear_hidden1'])
        self.bn1=nn.BatchNorm1d(config['linear_hidden1'])
        self.drop1=nn.Dropout(0.5)
        self.relu1=nn.ReLU()
        
        self.linear2=nn.Linear(config['linear_hidden1']+config['embed_dim'],config['dnn_hidden_units'][0])
        self.bn2=nn.BatchNorm1d(config['dnn_hidden_units'][0])
        self.drop2=nn.Dropout(0.5)
        self.relu2=nn.ReLU()
        
        self.linear3=nn.Linear(config['dnn_hidden_units'][0],config['dnn_hidden_units'][1])
        self.bn3=nn.BatchNorm1d(config['dnn_hidden_units'][1])
        #self.drop3=nn.Dropout(0.3)
        self.relu3=nn.ReLU()
        
        #self.embedding_layers=nn.Embedding(config['embed_input_dim'],config['embed_dim'])
        
        
            
            
        
        
        
        #self.dnn_softmax=nn.Softmax(dim=1) # 按列SoftMax,列和为1  #注意nn.softmax的定义和调用
        #self.dnn_softmax_=F.softmax(dim=1)
        #self.dnn_hidden_units=config['dnn_hidden_units']
    def forward(self, x,bi_x):
        # 先区分出稀疏特征和稠密特征，这里是按照列来划分的，即所有的行都要进行筛选
        #bi_x=bi_x.long()
        #print(x.dtype)
        # 求出线性部分
        #x=F.relu(self.drop(self.BN_linear1(self.linear_model1(self.BN_num(x))))
        #x=F.relu(self.drop(self.BN_linear1(self.linear_model1(x))))
        #print("x,,bi_x",x.shape,bi_x.shape)
        x=self.BN_num(x)#####
        #print("x_BN:",bi_x.shape)
        #x=self.linear_model1(x)
        
        #x1=torch.cat((x,bi_x),dim=1)
        #print("linear_output:",linear_output)
        #linear_output=linear_output.view(-1,self.__config['linear_hidden1'])
        #linear_output=self.drop(linear_output)
        #linear_output=self.BN_linear(linear_output)
        # 求出稀疏特征的embedding向量
        
        
        #print('bi_out.shape:',bi_out.shape)
        #print(x.dtype)
        #print(bi_out.dtype)
        
        #input=x,bi_x#不能是list，必须是tensor
        #x1,x2=input
        y1=self.relu1(self.drop1(self.bn1(self.linear1(x))))
        bi_x=torch.tensor(bi_x,dtype=torch.float)#######
        bi_x=self.bi_BN(bi_x)####
        x2=torch.cat((y1,bi_x),dim=1)
        #print('y1.shape:',y1.shape)
        y2=self.relu2(self.drop2(self.bn2(self.linear2(x2))))
        #x3=torch.cat((y2,bi_x),dim=1)
        #print('y2.shape:',y2.linear3(y2)))
        #print('y3.shape:',y3.shape)
        y3=self.relu3(self.bn3(self.linear3(y2)))
        y=F.softmax(y3,dim=1)
        #x3=torch.cat((y2,bi_x),dim=1)
        #x3=torch.cat((y2,bi_x),dim=1)
        #print('x3.shape:',x3.shape)
        
        
        y_pred=y
        #y_pred=self.dnn_softmax(dnn_output)#增加
        #y_pred=F.softmax(dnn_output,dim=0)
        # Final
        #output = linear_output + y_pred#修改
        #y_pred = self.dnn_softmax(output,dim=0)

        return y_pred
    
nfm = NFM(nfm_config).cuda()
nfm.cuda()
nfm_params = list(nfm.named_parameters())
#print(nfm_params[1])

import numpy as np
import math
import matplotlib.pyplot as plt

def plotLoss(loss,epoch):
    plt.rcParams['font.sans-serif']=['SimHei']
    plt.rcParams['axes.unicode_minus'] = False
    plt.figure(figsize=(8, 5))
    x=[i for i in range(epoch)]
    #acc_train=acc_train.cpu()
    #acc_test=acc_test.cpu()
    plt.plot(x, loss, 'r-', mec='k', label='Logistic Loss', lw=2)
    #plt.plot(x,acc_train,'b-',mec='k',label='accuracy Train',lw=2)
    #plt.plot(x,acc_test,'g-',mec='k',label='accuracy Test',lw=2)
    #plt.plot(x, y_01, 'g-', mec='k', label='0/1 Loss', lw=2)
    #plt.plot(x, y_hinge, 'b-',mec='k', label='Hinge Loss', lw=2)
    #plt.plot(x, boost, 'm--',mec='k', label='Adaboost Loss',lw=2)
    plt.grid(True, ls='--')
    plt.legend(loc='upper right')
    plt.title('损失函数')
    plt.show()

# %%
model=nfm
K=10
test_metrics=[]
train_loss_total_list=[]
for ki in range(K):
    trainset = KZDataset(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/train_val_info.csv',K=K, n_class=nfm_config['n_class'],ki=ki,  typ='train', transform=None, rand=True)
    valset = KZDataset(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/train_val_info.csv', K=K,n_class=nfm_config['n_class'],ki=ki,  typ='val', transform=None, rand=True)
    train_loader = data.DataLoader(
         dataset=trainset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size'],
         shuffle=True)
    val_loader = data.DataLoader(
         dataset=valset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
    
    model_path='models/NFM_layer_2/'
    #BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    #total = 0
    
    
    loss_func=torch.nn.CrossEntropyLoss()
    
    num=0
   
    
    epoches=101
    for epoch_id in range(epoches):
          
        
        
        train_loss_total,acc_train=train_epoch(model,train_loader,nfm_config['batch_size'],optimizer,loss_func)
        train_loss_total_list.append(train_loss_total)#
        if epoch_id %20==0:
            num=num+1
            #path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pkl')
            #torch.save(model.state_dict(),path)
            # 保存模型
            
            path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pt')##################pt
            torch.save(model.state_dict(),path)
            #torch.save(model.state_dict(),path)
    print("the ",ki," epoch ends")
    plotLoss(train_loss_total_list,epoches)
    train_loss_total_list=[]
    acc_test=val_epoch(model,val_loader,nfm_config['batch_size'],optimizer)
    print("acc_test_each_k:",acc_test)
    test_metrics.append(acc_test)

print(test_metrics)
#test_metrics=test_metrics.tolist()
test_metrics=[x.cpu().detach().numpy() for x in test_metrics]
print(test_metrics)
acc_test_metrics=np.mean(test_metrics) 
print("acc_test_metrics:",acc_test_metrics)
# Out:
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:318: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:319: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:320: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:573: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.1229, device='cuda:0')
# Training Epoch: 0, total loss: 43.944928
# total_train_accuracy: tensor(0.1792, device='cuda:0')
# Training Epoch: 1, total loss: 43.537130
# total_train_accuracy: tensor(0.2250, device='cuda:0')
# Training Epoch: 2, total loss: 43.212914
# total_train_accuracy: tensor(0.2250, device='cuda:0')
# Training Epoch: 3, total loss: 43.075110
# total_train_accuracy: tensor(0.2896, device='cuda:0')
# Training Epoch: 4, total loss: 42.728556
# total_train_accuracy: tensor(0.2750, device='cuda:0')
# Training Epoch: 5, total loss: 42.671942
# total_train_accuracy: tensor(0.3208, device='cuda:0')
# Training Epoch: 6, total loss: 42.262836
# total_train_accuracy: tensor(0.3542, device='cuda:0')
# Training Epoch: 7, total loss: 41.928217
# total_train_accuracy: tensor(0.4000, device='cuda:0')
# Training Epoch: 8, total loss: 41.526464
# total_train_accuracy: tensor(0.3896, device='cuda:0')
# Training Epoch: 9, total loss: 41.714628
# total_train_accuracy: tensor(0.4333, device='cuda:0')
# Training Epoch: 10, total loss: 41.079594
# total_train_accuracy: tensor(0.4396, device='cuda:0')
# Training Epoch: 11, total loss: 40.872550
# total_train_accuracy: tensor(0.4813, device='cuda:0')
# Training Epoch: 12, total loss: 40.543836
# total_train_accuracy: tensor(0.4771, device='cuda:0')
# Training Epoch: 13, total loss: 40.446860
# total_train_accuracy: tensor(0.5146, device='cuda:0')
# Training Epoch: 14, total loss: 39.959445
# total_train_accuracy: tensor(0.5396, device='cuda:0')
# Training Epoch: 15, total loss: 39.687660
# total_train_accuracy: tensor(0.5708, device='cuda:0')
# Training Epoch: 16, total loss: 39.352036
# total_train_accuracy: tensor(0.5750, device='cuda:0')
# Training Epoch: 17, total loss: 39.154900
# total_train_accuracy: tensor(0.5896, device='cuda:0')
# Training Epoch: 18, total loss: 38.794018
# total_train_accuracy: tensor(0.6062, device='cuda:0')
# Training Epoch: 19, total loss: 38.665974
# total_train_accuracy: tensor(0.5958, device='cuda:0')
# Training Epoch: 20, total loss: 38.245824
# total_train_accuracy: tensor(0.5792, device='cuda:0')
# Training Epoch: 21, total loss: 38.434465
# total_train_accuracy: tensor(0.5958, device='cuda:0')
# Training Epoch: 22, total loss: 38.130447
# total_train_accuracy: tensor(0.6062, device='cuda:0')
# Training Epoch: 23, total loss: 38.056564
# total_train_accuracy: tensor(0.6125, device='cuda:0')
# Training Epoch: 24, total loss: 37.853485
# total_train_accuracy: tensor(0.6250, device='cuda:0')
# Training Epoch: 25, total loss: 37.747318
# total_train_accuracy: tensor(0.6396, device='cuda:0')
# Training Epoch: 26, total loss: 37.409205
# total_train_accuracy: tensor(0.6583, device='cuda:0')
# Training Epoch: 27, total loss: 37.151175
# total_train_accuracy: tensor(0.6542, device='cuda:0')
# Training Epoch: 28, total loss: 37.149333
# total_train_accuracy: tensor(0.6813, device='cuda:0')
# Training Epoch: 29, total loss: 36.628451
# total_train_accuracy: tensor(0.6750, device='cuda:0')
# Training Epoch: 30, total loss: 36.686540
# total_train_accuracy: tensor(0.6667, device='cuda:0')
# Training Epoch: 31, total loss: 36.524726
# total_train_accuracy: tensor(0.6854, device='cuda:0')
# Training Epoch: 32, total loss: 36.470987
# total_train_accuracy: tensor(0.7146, device='cuda:0')
# Training Epoch: 33, total loss: 35.851020
# total_train_accuracy: tensor(0.7000, device='cuda:0')
# Training Epoch: 34, total loss: 36.308582
# total_train_accuracy: tensor(0.7333, device='cuda:0')
# Training Epoch: 35, total loss: 35.827205
# total_train_accuracy: tensor(0.7229, device='cuda:0')
# Training Epoch: 36, total loss: 35.768279
# total_train_accuracy: tensor(0.7375, device='cuda:0')
# Training Epoch: 37, total loss: 35.411419
# total_train_accuracy: tensor(0.7625, device='cuda:0')
# Training Epoch: 38, total loss: 35.257690
# total_train_accuracy: tensor(0.7250, device='cuda:0')
# Training Epoch: 39, total loss: 35.516760
# total_train_accuracy: tensor(0.7167, device='cuda:0')
# Training Epoch: 40, total loss: 35.546624
# total_train_accuracy: tensor(0.7479, device='cuda:0')
# Training Epoch: 41, total loss: 35.136437
# total_train_accuracy: tensor(0.7729, device='cuda:0')
# Training Epoch: 42, total loss: 34.846406
# total_train_accuracy: tensor(0.7333, device='cuda:0')
# Training Epoch: 43, total loss: 35.440197
# total_train_accuracy: tensor(0.7521, device='cuda:0')
# Training Epoch: 44, total loss: 35.222984
# total_train_accuracy: tensor(0.7688, device='cuda:0')
# Training Epoch: 45, total loss: 34.726601
# total_train_accuracy: tensor(0.7646, device='cuda:0')
# Training Epoch: 46, total loss: 34.771578
# total_train_accuracy: tensor(0.7875, device='cuda:0')
# Training Epoch: 47, total loss: 34.476119
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 48, total loss: 34.227697
# total_train_accuracy: tensor(0.8063, device='cuda:0')
# Training Epoch: 49, total loss: 34.082624
# total_train_accuracy: tensor(0.7917, device='cuda:0')
# Training Epoch: 50, total loss: 34.186072
# total_train_accuracy: tensor(0.7854, device='cuda:0')
# Training Epoch: 51, total loss: 34.386490
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 52, total loss: 34.033607
# total_train_accuracy: tensor(0.7583, device='cuda:0')
# Training Epoch: 53, total loss: 34.660849
# total_train_accuracy: tensor(0.7875, device='cuda:0')
# Training Epoch: 54, total loss: 33.943295
# total_train_accuracy: tensor(0.7667, device='cuda:0')
# Training Epoch: 55, total loss: 34.244779
# total_train_accuracy: tensor(0.7625, device='cuda:0')
# Training Epoch: 56, total loss: 34.345720
# total_train_accuracy: tensor(0.8042, device='cuda:0')
# Training Epoch: 57, total loss: 34.033279
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 58, total loss: 33.611768
# total_train_accuracy: tensor(0.7875, device='cuda:0')
# Training Epoch: 59, total loss: 33.891276
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# Training Epoch: 60, total loss: 33.329740
# total_train_accuracy: tensor(0.8333, device='cuda:0')
# Training Epoch: 61, total loss: 33.308355
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# Training Epoch: 62, total loss: 33.726917
# total_train_accuracy: tensor(0.8479, device='cuda:0')
# Training Epoch: 63, total loss: 33.240670
# total_train_accuracy: tensor(0.8271, device='cuda:0')
# Training Epoch: 64, total loss: 33.143953
# total_train_accuracy: tensor(0.8562, device='cuda:0')
# Training Epoch: 65, total loss: 33.106160
# total_train_accuracy: tensor(0.8208, device='cuda:0')
# Training Epoch: 66, total loss: 33.536951
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# Training Epoch: 67, total loss: 33.278523
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 68, total loss: 33.028299
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 69, total loss: 33.103593
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 70, total loss: 32.730910
# total_train_accuracy: tensor(0.8333, device='cuda:0')
# Training Epoch: 71, total loss: 33.135037
# total_train_accuracy: tensor(0.8563, device='cuda:0')
# Training Epoch: 72, total loss: 32.724244
# total_train_accuracy: tensor(0.8646, device='cuda:0')
# Training Epoch: 73, total loss: 32.576395
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 74, total loss: 32.792423
# total_train_accuracy: tensor(0.8083, device='cuda:0')
# Training Epoch: 75, total loss: 33.086920
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 76, total loss: 32.814864
# total_train_accuracy: tensor(0.8542, device='cuda:0')
# Training Epoch: 77, total loss: 32.729287
# total_train_accuracy: tensor(0.8542, device='cuda:0')
# Training Epoch: 78, total loss: 32.784512
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 79, total loss: 32.252469
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 80, total loss: 32.473749
# total_train_accuracy: tensor(0.8625, device='cuda:0')
# Training Epoch: 81, total loss: 32.314571
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 82, total loss: 31.989805
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 83, total loss: 32.287435
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 84, total loss: 31.863866
# total_train_accuracy: tensor(0.8563, device='cuda:0')
# Training Epoch: 85, total loss: 32.333874
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 86, total loss: 32.027349
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 87, total loss: 31.934096
# total_train_accuracy: tensor(0.8729, device='cuda:0')
# Training Epoch: 88, total loss: 32.026612
# total_train_accuracy: tensor(0.8812, device='cuda:0')
# Training Epoch: 89, total loss: 31.849254
# total_train_accuracy: tensor(0.8813, device='cuda:0')
# Training Epoch: 90, total loss: 31.758402
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 91, total loss: 31.815628
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# Training Epoch: 92, total loss: 31.759993
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 93, total loss: 31.925821
# total_train_accuracy: tensor(0.8729, device='cuda:0')
# Training Epoch: 94, total loss: 31.824908
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 95, total loss: 31.508384
# total_train_accuracy: tensor(0.8729, device='cuda:0')
# Training Epoch: 96, total loss: 31.956025
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# Training Epoch: 97, total loss: 31.604147
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 98, total loss: 31.792007
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 99, total loss: 31.990332
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# total_train_accuracy: tensor(0.8854, device='cuda:0')
# Training Epoch: 100, total loss: 31.612998
# the  0  epoch ends
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:362: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:363: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:364: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# test
# test
# total_test_accuracy: tensor(0.7917, device='cuda:0')
# acc_test_each_k: tensor(0.7917, device='cuda:0')
# total_train_accuracy: tensor(0.8646, device='cuda:0')
# Training Epoch: 0, total loss: 31.977997
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 1, total loss: 32.126445
# total_train_accuracy: tensor(0.8667, device='cuda:0')
# Training Epoch: 2, total loss: 31.850750
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 3, total loss: 31.646194
# total_train_accuracy: tensor(0.8667, device='cuda:0')
# Training Epoch: 4, total loss: 31.592961
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 5, total loss: 31.820746
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 6, total loss: 31.360589
# total_train_accuracy: tensor(0.8729, device='cuda:0')
# Training Epoch: 7, total loss: 31.412452
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 8, total loss: 31.800488
# total_train_accuracy: tensor(0.8667, device='cuda:0')
# Training Epoch: 9, total loss: 31.776094
# total_train_accuracy: tensor(0.8813, device='cuda:0')
# Training Epoch: 10, total loss: 31.531604
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 11, total loss: 31.499957
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 12, total loss: 31.309843
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 13, total loss: 31.418795
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 14, total loss: 30.804336
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 15, total loss: 31.341108
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 16, total loss: 31.116547
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 17, total loss: 31.316903
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 18, total loss: 31.215749
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 19, total loss: 31.108826
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 20, total loss: 31.486517
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 21, total loss: 31.113356
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 22, total loss: 31.149388
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 23, total loss: 30.835691
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 24, total loss: 31.197664
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 25, total loss: 31.504115
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 26, total loss: 31.303148
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 27, total loss: 31.163546
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 28, total loss: 30.959963
# total_train_accuracy: tensor(0.8667, device='cuda:0')
# Training Epoch: 29, total loss: 31.421364
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 30, total loss: 31.056478
# total_train_accuracy: tensor(0.8854, device='cuda:0')
# Training Epoch: 31, total loss: 30.997546
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 32, total loss: 30.608358
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 33, total loss: 30.394556
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 34, total loss: 30.480725
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 35, total loss: 30.466101
# total_train_accuracy: tensor(0.8667, device='cuda:0')
# Training Epoch: 36, total loss: 31.470620
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 37, total loss: 30.864337
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 38, total loss: 31.049717
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 39, total loss: 30.760027
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 40, total loss: 30.802199
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 41, total loss: 30.900482
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 42, total loss: 30.727029
# total_train_accuracy: tensor(0.9062, device='cuda:0')
# Training Epoch: 43, total loss: 30.647636
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# Training Epoch: 44, total loss: 31.200725
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 45, total loss: 30.481199
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 46, total loss: 30.315459
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 47, total loss: 30.531163
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 48, total loss: 30.397670
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 49, total loss: 30.497527
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 50, total loss: 30.447708
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 51, total loss: 30.926431
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 52, total loss: 30.727490
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 53, total loss: 30.807491
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 54, total loss: 31.049968
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 55, total loss: 30.842047
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 56, total loss: 30.476220
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 57, total loss: 30.859425
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 58, total loss: 30.250986
# total_train_accuracy: tensor(0.9062, device='cuda:0')
# Training Epoch: 59, total loss: 30.601287
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 60, total loss: 30.774770
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 61, total loss: 30.051303
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 62, total loss: 30.401501
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 63, total loss: 30.016686
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 64, total loss: 30.049685
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 65, total loss: 29.880574
# total_train_accuracy: tensor(0.9062, device='cuda:0')
# Training Epoch: 66, total loss: 30.482574
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 67, total loss: 30.256105
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 68, total loss: 29.959679
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 69, total loss: 30.155781
# total_train_accuracy: tensor(0.9187, device='cuda:0')
# Training Epoch: 70, total loss: 30.397166
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 71, total loss: 30.490295
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 72, total loss: 29.941161
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 73, total loss: 29.990854
# total_train_accuracy: tensor(0.9187, device='cuda:0')
# Training Epoch: 74, total loss: 30.253888
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 75, total loss: 30.242738
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 76, total loss: 30.146900
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 77, total loss: 29.791187
# total_train_accuracy: tensor(0.9187, device='cuda:0')
# Training Epoch: 78, total loss: 30.140194
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 79, total loss: 30.089622
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 80, total loss: 29.960214
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 81, total loss: 30.165737
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 82, total loss: 30.299222
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# Training Epoch: 83, total loss: 30.644591
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 84, total loss: 30.001381
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 85, total loss: 30.474563
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 86, total loss: 30.054669
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 87, total loss: 29.987942
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 88, total loss: 30.078434
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 89, total loss: 29.845905
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# Training Epoch: 90, total loss: 30.679274
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 91, total loss: 30.015017
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 92, total loss: 30.051442
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 93, total loss: 30.546452
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 94, total loss: 29.618898
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 95, total loss: 29.630355
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 96, total loss: 29.713633
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 97, total loss: 29.936121
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 98, total loss: 29.720723
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 99, total loss: 29.909389
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 100, total loss: 30.199555
# the  1  epoch ends
# test
# test
# total_test_accuracy: tensor(0.9375, device='cuda:0')
# acc_test_each_k: tensor(0.9375, device='cuda:0')
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 0, total loss: 30.155549
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 1, total loss: 30.084684
# total_train_accuracy: tensor(0.8813, device='cuda:0')
# Training Epoch: 2, total loss: 30.898191
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 3, total loss: 30.348492
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 4, total loss: 29.950512
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 5, total loss: 29.909048
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 6, total loss: 29.851037
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 7, total loss: 29.999954
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 8, total loss: 29.733832
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 9, total loss: 29.880664
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 10, total loss: 29.959810
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 11, total loss: 29.674188
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 12, total loss: 29.755260
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 13, total loss: 29.692875
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 14, total loss: 29.705605
# total_train_accuracy: tensor(0.9187, device='cuda:0')
# Training Epoch: 15, total loss: 30.005201
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 16, total loss: 29.905616
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 17, total loss: 29.845975
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 18, total loss: 29.697011
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 19, total loss: 29.778321
# total_train_accuracy: tensor(0.9187, device='cuda:0')
# Training Epoch: 20, total loss: 30.234021
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 21, total loss: 29.691076
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 22, total loss: 30.174216
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 23, total loss: 29.666736
# total_train_accuracy: tensor(0.9312, device='cuda:0')
# Training Epoch: 24, total loss: 29.845071
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 25, total loss: 29.617107
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 26, total loss: 29.977499
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 27, total loss: 29.715459
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 28, total loss: 29.594682
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 29, total loss: 29.752432
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 30, total loss: 29.560746
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 31, total loss: 29.281914
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 32, total loss: 29.346406
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 33, total loss: 29.381888
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 34, total loss: 29.645886
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 35, total loss: 29.464244
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 36, total loss: 29.638255
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 37, total loss: 29.307150
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 38, total loss: 29.416725
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 39, total loss: 29.469897
# total_train_accuracy: tensor(0.9312, device='cuda:0')
# Training Epoch: 40, total loss: 29.751840
# total_train_accuracy: tensor(0.9437, device='cuda:0')
# Training Epoch: 41, total loss: 29.197821
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 42, total loss: 29.497615
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 43, total loss: 29.486289
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 44, total loss: 29.666136
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 45, total loss: 29.566813
# total_train_accuracy: tensor(0.9437, device='cuda:0')
# Training Epoch: 46, total loss: 29.456999
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 47, total loss: 29.671991
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 48, total loss: 29.541141
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 49, total loss: 29.513777
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 50, total loss: 29.562542
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 51, total loss: 29.628445
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 52, total loss: 29.429303
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 53, total loss: 29.550292
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 54, total loss: 30.004110
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 55, total loss: 29.331571
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 56, total loss: 29.896671
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 57, total loss: 29.957045
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 58, total loss: 29.287126
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 59, total loss: 29.245129
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 60, total loss: 29.751438
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 61, total loss: 29.311220
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 62, total loss: 29.422298
# total_train_accuracy: tensor(0.9562, device='cuda:0')
# Training Epoch: 63, total loss: 29.364787
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 64, total loss: 29.767546
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 65, total loss: 29.325117
# total_train_accuracy: tensor(0.9687, device='cuda:0')
# Training Epoch: 66, total loss: 29.022997
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 67, total loss: 29.186881
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 68, total loss: 28.824979
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 69, total loss: 29.009820
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 70, total loss: 29.384799
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 71, total loss: 29.243335
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 72, total loss: 29.456580
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 73, total loss: 29.151055
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 74, total loss: 29.439288
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 75, total loss: 29.363340
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 76, total loss: 29.604011
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 77, total loss: 29.415421
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 78, total loss: 29.373254
# total_train_accuracy: tensor(0.9437, device='cuda:0')
# Training Epoch: 79, total loss: 29.546152
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 80, total loss: 29.099552
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 81, total loss: 29.518866
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 82, total loss: 29.182879
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 83, total loss: 29.048205
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 84, total loss: 28.824824
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 85, total loss: 29.151321
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 86, total loss: 28.742661
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 87, total loss: 29.722183
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 88, total loss: 29.348062
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 89, total loss: 29.478328
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 90, total loss: 28.970239
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 91, total loss: 29.447522
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 92, total loss: 29.614836
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 93, total loss: 29.489060
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 94, total loss: 29.343719
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 95, total loss: 29.143027
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 96, total loss: 29.165066
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 97, total loss: 29.231160
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 98, total loss: 28.922741
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 99, total loss: 29.024156
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 100, total loss: 29.266157
# the  2  epoch ends
# test
# test
# total_test_accuracy: tensor(0.9583, device='cuda:0')
# acc_test_each_k: tensor(0.9583, device='cuda:0')
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 0, total loss: 29.560224
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 1, total loss: 29.446906
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 2, total loss: 29.205872
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 3, total loss: 29.137469
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 4, total loss: 29.265586
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 5, total loss: 29.402068
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 6, total loss: 29.522774
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 7, total loss: 29.456480
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 8, total loss: 29.110169
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 9, total loss: 29.581517
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 10, total loss: 29.256232
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 11, total loss: 29.546815
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 12, total loss: 29.027189
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 13, total loss: 28.792731
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 14, total loss: 29.280771
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 15, total loss: 29.300549
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 16, total loss: 28.847132
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 17, total loss: 29.247759
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 18, total loss: 28.991724
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 19, total loss: 29.194542
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 20, total loss: 29.079840
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 21, total loss: 29.014837
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 22, total loss: 29.230310
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 23, total loss: 29.238873
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 24, total loss: 29.105705
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 25, total loss: 29.404882
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 26, total loss: 29.333007
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 27, total loss: 29.245035
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 28, total loss: 28.826415
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 29, total loss: 29.132737
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 30, total loss: 29.301864
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 31, total loss: 28.729834
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 32, total loss: 29.041100
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 33, total loss: 28.932589
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 34, total loss: 28.649724
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 35, total loss: 29.187713
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 36, total loss: 29.347191
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 37, total loss: 29.106890
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 38, total loss: 29.376469
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 39, total loss: 29.197500
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 40, total loss: 29.344248
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 41, total loss: 28.969779
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 42, total loss: 28.951054
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 43, total loss: 28.899748
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 44, total loss: 29.356016
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 45, total loss: 28.868302
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 46, total loss: 29.203445
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 47, total loss: 29.076846
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 48, total loss: 28.880321
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 49, total loss: 28.786139
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 50, total loss: 29.213310
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 51, total loss: 29.062140
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 52, total loss: 28.819441
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 53, total loss: 28.847978
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 54, total loss: 29.549416
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 55, total loss: 29.314450
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 56, total loss: 29.110339
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 57, total loss: 29.267235
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 58, total loss: 29.228791
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 59, total loss: 29.120316
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 60, total loss: 28.927055
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 61, total loss: 29.130032
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 62, total loss: 28.844055
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 63, total loss: 29.226503
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 64, total loss: 28.648176
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 65, total loss: 29.183561
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 66, total loss: 29.070915
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 67, total loss: 29.157811
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 68, total loss: 29.043908
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 69, total loss: 28.948888
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 70, total loss: 29.118050
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 71, total loss: 29.029511
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 72, total loss: 29.283918
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 73, total loss: 28.888476
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 74, total loss: 29.036056
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 75, total loss: 29.080099
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 76, total loss: 28.810659
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 77, total loss: 28.712175
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 78, total loss: 28.630448
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 79, total loss: 28.756938
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 80, total loss: 28.981537
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 81, total loss: 28.855535
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 82, total loss: 29.200283
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 83, total loss: 29.509298
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 84, total loss: 28.834479
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 85, total loss: 29.049986
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 86, total loss: 28.902861
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 87, total loss: 29.019738
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 88, total loss: 28.776059
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 89, total loss: 28.587625
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 90, total loss: 28.960449
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 91, total loss: 28.807702
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 92, total loss: 28.771121
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 93, total loss: 28.957956
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 94, total loss: 29.187275
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 95, total loss: 28.934000
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 96, total loss: 28.811011
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 97, total loss: 28.584063
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 98, total loss: 28.836423
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 99, total loss: 28.755983
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 100, total loss: 29.113433
# the  3  epoch ends
# test
# test
# total_test_accuracy: tensor(0.9583, device='cuda:0')
# acc_test_each_k: tensor(0.9583, device='cuda:0')
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 0, total loss: 28.834800
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 1, total loss: 28.904684
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 2, total loss: 28.944108
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 3, total loss: 28.626809
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 4, total loss: 29.219786
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 5, total loss: 29.249175
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 6, total loss: 28.941078
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 7, total loss: 28.739249
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 8, total loss: 28.738078
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 9, total loss: 28.836520
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 10, total loss: 28.647950
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 11, total loss: 28.979446
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 12, total loss: 28.678365
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 13, total loss: 28.967060
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 14, total loss: 29.059067
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 15, total loss: 29.067472
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 16, total loss: 28.577595
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 17, total loss: 28.732652
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 18, total loss: 28.849048
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 19, total loss: 28.886551
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 20, total loss: 28.720167
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 21, total loss: 28.587401
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 22, total loss: 28.411442
# total_train_accuracy: tensor(0.9687, device='cuda:0')
# Training Epoch: 23, total loss: 28.631778
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 24, total loss: 28.734781
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 25, total loss: 28.813355
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 26, total loss: 28.622363
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 27, total loss: 28.681100
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 28, total loss: 28.692651
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 29, total loss: 28.948866
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 30, total loss: 28.390101
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 31, total loss: 28.633483
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 32, total loss: 28.735028
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 33, total loss: 28.575309
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 34, total loss: 28.857512
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 35, total loss: 28.735896
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 36, total loss: 28.878156
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 37, total loss: 28.562504
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 38, total loss: 29.251465
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 39, total loss: 28.888605
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 40, total loss: 29.190358
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 41, total loss: 28.789469
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 42, total loss: 28.905288
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 43, total loss: 29.210899
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 44, total loss: 28.788291
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 45, total loss: 28.677561
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 46, total loss: 28.708033
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 47, total loss: 28.746798
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 48, total loss: 28.619473
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 49, total loss: 28.678315
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 50, total loss: 28.630432
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 51, total loss: 29.068231
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# ...
# Training Epoch: 44, total loss: 28.075943
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 45, total loss: 28.329784
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 46, total loss: 28.281943
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 47, total loss: 28.334168
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 48, total loss: 28.263639
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 49, total loss: 28.233880
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 50, total loss: 28.332659
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 51, total loss: 28.363508
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 52, total loss: 28.207807
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 53, total loss: 28.293560
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 54, total loss: 28.352468
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 55, total loss: 28.432296
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 56, total loss: 28.195533
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 57, total loss: 28.227017
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 58, total loss: 28.487766
# total_train_accuracy: tensor(0.9687, device='cuda:0')
# Training Epoch: 59, total loss: 28.436166
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 60, total loss: 28.354191
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 61, total loss: 28.345892
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 62, total loss: 28.104460
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 63, total loss: 28.339188
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 64, total loss: 28.439552
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 65, total loss: 28.434219
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 66, total loss: 28.580059
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 67, total loss: 28.399355
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 68, total loss: 28.512976
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 69, total loss: 28.072008
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 70, total loss: 28.708625
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 71, total loss: 28.730085
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 72, total loss: 28.357109
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 73, total loss: 28.341760
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 74, total loss: 28.370335
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 75, total loss: 28.439691
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 76, total loss: 28.342465
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 77, total loss: 28.567583
# total_train_accuracy: tensor(0.9812, device='cuda:0')
# Training Epoch: 78, total loss: 28.232652
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 79, total loss: 28.190946
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 80, total loss: 28.217885
# total_train_accuracy: tensor(0.9687, device='cuda:0')
# Training Epoch: 81, total loss: 28.448572
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 82, total loss: 28.604845
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 83, total loss: 28.457511
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 84, total loss: 28.195462
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 85, total loss: 28.471961
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 86, total loss: 28.149263
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 87, total loss: 28.372326
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 88, total loss: 28.529536
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 89, total loss: 28.338297
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 90, total loss: 28.481630
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 91, total loss: 28.146111
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 92, total loss: 28.687421
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 93, total loss: 28.431435
# total_train_accuracy: tensor(0.9896, device='cuda:0')
# Training Epoch: 94, total loss: 28.092339
# total_train_accuracy: tensor(0.9687, device='cuda:0')
# Training Epoch: 95, total loss: 28.535681
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 96, total loss: 28.260479
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 97, total loss: 28.070240
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 98, total loss: 28.505498
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 99, total loss: 28.583344
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 100, total loss: 28.389564
# the  8  epoch ends
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# acc_test_each_k: tensor(1., device='cuda:0')
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 0, total loss: 28.466954
# total_train_accuracy: tensor(0.9812, device='cuda:0')
# Training Epoch: 1, total loss: 28.189151
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 2, total loss: 28.294253
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 3, total loss: 28.139012
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 4, total loss: 28.436952
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 5, total loss: 28.379052
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 6, total loss: 28.435004
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 7, total loss: 28.201459
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 8, total loss: 28.878305
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 9, total loss: 28.393763
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 10, total loss: 28.384331
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 11, total loss: 28.400673
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 12, total loss: 28.344396
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 13, total loss: 28.139699
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 14, total loss: 28.549041
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 15, total loss: 28.637583
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 16, total loss: 28.465408
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 17, total loss: 28.143888
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 18, total loss: 28.223673
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 19, total loss: 28.139736
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 20, total loss: 28.120473
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 21, total loss: 28.179775
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 22, total loss: 28.479171
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 23, total loss: 28.200411
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 24, total loss: 28.354260
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 25, total loss: 28.397767
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 26, total loss: 28.204931
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 27, total loss: 28.117656
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 28, total loss: 28.158004
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 29, total loss: 28.225959
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 30, total loss: 28.263902
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 31, total loss: 28.496453
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 32, total loss: 28.487333
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 33, total loss: 28.648594
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 34, total loss: 28.288191
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 35, total loss: 28.297463
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 36, total loss: 28.196701
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 37, total loss: 28.335277
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 38, total loss: 28.151421
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 39, total loss: 28.399193
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 40, total loss: 28.469034
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 41, total loss: 28.624842
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 42, total loss: 28.329443
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 43, total loss: 28.202709
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 44, total loss: 28.290132
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 45, total loss: 28.223646
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 46, total loss: 28.162033
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 47, total loss: 28.005466
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 48, total loss: 28.183356
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 49, total loss: 28.373860
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 50, total loss: 28.299108
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 51, total loss: 28.202362
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 52, total loss: 28.155766
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 53, total loss: 28.483964
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 54, total loss: 28.376267
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 55, total loss: 28.326794
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 56, total loss: 28.365841
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 57, total loss: 28.334277
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 58, total loss: 28.273656
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 59, total loss: 28.226810
# total_train_accuracy: tensor(0.9812, device='cuda:0')
# Training Epoch: 60, total loss: 28.187500
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 61, total loss: 28.271656
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 62, total loss: 28.125283
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 63, total loss: 28.832884
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 64, total loss: 28.272458
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 65, total loss: 28.495509
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 66, total loss: 28.292128
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 67, total loss: 28.419903
# total_train_accuracy: tensor(0.9812, device='cuda:0')
# Training Epoch: 68, total loss: 28.215480
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 69, total loss: 28.058091
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 70, total loss: 28.283808
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 71, total loss: 28.190310
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 72, total loss: 28.111389
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 73, total loss: 28.194652
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 74, total loss: 28.178288
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 75, total loss: 28.314481
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 76, total loss: 28.580438
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 77, total loss: 28.041678
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 78, total loss: 28.129307
# total_train_accuracy: tensor(0.9812, device='cuda:0')
# Training Epoch: 79, total loss: 28.033270
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 80, total loss: 28.412539
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 81, total loss: 28.226265
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 82, total loss: 28.263510
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 83, total loss: 28.543278
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 84, total loss: 28.267667
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 85, total loss: 28.312556
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 86, total loss: 28.403058
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 87, total loss: 28.156061
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 88, total loss: 28.436874
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 89, total loss: 28.389351
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 90, total loss: 28.752454
# total_train_accuracy: tensor(0.9812, device='cuda:0')
# Training Epoch: 91, total loss: 28.234769
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 92, total loss: 28.250329
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 93, total loss: 28.251106
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 94, total loss: 28.252329
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 95, total loss: 28.272492
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 96, total loss: 28.489728
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 97, total loss: 28.204107
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 98, total loss: 28.370364
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 99, total loss: 28.180830
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 100, total loss: 28.212915
# the  9  epoch ends
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# acc_test_each_k: tensor(1., device='cuda:0')
# [tensor(0.7917, device='cuda:0'), tensor(0.9375, device='cuda:0'), tensor(0.9583, device='cuda:0'), tensor(0.9583, device='cuda:0'), tensor(0.9583, device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0')]
# [array(0.7916666, dtype=float32), array(0.9375, dtype=float32), array(0.9583333, dtype=float32), array(0.9583334, dtype=float32), array(0.9583334, dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(1., dtype=float32)]
# acc_test_metrics: 0.9604167

# %%
import pandas as pd 
data1='dataset/qiuguan/origin_800/xiaoguan/test_info.csv'
data2='dataset/qiuguan/origin_800/xiaoqiu/test_info.csv'

df1=pd.read_csv(data1,sep=',')
df2=pd.read_csv(data2,sep=',')

df=pd.concat([df1,df2],axis=0)
df0=df.iloc[:,1:]
print(df0.shape)

#print(df0.head)

df0.to_csv('dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info.csv')
# Out:
# (138, 3301)

# %%
import torch

#功能：加载保存到path中的各层参数到神经网络

#path='models/NFM_layer_2/MLP610.pkl'
path='models/NFM_layer_2/MLP610.pt'
nfm=NFM(nfm_config)
#mlp=MLP()
print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
nfm.load_state_dict(torch.load(path),strict=False)
nfm.cuda()

print(nfm)




nfm_params = list(nfm.named_parameters())
#print(nfm_params)
net=nfm


testset = KZDatasetTest(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info.csv')
   
test_loader = data.DataLoader(
         dataset=testset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
#———————————————— 
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/jclian91/article/details/121708431# 
from torch.autograd import Variable 
from torch.utils.data import DataLoader 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import accuracy_score 
 
def evaluate_model(test_dl, model): 
    model.eval()#测试数据稳定
    predictions, actuals = [], [] 
    for i, (inputs,bi_inputs ,targets) in enumerate(test_dl): 
        # evaluate the model on the test set 
        #print(\ inputs:\ ,inputs) 
        #print(\ targets:\ ,targets) 
        inputs = Variable(inputs) 
        bi_inputs=Variable(bi_inputs)
        targets = Variable(targets) 
                 
                 
        #x = torch.tensor(x, dtype=torch.float) 
        #x=x.clone().detach().requires_grad_(True) 
        inputs=torch.tensor(inputs,dtype=torch.float) 
        bi_inputs=torch.tensor(bi_inputs,dtype=torch.float)
        targets=torch.tensor(targets,dtype=torch.float) 
        inputs,bi_inputs, targets = inputs.cuda(), bi_inputs.cuda(),targets.cuda() 
        yhat = model(inputs,bi_inputs) 
        # retrieve numpy array 
        #yhat = yhat.detach().numpy() 
        yhat = yhat.detach().cpu().numpy()#转换到cpu 
        # yhat=yhat.argmax(axis=1) 
        #print(yhat:\ ,yhat) 
        #print('yhat.shape:',yhat.shape) 
        actual = targets.detach().cpu().numpy() 
        actual=actual.round() 
        #print(\ actual:\ ,actual) 
        #print('actual.shape:',actual.shape
        #predictions.appe) 
        #actual = actual.reshape(-1, 1) 
        # round to class values 
        yhat = yhat.round() 
        # store nd(yhat) 
        actuals.append(actual) 
        predictions.append(yhat)
    #print("prediction:" ,predictions) 
    #print("actuals:",actuals) 
    predictions, actuals = np.vstack(predictions), np.vstack(actuals) 
    #print("prediction:" ,predictions) 
    #print("actuals:" ,actuals) 
    # calculate accuracy 
    acc_test = accuracy_score(actuals, predictions) 
    return  actuals, predictions,acc_test 

import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch

#功能：加载保存到path中的各层参数到神经网络






import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 
target_list=actuals 
pred_list=predictions 
      
y_true=target_list 
y_pred=pred_list 
      
f1=f1_score(y_true=target_list, y_pred=pred_list, average='macro') # 也可以指定micro模式 
acc_score=accuracy_score(y_true=target_list, y_pred=pred_list) 
rec_score=recall_score(y_true=target_list,y_pred=pred_list,average='macro') # 也可以指定micro模式 
pre_recall=precision_score(y_true=target_list,y_pred=pred_list,average='macro') 
print("f1_score:  %.4f" ,f1) 
print("accuracy_score:" ,acc_score) 
print("recall_score:",rec_score) 
print("pre_recall:" ,pre_recall)



auc_curve = roc_auc_score(y_true, y_pred, multi_class='ovo')
#———————————————— 
#版权声明：本文为CSDN博主「农民小飞侠」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/w5688414/article/details/106595892 
PM_y=y_pred 
true_y=y_true 
n_classes=PM_y.shape[1] 
      
print("n_classes:",n_classes) 
fpr = dict() 
tpr = dict() 
roc_auc = dict() 
for i in range(n_classes): 
    fpr[i], tpr[i], _ = roc_curve(true_y[:, i], PM_y[:, i]) 
    roc_auc[i] = auc(fpr[i], tpr[i]) 
    #print(i) 
    #print(fpr) 
    #print(tpr) 
    
    
    
#计算macro auc 
from scipy import interp 
# First aggregate all false positive rates 
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)])) 
       
# Then interpolate all ROC curves at this points 
mean_tpr = np.zeros_like(all_fpr) 
for i in range(n_classes): 
    mean_tpr += interp(all_fpr, fpr[i], tpr[i]) 
       
    # Finally average it and compute AUC 
    mean_tpr /= n_classes 
       
    fpr["macro"] = all_fpr 
    tpr["macro"] = mean_tpr 
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    
    
    
#画图 
      
import matplotlib.pyplot as plt 
from itertools import cycle 
from matplotlib.ticker import FuncFormatter 
lw = 2 
# Plot all ROC curves 
plt.figure() 
labels=['Con(0)','DN(1)','FSGS(2)','HT(3)','IgA(4)','MCD(5)','MGN(6)','RPGN(7)','SLE(8)'] 

'''
plt.plot(fpr["macro"], tpr["macro"], 
              label='macro-average ROC curve (area = {0:0.4f})' 
                    ''.format(roc_auc["macro"]), 
              color='navy', linestyle=':', linewidth=4) 
'''

       
colors = cycle(['aqua', 'darkorange', 'cornflowerblue','blue','yellow','burlywood','cornsilk','darkblue','goldenrod','greenyellow','maroon']) 
for i, color in zip(range(n_classes), colors): 
    plt.plot(fpr[i], tpr[i], color=color, lw=lw, 
                  label=labels[i]+'(area = {0:0.4f})'.format(roc_auc[i])) 
       
    plt.plot([0, 1], [0, 1], 'k--', lw=lw) 
    plt.xlim([0.0, 1.0]) 
    plt.ylim([0.0, 1.05]) 
      
      
    plt.xlabel('1-Specificity (%)') 
    plt.ylabel('Sensitivity (%)') 
    plt.title('NFM_layer_2_non_encode') 
      

        
def to_percent(temp, position): 
    return '%1.0f'%(100*temp) 
      
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.legend(loc="lower right" ) 
      
plt.show() 



#———————————————— 
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/jclian91/article/details/103074506/ 
      
from sklearn.metrics import confusion_matrix 
import matplotlib.pyplot as plt 
import matplotlib as mpl 
      
# 支持中文字体显示, 使用于Mac系统 
#zhfont=mpl.font_manager.FontProperties(fname=\ /Library/Fonts/Songti.ttc\ ) 
      
y_true=actuals# = ['北京', '上海', '成都', '成都', '上海', '北京', '上海', '成都', '北京', '上海'] 
y_pred=predictions #= ['北京', '上海', '成都', '上海', '成都', '成都', '上海', '成都', '北京', '上海'] 
      
#ValueError: multilabel-indicator is not supported 
      
classes = [0,1,2,3,4,5,6,7,8] 
#confusion = confusion_matrix(y_true, y_pred)#ValueError: multilabel-indicator is not supported 
      
confusion = confusion_matrix(y_true.argmax(axis=1), y_pred.argmax(axis=1)) 
# 绘制热度图 
plt.imshow(confusion, cmap=plt.cm.Greens) 
indices = range(len(confusion)) 
#plt.xticks(indices, classes, fontproperties=zhfont) 
#plt.yticks(indices, classes, fontproperties=zhfont) 
      
plt.xticks(indices, classes) 
plt.yticks(indices, classes) 
plt.colorbar() 
plt.xlabel('y_pred') 
plt.ylabel('y_true') 
      
# 显示数据 
for first_index in range(len(confusion)): 
    for second_index in range(len(confusion[first_index])): 
        plt.text(first_index, second_index, confusion[first_index][second_index]) 
      
# 显示图片 
plt.show()
# Out:
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=3300, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=3300, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:56: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:572: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:56: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:572: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:159: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# f1_score:  %.4f 0.9390215614205822
# accuracy_score: 0.9083333333333333
# recall_score: 0.9182071339966077
# pre_recall: 0.968073593073593
# n_classes: 9

# %%
#predict and find the correctly predicted samples
#to compute mean of X
import torch

#功能：加载保存到path中的各层参数到神经网络

path='models/NFM_layer_2/MLP610.pkl'

nfm=NFM(nfm_config)
#mlp=MLP()
print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
nfm.load_state_dict(torch.load(path),strict=False)
nfm.cuda()

print(nfm)




nfm_params = list(nfm.named_parameters())
#print(nfm_params)
net=nfm


testset = KZDatasetTest(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info.csv')
   
test_loader = data.DataLoader(
         dataset=testset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
#———————————————— 
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/jclian91/article/details/121708431# 
from torch.autograd import Variable 
from torch.utils.data import DataLoader 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import accuracy_score 
 
def predict_model(test_dl, model): 
    model.eval()#测试数据稳定
    error_dataset=torch.tensor([0])
    error_dataset=error_dataset.view(1,1)
    predictions, actuals = [], [] 
    num=0
    for i, (inputs,bi_inputs ,targets) in enumerate(test_dl): 
        # evaluate the model on the test set 
        #print(\ inputs:\ ,inputs) 
        #print(\ targets:\ ,targets) 
        inputs = Variable(inputs) 
        bi_inputs=Variable(bi_inputs)
        targets = Variable(targets) 
                
        targets=targets.argmax(axis=1)  
        print('targets:',targets.shape)
        #x = torch.tensor(x, dtype=torch.float) 
        #x=x.clone().detach().requires_grad_(True) 
        inputs=torch.tensor(inputs,dtype=torch.float) 
        bi_inputs=torch.tensor(bi_inputs,dtype=torch.float)
        targets=torch.tensor(targets,dtype=torch.float) 
        inputs,bi_inputs, targets = inputs.cuda(), bi_inputs.cuda(),targets.cuda() 
        yhat = model(inputs,bi_inputs) 
        
        yhat=yhat.argmax(axis=1)
        print('yhat:',yhat.shape)
        
        for j in range(nfm_config['batch_size']):
            
            if yhat[j]!=targets[j] and num==0:
                print(inputs[j])
                inputs_v=inputs[j].view(1,3300)
                yhat_v=yhat[j].view(1,1)
                error_dataset=torch.hstack([inputs_v,yhat_v])
                error_dataset=error_dataset.view(1,3301)
                print('err_dataset:',error_dataset.shape)
                num=num+1
            elif yhat[j]!=targets[j] and num>0:
                inputs_v=inputs[j].view(1,3300)
                yhat_v=yhat[j].view(1,1)
                data=torch.hstack([inputs[j],yhat[j]])
                data=data.view(1,3301)
                print('data:',data.shape)
                #print('err_dataset:',error_dataset.shape)
                error_dataset=torch.cat([error_dataset,data],dim=0)
                print('err_dataset:',error_dataset.shape)
                num=num+1
        
        
    
    return  error_dataset


error_dataset=predict_model(test_loader,nfm)
print(error_dataset.shape)

error_dataset_numpy=error_dataset.cpu().detach().numpy()
df_error=pd.DataFrame(error_dataset_numpy)
test_df=pd.read_csv('dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info.csv',sep=',')
test_df=test_df.iloc[:,1:]
test_columns=test_df.columns.to_list()
df_error.columns=test_columns
print(df_error)

df_error.to_csv('results_genes/NFM_layer_2/df_error.csv')
# Out:
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=3300, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=3300, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# targets: torch.Size([24])
# yhat: torch.Size([24])
# tensor([10.5749,  6.0681, 10.0708,  ..., 10.5033,  5.9604,  5.1446],
#        device='cuda:0')
# err_dataset: torch.Size([1, 3301])
# data: torch.Size([1, 3301])
# err_dataset: torch.Size([2, 3301])
# targets: torch.Size([24])
# yhat: torch.Size([24])
# data: torch.Size([1, 3301])
# err_dataset: torch.Size([3, 3301])
# data: torch.Size([1, 3301])
# err_dataset: torch.Size([4, 3301])
# data: torch.Size([1, 3301])
# err_dataset: torch.Size([5, 3301])
# targets: torch.Size([24])
# yhat: torch.Size([24])
# data: torch.Size([1, 3301])
# err_dataset: torch.Size([6, 3301])
# data: torch.Size([1, 3301])
# err_dataset: torch.Size([7, 3301])
# targets: torch.Size([24])
# yhat: torch.Size([24])
# data: torch.Size([1, 3301])
# err_dataset: torch.Size([8, 3301])
# targets: torch.Size([24])
# yhat: torch.Size([24])
# data: torch.Size([1, 3301])
# err_dataset: torch.Size([9, 3301])
# torch.Size([9, 3301])
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:62: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:63: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:64: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:571: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#         RHOA      STX2      CISD1     WDR11     SCYL2   MGC2889     CCDC47  \
# 0  10.574853  6.068130  10.070807  7.552310  6.237669  4.421511   8.082016
# 1  11.051847  6.016150  10.200660  8.176332  6.898790  4.543062   8.596111
# 2  11.076604  6.028471  10.052066  7.829381  6.879524  4.682755   8.537395
# 3  10.943367  6.081674   9.857302  7.385812  6.565125  4.541350   8.452517
# 4  11.081944  5.963155   9.811984  7.446486  6.028989  4.386786   8.673888
# 5  10.588021  6.050490  10.087381  7.430877  6.397605  4.402184   8.062417
# 6  10.721221  6.111177   9.947128  7.124047  6.495440  4.570862   8.083422
# 7  12.677155  9.058852   8.832618  9.313186  7.417440  5.208508  10.022384
# 8  12.505198  8.701312   9.279246  8.981455  6.361914  5.317983   9.683584
#
#        KLF8      CCL1   SLCO3A1  ...     PLAC4     NRBP1    LRRC23     SPHK2  \
# 0  5.013911  4.664985  5.024240  ...  5.280835  7.204955  6.407804  7.546784
# 1  5.069466  4.550434  4.885085  ...  5.170158  7.173776  6.470484  7.173542
# 2  4.866892  4.605386  4.999154  ...  5.609736  7.273584  6.464399  7.244013
# 3  5.159841  4.590762  5.182266  ...  5.455276  6.858460  6.565383  7.110857
# 4  5.077232  4.379622  5.212379  ...  5.550090  6.976279  6.328939  6.981522
# 5  5.117215  4.642196  5.137237  ...  5.343421  7.152281  6.431950  7.380373
# 6  4.854882  4.844818  4.965109  ...  5.580214  7.272808  6.780969  7.503222
# 7  6.211172  5.208344  7.624451  ...  6.636751  8.685239  6.093445  7.885623
# 8  5.929534  5.315530  7.644356  ...  6.230000  8.775293  7.094709  8.156054
#
#    KIAA0513    SULT1A1       AMOT       CA1     GPR35  label
# 0  5.727374   8.647378  10.503287  5.960427  5.144612    7.0
# 1  5.696511   9.012268   9.906088  5.715785  4.832949    8.0
# 2  5.717652   7.837471  10.329243  5.781045  5.029810    8.0
# 3  5.788134   9.109585  10.262417  5.926415  5.042332    8.0
# 4  5.765681  10.006198  10.267508  6.202271  4.920636    8.0
# 5  5.713672   8.997856  10.749501  5.958055  5.185850    7.0
# 6  5.561408   9.039688  10.431449  6.091958  5.386509    0.0
# 7  7.733089  12.205298  12.786480  6.659716  5.714126    8.0
# 8  7.319871  11.769500  12.604125  6.876892  5.325369    8.0
#
# [9 rows x 3301 columns]

# %%
from torch.autograd import Variable 
from torch.utils.data import DataLoader 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import accuracy_score 
 
def bool_predict_model(test_dl, model): 
    model.eval()#测试数据稳定
    error_dataset=torch.tensor([0])
    error_dataset=error_dataset.view(1,1)
    predictions, actuals = [], [] 
    num=0
    for i, (inputs,bi_inputs ,targets) in enumerate(test_dl): 
        # evaluate the model on the test set 
        #print(\ inputs:\ ,inputs) 
        #print(\ targets:\ ,targets) 
        inputs = Variable(inputs) 
        bi_inputs=Variable(bi_inputs)
        targets = Variable(targets) 
                
        targets=targets.argmax(axis=1)  
        print('targets:',targets.shape)
        #x = torch.tensor(x, dtype=torch.float) 
        #x=x.clone().detach().requires_grad_(True) 
        inputs=torch.tensor(inputs,dtype=torch.float) 
        bi_inputs=torch.tensor(bi_inputs,dtype=torch.float)
        targets=torch.tensor(targets,dtype=torch.float) 
        inputs,bi_inputs, targets = inputs.cuda(), bi_inputs.cuda(),targets.cuda() 
        yhat = model(inputs,bi_inputs) 
        
        yhat=yhat.argmax(axis=1)
        print('yhat:',yhat.shape)
        
        if targets==yhat:
            return True
        else:
            return False

# %%
import pandas as pd 
test_df=pd.read_csv('dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info1.csv',sep=',')
test_df=test_df.iloc[:,1:]
rows,cols=test_df.shape
print(rows,cols)
import torch

#功能：加载保存到path中的各层参数到神经网络

path='models/NFM_layer_2/MLP610.pt'

nfm=NFM(nfm_config)
#mlp=MLP()
print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
nfm.load_state_dict(torch.load(path),strict=False)
nfm.cuda()

print(nfm)




nfm_params = list(nfm.named_parameters())
#print(nfm_params)
net=nfm


testset = KZDatasetPredict(test_df)
   
test_loader = data.DataLoader(
         dataset=testset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )

for i in range(rows):
    #data_set=testset[i]
    print(data_set)
    print('this is data_set')
    testset = KZDatasetPredict(test_df[i])
    data_test_loader=data.DataLoader(dataset=data_set,
                                    batch_size=1)
    print(data_test_loader)
    bool_index=bool_predict_model(data_test_loader,nfm)
    print(bool_index)
    if bool_index==False:
        print(i)
        test_df.drop(index=i, inplace=True)
        
print(test_df.shape)
# Out:
# 138 3301
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=3300, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=3300, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# (tensor([10.4388,  6.2062,  9.8362,  ..., 10.4819,  6.6075,  5.0850],
#        dtype=torch.float64), tensor([6462988.5000,       0.0000,  324175.7812,       0.0000,  316585.8750,
#               0.0000,   60882.6953,       0.0000,       0.0000, 2053495.2500]), tensor([0.0222, 0.0222, 0.0222, 0.0222, 0.0222, 0.8222, 0.0222, 0.0222, 0.0222]))
# this is data_set
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-0fce207603cc> in <module>
#      42     print(data_set)
#      43     print('this is data_set')
# ---> 44     testset = KZDatasetPredict(test_df[i])
#      45     data_test_loader=data.DataLoader(dataset=data_set,
#      46                                     batch_size=1)
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
# -> 2893                 raise KeyError(key) from err
#    2894
#    2895         if tolerance is not None:
#
# KeyError: 0

# %%
#delete the erroly predicted samples from test_info.csv
import pandas as pd 
test_df=pd.read_csv('dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info1.csv',sep=',')
error_df=pd.read_csv('results_genes/NFM_layer_2/df_error.csv',sep=',')
test_df=test_df.iloc[:,1:]
error_df=error_df.iloc[:,1:]   

t_rows,t_cols=test_df.shape
e_rows,e_cols=error_df.shape
print('e_rows:',e_rows)
row_list=[i for i in range(t_rows)]
test_df.index=row_list
print(test_df)

mask_list=[False for i in range(t_cols)]
final_list=[]
for i in range(e_rows):
    for j in range(t_rows):
        
        row1=error_df.iloc[i,:].tolist()
        #print(type(row1[5]))
        #print(type(row2[5]))
        row2=test_df.iloc[j,:].tolist()
        print(type(row1[5]))
        print(type(row2[5]))
        for k,a in enumerate(row1):
            #print('j:',j)
            if a!=row2[k]:
                break
            else:
                print(a)
                mask_list[k]=True
                
        if False not in mask_list:
            final_list.append(j)
                #test_df.drop(index=j, axis=0, inplace=True)
        mask_list=[False for m in range(t_cols)]
print(final_list)
# Out:
# e_rows: 9
#           RHOA      STX2      CISD1     WDR11     SCYL2   MGC2889     CCDC47  \
# 0    10.438773  6.206201   9.836246  7.038886  6.703749  4.992983   7.756205
# 1    10.757762  5.784611  10.159105  7.212917  6.947931  4.506135   8.508244
# 2    10.731982  5.826351   9.697981  7.459397  5.982515  4.725452   8.610902
# 3    10.788461  6.213283   9.902440  7.238627  6.595625  4.276114   8.500639
# 4    10.772364  6.233683  10.151475  8.030659  6.286044  4.602685   8.603736
# ..         ...       ...        ...       ...       ...       ...        ...
# 133  12.153250  8.550679   9.548931  8.448184  6.963025  5.560785  10.061710
# 134  12.500807  8.632233   9.365225  9.203636  7.629996  5.258812  10.790601
# 135  12.211943  8.845553   8.872259  8.688882  7.165949  5.274345   9.990952
# 136  12.455192  8.813249   8.660721  8.951007  6.919346  5.590529   9.808096
# 137  12.447406  8.842976   9.422864  8.981440  6.963361  5.232355  10.180057
#
#          KLF8      CCL1   SLCO3A1  ...     PLAC4     NRBP1    LRRC23  \
# 0    5.403539  4.953337  4.975167  ...  5.909758  7.399954  6.614376
# 1    4.792093  4.616944  4.775627  ...  5.622651  7.374075  6.690741
# 2    5.021616  4.482129  4.973849  ...  5.896752  7.194073  6.497418
# 3    5.046518  4.423059  4.887678  ...  5.534880  7.192119  6.731126
# 4    4.994478  4.593943  5.019463  ...  5.600377  7.128291  5.985150
# ..        ...       ...       ...  ...       ...       ...       ...
# 133  5.838032  5.435461  7.367615  ...  6.817916  8.516984  6.326146
# 134  6.247450  5.101022  7.697747  ...  6.569032  8.373829  6.509216
# 135  5.962292  5.454457  8.012946  ...  6.687817  8.576306  6.297928
# 136  6.147042  5.336929  7.800522  ...  6.744503  8.897809  6.326779
# 137  6.093205  5.344227  8.107972  ...  6.772365  8.747005  6.168589
#
#         SPHK2  KIAA0513    SULT1A1       AMOT       CA1     GPR35  label
# 0    7.272938  5.729318   7.674584  10.481910  6.607492  5.084990      5
# 1    7.390787  5.591222   8.241191  10.226522  5.914911  4.968402      5
# 2    7.430893  5.896916   8.175035  10.639654  6.074184  5.161094      8
# 3    7.515222  5.657311   9.043599  10.453041  5.812049  4.867461      6
# 4    7.270949  5.730299   9.299417  10.552800  5.974691  4.797138      6
# ..        ...       ...        ...        ...       ...       ...    ...
# 133  8.170894  7.434878  11.706813  12.598518  6.781732  5.566797      4
# 134  7.947656  7.205314  10.600006  12.976043  8.518399  5.697897      6
# 135  7.978047  7.433020  10.752438  12.603443  6.951718  5.589825      2
# 136  7.938734  7.661181  11.715816  12.731128  7.054085  5.736978      7
# 137  8.323465  7.353506  11.461577  13.064383  6.790510  5.548161      7
#
# [138 rows x 3301 columns]
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# []

# %%
x = torch.randn(3)
print(x)
l=torch.tensor([0])
y=torch.hstack([x,l])
print(x)
print(y)
# Out:
# tensor([-1.1127, -0.1882,  2.4478])
# tensor([-1.1127, -0.1882,  2.4478])
# tensor([-1.1127, -0.1882,  2.4478,  0.0000])

# %%
a=3.147
b=3.147
print(a==b)
# Out:
# True

# %%
import torch

#功能：加载保存到path中的各层参数到神经网络

import torch

#功能：加载保存到path中的各层参数到神经网络

import torch

#功能：加载保存到path中的各层参数到神经网络

import torch

#功能：加载保存到path中的各层参数到神经网络

import torch

#功能：加载保存到path中的各层参数到神经网络

path='dataset/qiuguan/model_new_K_fold_RandomTree/NFM_layer_2_non_encode/MLP610.pkl'

#nfm=NFM(nfm_config)
nfm=NFM(nfm_config)
#print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
nfm.load_state_dict(torch.load(path),strict=False)
nfm.cuda()

print(nfm)




nfm_params = list(nfm.named_parameters())
#print(nfm_params)
net=nfm



weight={}
for name,parameters in net.named_parameters():
    print(name,':',parameters.size())
    #names.append(name)
    weight[name]=parameters




genes=[]
gene_res={}



def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    n = len(labels)
    #n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output


new_labels=[i for i in range(nfm_config['n_class'])]
new_targets=one_hot_smoothing(new_labels,nfm_config['n_class'])
print(new_targets)

'''
bn0.weight : torch.Size([10477])
bn0.bias : torch.Size([10477])
fc1.weight : torch.Size([2000, 10477])
fc1.bias : torch.Size([2000])
bn1.weight : torch.Size([2000])
bn1.bias : torch.Size([2000])
fc2.weight : torch.Size([100, 2000])
fc2.bias : torch.Size([100])
bn2.weight : torch.Size([100])
bn2.bias : torch.Size([100])
fc3.weight : torch.Size([9, 100])
fc3.bias : torch.Size([9])
bn3.weight : torch.Size([9])
bn3.bias : torch.Size([9])

'''


gene_name=[]
genes=[]
for i in range(nfm_config['n_class']):
    '''
    BN_num.weight : torch.Size([10477])
    BN_num.bias : torch.Size([10477])
    linear1.weight : torch.Size([2000, 10477])
    linear1.bias : torch.Size([2000])
    bn1.weight : torch.Size([2000])
    bn1.bias : torch.Size([2000])
    linear2.weight : torch.Size([100, 2010])
    linear2.bias : torch.Size([100])
    bn2.weight : torch.Size([100])
    bn2.bias : torch.Size([100])
    linear3.weight : torch.Size([9, 100])
    linear3.bias : torch.Size([9])
    bn3.weight : torch.Size([9])
    bn3.bias : torch.Size([9])
    
    
    
    '''
    #genes=[]
    gene=[]
    #gene.appenda(i)
    #new_targets=torch.tensor([0, 0, 0, 0, 0, 0, 0, 1])
    new_targets=torch.tensor(new_targets).cuda()
    l1=torch.mv(weight['linear3.weight'].T,(new_targets[i]-weight['linear3.bias']))
    #l1=l1[:100]
    l2=torch.mv(weight['linear2.weight'].T,(l1-weight['linear2.bias']))
    #l2=l2[100:]
    l2=l2[:800]
    print('l2.shape:',l2.shape)
    #print('linear1.bias.shape:',linear1.bias.shape)
    #print('linear1.weight.shape:',linear2.weight.shape)
    l3=torch.mv(weight['linear1.weight'].T,(l2-weight['linear1.bias']))
    #l4=torch.mv(weight['linear_model1.weight'].T,(l3-weight['linear_model1.bias']))
    top_k=torch.topk(l3,50,largest=True)
    #print(top_k)
    index=top_k.indices
    index=index.tolist()
    #print(index)
    d1=pd.DataFrame(title,columns=index)#
    gene=d1.iloc[1,:]
    gene=gene.tolist()
    #gene.append(dis_names[i])
    genes.append(gene)
    #print(genes)
    
    gene_res=dict(zip(dis_names,genes))
print(gene_res)

genes=np.array(genes)
genes=pd.DataFrame(genes)
genes.to_csv('dataset/qiuguan/results_K_FOLD_800/gene_100/NFM_layer_2_non_encode_genes.csv')
