# %%
import torch
import Trainer
#from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':100,#线性模型输出层（隐层个数）
    'embed_input_dim':1001,#embed输入维度
    'embed_dim': 100, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    'dnn_hidden_units': [50,9],#MLP隐层和输出层
    'num_sparse_features_cols':274,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 24,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'train_label': 'dataset/gene_247/train/guan_train_label.csv',
    'train_data':'dataset/gene_247/train/guan_train_data.csv',
    'test_label':'dataset/gene_247/test/qiu_test_label.csv',
    'test_data':'dataset/gene_247/test/qiu_test_data.csv'
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
}

# %%
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import torch.nn.functional as F  # 激励函数的库
#import network
import config
import evaluate
import data_utils
import Trainer
#from utils import

# %%
import numpy as np
import pandas as pd 

from sklearn.model_selection import train_test_split


X=pd.read_csv('dataset/gene_247/data/guan/guan_data_encode_1000.csv',sep=',')
X=X.iloc[1:,1:]
X=X.values

y=pd.read_csv('dataset/gene_247/data/guan/guan_label.csv',sep=',')
y=y.values
#y=np.array(y)
train_data,test_data,train_label,test_label=train_test_split(X,y,test_size=0.25,stratify=y,random_state=2)
print(train_data.shape)
print(test_data.shape)
print(train_label.shape)
print(test_label.shape)
print(train_data)
# Out:
# (253, 274)
# (85, 274)
# (253, 1)
# (85, 1)
# [[660 251 859 ... 644 109 353]
#  [647 214 810 ... 498 121 360]
#  [634 484 831 ... 570 143 343]
#  ...
#  [614 204 847 ... 654 101 362]
#  [728 232 859 ... 662  99 362]
#  [685 302 820 ... 587 182 359]]

# %%
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter

#import network
import config
import evaluate
import data_utils
import Trainer


# In[ ]:


def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    #n = len(labels)
    n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output

def one_hot(labels, classes):
    n = len(labels)
    #eoff = label_smoothing / classes
    output = np.zeros((n, classes), dtype=np.float32)
    for row, label in enumerate(labels):
        output[row, label] = 1
        #print("row:",row,"label:",label)
    return output

class FMData(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, fdata,flabel, n_class):
        super(FMData, self).__init__()
        self.label =torch.Tensor([])
        self.features = torch.Tensor([])
        self.bi_features=torch.Tensor([])
        
        
        #fd=pd.read_csv(file,sep=',')
        
        #n_fd=np.array(fd)
        
        
        self.features=np.array(fdata)
        self.bi_features=torch.from_numpy(self.features)
        self.bi_features=embding_process(nfm_config,self.bi_features)
        
        self.features=torch.from_numpy(self.features)
        nrow,ncol=self.features.shape
        

        
        #label_fd=pd.read_csv(label_file,sep=',')
        #print(features)
        #print(label_fd)
        label=np.array(flabel)
        #label=label[:,1:]
        label=one_hot_smoothing(label,n_class)
        self.label=label
        self.label=torch.from_numpy(self.label)
        
        #print(self.features)
        #print(self.bi_features)
        #print(self.label)
        #print("label:",label)
        #print("features:",self.features)
        #print(label)
        # convert labels
        """if config.loss_type == 'square_loss':
            self.label.append(np.float32(items[0]))
        else: # log_loss
            label = 1 if float(items[0]) > 0 else 0
            self.label.append(label)
        """
        
        """
        assert all(len(item) == len(self.features[0]
            ) for item in self.features), 'features are of different length'
        """
        #print(len(self.features))
        #print(len(self.feature_values))
        #print(len(self.label))

    def __len__(self):
        return len(self.label)

    def __getitem__(self, idx):
        label = self.label[idx]
        features = self.features[idx]
        bi_features=self.bi_features[idx]
        #feature_values = self.feature_values[idx]
        #return features, feature_values, label
        return features, bi_features, label

# %%
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn

# %%
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter

#import network
import config
import evaluate
import data_utils
import Trainer
#from utils import 
#准备训练集
#from new_dataset_processed import FMData
#from dataset_process import FMData
def prepare_dataset(m_data,m_label,batch_size,n_class):
    m_dataset=FMData(m_data,m_label,n_class)
    m_dataloader=data.DataLoader(m_dataset, drop_last=True,batch_size=batch_size,shuffle=True)
    
    return m_dataset,m_dataloader

# %%
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
#from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics
def   train_model(model,train_loader,test_loader,batch_size,model_path):
    #train_accuracy=torchmetrics.Accuracy()
    #test_accuracy=torchmetrics.Accuracy()
    BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    total = 0
    
    #loss_func = torch.nn.BCELoss()
    loss_func=torch.nn.CrossEntropyLoss()
    #loss_func=nn.MultiLabelSoftMarginLoss()
    #loss_func=torch.nn.LogSoftmax()
    num=2000
    #model=nn.Softmax(nn.Linear(10149,16)).to(device)
    # 从DataLoader中获取小批量的id以及数据
    
    batch_size=0
    for epoch_id in range(2000):
        correct=0
        total=0
        total_test_acc=0
        total_train_accuracy=0
        for batch_idx, (x, bi_x,labels) in enumerate(train_loader):
            x = Variable(x)
            bi_x=Variable(bi_x)
            labels = Variable(labels)
            
            
            #x = torch.tensor(x, dtype=torch.float)
            #x=x.clone().detach().requires_grad_(True)
            x=torch.tensor(x,dtype=torch.float)
            bi_x=torch.tensor(bi_x,dtype=torch.long)
            labels=torch.tensor(labels,dtype=torch.float)
            x, bi_x,labels = x.cuda(),bi_x.cuda(), labels.cuda()
            labels_int=labels=torch.max(labels,1)[1]
            
            optimizer.zero_grad()
            y_predict = model(x,bi_x)
            #print("y_predict:",y_predict)
            #loss = loss_func(y_predict.view(-1), labels)
            loss = loss_func(y_predict, labels)
            loss.backward()
            optimizer.step()
            
            loss = loss.item()
            #loss, predicted = self._train_single_batch(x, labels)

            total += loss
            #yhat = torch.max(yhat.data,1)[1]
            #yhat=yhat.detach().cpu().numpy()
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
             #predicted = torch.max(y_predict.data,1)[1]
            batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
            #print('batch_train_acc:',batch_train_acc)
            total_train_accuracy+=batch_train_acc
        #total_train_accuracy=torchmetrics.functional.compute_details()
        total_train_accuracy/=(batch_idx+1)
        print('total_train_accuracy:',total_train_accuracy)
        #print('total_train_accuracy:',total_train_accuracy)
        for i , (inputs ,bi_inputs, targets) in enumerate(test_loader):   
            print("test")
            # evaluate the model on the test set   
            #print(\ inputs:\  inputs)   
            #print(\ targets:\  targets)   
            inputs = Variable(inputs)   
            bi_inputs=Variable(bi_inputs)
            targets = Variable(targets)     
            #x = torch.tensor(x  dtype=torch.float)   
            #x=x.clone().detach().requires_grad_(True)   
            inputs=torch.tensor(inputs ,dtype=torch.float)  
            bi_inputs=torch.tensor(bi_inputs,dtype=torch.float)
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs ,bi_inputs, targets = inputs.cuda(),bi_inputs.cuda(), targets.cuda()   
            yhat = model(inputs,bi_inputs)  
            
            targets=torch.max(targets,1)[1]
            #print("labels:",labels)
            #labels=labels[1]
            #targets=targets.detach().cpu().numpy()
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            #print("batch_test_acc:",batch_test_acc)
            total_test_acc+=batch_test_acc
            #total_test_accuracy=torchmetrics.functional.compute_details()
            batch_size=i
        print('total_test_accuracy:',total_test_acc/(batch_size+1))
        
                    
                    
            
            #model.evaluate()
            #model.eval()
            #train_result = evaluate.metrics(model, train_loader)
            #valid_result = evaluate.metrics(model, valid_loader)
            #est_result = evaluate.metrics(model, test_loader)
            #acturals,predictions,acc_test=evaluate_model(test_loader,model)
            #print("acc_test:  %d  " %(acc_test))
            #print("Train_RMSE: {:.3f}, Valid_RMSE: {:.3f}, Test_RMSE: {:.3f}".format(
            #train_result, valid_result, test_result))
            # print('[Training Epoch: {}] Batch: {}, Loss: {}'.format(epoch_id, batch_id, loss))
        print("Training Epoch: %d, total loss: %f" % (epoch_id, total))
        #print("auc:",roc_auc_score)
    #功能：保存训练完的网络的各层参数（即weights和bias)
    #path='dataset/xiaoguan/RF/RF_for_train/train_class_9/model/gene_4000_NFM.pkl'
        if epoch_id %100==0:
            num=num+1
            path=os.path.join(model_path,'NMF'+str(num)+'.pkl')
            torch.save(model.state_dict(),path)

# %%
import torch.nn as nn
class BiInteractionPooling(nn.Module):
    """Bi-Interaction Layer used in Neural FM,compress the
      pairwise element-wise product of features into one single vector.
      Input shape
        - A 3D tensor with shape:``(batch_size,field_size,embedding_size)``.
      Output shape
    http://127.0.0.1:3000/notebooks/NFM-pyorch-master/NFM-pyorch-master/%E6%9C%AA%E5%91%BD%E5%90%8D5.ipynb?kernel_name=python3#    - 3D tensor with shape: ``(batch_size,1,embedding_size)``.
    """
    def __init__(self):
        super(BiInteractionPooling, self).__init__()

    def forward(self, inputs):
        concated_embeds_value = inputs
        square_of_sum = torch.pow(
            torch.sum(concated_embeds_value, dim=1, keepdim=True), 2)
        sum_of_square = torch.sum(
            concated_embeds_value * concated_embeds_value, dim=1, keepdim=True)
        cross_term = 0.5 * (square_of_sum - sum_of_square)
        return cross_term

# %%
def embding_process(config,sparse_inputs):
    
    sparse_inputs=sparse_inputs.long()###
    embedding_layers=nn.Embedding(config['embed_input_dim'],config['embed_dim'])
        
    # B-Interaction 层
    bi_pooling = BiInteractionPooling()
    bi_dropout = config['bi_dropout']
    if bi_dropout > 0:
        dropout = nn.Dropout(bi_dropout)
            
    num_sparse_feature=config['num_sparse_features_cols']
    
    sparse_embeds = [embedding_layers(sparse_inputs[:, i]) for i in range(sparse_inputs.shape[1])]
    sparse_embeds = torch.cat(sparse_embeds, axis=-1)
    BN_bi = nn.BatchNorm1d(config['embed_dim'])
    # 送入B-Interaction层
    fm_input = sparse_embeds.view(-1, num_sparse_feature, config['embed_dim'])#整理成n行m列
    # print(fm_input)
    # print(fm_input.shape)

    bi_out = bi_pooling(fm_input)
    if bi_dropout:
        bi_out = dropout(bi_out)

    bi_out = bi_out.view(-1, config['embed_dim'])
    bi_out=BN_bi(bi_out)
    
    return bi_out

# %%
import torch
import torch.nn as nn
from basemodel import BaseModel
import torch.nn.functional as F



    



class NFM(BaseModel):
    def __init__(self, config, dense_features_cols=[]):#=[]为新增
    #def __init__(self, config, dense_features_cols, sparse_features_cols):
        super(NFM, self).__init__(config)
        # 稠密和稀疏特征的数量
        #self.num_dense_feature = dense_features_cols.__len__()
        self.num_dense_feature = 0#修改
        self.num_sparse_feature = config['num_sparse_features_cols']
        #self.num_sparse_feature = 0##修改
        self.__config=config
        
        
        self.BN_num=nn.BatchNorm1d(self.num_sparse_feature)
        self.linear1=nn.Linear(config['num_sparse_features_cols'],config['linear_hidden1'])
        self.bn1=nn.BatchNorm1d(config['linear_hidden1'])
        self.drop1=nn.Dropout(0.5)
        self.relu1=nn.ReLU()
        
        self.linear2=nn.Linear(config['linear_hidden1']+config['embed_dim'],config['dnn_hidden_units'][0])
        self.bn2=nn.BatchNorm1d(config['dnn_hidden_units'][0])
        self.drop2=nn.Dropout(0.5)
        self.relu2=nn.ReLU()
        
        self.linear3=nn.Linear(config['dnn_hidden_units'][0],config['dnn_hidden_units'][1])
        self.bn3=nn.BatchNorm1d(config['dnn_hidden_units'][1])
        #self.drop3=nn.Dropout(0.3)
        self.relu3=nn.ReLU()
        
        #self.embedding_layers=nn.Embedding(config['embed_input_dim'],config['embed_dim'])
        
        
            
            
        
        
        
        #self.dnn_softmax=nn.Softmax(dim=1) # 按列SoftMax,列和为1  #注意nn.softmax的定义和调用
        #self.dnn_softmax_=F.softmax(dim=1)
        #self.dnn_hidden_units=config['dnn_hidden_units']
    def forward(self, x,bi_x):
        # 先区分出稀疏特征和稠密特征，这里是按照列来划分的，即所有的行都要进行筛选
        #bi_x=bi_x.long()
        #print(x.dtype)
        # 求出线性部分
        #x=F.relu(self.drop(self.BN_linear1(self.linear_model1(self.BN_num(x))))
        #x=F.relu(self.drop(self.BN_linear1(self.linear_model1(x))))
        x=self.BN_num(x)
        #x=self.linear_model1(x)
        
        #x1=torch.cat((x,bi_x),dim=1)
        #print("linear_output:",linear_output)
        #linear_output=linear_output.view(-1,self.__config['linear_hidden1'])
        #linear_output=self.drop(linear_output)
        #linear_output=self.BN_linear(linear_output)
        # 求出稀疏特征的embedding向量
        
        
        #print('bi_out.shape:',bi_out.shape)
        #print(x.dtype)
        #print(bi_out.dtype)
        
        #input=x,bi_x#不能是list，必须是tensor
        #x1,x2=input
        y1=self.relu1(self.drop1(self.bn1(self.linear1(x))))
        x2=torch.cat((y1,bi_x),dim=1)
        #print('y1.shape:',y1.shape)
        y2=self.relu2(self.drop2(self.bn2(self.linear2(x2))))
        #print('y2.shape:',y2.shape)
        #x3=torch.cat((y2,x2),dim=1)
        #x3=torch.cat((y2,bi_x),dim=1)
        #print('x3.shape:',x3.shape)
        y3=self.relu3(self.bn3(self.linear3(y2)))
        #print('y3.shape:',y3.shape)
        y=F.softmax(y3,dim=1)
        
        y_pred=y
        #y_pred=self.dnn_softmax(dnn_output)#增加
        #y_pred=F.softmax(dnn_output,dim=0)
        # Final
        #output = linear_output + y_pred#修改
        #y_pred = self.dnn_softmax(output,dim=0)

        return y_pred

# %%
train_dataset,train_loader=prepare_dataset(train_data,train_label,nfm_config['batch_size'],nfm_config['n_class'])
test_dataset,test_loader=prepare_dataset(test_data,test_label,nfm_config['batch_size'],nfm_config['n_class'])

#from new_nfm_network_batch_1 import NFM
#model=MLP(10477,1000,100,9)
model=NFM(nfm_config)
model.cuda()#########
print("NFM:",model)
train_model(model,train_loader,test_loader,nfm_config['batch_size'],'dataset/gene_247/model/NFM_non_encode/')
# Out:
# NFM: NFM(
#   (BN_num): BatchNorm1d(274, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=374, out_features=100, bias=True)
#   (bn1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=100, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# total_train_accuracy: tensor(0.1417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.1806, device='cuda:0')
# Training Epoch: 0, total loss: 21.974501
# total_train_accuracy: tensor(0.1583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.1528, device='cuda:0')
# Training Epoch: 1, total loss: 21.828291
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:56: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:94: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:95: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:96: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.2500, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.2639, device='cuda:0')
# Training Epoch: 2, total loss: 21.582507
# total_train_accuracy: tensor(0.2625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.2083, device='cuda:0')
# Training Epoch: 3, total loss: 21.455648
# total_train_accuracy: tensor(0.3375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.2778, device='cuda:0')
# Training Epoch: 4, total loss: 21.297174
# total_train_accuracy: tensor(0.3458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.2361, device='cuda:0')
# Training Epoch: 5, total loss: 21.064723
# total_train_accuracy: tensor(0.3542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.3611, device='cuda:0')
# Training Epoch: 6, total loss: 20.998100
# total_train_accuracy: tensor(0.3917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.3611, device='cuda:0')
# Training Epoch: 7, total loss: 20.808826
# total_train_accuracy: tensor(0.4542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.3750, device='cuda:0')
# Training Epoch: 8, total loss: 20.675271
# total_train_accuracy: tensor(0.5250, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.3333, device='cuda:0')
# Training Epoch: 9, total loss: 20.449696
# total_train_accuracy: tensor(0.5417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.3472, device='cuda:0')
# Training Epoch: 10, total loss: 20.233680
# total_train_accuracy: tensor(0.5333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4028, device='cuda:0')
# Training Epoch: 11, total loss: 20.305247
# total_train_accuracy: tensor(0.6292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4306, device='cuda:0')
# Training Epoch: 12, total loss: 19.853452
# total_train_accuracy: tensor(0.6125, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4167, device='cuda:0')
# Training Epoch: 13, total loss: 19.817378
# total_train_accuracy: tensor(0.6417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4583, device='cuda:0')
# Training Epoch: 14, total loss: 19.725674
# total_train_accuracy: tensor(0.6000, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 15, total loss: 19.790738
# total_train_accuracy: tensor(0.6667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 16, total loss: 19.458868
# total_train_accuracy: tensor(0.6625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 17, total loss: 19.456933
# total_train_accuracy: tensor(0.6667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 18, total loss: 19.420207
# total_train_accuracy: tensor(0.6917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4028, device='cuda:0')
# Training Epoch: 19, total loss: 19.371017
# total_train_accuracy: tensor(0.6958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 20, total loss: 19.066555
# total_train_accuracy: tensor(0.6917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 21, total loss: 19.138943
# total_train_accuracy: tensor(0.7125, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 22, total loss: 19.096071
# total_train_accuracy: tensor(0.7542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 23, total loss: 18.710092
# total_train_accuracy: tensor(0.7333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4444, device='cuda:0')
# Training Epoch: 24, total loss: 18.709341
# total_train_accuracy: tensor(0.7833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 25, total loss: 18.641557
# total_train_accuracy: tensor(0.7583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 26, total loss: 18.579270
# total_train_accuracy: tensor(0.7875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 27, total loss: 18.413182
# total_train_accuracy: tensor(0.7917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 28, total loss: 18.329174
# total_train_accuracy: tensor(0.7917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 29, total loss: 18.402565
# total_train_accuracy: tensor(0.7583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 30, total loss: 18.592397
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 31, total loss: 18.031054
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 32, total loss: 18.137853
# total_train_accuracy: tensor(0.7792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 33, total loss: 18.185899
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 34, total loss: 17.961066
# total_train_accuracy: tensor(0.8292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 35, total loss: 17.956416
# total_train_accuracy: tensor(0.8333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4583, device='cuda:0')
# Training Epoch: 36, total loss: 17.822065
# total_train_accuracy: tensor(0.7625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 37, total loss: 18.098174
# total_train_accuracy: tensor(0.7875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4444, device='cuda:0')
# Training Epoch: 38, total loss: 17.938224
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 39, total loss: 17.728445
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4444, device='cuda:0')
# Training Epoch: 40, total loss: 17.590831
# total_train_accuracy: tensor(0.8250, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 41, total loss: 17.768099
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 42, total loss: 17.778461
# total_train_accuracy: tensor(0.7958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 43, total loss: 17.786403
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 44, total loss: 17.539376
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 45, total loss: 17.313566
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 46, total loss: 17.374261
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 47, total loss: 17.138774
# total_train_accuracy: tensor(0.8542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 48, total loss: 17.399814
# total_train_accuracy: tensor(0.8542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 49, total loss: 17.352501
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4583, device='cuda:0')
# Training Epoch: 50, total loss: 17.228107
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 51, total loss: 17.129931
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 52, total loss: 17.220218
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 53, total loss: 16.989712
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 54, total loss: 16.864793
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 55, total loss: 16.811583
# total_train_accuracy: tensor(0.8708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 56, total loss: 17.005569
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 57, total loss: 16.744490
# total_train_accuracy: tensor(0.8333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 58, total loss: 17.203399
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 59, total loss: 16.995083
# total_train_accuracy: tensor(0.8708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 60, total loss: 16.907859
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 61, total loss: 16.777836
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6389, device='cuda:0')
# Training Epoch: 62, total loss: 16.698459
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 63, total loss: 16.912736
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 64, total loss: 16.697166
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 65, total loss: 16.631338
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 66, total loss: 16.847830
# total_train_accuracy: tensor(0.8708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 67, total loss: 16.881250
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 68, total loss: 16.905648
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 69, total loss: 16.545339
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 70, total loss: 16.770754
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4028, device='cuda:0')
# Training Epoch: 71, total loss: 16.575286
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 72, total loss: 16.469213
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 73, total loss: 16.454717
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 74, total loss: 16.711171
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 75, total loss: 16.432053
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 76, total loss: 16.361313
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 77, total loss: 16.357639
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 78, total loss: 16.634901
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6250, device='cuda:0')
# Training Epoch: 79, total loss: 16.225791
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 80, total loss: 16.335138
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 81, total loss: 16.296371
# total_train_accuracy: tensor(0.8542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 82, total loss: 16.731193
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 83, total loss: 16.300121
# total_train_accuracy: tensor(0.8667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 84, total loss: 16.483238
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6389, device='cuda:0')
# Training Epoch: 85, total loss: 16.742459
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 86, total loss: 16.310521
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 87, total loss: 16.315883
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 88, total loss: 16.349819
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4306, device='cuda:0')
# Training Epoch: 89, total loss: 16.220309
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 90, total loss: 16.265953
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 91, total loss: 16.267803
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 92, total loss: 16.050223
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 93, total loss: 16.259562
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 94, total loss: 16.245576
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 95, total loss: 16.130540
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 96, total loss: 16.478962
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 97, total loss: 16.087514
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 98, total loss: 16.273942
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6250, device='cuda:0')
# Training Epoch: 99, total loss: 15.826420
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 100, total loss: 15.859440
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 101, total loss: 16.096977
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 102, total loss: 15.938934
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 103, total loss: 16.232214
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 104, total loss: 16.008912
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 105, total loss: 15.994870
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 106, total loss: 16.037437
# total_train_accuracy: tensor(0.8667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 107, total loss: 16.301506
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 108, total loss: 15.952718
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 109, total loss: 15.979759
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 110, total loss: 16.016538
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 111, total loss: 16.076349
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 112, total loss: 16.152824
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 113, total loss: 15.869828
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 114, total loss: 15.797345
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 115, total loss: 15.969480
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.7222, device='cuda:0')
# Training Epoch: 116, total loss: 16.119599
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 117, total loss: 16.114088
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 118, total loss: 15.866317
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 119, total loss: 16.080841
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6389, device='cuda:0')
# Training Epoch: 120, total loss: 15.634606
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 121, total loss: 16.163529
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 122, total loss: 15.900946
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6250, device='cuda:0')
# Training Epoch: 123, total loss: 15.630170
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6389, device='cuda:0')
# Training Epoch: 124, total loss: 15.831618
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 125, total loss: 15.902739
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 126, total loss: 15.964739
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 127, total loss: 15.928772
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 128, total loss: 15.812327
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 129, total loss: 15.834511
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 130, total loss: 15.521635
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6250, device='cuda:0')
# Training Epoch: 131, total loss: 15.465017
# total_train_accuracy: tensor(0.8708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 132, total loss: 15.948851
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 133, total loss: 15.628400
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 134, total loss: 15.543879
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 135, total loss: 15.605446
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 136, total loss: 15.603193
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 137, total loss: 15.941209
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 138, total loss: 15.588352
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 139, total loss: 15.973279
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 140, total loss: 15.881221
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 141, total loss: 15.832606
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6667, device='cuda:0')
# Training Epoch: 142, total loss: 15.415913
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 143, total loss: 15.908240
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 144, total loss: 15.531268
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 145, total loss: 15.675978
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 146, total loss: 15.777895
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4583, device='cuda:0')
# Training Epoch: 147, total loss: 15.644309
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6667, device='cuda:0')
# Training Epoch: 148, total loss: 15.773006
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 149, total loss: 15.653171
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 150, total loss: 15.634801
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 151, total loss: 15.510395
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 152, total loss: 15.790519
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 153, total loss: 15.479768
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 154, total loss: 15.639325
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 155, total loss: 15.890867
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 156, total loss: 15.280047
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 157, total loss: 15.477816
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 158, total loss: 15.502838
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 159, total loss: 15.400307
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 160, total loss: 15.476063
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 161, total loss: 15.412121
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 162, total loss: 15.443601
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 163, total loss: 15.599774
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 164, total loss: 15.592821
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 165, total loss: 15.480627
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 166, total loss: 15.166332
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 167, total loss: 15.264591
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6806, device='cuda:0')
# Training Epoch: 168, total loss: 15.401885
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 169, total loss: 15.410375
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6389, device='cuda:0')
# Training Epoch: 170, total loss: 15.684333
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 171, total loss: 15.390885
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 172, total loss: 15.392588
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6806, device='cuda:0')
# Training Epoch: 173, total loss: 15.321503
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 174, total loss: 15.393257
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6250, device='cuda:0')
# Training Epoch: 175, total loss: 15.463614
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 176, total loss: 15.252204
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 177, total loss: 15.418859
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6667, device='cuda:0')
# Training Epoch: 178, total loss: 15.234382
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 179, total loss: 15.344757
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 180, total loss: 15.141350
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 181, total loss: 15.352251
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 182, total loss: 15.117809
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6667, device='cuda:0')
# Training Epoch: 183, total loss: 15.263314
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 184, total loss: 15.549015
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 185, total loss: 15.236045
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 186, total loss: 15.450834
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 187, total loss: 15.128768
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 188, total loss: 15.589074
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 189, total loss: 15.467969
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6389, device='cuda:0')
# Training Epoch: 190, total loss: 15.099314
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 191, total loss: 15.118684
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 192, total loss: 15.222905
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 193, total loss: 15.031648
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 194, total loss: 15.364290
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 195, total loss: 15.084982
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 196, total loss: 15.390378
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 197, total loss: 15.249479
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 198, total loss: 15.317137
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 199, total loss: 15.283610
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 200, total loss: 15.202746
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 201, total loss: 14.999905
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 202, total loss: 15.429552
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6389, device='cuda:0')
# Training Epoch: 203, total loss: 15.340434
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 204, total loss: 15.123726
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 205, total loss: 15.195482
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6389, device='cuda:0')
# Training Epoch: 206, total loss: 15.017785
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 207, total loss: 15.279632
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 208, total loss: 15.390976
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6250, device='cuda:0')
# Training Epoch: 209, total loss: 14.821417
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 210, total loss: 14.922508
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 211, total loss: 15.033885
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 212, total loss: 15.148407
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 213, total loss: 15.099445
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 214, total loss: 14.953711
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 215, total loss: 15.002922
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 216, total loss: 15.038477
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 217, total loss: 15.297578
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 218, total loss: 15.209337
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 219, total loss: 15.091366
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 220, total loss: 15.012290
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 221, total loss: 15.105244
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 222, total loss: 15.268643
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6528, device='cuda:0')
# Training Epoch: 223, total loss: 15.347912
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 224, total loss: 15.229058
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 225, total loss: 15.159873
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 226, total loss: 15.014177
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4722, device='cuda:0')
# Training Epoch: 227, total loss: 14.893836
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 228, total loss: 15.616554
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 229, total loss: 15.442524
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 230, total loss: 15.072860
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6667, device='cuda:0')
# Training Epoch: 231, total loss: 15.334762
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 232, total loss: 15.091758
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 233, total loss: 15.080029
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 234, total loss: 15.321186
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6528, device='cuda:0')
# Training Epoch: 235, total loss: 15.250924
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 236, total loss: 14.961037
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 237, total loss: 15.260718
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 238, total loss: 14.937639
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 239, total loss: 15.041690
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6250, device='cuda:0')
# Training Epoch: 240, total loss: 15.052461
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 241, total loss: 15.050852
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 242, total loss: 14.974919
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 243, total loss: 15.053288
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6389, device='cuda:0')
# Training Epoch: 244, total loss: 14.842170
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 245, total loss: 15.272343
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 246, total loss: 15.202499
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6389, device='cuda:0')
# Training Epoch: 247, total loss: 14.833718
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 248, total loss: 15.115319
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 249, total loss: 15.111026
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 250, total loss: 14.858626
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 251, total loss: 15.119741
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 252, total loss: 14.713545
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 253, total loss: 15.246854
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 254, total loss: 15.040015
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 255, total loss: 14.796265
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6528, device='cuda:0')
# Training Epoch: 256, total loss: 14.935693
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6250, device='cuda:0')
# Training Epoch: 257, total loss: 15.039665
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 258, total loss: 14.796918
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 259, total loss: 14.822518
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 260, total loss: 14.630846
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 261, total loss: 15.040862
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 262, total loss: 15.010664
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 263, total loss: 14.883619
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6528, device='cuda:0')
# Training Epoch: 264, total loss: 15.055742
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 265, total loss: 14.808160
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 266, total loss: 14.823941
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 267, total loss: 14.847276
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 268, total loss: 15.240541
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 269, total loss: 14.869784
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 270, total loss: 14.978620
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 271, total loss: 14.889581
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 272, total loss: 15.065889
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 273, total loss: 15.010169
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 274, total loss: 14.798068
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 275, total loss: 14.629407
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 276, total loss: 14.692757
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# test
# test
# ...
# Training Epoch: 1903, total loss: 14.458205
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1904, total loss: 14.080950
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 1905, total loss: 14.042445
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 1906, total loss: 14.077417
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1907, total loss: 14.168244
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 1908, total loss: 14.021265
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1909, total loss: 14.136319
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 1910, total loss: 13.973177
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1911, total loss: 14.025366
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 1912, total loss: 14.078157
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 1913, total loss: 14.086813
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 1914, total loss: 14.093173
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 1915, total loss: 13.972612
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 1916, total loss: 13.968947
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 1917, total loss: 13.959295
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 1918, total loss: 14.131411
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 1919, total loss: 14.003117
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 1920, total loss: 14.019994
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 1921, total loss: 14.076635
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 1922, total loss: 14.152116
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 1923, total loss: 13.981899
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 1924, total loss: 13.924198
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1925, total loss: 14.102651
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4722, device='cuda:0')
# Training Epoch: 1926, total loss: 13.987093
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 1927, total loss: 14.028969
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1928, total loss: 14.125535
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 1929, total loss: 14.173353
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4444, device='cuda:0')
# Training Epoch: 1930, total loss: 13.948462
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1931, total loss: 14.040685
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4167, device='cuda:0')
# Training Epoch: 1932, total loss: 13.945256
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1933, total loss: 13.920448
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 1934, total loss: 13.962598
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6250, device='cuda:0')
# Training Epoch: 1935, total loss: 13.986078
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 1936, total loss: 14.069349
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 1937, total loss: 14.023597
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 1938, total loss: 13.829955
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 1939, total loss: 13.942956
# total_train_accuracy: tensor(1., device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 1940, total loss: 13.841896
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 1941, total loss: 14.115130
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4722, device='cuda:0')
# Training Epoch: 1942, total loss: 14.079225
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4722, device='cuda:0')
# Training Epoch: 1943, total loss: 13.928776
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 1944, total loss: 14.185073
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 1945, total loss: 14.025664
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1946, total loss: 13.890863
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 1947, total loss: 14.003007
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4583, device='cuda:0')
# Training Epoch: 1948, total loss: 13.997286
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1949, total loss: 14.093913
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1950, total loss: 14.036654
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1951, total loss: 13.972266
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1952, total loss: 14.087124
# total_train_accuracy: tensor(1., device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 1953, total loss: 13.876583
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1954, total loss: 13.961580
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 1955, total loss: 13.998085
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4444, device='cuda:0')
# Training Epoch: 1956, total loss: 14.079458
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1957, total loss: 13.974779
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4444, device='cuda:0')
# Training Epoch: 1958, total loss: 14.068202
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 1959, total loss: 14.128435
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1960, total loss: 14.042730
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 1961, total loss: 13.989949
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4583, device='cuda:0')
# Training Epoch: 1962, total loss: 14.290638
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4444, device='cuda:0')
# Training Epoch: 1963, total loss: 14.044721
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 1964, total loss: 13.939364
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 1965, total loss: 13.903119
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4167, device='cuda:0')
# Training Epoch: 1966, total loss: 14.130549
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1967, total loss: 13.971824
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1968, total loss: 14.036588
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 1969, total loss: 14.045466
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 1970, total loss: 14.137556
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1971, total loss: 13.927778
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1972, total loss: 14.094339
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 1973, total loss: 14.072141
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1974, total loss: 14.064245
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1975, total loss: 14.002966
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1976, total loss: 13.930107
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4722, device='cuda:0')
# Training Epoch: 1977, total loss: 14.187069
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 1978, total loss: 14.026256
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4583, device='cuda:0')
# Training Epoch: 1979, total loss: 14.146861
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 1980, total loss: 13.983171
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4583, device='cuda:0')
# Training Epoch: 1981, total loss: 14.088079
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4583, device='cuda:0')
# Training Epoch: 1982, total loss: 14.052660
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1983, total loss: 13.963304
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 1984, total loss: 14.025947
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 1985, total loss: 14.105677
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 1986, total loss: 13.991863
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4583, device='cuda:0')
# Training Epoch: 1987, total loss: 14.025075
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4722, device='cuda:0')
# Training Epoch: 1988, total loss: 14.017100
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4722, device='cuda:0')
# Training Epoch: 1989, total loss: 14.084079
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5556, device='cuda:0')
# Training Epoch: 1990, total loss: 13.996460
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4722, device='cuda:0')
# Training Epoch: 1991, total loss: 14.028040
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1992, total loss: 14.206021
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4444, device='cuda:0')
# Training Epoch: 1993, total loss: 14.062898
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5139, device='cuda:0')
# Training Epoch: 1994, total loss: 14.057969
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1995, total loss: 14.073013
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4306, device='cuda:0')
# Training Epoch: 1996, total loss: 14.142310
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 1997, total loss: 14.199039
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 1998, total loss: 14.040630
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# test
# test
# test
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 1999, total loss: 14.056685

# %%
import torch

#功能：加载保存到path中的各层参数到神经网络
#from new_nfm_network import NFM
path='dataset/gene_247/data/model/NMF2020.pkl'
nfm = NFM(nfm_config).cuda()
net=nfm
print(net)
#net = nn.DataParallel(net)
#net = net.to(device)
net.load_state_dict(torch.load(path),strict=False)
net.cuda()

print(net)

params = list(net.named_parameters())
print(params)
