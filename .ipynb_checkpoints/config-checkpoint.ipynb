# %%
# %load config.py
#!/usr/bin/env python

# In[ ]:


# %load config.py
#!/usr/bin/env python

# In[ ]:


# %load config.py
#!/usr/bin/env python

# In[ ]:


dataset = 'frappe'
assert dataset in ['ml-tag', 'frappe']

# model name
model = 'NFM'
assert model in ['FM', 'NFM']

# as the log_loss is not implemented in Xiangnan's repo, I thus remove this loss type
#loss_type = 'square_loss'
#assert loss_type in ['square_loss'] 
loss_type='cross_entropy_loss'
assert loss_type in ['cross_entropy_loss']
# important settings (normally default is the paper choice)
optimizer = 'Adagrad'


activation_function = 'softmax'
assert optimizer in ['Adagrad', 'Adam', 'SGD', 'Momentum']
assert activation_function in ['relu', 'sigmoid', 'tanh', 'identity','softmax']

# paths
main_path = 'data/{}/'.format(dataset)

#train_libfm = main_path + '{}.train.libfm'.format(dataset)
#valid_libfm = main_path + '{}.validation.libfm'.format(dataset)
#test_libfm = main_path + '{}.test.libfm'.format(dataset)


train_libfm = main_path + '{}.train_data.csv'.format(dataset)
valid_libfm = main_path + '{}.validation_data.csv'.format(dataset)
test_libfm = main_path + '{}.test_data.csv'.format(dataset)


train_label = main_path + '{}.train_label.csv'.format(dataset)
valid_label = main_path + '{}.validation_label.csv'.format(dataset)
test_label = main_path + '{}.test_label.csv'.format(dataset)


model_path = './models/'
FM_model_path = model_path + 'FM.pth' # useful when pre-train
NFM_model_path = model_path + 'NFM.pth'


# In[ ]:





# In[ ]:
