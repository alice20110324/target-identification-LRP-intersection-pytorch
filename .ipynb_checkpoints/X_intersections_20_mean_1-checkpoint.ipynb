# %%
#computer intersection of two models or three models
#considerate top 20 and top 30 


#firstly computer intersection of every disease
#then computer the union of them and get the feature genes
#extract new dataset based on the features
#evaluate the new dataset according to the classification efficient of the model trained by the dataset

# %%
#related functions to evaluate models

import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':2000,
    #'linear_hidden':100,#线性模型输出层（隐层个数）
    #'embed_input_dim':1001,#embed输入维度
    #'embed_dim': 100, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    #'dnn_hidden_units': [100,11],#MLP隐层和输出层
    
    'dnn_hidden_units':[100,9],#MLP隐层
    'num_sparse_features_cols':10477,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 16,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'epoch':1000,
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    #'train_file':'data/xiaoqiu_gene_5000/train/final_5000_encode_100x.csv',
    #'train_data':'dataset/qiuguan/encode/encode_1000/train/train_encode_data_1000_new.csv',
    #'train_label':'dataset/qiuguan/non_code/train/train_label.csv',
    #'guan_test_data':'dataset/qiuguan/non_code/guan_test/guan_test_data.csv',
    #'guan_test_label':'dataset/qiuguan/non_code/guan_test/guan_test_label.csv',
    #'test_data':'dataset/qiuguan/encode/encode_1000/test/test_encode_data_1000_new.csv',
    #'test_label':'dataset/qiuguan/non_code/test/test_labels.csv',
    #'title':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_data.csv',
    
    #'all':''
    #'title':'data/xiaoqiu_gene_5000/train/gene_5000_gene_name.csv',
    #'all':'data/xiaoqiu_gene_5000/train/gene_5000_label_name.csv'
}

#model definition
import torch.nn as nn
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(3300)
        self.fc1 = nn.Linear(3300, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model = MLP().cuda()
print(model)

class MLP1(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(237)
        self.fc1 = nn.Linear(237, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model1 = MLP1().cuda()
print(model1)
class MLP2(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(93)
        self.fc1 = nn.Linear(93, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model2 = MLP2().cuda()
print(model2)
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import torch.nn.functional as F  # 激励函数的库
#import network
import config
import evaluate
import data_utils
#import Trainer



def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    #n = len(labels)
    n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output

def one_hot(labels, classes):
    n = len(labels)
    #eoff = label_smoothing / classes
    output = np.zeros((n, classes), dtype=np.float32)
    for row, label in enumerate(labels):
        output[row, label] = 1
        #print("row:",row,"label:",label)
    return output


def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    #n = len(labels)
    n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output

def one_hot(labels, classes):
    n = len(labels)
    #eoff = label_smoothing / classes
    output = np.zeros((n, classes), dtype=np.float32)
    for row, label in enumerate(labels):
        output[row, label] = 1
        #print("row:",row,"label:",label)
    return output



class KZDatasetPredict(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, df_list):
    
       
        self.data_info = self.get_data_info(df_list)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data,label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data,label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,df_list):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        print('data_info:',df_list[-1])
        #df=pd.read_csv(csv_path,sep=',')
        #df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        label=int(df_list[-1])
        labels.append(label)
        print('labels:',labels)
        data=df_list[:-1]
        #df_np=np.array(df_list)
        #print(rows,cols)
        
        #print('labels:',labels)
        labels=np.array(labels)
        print('labels.shape:',labels.shape)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        
           
        
        data=np.array(data)#
            
            
            
            
            
            
            
            
        data=torch.from_numpy(data)#
            
        labels=torch.from_numpy(labels)#
        #bi_data=embding_process(nfm_config,data)
        #print("bi_data.shape:",bi_data.shape)
            
            
        data_info.append((data,label))
        return data_info
class KZDatasetTest(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, csv_path):
    
       
        self.data_info = self.get_data_info(csv_path)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]
            data=data.astype(float)#
            data=np.array(data)#
            
            label=labels[i]
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            label=torch.from_numpy(label)#
            
            
            data_info.append((data,label))
        return data_info
import torch
import torch.nn as nn
from torch.utils.data.dataset import *
from PIL import Image
from torch.nn import functional as F
import random
from sklearn.model_selection import train_test_split
import ast
import torchvision


        

class KZDataset(Dataset):
    def __init__(self, csv_path, K,n_class,ki=0, typ='train', transform=None, rand=False):
       
        self.all_data_info = self.get_data_info(csv_path)
        
        if rand:
            random.seed(1)
            random.shuffle(self.all_data_info)
        leng = len(self.all_data_info)
        every_z_len = leng // K
        if typ == 'val':
            self.data_info = self.all_data_info[every_z_len * ki : every_z_len * (ki+1)]
        elif typ == 'train':
            self.data_info = self.all_data_info[: every_z_len * ki] + self.all_data_info[every_z_len * (ki+1) :]
            
        self.transform = transform
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, label

    def __len__(self):
        return len(self.data_info)
    
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        
        print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]
            data=data.astype(float)#
            data=np.array(data)#
            
            label=labels[i]
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            label=torch.from_numpy(label)#
            
            
            data_info.append((data,label))
        return data_info
            
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics

from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics


def train_epoch(model,train_loader,batch_size,optimizer,loss_func):
    BATCH_SIZE=batch_size
    total = 0
    correct=0
    total_loss=0
    #
    model.train()
    total_train_accuracy=0  
    for batch_idx, (x, labels) in enumerate(train_loader):
            
        labels = Variable(labels)
        x = Variable(x)
            
            
        x=torch.tensor(x,dtype=torch.float)
        labels=torch.tensor(labels,dtype=torch.float)
        x, labels = x.cuda(), labels.cuda()
        labels_int=labels=torch.max(labels,1)[1]
            
            
        optimizer.zero_grad()
        y_predict = model(x)
            
        loss = loss_func(y_predict, labels)
        loss.backward()
        optimizer.step()
            
        loss = loss.item()
           

        total_loss += loss
            
            
            
        batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
        total_train_accuracy+=batch_train_acc
            
    total_train_accuracy/=(batch_idx+1)
    print('total_train_accuracy:',total_train_accuracy)
    print("Training Epoch: %d, total loss: %f" % (epoch_id, total_loss))
    return total_loss,total_train_accuracy

def val_epoch(model,test_loader,batch_size,optimizer): 
    batch_size_num=0
    total_test_acc=0
    model.eval()
    for i , (inputs , targets) in enumerate(test_loader):   
            print("test")
            
            inputs = Variable(inputs)   
            targets = Variable(targets)     
           
            inputs=torch.tensor(inputs ,dtype=torch.float)   
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs , targets = inputs.cuda(),  targets.cuda()   
            yhat = model(inputs)  
            
            
            
            targets=torch.max(targets,1)[1]
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            
            total_test_acc+=batch_test_acc
            
            batch_size_num=i
    total_test_acc/=(batch_size_num+1)
        ###print('total_test_accuracy:',total_test_acc/(batch_size+1))
    print('total_test_accuracy:',total_test_acc)
        
                    
                    
            
            
    
        
   
    
    return total_test_acc


import numpy as np
import math
import matplotlib.pyplot as plt

def plotLoss(loss,epoch):
    plt.rcParams['font.sans-serif']=['SimHei']
    plt.rcParams['axes.unicode_minus'] = False
    plt.figure(figsize=(8, 5))
    x=[i for i in range(epoch)]
    #acc_train=acc_train.cpu()
    #acc_test=acc_test.cpu()
    plt.plot(x, loss, 'r-', mec='k', label='Logistic Loss', lw=2)
    #plt.plot(x,acc_train,'b-',mec='k',label='accuracy Train',lw=2)
    #plt.plot(x,acc_test,'g-',mec='k',label='accuracy Test',lw=2)
    #plt.plot(x, y_01, 'g-', mec='k', label='0/1 Loss', lw=2)
    #plt.plot(x, y_hinge, 'b-',mec='k', label='Hinge Loss', lw=2)
    #plt.plot(x, boost, 'm--',mec='k', label='Adaboost Loss',lw=2)
    plt.grid(True, ls='--')
    plt.legend(loc='upper right')
    plt.title('损失函数')
    plt.show()

# %%
#begining evaluate
#MLP and NFM
#top 20
#for 20_genes
import pandas as pd 
import numpy as np
mlp_20_path='results_genes/MLP/contri_20_names_df_from_train_mean.csv'
nfm_layer_20_path='results_genes/NFM_layer_2/contri_20_names_df_from_train_mean.csv'


mlp_20_df=pd.read_csv(mlp_20_path,sep=',')
nfm_layer_20_df=pd.read_csv(nfm_layer_20_path,sep=',')

#print(mlp_20_df)
mlp_20_df=mlp_20_df.iloc[:,1:]
nfm_layer_20_df=nfm_layer_20_df.iloc[:,1:]
#print(mlp_20_df.shape)
mlp_20_np=np.array(mlp_20_df)
nfm_layer_20_np=np.array(nfm_layer_20_df)

#print(mlp_20_np)


import csv
csv_filename = "results_genes/intersections/intersecions_20_df_from_train_mean.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    #writer.writerow(result_list)

    #intersections_20_list=[]
    for i in range(9):
        mlp_data=mlp_20_np[i,:].tolist()
        nfm_data=nfm_layer_20_np[i,:].tolist()
    
        # 将列表转换为集合
        mlp_set = set(mlp_data)
        nfm_set = set(nfm_data)

        # 求交集
        intersection = mlp_set.intersection(nfm_set)

        # 将交集转换回列表
        intersection_list = list(intersection)
        print('intersecion_list:',intersection_list)
        writer.writerow(intersection_list)
        #intersections_20_list.append(intersection_list)
#print('len:',len(intersections_20_list))    
file.close()    
#intersections_20_np=np.array(intersections_20_list)  
#intersections_20_df=pd.DataFrame(intersections_20_np)
#intersections_20_df.to_csv('results_genes/intersections/intersecions_20_df.csv')
# Out:
# intersecion_list: ['ABCB7', 'AHCYL1', 'PCK1', 'PTP4A1', 'LYPLA1', 'RHOB', 'ADPRM', 'GPX3', 'IFI6', 'KLF6', 'CYP39A1', 'GDF15']
# intersecion_list: ['CHP1', 'NDUFA13', 'MST1L', 'ZNHIT1', 'LGMN', 'CYP2J2', 'IFI6', 'AGL', 'LHPP', 'MEST', 'RPS27L', 'CTSG', 'CPVL', 'RGS5']
# intersecion_list: ['ISCU', 'METTL9', 'EPM2AIP1', 'TUBA4B', 'NEAT1', 'ACTA2', 'VDR', 'CFLAR', 'CAMLG', 'VTCN1', 'ACVR1B', 'TRA2A', 'TFAP2A', 'ACP6', 'MRPS15', 'MEST']
# intersecion_list: ['BCCIP', 'TYMP', 'SLC3A2', 'ATP6V1F', 'KLF9', 'FST', 'BHLHE40', 'TESC']
# intersecion_list: ['LARP1', 'ITGB3BP', 'COX15', 'LYPLA1', 'WDR12', 'RPL38', 'FKBP4', 'ABLIM3', 'GLB1L', 'TMEM100', 'WASHC3']
# intersecion_list: ['PTMS', 'LIPC', 'ATP5IF1', 'RRM2', 'OLFML3', 'MRPS16', 'LGMN', 'IFIT1', 'IFI6', 'BHLHE40', 'DEPTOR', 'COL4A3BP']
# intersecion_list: ['ACAD10', 'PTP4A1', 'ADI1', 'CAMLG', 'PLIN3', 'ZNHIT1', 'NDUFB1', 'ABHD2', 'ABLIM1', 'WASHC4', 'BDKRB2', 'SPI1', 'SERPINF1', 'RGN', 'UCHL1']
# intersecion_list: ['METTL9', 'BCCIP', 'ATP6V1F', 'IGLV2-14', 'SH3BP2', 'KLF9', 'CGREF1', 'GPX2', 'IFI6', 'SERPINA3', 'UGDH', 'CD163', 'ABCC3', 'CPVL', 'CFB']
# intersecion_list: ['TFAM', 'NDUFA13', 'MS4A4A', 'TRIM14', 'LGMN', 'MAP3K1', 'IFIT1', 'GPX3', 'IFI6', 'ABLIM1', 'MRPS16', 'DEPTOR', 'ALB', 'CPVL']

# %%
#compute unions for  the intersections_20_df of every class 
#intersections_20_df=pd.read_csv('results_genes/intersections/intersecions_20_df.csv',sep=',')
#from chartGPT of the following code
#intersections_20_df=intersections_20_df.iloc[:,1:]
#print(intersections_20_df)
#intersections_20_np=np.array(intersections_20_df)


result = set()
import csv
csv_filename = "results_genes/intersections/intersecions_20_df_from_train_mean.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='r', newline='') as csvfile:
    csv_reader = csv.reader(csvfile)
    # 逐行读取数据
    for row in csv_reader:
        row_set=set(row)
        result=result.union(row_set)
        
        

# 或者使用集合的union方法的更简洁写法，使用集合解析
# result = set().union(*list_of_lists)

# 或者使用 | 运算符
# result = set().union(*list_of_lists)

# 将结果转回列表
result_list = list(result)

print(len(result_list))

import csv
csv_filename = "results_genes/intersections/genes_intersections_20_from_train_mean.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    writer.writerow(result_list)

#这将输出所有列表的并集，不包含重复的元素。在这个例子中，结果会是 [1, 2, 3, 4, 5, 6, 7]。你可以根据你的实际需求将这个结果转换为列表或者保留为集合，具体取决于你的应用场景。
#抽取训练集和测试集中的数据

#生成新选取元素的数据集
train_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/train_val_info.csv'
test_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info.csv'

train_df=pd.read_csv(train_path,sep=',')


train_df=train_df.iloc[:,1:]


columns=result_list
columns.append('label')
print('columns:',columns)


train_df2=train_df[columns]
print(train_df2.shape)
train_df2.to_csv('results_genes/intersections/dataset/from_train_mean_train_val_info.csv')

test_df=pd.read_csv(test_path,sep=',')

test_df=test_df.iloc[:,1:]



test_df=test_df[columns]
print(test_df.shape)
test_df.to_csv('results_genes/intersections/dataset/from_train_mean_test_info.csv')
# Out:
# 93
# columns: ['PTMS', 'PCK1', 'IGLV2-14', 'CFLAR', 'CGREF1', 'ZNHIT1', 'MRPS16', 'WASHC4', 'BDKRB2', 'RGN', 'CFB', 'LARP1', 'LIPC', 'TUBA4B', 'ITGB3BP', 'ATP6V1F', 'LYPLA1', 'MS4A4A', 'OLFML3', 'SERPINA3', 'CPVL', 'WASHC3', 'ISCU', 'RRM2', 'MST1L', 'SH3BP2', 'ADPRM', 'FST', 'GPX3', 'ABLIM1', 'AGL', 'ABLIM3', 'SPI1', 'SERPINF1', 'UCHL1', 'CHP1', 'AHCYL1', 'NEAT1', 'SLC3A2', 'COX15', 'IFI6', 'RPL38', 'FKBP4', 'RPS27L', 'COL4A3BP', 'MRPS15', 'TESC', 'TFAM', 'ABCB7', 'METTL9', 'CAMLG', 'TRIM14', 'ABCC3', 'GLB1L', 'DEPTOR', 'PLIN3', 'ATP5IF1', 'WDR12', 'VTCN1', 'GPX2', 'MAP3K1', 'TRA2A', 'ACP6', 'ACAD10', 'EPM2AIP1', 'PTP4A1', 'VDR', 'KLF9', 'ACVR1B', 'NDUFB1', 'IFIT1', 'KLF6', 'UGDH', 'LHPP', 'CTSG', 'TMEM100', 'BCCIP', 'ALB', 'RGS5', 'NDUFA13', 'TYMP', 'ACTA2', 'ADI1', 'RHOB', 'LGMN', 'TFAP2A', 'CYP2J2', 'BHLHE40', 'ABHD2', 'CD163', 'CYP39A1', 'MEST', 'GDF15', 'label']
# (549, 94)
# (138, 94)

# %%
#train model with new features of 94
model=model2
K=10
test_metrics=[]
train_loss_total_list=[]
for ki in range(K):
    trainset = KZDataset(csv_path='results_genes/intersections/dataset/from_train_mean_train_val_info.csv',K=K, n_class=nfm_config['n_class'],ki=ki,  typ='train', transform=None, rand=True)
    valset = KZDataset(csv_path='results_genes/intersections/dataset/from_train_mean_train_val_info.csv', K=K,n_class=nfm_config['n_class'],ki=ki,  typ='val', transform=None, rand=True)
    train_loader = data.DataLoader(
         dataset=trainset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size'],
         shuffle=True)
    val_loader = data.DataLoader(
         dataset=valset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
    
    model_path='results_genes/intersections/models/from_train_mean/'
    #BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    #total = 0
    
    
    loss_func=torch.nn.CrossEntropyLoss()
    
    num=0
   
    
    epoches=101
    for epoch_id in range(epoches):
          
        
        
        train_loss_total,acc_train=train_epoch(model,train_loader,nfm_config['batch_size'],optimizer,loss_func)
        train_loss_total_list.append(train_loss_total)#
        if epoch_id %20==0:
            num=num+1
            #path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pkl')
            #torch.save(model.state_dict(),path)
            # 保存模型
            
            path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pt')##################pt
            torch.save(model.state_dict(),path)
            #torch.save(model.state_dict(),path)
    print("the ",ki," epoch ends")
    plotLoss(train_loss_total_list,epoches)
    train_loss_total_list=[]
    acc_test=val_epoch(model,val_loader,nfm_config['batch_size'],optimizer)
    print("acc_test_each_k:",acc_test)
    test_metrics.append(acc_test)

print(test_metrics)
#test_metrics=test_metrics.tolist()
test_metrics=[x.cpu().detach().numpy() for x in test_metrics]
print(test_metrics)
acc_test_metrics=np.mean(test_metrics) 
print("acc_test_metrics:",acc_test_metrics)
# Out:
# 549 94
# 549 94
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:450: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:451: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.2375, device='cuda:0')
# Training Epoch: 0, total loss: 64.380290
# total_train_accuracy: tensor(0.4646, device='cuda:0')
# Training Epoch: 1, total loss: 61.261603
# total_train_accuracy: tensor(0.5771, device='cuda:0')
# Training Epoch: 2, total loss: 59.427433
# total_train_accuracy: tensor(0.6729, device='cuda:0')
# Training Epoch: 3, total loss: 57.864467
# total_train_accuracy: tensor(0.6708, device='cuda:0')
# Training Epoch: 4, total loss: 57.266809
# total_train_accuracy: tensor(0.7104, device='cuda:0')
# Training Epoch: 5, total loss: 56.253893
# total_train_accuracy: tensor(0.7313, device='cuda:0')
# Training Epoch: 6, total loss: 55.898673
# total_train_accuracy: tensor(0.7396, device='cuda:0')
# Training Epoch: 7, total loss: 55.336601
# total_train_accuracy: tensor(0.7813, device='cuda:0')
# Training Epoch: 8, total loss: 54.128788
# total_train_accuracy: tensor(0.7854, device='cuda:0')
# Training Epoch: 9, total loss: 54.184533
# total_train_accuracy: tensor(0.7896, device='cuda:0')
# Training Epoch: 10, total loss: 53.826977
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# Training Epoch: 11, total loss: 53.153464
# total_train_accuracy: tensor(0.7875, device='cuda:0')
# Training Epoch: 12, total loss: 53.082388
# total_train_accuracy: tensor(0.8188, device='cuda:0')
# Training Epoch: 13, total loss: 52.494204
# total_train_accuracy: tensor(0.8250, device='cuda:0')
# Training Epoch: 14, total loss: 52.304660
# total_train_accuracy: tensor(0.8250, device='cuda:0')
# Training Epoch: 15, total loss: 52.466430
# total_train_accuracy: tensor(0.8229, device='cuda:0')
# Training Epoch: 16, total loss: 51.988499
# total_train_accuracy: tensor(0.8271, device='cuda:0')
# Training Epoch: 17, total loss: 51.808528
# total_train_accuracy: tensor(0.8083, device='cuda:0')
# Training Epoch: 18, total loss: 52.024067
# total_train_accuracy: tensor(0.8354, device='cuda:0')
# Training Epoch: 19, total loss: 51.227610
# total_train_accuracy: tensor(0.8292, device='cuda:0')
# Training Epoch: 20, total loss: 51.213656
# total_train_accuracy: tensor(0.8479, device='cuda:0')
# Training Epoch: 21, total loss: 50.683862
# total_train_accuracy: tensor(0.8333, device='cuda:0')
# Training Epoch: 22, total loss: 50.588848
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 23, total loss: 50.619012
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 24, total loss: 49.640957
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 25, total loss: 49.566566
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 26, total loss: 50.325970
# total_train_accuracy: tensor(0.8708, device='cuda:0')
# Training Epoch: 27, total loss: 49.784192
# total_train_accuracy: tensor(0.8604, device='cuda:0')
# Training Epoch: 28, total loss: 49.781199
# total_train_accuracy: tensor(0.9063, device='cuda:0')
# Training Epoch: 29, total loss: 49.266577
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 30, total loss: 49.292732
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 31, total loss: 49.142573
# total_train_accuracy: tensor(0.8521, device='cuda:0')
# Training Epoch: 32, total loss: 49.652841
# total_train_accuracy: tensor(0.8688, device='cuda:0')
# Training Epoch: 33, total loss: 49.540348
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 34, total loss: 48.761254
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 35, total loss: 49.268672
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 36, total loss: 48.645685
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 37, total loss: 48.164554
# total_train_accuracy: tensor(0.8688, device='cuda:0')
# Training Epoch: 38, total loss: 49.042521
# total_train_accuracy: tensor(0.8708, device='cuda:0')
# Training Epoch: 39, total loss: 48.707014
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 40, total loss: 48.360279
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 41, total loss: 48.651364
# total_train_accuracy: tensor(0.8646, device='cuda:0')
# Training Epoch: 42, total loss: 48.731797
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 43, total loss: 48.292248
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 44, total loss: 48.423611
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 45, total loss: 47.672008
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 46, total loss: 46.970603
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 47, total loss: 47.462562
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 48, total loss: 46.998087
# total_train_accuracy: tensor(0.9063, device='cuda:0')
# Training Epoch: 49, total loss: 47.187161
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 50, total loss: 47.689474
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 51, total loss: 46.791000
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 52, total loss: 47.564905
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 53, total loss: 46.833404
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# Training Epoch: 54, total loss: 47.500053
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 55, total loss: 47.666959
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 56, total loss: 47.151948
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 57, total loss: 47.124161
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 58, total loss: 46.863014
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 59, total loss: 46.618526
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 60, total loss: 46.629642
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 61, total loss: 46.551705
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 62, total loss: 47.265183
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 63, total loss: 46.865032
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 64, total loss: 46.556934
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 65, total loss: 47.232226
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 66, total loss: 46.663778
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 67, total loss: 46.375687
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 68, total loss: 46.846383
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# Training Epoch: 69, total loss: 46.848781
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 70, total loss: 46.338578
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 71, total loss: 46.528841
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 72, total loss: 46.763903
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 73, total loss: 46.409987
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 74, total loss: 47.044747
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 75, total loss: 46.791966
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 76, total loss: 45.948736
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 77, total loss: 45.239925
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 78, total loss: 46.019845
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 79, total loss: 46.183565
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 80, total loss: 45.639631
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 81, total loss: 45.770813
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 82, total loss: 45.873773
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 83, total loss: 45.825356
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 84, total loss: 45.549687
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 85, total loss: 46.506729
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 86, total loss: 46.102713
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 87, total loss: 45.587642
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 88, total loss: 45.652751
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 89, total loss: 46.015731
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 90, total loss: 45.739042
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 91, total loss: 45.517680
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 92, total loss: 45.706279
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 93, total loss: 45.056816
# total_train_accuracy: tensor(0.9063, device='cuda:0')
# Training Epoch: 94, total loss: 45.904222
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 95, total loss: 45.355710
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 96, total loss: 46.491220
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 97, total loss: 45.730865
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 98, total loss: 45.824911
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 99, total loss: 45.209763
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 100, total loss: 44.456620
# the  0  epoch ends
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# test
# test
# test
# total_test_accuracy: tensor(0.8750, device='cuda:0')
# acc_test_each_k: tensor(0.8750, device='cuda:0')
# 549 94
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:488: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:489: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 549 94
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 0, total loss: 45.930252
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 1, total loss: 45.923582
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 2, total loss: 45.764692
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 3, total loss: 45.261817
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 4, total loss: 45.153184
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 5, total loss: 45.726320
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 6, total loss: 44.994199
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 7, total loss: 45.373702
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 8, total loss: 44.710334
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 9, total loss: 45.349319
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 10, total loss: 44.931605
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 11, total loss: 44.686908
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 12, total loss: 45.640513
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 13, total loss: 45.460876
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 14, total loss: 45.159464
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 15, total loss: 44.985246
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 16, total loss: 44.683745
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 17, total loss: 44.811453
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 18, total loss: 44.251488
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 19, total loss: 45.252459
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 20, total loss: 44.376737
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 21, total loss: 44.749011
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 22, total loss: 44.966995
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 23, total loss: 44.636133
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 24, total loss: 45.184236
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 25, total loss: 44.645202
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 26, total loss: 44.586321
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 27, total loss: 44.403825
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 28, total loss: 44.695973
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 29, total loss: 44.495364
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 30, total loss: 44.467001
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 31, total loss: 44.878843
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 32, total loss: 44.634918
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 33, total loss: 44.712005
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 34, total loss: 44.094998
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 35, total loss: 45.350203
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 36, total loss: 44.728900
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 37, total loss: 45.559097
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 38, total loss: 44.558122
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 39, total loss: 44.168410
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 40, total loss: 44.225739
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 41, total loss: 43.919873
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 42, total loss: 43.923591
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 43, total loss: 44.189564
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 44, total loss: 44.363950
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 45, total loss: 44.063091
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 46, total loss: 44.494362
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 47, total loss: 43.822760
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 48, total loss: 44.385853
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 49, total loss: 44.364997
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 50, total loss: 44.104755
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 51, total loss: 44.387698
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 52, total loss: 44.151102
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 53, total loss: 43.947537
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 54, total loss: 43.676535
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 55, total loss: 43.751984
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 56, total loss: 44.550144
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 57, total loss: 43.980898
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 58, total loss: 43.928342
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 59, total loss: 44.439085
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 60, total loss: 44.789451
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 61, total loss: 44.243670
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 62, total loss: 43.929331
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 63, total loss: 44.215524
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 64, total loss: 43.858647
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 65, total loss: 44.077435
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 66, total loss: 43.692581
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 67, total loss: 44.025337
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 68, total loss: 43.630632
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 69, total loss: 43.670649
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 70, total loss: 44.998131
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 71, total loss: 44.116825
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 72, total loss: 43.950370
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 73, total loss: 43.933120
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 74, total loss: 44.371650
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 75, total loss: 44.220771
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 76, total loss: 43.486259
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 77, total loss: 43.756095
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 78, total loss: 43.497854
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 79, total loss: 43.691546
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 80, total loss: 43.531518
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 81, total loss: 44.196621
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 82, total loss: 43.882553
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 83, total loss: 43.770903
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 84, total loss: 43.521340
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 85, total loss: 43.477178
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 86, total loss: 43.574448
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 87, total loss: 43.813149
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 88, total loss: 43.640753
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 89, total loss: 43.795182
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 90, total loss: 43.908533
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 91, total loss: 43.944728
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 92, total loss: 43.584110
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 93, total loss: 43.830831
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 94, total loss: 43.609704
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 95, total loss: 43.475107
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 96, total loss: 43.710853
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 97, total loss: 43.661561
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 98, total loss: 43.896348
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 99, total loss: 43.236739
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 100, total loss: 42.979586
# the  1  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(0.9583, device='cuda:0')
# acc_test_each_k: tensor(0.9583, device='cuda:0')
# 549 94
# 549 94
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 0, total loss: 43.997324
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 1, total loss: 43.486697
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 2, total loss: 43.938997
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 3, total loss: 43.780332
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 4, total loss: 43.369251
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 5, total loss: 43.265541
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 6, total loss: 43.574029
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 7, total loss: 43.746509
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 8, total loss: 43.692093
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 9, total loss: 43.802684
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 10, total loss: 43.684696
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 11, total loss: 43.264210
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 12, total loss: 43.514832
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 13, total loss: 43.270614
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 14, total loss: 43.429060
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 15, total loss: 44.030971
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 16, total loss: 43.796504
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 17, total loss: 43.136829
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 18, total loss: 43.553736
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 19, total loss: 43.203680
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 20, total loss: 43.808671
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 21, total loss: 43.600953
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 22, total loss: 43.227792
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 23, total loss: 43.809189
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 24, total loss: 43.844304
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 25, total loss: 43.453516
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 26, total loss: 43.365910
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 27, total loss: 43.563157
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 28, total loss: 43.220861
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 29, total loss: 43.669102
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 30, total loss: 43.354627
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 31, total loss: 43.123963
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 32, total loss: 43.922841
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 33, total loss: 43.086280
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 34, total loss: 43.417757
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 35, total loss: 43.490654
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 36, total loss: 43.632918
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 37, total loss: 43.422360
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 38, total loss: 43.796637
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 39, total loss: 43.490235
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 40, total loss: 43.208331
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 41, total loss: 43.616511
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 42, total loss: 43.329926
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 43, total loss: 43.514052
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 44, total loss: 43.164146
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 45, total loss: 43.612435
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 46, total loss: 43.366624
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 47, total loss: 43.381026
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 48, total loss: 43.190195
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 49, total loss: 43.044520
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 50, total loss: 43.671679
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 51, total loss: 42.978673
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 52, total loss: 43.188764
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 53, total loss: 43.111964
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 54, total loss: 43.303452
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 55, total loss: 43.470405
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 56, total loss: 42.937999
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 57, total loss: 43.551002
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 58, total loss: 43.247799
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 59, total loss: 42.985784
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 60, total loss: 42.894766
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 61, total loss: 43.368140
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 62, total loss: 42.930256
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 63, total loss: 42.875190
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 64, total loss: 42.949157
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 65, total loss: 43.340610
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 66, total loss: 43.450791
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 67, total loss: 43.148116
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 68, total loss: 42.791052
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 69, total loss: 43.152644
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 70, total loss: 43.562168
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 71, total loss: 42.818918
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 72, total loss: 42.659228
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 73, total loss: 43.473614
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 74, total loss: 43.215377
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 75, total loss: 43.017305
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 76, total loss: 42.978758
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 77, total loss: 43.296765
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 78, total loss: 42.844073
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 79, total loss: 42.903452
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 80, total loss: 43.290041
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 81, total loss: 43.268873
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 82, total loss: 42.824679
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 83, total loss: 43.058121
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 84, total loss: 43.174084
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 85, total loss: 43.372242
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 86, total loss: 43.167396
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 87, total loss: 43.313139
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 88, total loss: 43.310117
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 89, total loss: 43.448293
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 90, total loss: 42.801610
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 91, total loss: 43.222225
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 92, total loss: 43.005438
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 93, total loss: 42.545285
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 94, total loss: 42.899700
# total_train_accuracy: tensor(0.9896, device='cuda:0')
# Training Epoch: 95, total loss: 42.558098
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 96, total loss: 43.344122
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 97, total loss: 43.196839
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 98, total loss: 43.679201
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 99, total loss: 42.915595
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 100, total loss: 43.158081
# the  2  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(0.9792, device='cuda:0')
# acc_test_each_k: tensor(0.9792, device='cuda:0')
# 549 94
# 549 94
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 0, total loss: 42.982355
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 1, total loss: 43.343689
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 2, total loss: 43.111475
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 3, total loss: 43.232065
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 4, total loss: 42.879764
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 5, total loss: 43.434692
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 6, total loss: 42.996340
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 7, total loss: 43.652741
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 8, total loss: 43.110126
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 9, total loss: 42.833313
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 10, total loss: 42.859752
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 11, total loss: 42.674086
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 12, total loss: 43.364154
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 13, total loss: 43.466510
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 14, total loss: 42.699106
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 15, total loss: 42.973285
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 16, total loss: 42.679709
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 17, total loss: 42.783894
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 18, total loss: 42.936994
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 19, total loss: 43.077586
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 20, total loss: 43.606273
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 21, total loss: 43.358589
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 22, total loss: 42.898191
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 23, total loss: 43.124287
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 24, total loss: 42.809445
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 25, total loss: 42.859875
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 26, total loss: 42.985598
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 27, total loss: 43.344457
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 28, total loss: 43.235322
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 29, total loss: 42.669232
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 30, total loss: 42.883942
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 31, total loss: 43.065473
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 32, total loss: 42.489861
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 33, total loss: 42.997858
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 34, total loss: 42.764017
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 35, total loss: 43.187630
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 36, total loss: 43.202751
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 37, total loss: 43.126530
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 38, total loss: 42.748829
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 39, total loss: 43.383404
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 40, total loss: 42.818757
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 41, total loss: 43.310087
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 42, total loss: 43.310688
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 43, total loss: 43.223884
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 44, total loss: 43.278688
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 45, total loss: 43.089614
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 46, total loss: 43.322998
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 47, total loss: 43.030463
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 48, total loss: 42.771053
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 49, total loss: 42.864644
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 50, total loss: 43.362850
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 51, total loss: 43.314718
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 52, total loss: 43.053036
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 53, total loss: 42.435643
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 54, total loss: 42.950584
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 55, total loss: 42.456221
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 56, total loss: 42.938686
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 57, total loss: 42.783183
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 58, total loss: 42.988256
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 59, total loss: 43.379477
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 60, total loss: 42.687322
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 61, total loss: 42.753367
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 62, total loss: 43.004062
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 63, total loss: 43.089485
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 64, total loss: 43.808926
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 65, total loss: 42.757863
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 66, total loss: 42.376320
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 67, total loss: 43.183485
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 68, total loss: 42.759024
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 69, total loss: 42.931956
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 70, total loss: 42.624687
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 71, total loss: 42.879147
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 72, total loss: 43.233514
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 73, total loss: 42.499639
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 74, total loss: 42.803822
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 75, total loss: 42.759459
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 76, total loss: 42.858844
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 77, total loss: 42.630472
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 78, total loss: 42.452388
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 79, total loss: 42.928366
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 80, total loss: 42.491195
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 81, total loss: 42.459697
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 82, total loss: 42.668011
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 83, total loss: 42.603498
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 84, total loss: 42.816578
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 85, total loss: 42.395816
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 86, total loss: 42.486771
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 87, total loss: 42.965757
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 88, total loss: 42.637455
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 89, total loss: 42.617870
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 90, total loss: 42.868714
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 91, total loss: 42.668144
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 92, total loss: 42.660247
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 93, total loss: 42.740730
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 94, total loss: 42.674966
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 95, total loss: 42.537740
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 96, total loss: 42.992836
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 97, total loss: 43.076687
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 98, total loss: 42.630975
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 99, total loss: 42.988301
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 100, total loss: 42.605785
# the  3  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# acc_test_each_k: tensor(1., device='cuda:0')
# 549 94
# 549 94
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 0, total loss: 43.639656
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 1, total loss: 42.894591
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 2, total loss: 42.682044
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 3, total loss: 43.095458
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 4, total loss: 43.070184
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 5, total loss: 43.237895
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 6, total loss: 42.666424
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 7, total loss: 42.595446
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 8, total loss: 42.330744
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 9, total loss: 42.304451
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 10, total loss: 43.003306
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 11, total loss: 42.753781
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 12, total loss: 42.655638
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 13, total loss: 42.768080
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 14, total loss: 42.649057
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 15, total loss: 42.575145
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 16, total loss: 42.863246
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 17, total loss: 43.057534
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 18, total loss: 42.828386
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 19, total loss: 42.745022
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 20, total loss: 42.566416
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 21, total loss: 42.617171
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 22, total loss: 43.021673
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 23, total loss: 42.646332
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 24, total loss: 42.918701
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 25, total loss: 42.645209
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 26, total loss: 42.622241
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 27, total loss: 42.597617
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 28, total loss: 42.968071
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 29, total loss: 42.528063
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 30, total loss: 42.550416
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 31, total loss: 42.951980
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 32, total loss: 42.820665
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 33, total loss: 42.699431
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 34, total loss: 42.570034
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 35, total loss: 43.299719
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 36, total loss: 42.317091
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 37, total loss: 42.631092
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 38, total loss: 42.870193
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 39, total loss: 42.592353
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 40, total loss: 43.197923
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 41, total loss: 43.113122
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 42, total loss: 42.937960
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 43, total loss: 43.135353
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 44, total loss: 42.877621
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 45, total loss: 42.400820
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 46, total loss: 42.611678
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 47, total loss: 42.347699
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 48, total loss: 42.902026
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 49, total loss: 42.810553
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 50, total loss: 42.981266
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 51, total loss: 42.593884
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 52, total loss: 42.252827
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 53, total loss: 43.236381
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 54, total loss: 42.415432
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 55, total loss: 42.631106
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 56, total loss: 42.390881
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 57, total loss: 43.085123
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 58, total loss: 42.906223
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 59, total loss: 42.906118
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 60, total loss: 42.693115
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# ...
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 45, total loss: 42.682807
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 46, total loss: 42.678745
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 47, total loss: 42.554669
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 48, total loss: 42.370980
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 49, total loss: 42.405792
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 50, total loss: 42.247344
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 51, total loss: 42.432153
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 52, total loss: 42.547311
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 53, total loss: 42.825424
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 54, total loss: 42.448227
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 55, total loss: 42.840152
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 56, total loss: 42.707499
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 57, total loss: 42.496496
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 58, total loss: 42.874418
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 59, total loss: 42.544900
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 60, total loss: 42.463713
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 61, total loss: 42.001186
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 62, total loss: 42.769698
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 63, total loss: 42.651176
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 64, total loss: 42.352987
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 65, total loss: 42.572248
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 66, total loss: 42.748441
# total_train_accuracy: tensor(0.9938, device='cuda:0')
# Training Epoch: 67, total loss: 41.786638
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 68, total loss: 42.354970
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 69, total loss: 42.210300
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 70, total loss: 42.547046
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 71, total loss: 42.296890
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 72, total loss: 42.340761
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 73, total loss: 42.391653
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 74, total loss: 42.591800
# total_train_accuracy: tensor(0.9938, device='cuda:0')
# Training Epoch: 75, total loss: 41.854539
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 76, total loss: 42.499132
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 77, total loss: 42.081628
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 78, total loss: 42.322247
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 79, total loss: 43.082285
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 80, total loss: 42.468027
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 81, total loss: 42.884296
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 82, total loss: 42.540530
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 83, total loss: 42.404102
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 84, total loss: 42.108632
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 85, total loss: 42.099297
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 86, total loss: 42.428001
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 87, total loss: 42.449749
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 88, total loss: 42.189292
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 89, total loss: 42.217300
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 90, total loss: 42.275895
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 91, total loss: 42.499486
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 92, total loss: 42.977406
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 93, total loss: 42.476089
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 94, total loss: 42.594669
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 95, total loss: 42.503130
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 96, total loss: 42.200575
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 97, total loss: 42.362554
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 98, total loss: 42.374559
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 99, total loss: 42.225302
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 100, total loss: 42.401010
# the  8  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# acc_test_each_k: tensor(1., device='cuda:0')
# 549 94
# 549 94
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 0, total loss: 42.672398
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 1, total loss: 42.815764
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 2, total loss: 42.265421
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 3, total loss: 42.734575
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 4, total loss: 42.263446
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 5, total loss: 42.605935
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 6, total loss: 42.732762
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 7, total loss: 42.283173
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 8, total loss: 42.344934
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 9, total loss: 42.812240
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 10, total loss: 42.871984
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 11, total loss: 42.435441
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 12, total loss: 42.191772
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 13, total loss: 42.206068
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 14, total loss: 42.114954
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 15, total loss: 42.851963
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 16, total loss: 42.975081
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 17, total loss: 42.463225
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 18, total loss: 42.132231
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 19, total loss: 42.323156
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 20, total loss: 42.762402
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 21, total loss: 42.511203
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 22, total loss: 42.463099
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 23, total loss: 42.635960
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 24, total loss: 42.641360
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 25, total loss: 42.241381
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 26, total loss: 42.367697
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 27, total loss: 42.555513
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 28, total loss: 42.613787
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 29, total loss: 42.449265
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 30, total loss: 42.617434
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 31, total loss: 42.547218
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 32, total loss: 42.462422
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 33, total loss: 42.016261
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 34, total loss: 42.352424
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 35, total loss: 42.734295
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 36, total loss: 42.057101
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 37, total loss: 42.258948
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 38, total loss: 42.287895
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 39, total loss: 42.429549
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 40, total loss: 42.436669
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 41, total loss: 42.333826
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 42, total loss: 42.446640
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 43, total loss: 42.654942
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 44, total loss: 42.157784
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 45, total loss: 42.260651
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# Training Epoch: 46, total loss: 41.874880
# total_train_accuracy: tensor(0.9938, device='cuda:0')
# Training Epoch: 47, total loss: 41.725434
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 48, total loss: 42.161740
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 49, total loss: 42.556244
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 50, total loss: 42.683943
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 51, total loss: 42.165397
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 52, total loss: 42.334613
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 53, total loss: 42.702543
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 54, total loss: 42.756754
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 55, total loss: 42.719758
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 56, total loss: 42.419605
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 57, total loss: 42.317962
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 58, total loss: 42.532206
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 59, total loss: 42.646744
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 60, total loss: 42.770369
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 61, total loss: 42.658674
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 62, total loss: 42.695384
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 63, total loss: 42.483684
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 64, total loss: 42.409677
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 65, total loss: 42.201461
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 66, total loss: 42.284292
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 67, total loss: 42.776912
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 68, total loss: 41.945013
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 69, total loss: 42.487346
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 70, total loss: 42.454827
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 71, total loss: 42.598948
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 72, total loss: 42.199881
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 73, total loss: 42.438540
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 74, total loss: 42.467595
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 75, total loss: 42.128049
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 76, total loss: 42.246942
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 77, total loss: 42.497600
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 78, total loss: 42.309010
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 79, total loss: 42.286907
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 80, total loss: 42.476597
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 81, total loss: 42.479994
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 82, total loss: 42.612005
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 83, total loss: 42.245549
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 84, total loss: 42.173497
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 85, total loss: 42.576152
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 86, total loss: 42.367473
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 87, total loss: 42.342853
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 88, total loss: 42.156876
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 89, total loss: 42.405790
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 90, total loss: 42.201667
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 91, total loss: 42.642401
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 92, total loss: 42.749521
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 93, total loss: 42.098020
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 94, total loss: 42.170546
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 95, total loss: 42.740663
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 96, total loss: 42.234740
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 97, total loss: 42.394409
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 98, total loss: 42.160830
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 99, total loss: 42.401208
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 100, total loss: 42.303562
# the  9  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(0.9792, device='cuda:0')
# acc_test_each_k: tensor(0.9792, device='cuda:0')
# [tensor(0.8750, device='cuda:0'), tensor(0.9583, device='cuda:0'), tensor(0.9792, device='cuda:0'), tensor(1., device='cuda:0'), tensor(0.9792, device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(0.9792, device='cuda:0'), tensor(1., device='cuda:0'), tensor(0.9792, device='cuda:0')]
# [array(0.875, dtype=float32), array(0.9583334, dtype=float32), array(0.9791667, dtype=float32), array(1., dtype=float32), array(0.9791667, dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(0.9791667, dtype=float32), array(1., dtype=float32), array(0.9791667, dtype=float32)]
# acc_test_metrics: 0.9750001

# %%
import torch

#功能：加载保存到path中的各层参数到神经网络

#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP610.pkl'
#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP9110.pkl'
path='results_genes/intersections/models/from_train_mean/MLP610.pt'
#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP10910.pkl'
#nfm=NFM(nfm_config)
mlp=MLP2()
#print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
mlp.load_state_dict(torch.load(path),strict=False)
mlp.cuda()

print(mlp)




mlp_params = list(mlp.named_parameters())
#print(nfm_params)
net=mlp


testset = KZDatasetTest(csv_path='results_genes/intersections/dataset/from_train_mean_test_info.csv')
   
test_loader = data.DataLoader(
         dataset=testset,
         #transform=torchvision.transforms.ToTensor(),
         
         batch_size=nfm_config['batch_size']
        
     )
#———————————————— 
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/jclian91/article/details/121708431# 
from torch.autograd import Variable 
from torch.utils.data import DataLoader 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import accuracy_score 
 
def evaluate_model(test_dl, model): 
    model.eval()#测试数据稳定
    predictions, actuals = [], [] 
    for i, (inputs, targets) in enumerate(test_dl): 
        # evaluate the model on the test set 
        #print(\ inputs:\ ,inputs) 
        #print(\ targets:\ ,targets) 
        inputs = Variable(inputs) 
        targets = Variable(targets) 
                 
                 
        #x = torch.tensor(x, dtype=torch.float) 
        #x=x.clone().detach().requires_grad_(True) 
        inputs=torch.tensor(inputs,dtype=torch.float) 
        targets=torch.tensor(targets,dtype=torch.float) 
        inputs, targets = inputs.cuda(), targets.cuda() 
        yhat = model(inputs) 
        yhat=(yhat==torch.max(yhat,1,keepdim=True)[0]).to(dtype=torch.int32)
        # retrieve numpy array 
        #yhat = yhat.detach().numpy() 
        yhat = yhat.detach().cpu().numpy()#转换到cpu 
        # yhat=yhat.argmax(axis=1) 
        #print(yhat:\ ,yhat) 
        #print('yhat.shape:',yhat.shape) 
        actual = targets.detach().cpu().numpy() 
        actual=actual.round() 
        #print(\ actual:\ ,actual) 
        #print('actual.shape:',actual.shape
        #predictions.appe) 
        #actual = actual.reshape(-1, 1) 
        # round to class values 
        yhat = yhat.round() 
        # store nd(yhat) 
        actuals.append(actual) 
        predictions.append(yhat)
    #print("prediction:" ,predictions) 
    #print("actuals:",actuals) 
    predictions, actuals = np.vstack(predictions), np.vstack(actuals) 
    #print("prediction:" ,predictions) 
    #print("actuals:" ,actuals) 
    # calculate accuracy 
    acc_test = accuracy_score(actuals, predictions) 
    return  actuals, predictions,acc_test 

import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 
target_list=actuals 
pred_list=predictions 
      
y_true=target_list 
y_pred=pred_list 
      
f1=f1_score(y_true=target_list, y_pred=pred_list, average='macro') # 也可以指定micro模式 
acc_score=accuracy_score(y_true=target_list, y_pred=pred_list) 
rec_score=recall_score(y_true=target_list,y_pred=pred_list,average='macro') # 也可以指定micro模式 
pre_recall=precision_score(y_true=target_list,y_pred=pred_list,average='macro') 
print("f1_score:  %.4f" ,f1) 
print("accuracy_score:" ,acc_score) 
print("recall_score:",rec_score) 
print("pre_recall:" ,pre_recall)



auc_curve = roc_auc_score(y_true, y_pred, multi_class='ovo')
#———————————————— 
#版权声明：本文为CSDN博主「农民小飞侠」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/w5688414/article/details/106595892 
PM_y=y_pred 
true_y=y_true 
n_classes=PM_y.shape[1] 
      
print("n_classes:",n_classes) 
fpr = dict() 
tpr = dict() 
roc_auc = dict() 
for i in range(n_classes): 
    fpr[i], tpr[i], _ = roc_curve(true_y[:, i], PM_y[:, i]) 
    roc_auc[i] = auc(fpr[i], tpr[i]) 
    #print(i) 
    #print(fpr) 
    #print(tpr) 
    
    
    
#计算macro auc 
from scipy import interp 
# First aggregate all false positive rates 
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)])) 
       
# Then interpolate all ROC curves at this points 
mean_tpr = np.zeros_like(all_fpr) 
for i in range(n_classes): 
    mean_tpr += interp(all_fpr, fpr[i], tpr[i]) 
       
    # Finally average it and compute AUC 
    mean_tpr /= n_classes 
       
    fpr["macro"] = all_fpr 
    tpr["macro"] = mean_tpr 
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    
    
    
#画图 
      
import matplotlib.pyplot as plt 
from itertools import cycle 
from matplotlib.ticker import FuncFormatter 
lw = 2 
# Plot all ROC curves 
plt.figure() 
labels=['Con(0)','DN(1)','FSGS(2)','HT(3)','IgA(4)','MCD(5)','MGN(6)','RPGN(7)','SLE(8)'] 

'''
plt.plot(fpr["macro"], tpr["macro"], 
              label='macro-average ROC curve (area = {0:0.4f})' 
                    ''.format(roc_auc["macro"]), 
              color='navy', linestyle=':', linewidth=4) 
'''

       
colors = cycle(['aqua', 'darkorange', 'cornflowerblue','blue','yellow','burlywood','cornsilk','darkblue','goldenrod','greenyellow','maroon']) 
for i, color in zip(range(n_classes), colors): 
    plt.plot(fpr[i], tpr[i], color=color, lw=lw, 
                  label=labels[i]+'(area = {0:0.4f})'.format(roc_auc[i])) 
       
    plt.plot([0, 1], [0, 1], 'k--', lw=lw) 
    plt.xlim([0.0, 1.0]) 
    plt.ylim([0.0, 1.05]) 
      
      
    plt.xlabel('1-Specificity (%)') 
    plt.ylabel('Sensitivity (%)') 
    #plt.title('testing on kidney tubules with F800 without augment') 
    plt.title('testing on kidney tubules with F800 \n without augment')   

        
def to_percent(temp, position): 
    return '%1.0f'%(100*temp) 
      
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.legend(loc="lower right" ) 
      
plt.show()
# Out:
# MLP2(
#   (bn0): BatchNorm1d(93, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=93, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# 138 94
# f1_score:  %.4f 0.9321463764750482
# accuracy_score: 0.9347826086956522
# recall_score: 0.9404761904761904
# pre_recall: 0.929697730794222
# n_classes: 9
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:151: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
