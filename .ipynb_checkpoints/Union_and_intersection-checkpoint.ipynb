# %%
#programm test

from sklearn.datasets import make_blobs
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
#from data_process import preData,getFeaturesData,getDF,convert_to_df
import os 
import itertools
#file_dir="data/guan/"
file_dir="dataset/qiuguan/results/"
all_file_list=os.listdir(file_dir)
#print(all_file_list)
n=0
gene_names_list=[]
genes_list=[]
for single_file in all_file_list:
    print(single_file)
    df1=pd.read_csv(file_dir+single_file,sep=',',header=None)
    df1=df1.iloc[1:,1:]
    #print(df1)
    #print(df1.iloc[1,:])
    #df1=df1.iloc[1:,1:]
    #col_names1=df1.iloc[0,:]
    #print(col_names1)

    #df1.columns=col_names1
    #df1=df1.sort_index(axis=1)
    #print(df1.head())
    
    #33print(df1)
    #print(df1.head())
    row,col=df1.shape 
    
    
    detail_df1=df1.iloc[3,:]
    np_df1=np.array(detail_df1)
    list_df1=np_df1.tolist()
    
    
    #以下是求所有文件中的特征基因的并集
    gene_names_list=list(itertools.chain(list_df1, gene_names_list))
    for i in gene_names_list:
        if i not in genes_list:
            genes_list.append(i)
    #gene_names_list.append(list_df1)
    gene_names_list=genes_list
    '''
    if row>=20:
        n=n+1
        file_names.append(single_file)
        if single_file==all_file_list[0]:
            df=df1
        else:
            df=pd.concat([df,df1],axis=0)
            #print(df.iloc[1,:])

    '''
    
print(genes_list)            
gene_list=np.array(genes_list)
gene_list=pd.DataFrame(gene_list)
gene_list.to_csv('dataset/qiuguan/features/genes_union.csv')
# Out:
# NFM_encode_1000_10_layer_2_genes.csv
# NFM_layer_3_encode_1000_10_genes.csv
# NFM_layer_3_non_encode_genes.csv
# MLP_non_encode_genes.csv
# NFM_encode_1000_20_layer_2_genes.csv
# NFM_layer_2_non_encode_genes.csv
# NFM_encode_100_20_layer_2_genes.csv
# MLP_encode_100_genes.csv
# NFM_encode_100_10_layer_2_genes.csv
# NFM_layer_3_encode_1000_20_genes.csv
# NFM_layer_3_encode_100_10_genes.csv
# NFM_layer_3_encode_100_20_genes.csv
# MLP_encode_1000_genes.csv
# ['GPX2', 'ATP6V1F', 'ADTRP', 'SLC16A6', 'OVOL1', 'EGLN3', 'IFI6', 'FOSB', 'TRIM14', 'PARD6B', 'TYMP', 'IFIT1', 'SPARCL1', 'NFIL3', 'KLF6', 'IGKC', 'MUC13', 'CRISPLD2', 'BCAT1', 'TTC1', 'CGA', 'AFP', 'TFRC', 'MAP3K1', 'ISCU', 'EPPK1', 'CHCHD2', 'GABARAPL1', 'TFAM', 'CYP21A2', 'NR0B2', 'PPDPF', 'RNF43', 'POLR1D', 'EIF5A', 'GADD45GIP1', 'NARS2', 'ATP2C2', 'TENT5C', 'RGS5', 'SH3BP1', 'TIMM8B', 'MRPL11', 'ACP1', 'DARS2', 'PTP4A1', 'CEBPD', 'FTL', 'TSC22D2', 'CERS4']

# %%
#programm test

from sklearn.datasets import make_blobs
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
#from data_process import preData,getFeaturesData,getDF,convert_to_df
import os 
import itertools
#file_dir="data/guan/"
file_dir="dataset/qiuguan/results/"
all_file_list=os.listdir(file_dir)
#print(all_file_list)
n=0
gene_names_list=[]
genes_list=[]
single_file=all_file_list[0]
df1=pd.read_csv(file_dir+single_file,sep=',',header=None)
df1=df1.iloc[1:,1:]
detail_df1=df1.iloc[3,:]
np_df1=np.array(detail_df1)
list_df1=np_df1.tolist()


for single_file in all_file_list:
    print(single_file)
    df2=pd.read_csv(file_dir+single_file,sep=',',header=None)
    df2=df2.iloc[1:,1:]
    #print(df1)
    #print(df1.iloc[1,:])
    #df1=df1.iloc[1:,1:]
    #col_names1=df1.iloc[0,:]
    #print(col_names1)

    #df1.columns=col_names1
    #df1=df1.sort_index(axis=1)
    #print(df1.head())
    
    #33print(df1)
    #print(df1.head())
    row,col=df2.shape 
    
    
    detail_df2=df2.iloc[3,:]
    np_df2=np.array(detail_df2)
    list_df2=np_df2.tolist()
    
    
    #以下是求所有文件中的特征基因的并集
    #gene_names_list=list(itertools.chain(list_df1, gene_names_list))
    
    
    
    gene_interaction_list = [v for v in list_df2 if v in list_df1]
    print(gene_interaction_list)
    '''
    if row>=20:
        n=n+1
        file_names.append(single_file)
        if single_file==all_file_list[0]:
            df=df1
        else:
            df=pd.concat([df,df1],axis=0)
            #print(df.iloc[1,:])

    '''
    list_df1=gene_interaction_list
    
print(gene_interaction_list)

gene_list=np.array(gene_interaction_list)
gene_list=pd.DataFrame(gene_list)
gene_list.to_csv('dataset/qiuguan/features/genes_interaction.csv')
# Out:
# NFM_encode_1000_10_layer_2_genes.csv
# ['GPX2', 'ATP6V1F', 'ADTRP', 'SLC16A6', 'OVOL1', 'EGLN3', 'IFI6', 'FOSB', 'TRIM14', 'PARD6B', 'TYMP', 'IFIT1', 'SPARCL1', 'NFIL3', 'KLF6', 'IGKC', 'MUC13', 'CRISPLD2', 'BCAT1', 'TTC1']
# NFM_layer_3_encode_1000_10_genes.csv
# ['EGLN3', 'SPARCL1', 'TRIM14', 'IGKC', 'KLF6', 'IFI6', 'GPX2', 'ADTRP', 'ATP6V1F', 'IFIT1', 'BCAT1', 'SLC16A6', 'MUC13']
# NFM_layer_3_non_encode_genes.csv
# ['IFI6', 'TRIM14', 'EGLN3', 'KLF6', 'GPX2', 'ADTRP', 'ATP6V1F', 'IGKC', 'IFIT1', 'SPARCL1']
# MLP_non_encode_genes.csv
# ['EGLN3', 'GPX2', 'TRIM14', 'ATP6V1F', 'KLF6', 'IGKC', 'ADTRP']
# NFM_encode_1000_20_layer_2_genes.csv
# ['EGLN3', 'ATP6V1F', 'TRIM14', 'KLF6', 'ADTRP', 'GPX2', 'IGKC']
# NFM_layer_2_non_encode_genes.csv
# ['EGLN3', 'ATP6V1F', 'TRIM14', 'ADTRP', 'KLF6']
# NFM_encode_100_20_layer_2_genes.csv
# ['ADTRP', 'KLF6', 'EGLN3']
# MLP_encode_100_genes.csv
# ['EGLN3', 'KLF6', 'ADTRP']
# NFM_encode_100_10_layer_2_genes.csv
# ['KLF6', 'EGLN3', 'ADTRP']
# ...
