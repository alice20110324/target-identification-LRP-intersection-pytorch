# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':12,
    'linear_hidden1':1000,
    'linear_hidden':100,#线性模型输出层（隐层个数）
    'embed_input_dim':1001,#embed输入维度
    'embed_dim': 100, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    #'dnn_hidden_units': [100,11],#MLP隐层和输出层
    
    'dnn_hidden_units':[100,9],#MLP隐层
    'num_sparse_features_cols':4224,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 16,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'epoch':1000,
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    #'train_file':'data/xiaoqiu_gene_5000/train/final_5000_encode_100x.csv',
    'train_data':'dataset/qiuguan/xiaoguan/train_new/train_data.csv',
    'train_label':'dataset/qiuguan/xiaoguan/train_new/train_label.csv',
    'guan_test_data':'dataset/qiuguan/non_code/guan_test/guan_test_data.csv',
    'guan_test_label':'dataset/qiuguan/non_code/guan_test/guan_test_label.csv',
    'test_data':'dataset/qiuguan/xiaoguan/test_new/test_data.csv',
    'test_label':'dataset/qiuguan/xiaoguan/test_new/test_label.csv',
    #'title':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_data.csv',
    
    #'all':''
    #'title':'data/xiaoqiu_gene_5000/train/gene_5000_gene_name.csv',
    #'all':'data/xiaoqiu_gene_5000/train/gene_5000_label_name.csv'
}

# %%
#准备训练集

import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter

#import network
import config
import evaluate
import data_utils
import Trainer
#from utils import 
#准备训练集
#from new_dataset_processed import FMData
from dataset_process import FMData
def prepare_dataset(m_data,m_label,batch_size,n_class):
    m_dataset=FMData(m_data,m_label,n_class)
    m_dataloader=data.DataLoader(m_dataset, drop_last=True,batch_size=batch_size,shuffle=True,num_workers=4)
    
    return m_dataset,m_dataloader
# Out:
# [[190 220 490 ... 360 370 420]
#  [110 220 500 ... 340 260 420]
#  [100 300 500 ... 330 350 390]
#  ...
#  [450 360 500 ... 430 360 500]
#  [420 350 530 ... 440 370 500]
#  [420 360 540 ... 430 370 450]]

# %%
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics
def   train_data(model,train_loader,test_loader,batch_size,model_path):
    #train_accuracy=torchmetrics.Accuracy()
    #test_accuracy=torchmetrics.Accuracy()
    BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    total = 0
    
    #loss_func = torch.nn.BCELoss()
    loss_func=torch.nn.CrossEntropyLoss()
    #loss_func=nn.MultiLabelSoftMarginLoss()
    #loss_func=torch.nn.LogSoftmax()
    num=0
    #model=nn.Softmax(nn.Linear(10149,16)).to(device)
    # 从DataLoader中获取小批量的id以及数据
    
    batch_size=0
    for epoch_id in range(1000):
        correct=0
        total=0
        total_test_acc=0
        total_train_accuracy=0
        for batch_idx, (x, labels) in enumerate(train_loader):
            x = Variable(x)
            labels = Variable(labels)
            
            
            #x = torch.tensor(x, dtype=torch.float)
            #x=x.clone().detach().requires_grad_(True)
            x=torch.tensor(x,dtype=torch.float)
            labels=torch.tensor(labels,dtype=torch.float)
            x, labels = x.cuda(), labels.cuda()
            labels_int=labels=torch.max(labels,1)[1]
            #labels_int.cuda()
            #print("labels:",labels)
            
            optimizer.zero_grad()
            y_predict = model(x)
            #print("y_predict:",y_predict)
            #loss = loss_func(y_predict.view(-1), labels)
            loss = loss_func(y_predict, labels)
            loss.backward()
            optimizer.step()
            
            loss = loss.item()
            #loss, predicted = self._train_single_batch(x, labels)

            total += loss
            
            
            #predicted = torch.max(y_predict.data,1)
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
            #predicted=predicted.detach().cpu().numpy()
            
            #labels=torch.max(labels,1)
            #print("labels:",labels)
            #labels=labels[1]
            #y_predict=y_predict.cuda()
            #labels=torch.max(labels,1)[1].cuda()
            #labels=labels.detach().cpu().numpy()
            #correct += (predicted == labels).sum()
            #print("correct:",correct)
            #correct=correct[0]
            #print("new_correct:",float(correct))
            #correct=float(correct)   
            #if batch_idx % 10 == 0:
            #print("batch_idx:",batch_idx)
            #print(correct/(BATCH_SIZE*(batch_idx+1)))
            batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
            #print('batch_train_acc:',batch_train_acc)
            total_train_accuracy+=batch_train_acc
        #total_train_accuracy=torchmetrics.functional.compute_details()
        total_train_accuracy/=(batch_idx+1)
        print('total_train_accuracy:',total_train_accuracy)
        #print('total_train_accuracy:',total_train_accuracy)
        for i , (inputs , targets) in enumerate(test_loader):   
            print("test")
            # evaluate the model on the test set   
            #print(\ inputs:\  inputs)   
            #print(\ targets:\  targets)   
            inputs = Variable(inputs)   
            targets = Variable(targets)     
            #x = torch.tensor(x  dtype=torch.float)   
            #x=x.clone().detach().requires_grad_(True)   
            inputs=torch.tensor(inputs ,dtype=torch.float)   
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs , targets = inputs.cuda(),  targets.cuda()   
            yhat = model(inputs)  
            
            #yhat = torch.max(yhat.data,1)[1]
            #yhat=yhat.detach().cpu().numpy()
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
             #predicted = torch.max(y_predict.data,1)[1]
            
            
            targets=torch.max(targets,1)[1]
            #print("labels:",labels)
            #labels=labels[1]
            #targets=targets.detach().cpu().numpy()
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            #print("batch_test_acc:",batch_test_acc)
            total_test_acc+=batch_test_acc
            #total_test_accuracy=torchmetrics.functional.compute_details()
            batch_size=i
        print('total_test_accuracy:',total_test_acc/(batch_size+1))
        
                    
                    
            
            #model.evaluate()
            #model.eval()
            #train_result = evaluate.metrics(model, train_loader)
            #valid_result = evaluate.metrics(model, valid_loader)
            #est_result = evaluate.metrics(model, test_loader)
            #acturals,predictions,acc_test=evaluate_model(test_loader,model)
            #print("acc_test:  %d  " %(acc_test))
            #print("Train_RMSE: {:.3f}, Valid_RMSE: {:.3f}, Test_RMSE: {:.3f}".format(
            #train_result, valid_result, test_result))
            # print('[Training Epoch: {}] Batch: {}, Loss: {}'.format(epoch_id, batch_id, loss))
        print("Training Epoch: %d, total loss: %f" % (epoch_id, total))
        #print("auc:",roc_auc_score)
    #功能：保存训练完的网络的各层参数（即weights和bias)
    #path='dataset/xiaoguan/RF/RF_for_train/train_class_9/model/gene_4000_NFM.pkl'
        if epoch_id %100==0:
            num=num+1
            path=os.path.join(model_path,'MLP'+str(num)+'.pkl')
            torch.save(model.state_dict(),path)

# %%
train_dataset,train_loader=prepare_dataset(nfm_config['train_data'],nfm_config['train_label'],nfm_config['batch_size'],nfm_config['n_class'])
test_dataset,test_loader=prepare_dataset(nfm_config['test_data'],nfm_config['test_label'],nfm_config['batch_size'],nfm_config['n_class'])
from MLP2 import MLP
#from new_nfm_network import NFM
model=MLP(10150,1000,100,12)
#model=NFM(nfm_config)
model.cuda()
print("MLP1:",model)
train_data(model,train_loader,test_loader,nfm_config['batch_size'],'dataset/qiuguan/model/single/xiaoguan/MLP_non_encode/')
# Out:
# FMData
# FMData
# MLP1: MLP(
#   (bn0): BatchNorm1d(10150, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=10150, out_features=1000, bias=True)
#   (bn1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=1000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=12, bias=True)
#   (bn3): BatchNorm1d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.1695, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.2188, device='cuda:0')
# Training Epoch: 0, total loss: 127.014299
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.2392, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.2500, device='cuda:0')
# Training Epoch: 1, total loss: 125.847168
# total_train_accuracy: tensor(0.2885, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.2969, device='cuda:0')
# Training Epoch: 2, total loss: 124.518600
# total_train_accuracy: tensor(0.2945, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1875, device='cuda:0')
# Training Epoch: 3, total loss: 123.846575
# total_train_accuracy: tensor(0.2825, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.2969, device='cuda:0')
# Training Epoch: 4, total loss: 123.974286
# total_train_accuracy: tensor(0.3474, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.2656, device='cuda:0')
# Training Epoch: 5, total loss: 122.790811
# total_train_accuracy: tensor(0.3209, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3594, device='cuda:0')
# Training Epoch: 6, total loss: 122.845597
# total_train_accuracy: tensor(0.3546, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.1875, device='cuda:0')
# Training Epoch: 7, total loss: 121.399794
# total_train_accuracy: tensor(0.3377, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.2344, device='cuda:0')
# Training Epoch: 8, total loss: 121.300518
# total_train_accuracy: tensor(0.3702, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3438, device='cuda:0')
# Training Epoch: 9, total loss: 120.721957
# total_train_accuracy: tensor(0.3834, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.2188, device='cuda:0')
# Training Epoch: 10, total loss: 120.221234
# total_train_accuracy: tensor(0.3834, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 11, total loss: 119.773943
# total_train_accuracy: tensor(0.3978, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3750, device='cuda:0')
# Training Epoch: 12, total loss: 119.187822
# total_train_accuracy: tensor(0.4291, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 13, total loss: 117.795145
# total_train_accuracy: tensor(0.4543, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3750, device='cuda:0')
# Training Epoch: 14, total loss: 117.174103
# total_train_accuracy: tensor(0.4279, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 15, total loss: 117.562417
# total_train_accuracy: tensor(0.4447, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3750, device='cuda:0')
# Training Epoch: 16, total loss: 116.810307
# total_train_accuracy: tensor(0.4748, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 17, total loss: 115.637441
# total_train_accuracy: tensor(0.5000, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 18, total loss: 113.998543
# total_train_accuracy: tensor(0.5060, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 19, total loss: 114.070803
# total_train_accuracy: tensor(0.5168, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 20, total loss: 113.442363
# total_train_accuracy: tensor(0.5409, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 21, total loss: 111.598337
# total_train_accuracy: tensor(0.5553, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 22, total loss: 111.060616
# total_train_accuracy: tensor(0.5433, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 23, total loss: 111.418723
# total_train_accuracy: tensor(0.5505, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 24, total loss: 110.519825
# total_train_accuracy: tensor(0.5757, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 25, total loss: 109.818684
# total_train_accuracy: tensor(0.5733, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3438, device='cuda:0')
# Training Epoch: 26, total loss: 109.609512
# total_train_accuracy: tensor(0.5733, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 27, total loss: 109.632293
# total_train_accuracy: tensor(0.5998, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 28, total loss: 108.317262
# total_train_accuracy: tensor(0.5938, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 29, total loss: 108.515902
# total_train_accuracy: tensor(0.6274, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5781, device='cuda:0')
# Training Epoch: 30, total loss: 107.412515
# total_train_accuracy: tensor(0.6274, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5625, device='cuda:0')
# Training Epoch: 31, total loss: 107.003495
# total_train_accuracy: tensor(0.6358, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 32, total loss: 106.189922
# total_train_accuracy: tensor(0.6358, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5938, device='cuda:0')
# Training Epoch: 33, total loss: 106.437734
# total_train_accuracy: tensor(0.6406, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5625, device='cuda:0')
# Training Epoch: 34, total loss: 105.862479
# total_train_accuracy: tensor(0.6358, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 35, total loss: 105.766650
# total_train_accuracy: tensor(0.6478, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 36, total loss: 105.782201
# total_train_accuracy: tensor(0.6490, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 37, total loss: 105.340857
# total_train_accuracy: tensor(0.6550, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5625, device='cuda:0')
# Training Epoch: 38, total loss: 104.854063
# total_train_accuracy: tensor(0.6731, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5625, device='cuda:0')
# Training Epoch: 39, total loss: 104.668042
# total_train_accuracy: tensor(0.6611, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 40, total loss: 104.530140
# total_train_accuracy: tensor(0.6983, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 41, total loss: 103.415922
# total_train_accuracy: tensor(0.6863, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 42, total loss: 103.430182
# total_train_accuracy: tensor(0.6875, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 43, total loss: 103.061988
# total_train_accuracy: tensor(0.7007, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 44, total loss: 102.805454
# total_train_accuracy: tensor(0.6911, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 45, total loss: 103.436577
# total_train_accuracy: tensor(0.6743, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 46, total loss: 103.681985
# total_train_accuracy: tensor(0.7284, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 47, total loss: 101.813295
# total_train_accuracy: tensor(0.6875, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 48, total loss: 102.854546
# total_train_accuracy: tensor(0.6983, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 49, total loss: 103.090428
# total_train_accuracy: tensor(0.7091, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 50, total loss: 102.183822
# total_train_accuracy: tensor(0.7031, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 51, total loss: 102.328285
# total_train_accuracy: tensor(0.7043, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 52, total loss: 102.731729
# total_train_accuracy: tensor(0.7055, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 53, total loss: 102.162549
# total_train_accuracy: tensor(0.7115, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 54, total loss: 101.818591
# total_train_accuracy: tensor(0.7175, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 55, total loss: 101.171827
# total_train_accuracy: tensor(0.7260, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 56, total loss: 101.014725
# total_train_accuracy: tensor(0.7284, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5781, device='cuda:0')
# Training Epoch: 57, total loss: 100.475374
# total_train_accuracy: tensor(0.7284, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 58, total loss: 100.771902
# total_train_accuracy: tensor(0.7260, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 59, total loss: 101.000451
# total_train_accuracy: tensor(0.7296, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3750, device='cuda:0')
# Training Epoch: 60, total loss: 100.680827
# total_train_accuracy: tensor(0.7284, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 61, total loss: 100.859416
# total_train_accuracy: tensor(0.7139, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 62, total loss: 101.059807
# total_train_accuracy: tensor(0.7392, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 63, total loss: 100.218584
# total_train_accuracy: tensor(0.7440, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 64, total loss: 100.217755
# total_train_accuracy: tensor(0.7103, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 65, total loss: 101.622185
# total_train_accuracy: tensor(0.7356, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 66, total loss: 100.411444
# total_train_accuracy: tensor(0.7620, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 67, total loss: 99.260244
# total_train_accuracy: tensor(0.7356, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 68, total loss: 99.817334
# total_train_accuracy: tensor(0.7332, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 69, total loss: 99.679878
# total_train_accuracy: tensor(0.7572, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 70, total loss: 99.223861
# total_train_accuracy: tensor(0.7428, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 71, total loss: 99.954995
# total_train_accuracy: tensor(0.7380, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 72, total loss: 99.678800
# total_train_accuracy: tensor(0.7500, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 73, total loss: 99.263680
# total_train_accuracy: tensor(0.7476, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3594, device='cuda:0')
# Training Epoch: 74, total loss: 99.137665
# total_train_accuracy: tensor(0.7476, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 75, total loss: 99.277499
# total_train_accuracy: tensor(0.7536, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 76, total loss: 98.826138
# total_train_accuracy: tensor(0.7608, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 77, total loss: 98.430318
# total_train_accuracy: tensor(0.7620, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 78, total loss: 98.780902
# total_train_accuracy: tensor(0.7524, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 79, total loss: 99.191049
# total_train_accuracy: tensor(0.7584, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 80, total loss: 98.786944
# total_train_accuracy: tensor(0.7500, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 81, total loss: 99.439733
# total_train_accuracy: tensor(0.7560, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 82, total loss: 98.760992
# total_train_accuracy: tensor(0.7620, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 83, total loss: 98.553082
# total_train_accuracy: tensor(0.7764, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 84, total loss: 97.742700
# total_train_accuracy: tensor(0.7716, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 85, total loss: 98.047011
# total_train_accuracy: tensor(0.7764, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 86, total loss: 98.310736
# total_train_accuracy: tensor(0.7776, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 87, total loss: 97.891976
# total_train_accuracy: tensor(0.7764, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 88, total loss: 97.809755
# total_train_accuracy: tensor(0.7957, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 89, total loss: 97.133446
# total_train_accuracy: tensor(0.7849, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 90, total loss: 97.720813
# total_train_accuracy: tensor(0.7812, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 91, total loss: 97.482683
# total_train_accuracy: tensor(0.7825, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 92, total loss: 97.694382
# total_train_accuracy: tensor(0.7897, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 93, total loss: 97.546908
# total_train_accuracy: tensor(0.7969, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 94, total loss: 96.913414
# total_train_accuracy: tensor(0.7716, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3594, device='cuda:0')
# Training Epoch: 95, total loss: 97.681183
# total_train_accuracy: tensor(0.7825, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 96, total loss: 97.229045
# total_train_accuracy: tensor(0.7849, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 97, total loss: 97.382015
# total_train_accuracy: tensor(0.7680, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 98, total loss: 97.757644
# total_train_accuracy: tensor(0.7656, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 99, total loss: 97.953257
# total_train_accuracy: tensor(0.7812, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 100, total loss: 97.356073
# total_train_accuracy: tensor(0.7885, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 101, total loss: 97.234886
# total_train_accuracy: tensor(0.7692, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 102, total loss: 97.751264
# total_train_accuracy: tensor(0.7752, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 103, total loss: 97.579489
# total_train_accuracy: tensor(0.8041, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 104, total loss: 96.551854
# total_train_accuracy: tensor(0.7837, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 105, total loss: 97.187564
# total_train_accuracy: tensor(0.7776, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 106, total loss: 97.560747
# total_train_accuracy: tensor(0.7800, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 107, total loss: 97.689091
# total_train_accuracy: tensor(0.7933, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 108, total loss: 97.006531
# total_train_accuracy: tensor(0.8077, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 109, total loss: 96.270307
# total_train_accuracy: tensor(0.8101, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 110, total loss: 95.733533
# total_train_accuracy: tensor(0.7921, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 111, total loss: 96.415495
# total_train_accuracy: tensor(0.8017, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 112, total loss: 96.135912
# total_train_accuracy: tensor(0.8137, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 113, total loss: 95.660051
# total_train_accuracy: tensor(0.8029, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 114, total loss: 96.062958
# total_train_accuracy: tensor(0.8089, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 115, total loss: 96.026912
# total_train_accuracy: tensor(0.7969, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3750, device='cuda:0')
# Training Epoch: 116, total loss: 96.002017
# total_train_accuracy: tensor(0.7957, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 117, total loss: 96.634000
# total_train_accuracy: tensor(0.8089, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 118, total loss: 95.744315
# total_train_accuracy: tensor(0.8089, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 119, total loss: 96.053706
# total_train_accuracy: tensor(0.7849, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 120, total loss: 97.259153
# total_train_accuracy: tensor(0.7969, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 121, total loss: 96.236260
# total_train_accuracy: tensor(0.8029, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 122, total loss: 96.224713
# total_train_accuracy: tensor(0.7993, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3594, device='cuda:0')
# Training Epoch: 123, total loss: 96.200833
# total_train_accuracy: tensor(0.8281, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 124, total loss: 95.368121
# total_train_accuracy: tensor(0.8065, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 125, total loss: 95.868427
# total_train_accuracy: tensor(0.8149, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 126, total loss: 95.759580
# total_train_accuracy: tensor(0.8029, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 127, total loss: 96.321911
# total_train_accuracy: tensor(0.8173, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 128, total loss: 95.346059
# total_train_accuracy: tensor(0.7897, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 129, total loss: 96.771896
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 130, total loss: 95.496109
# total_train_accuracy: tensor(0.8077, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 131, total loss: 95.893069
# total_train_accuracy: tensor(0.8137, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 132, total loss: 95.074301
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 133, total loss: 95.854153
# total_train_accuracy: tensor(0.8113, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 134, total loss: 96.014029
# total_train_accuracy: tensor(0.8185, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 135, total loss: 95.519221
# total_train_accuracy: tensor(0.8185, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 136, total loss: 95.177756
# total_train_accuracy: tensor(0.8257, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 137, total loss: 94.902437
# total_train_accuracy: tensor(0.8137, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 138, total loss: 95.054510
# total_train_accuracy: tensor(0.8257, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 139, total loss: 94.978355
# total_train_accuracy: tensor(0.8113, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 140, total loss: 95.871190
# total_train_accuracy: tensor(0.8233, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5625, device='cuda:0')
# Training Epoch: 141, total loss: 94.815380
# total_train_accuracy: tensor(0.8197, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 142, total loss: 95.019457
# total_train_accuracy: tensor(0.8341, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 143, total loss: 94.559046
# total_train_accuracy: tensor(0.8173, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 144, total loss: 94.894891
# total_train_accuracy: tensor(0.8245, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 145, total loss: 94.652327
# total_train_accuracy: tensor(0.8233, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 146, total loss: 94.780027
# total_train_accuracy: tensor(0.8101, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 147, total loss: 95.525705
# total_train_accuracy: tensor(0.8329, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 148, total loss: 94.597814
# total_train_accuracy: tensor(0.8149, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 149, total loss: 94.964105
# total_train_accuracy: tensor(0.8317, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 150, total loss: 94.569919
# total_train_accuracy: tensor(0.8185, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 151, total loss: 94.901129
# total_train_accuracy: tensor(0.8389, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 152, total loss: 94.511447
# total_train_accuracy: tensor(0.8161, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 153, total loss: 95.000876
# total_train_accuracy: tensor(0.8149, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 154, total loss: 95.079572
# total_train_accuracy: tensor(0.8053, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 155, total loss: 95.889157
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 156, total loss: 95.241212
# total_train_accuracy: tensor(0.8041, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 157, total loss: 95.598516
# total_train_accuracy: tensor(0.8197, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 158, total loss: 95.621806
# total_train_accuracy: tensor(0.8329, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 159, total loss: 94.104940
# total_train_accuracy: tensor(0.8209, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 160, total loss: 95.322688
# total_train_accuracy: tensor(0.8305, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 161, total loss: 94.599120
# total_train_accuracy: tensor(0.8245, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 162, total loss: 94.743545
# total_train_accuracy: tensor(0.8353, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 163, total loss: 93.999439
# total_train_accuracy: tensor(0.8305, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 164, total loss: 94.459247
# total_train_accuracy: tensor(0.8245, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 165, total loss: 94.452179
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 166, total loss: 95.020314
# total_train_accuracy: tensor(0.8173, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 167, total loss: 94.883042
# total_train_accuracy: tensor(0.8341, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 168, total loss: 94.016627
# total_train_accuracy: tensor(0.8401, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 169, total loss: 93.865279
# total_train_accuracy: tensor(0.8257, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 170, total loss: 94.240530
# total_train_accuracy: tensor(0.8353, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 171, total loss: 94.345929
# total_train_accuracy: tensor(0.8353, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 172, total loss: 94.431711
# total_train_accuracy: tensor(0.8269, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 173, total loss: 94.642524
# total_train_accuracy: tensor(0.8365, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 174, total loss: 94.138535
# total_train_accuracy: tensor(0.8377, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 175, total loss: 93.974506
# total_train_accuracy: tensor(0.8317, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 176, total loss: 94.447746
# total_train_accuracy: tensor(0.8185, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 177, total loss: 94.898733
# total_train_accuracy: tensor(0.8305, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 178, total loss: 94.321605
# total_train_accuracy: tensor(0.8293, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 179, total loss: 94.144567
# total_train_accuracy: tensor(0.8233, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 180, total loss: 94.547312
# total_train_accuracy: tensor(0.8401, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 181, total loss: 93.953927
# total_train_accuracy: tensor(0.8413, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 182, total loss: 93.777369
# total_train_accuracy: tensor(0.8209, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 183, total loss: 94.622832
# total_train_accuracy: tensor(0.8474, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 184, total loss: 93.434465
# total_train_accuracy: tensor(0.8089, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 185, total loss: 95.371491
# total_train_accuracy: tensor(0.8425, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 186, total loss: 93.495613
# total_train_accuracy: tensor(0.8450, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 187, total loss: 93.219773
# total_train_accuracy: tensor(0.8522, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 188, total loss: 93.224537
# total_train_accuracy: tensor(0.8498, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3750, device='cuda:0')
# Training Epoch: 189, total loss: 93.423312
# total_train_accuracy: tensor(0.8257, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3438, device='cuda:0')
# Training Epoch: 190, total loss: 94.545707
# total_train_accuracy: tensor(0.8353, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 191, total loss: 93.972247
# total_train_accuracy: tensor(0.8438, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3750, device='cuda:0')
# Training Epoch: 192, total loss: 93.391259
# total_train_accuracy: tensor(0.8474, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 193, total loss: 93.273799
# total_train_accuracy: tensor(0.8365, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 194, total loss: 93.649730
# total_train_accuracy: tensor(0.8474, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 195, total loss: 93.285593
# total_train_accuracy: tensor(0.8377, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 196, total loss: 93.982838
# total_train_accuracy: tensor(0.8341, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 197, total loss: 94.096690
# total_train_accuracy: tensor(0.8365, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 198, total loss: 93.783376
# total_train_accuracy: tensor(0.8305, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 199, total loss: 94.072636
# total_train_accuracy: tensor(0.8401, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 200, total loss: 93.604339
# total_train_accuracy: tensor(0.8534, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 201, total loss: 92.975637
# total_train_accuracy: tensor(0.8281, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 202, total loss: 94.063957
# total_train_accuracy: tensor(0.8341, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 203, total loss: 93.947690
# total_train_accuracy: tensor(0.8293, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 204, total loss: 94.597417
# total_train_accuracy: tensor(0.8341, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 205, total loss: 94.005764
# total_train_accuracy: tensor(0.8558, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 206, total loss: 92.838626
# total_train_accuracy: tensor(0.8534, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 207, total loss: 93.021603
# total_train_accuracy: tensor(0.8486, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 208, total loss: 93.386845
# total_train_accuracy: tensor(0.8233, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 209, total loss: 94.496463
# total_train_accuracy: tensor(0.8450, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 210, total loss: 93.652268
# total_train_accuracy: tensor(0.8377, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 211, total loss: 93.769447
# total_train_accuracy: tensor(0.8438, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 212, total loss: 93.391368
# total_train_accuracy: tensor(0.8293, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 213, total loss: 93.890599
# total_train_accuracy: tensor(0.8425, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 214, total loss: 93.326848
# total_train_accuracy: tensor(0.8486, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 215, total loss: 93.191879
# total_train_accuracy: tensor(0.8401, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 216, total loss: 93.310694
# total_train_accuracy: tensor(0.8365, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 217, total loss: 93.966980
# total_train_accuracy: tensor(0.8462, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 218, total loss: 93.483666
# total_train_accuracy: tensor(0.8305, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 219, total loss: 94.618328
# total_train_accuracy: tensor(0.8329, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 220, total loss: 94.012280
# total_train_accuracy: tensor(0.8474, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 221, total loss: 93.614149
# total_train_accuracy: tensor(0.8425, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 222, total loss: 93.578659
# total_train_accuracy: tensor(0.8389, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 223, total loss: 93.834371
# total_train_accuracy: tensor(0.8317, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 224, total loss: 93.852131
# total_train_accuracy: tensor(0.8534, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 225, total loss: 93.194869
# total_train_accuracy: tensor(0.8558, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 226, total loss: 92.884779
# total_train_accuracy: tensor(0.8474, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 227, total loss: 93.200360
# total_train_accuracy: tensor(0.8450, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 228, total loss: 93.447422
# total_train_accuracy: tensor(0.8498, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 229, total loss: 93.236743
# total_train_accuracy: tensor(0.8450, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 230, total loss: 93.223357
# total_train_accuracy: tensor(0.8161, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 231, total loss: 94.427320
# total_train_accuracy: tensor(0.8462, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 232, total loss: 93.300968
# total_train_accuracy: tensor(0.8558, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 233, total loss: 93.011775
# total_train_accuracy: tensor(0.8570, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 234, total loss: 92.789543
# total_train_accuracy: tensor(0.8173, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 235, total loss: 94.396882
# total_train_accuracy: tensor(0.8438, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 236, total loss: 93.502915
# total_train_accuracy: tensor(0.8389, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 237, total loss: 93.605154
# total_train_accuracy: tensor(0.8413, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 238, total loss: 93.396007
# total_train_accuracy: tensor(0.8486, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 239, total loss: 93.087746
# total_train_accuracy: tensor(0.8510, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 240, total loss: 93.036875
# total_train_accuracy: tensor(0.8486, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 241, total loss: 93.169497
# total_train_accuracy: tensor(0.8534, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 242, total loss: 92.892363
# total_train_accuracy: tensor(0.8377, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 243, total loss: 93.577008
# total_train_accuracy: tensor(0.8594, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 244, total loss: 92.514038
# total_train_accuracy: tensor(0.8353, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 245, total loss: 93.714916
# total_train_accuracy: tensor(0.8450, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5625, device='cuda:0')
# Training Epoch: 246, total loss: 93.256641
# total_train_accuracy: tensor(0.8438, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 247, total loss: 93.567268
# total_train_accuracy: tensor(0.8522, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 248, total loss: 93.082347
# total_train_accuracy: tensor(0.8389, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 249, total loss: 93.744525
# total_train_accuracy: tensor(0.8498, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 250, total loss: 92.921287
# total_train_accuracy: tensor(0.8462, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 251, total loss: 93.173586
# total_train_accuracy: tensor(0.8522, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 252, total loss: 93.027371
# total_train_accuracy: tensor(0.8558, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 253, total loss: 92.881023
# total_train_accuracy: tensor(0.8413, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 254, total loss: 93.566611
# total_train_accuracy: tensor(0.8558, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 255, total loss: 92.428649
# total_train_accuracy: tensor(0.8353, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 256, total loss: 93.770080
# total_train_accuracy: tensor(0.8618, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 257, total loss: 92.901519
# total_train_accuracy: tensor(0.8498, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 258, total loss: 93.107920
# total_train_accuracy: tensor(0.8486, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 259, total loss: 92.558914
# total_train_accuracy: tensor(0.8365, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 260, total loss: 93.745916
# total_train_accuracy: tensor(0.8438, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 261, total loss: 93.201536
# total_train_accuracy: tensor(0.8498, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 262, total loss: 92.849361
# total_train_accuracy: tensor(0.8305, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 263, total loss: 93.993061
# total_train_accuracy: tensor(0.8510, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 264, total loss: 92.860157
# total_train_accuracy: tensor(0.8606, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 265, total loss: 92.479918
# total_train_accuracy: tensor(0.8654, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 266, total loss: 92.209386
# total_train_accuracy: tensor(0.8486, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 267, total loss: 92.822175
# total_train_accuracy: tensor(0.8654, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 268, total loss: 92.310584
# total_train_accuracy: tensor(0.8498, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 269, total loss: 93.281636
# total_train_accuracy: tensor(0.8534, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 270, total loss: 92.851478
# total_train_accuracy: tensor(0.8618, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 271, total loss: 92.438807
# total_train_accuracy: tensor(0.8498, device='cuda:0')
# test
# test
# test
# test
# ...
# total_train_accuracy: tensor(0.8666, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 906, total loss: 91.547584
# total_train_accuracy: tensor(0.8834, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 907, total loss: 90.902545
# total_train_accuracy: tensor(0.8810, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 908, total loss: 90.908015
# total_train_accuracy: tensor(0.8666, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 909, total loss: 91.676352
# total_train_accuracy: tensor(0.8774, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 910, total loss: 91.144583
# total_train_accuracy: tensor(0.8726, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 911, total loss: 91.482158
# total_train_accuracy: tensor(0.8798, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 912, total loss: 90.963833
# total_train_accuracy: tensor(0.8726, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 913, total loss: 91.356134
# total_train_accuracy: tensor(0.8822, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 914, total loss: 91.300043
# total_train_accuracy: tensor(0.8786, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 915, total loss: 91.209113
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 916, total loss: 91.146983
# total_train_accuracy: tensor(0.8654, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 917, total loss: 91.718182
# total_train_accuracy: tensor(0.8618, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 918, total loss: 91.767110
# total_train_accuracy: tensor(0.8762, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 919, total loss: 91.029212
# total_train_accuracy: tensor(0.8798, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 920, total loss: 91.070171
# total_train_accuracy: tensor(0.8894, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 921, total loss: 90.655769
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 922, total loss: 90.543263
# total_train_accuracy: tensor(0.8834, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 923, total loss: 90.842582
# total_train_accuracy: tensor(0.8810, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 924, total loss: 90.719503
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 925, total loss: 91.164287
# total_train_accuracy: tensor(0.8618, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 926, total loss: 91.940431
# total_train_accuracy: tensor(0.8642, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 927, total loss: 91.623636
# total_train_accuracy: tensor(0.8906, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 928, total loss: 90.709931
# total_train_accuracy: tensor(0.8762, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 929, total loss: 91.235389
# total_train_accuracy: tensor(0.8918, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 930, total loss: 90.488234
# total_train_accuracy: tensor(0.8858, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 931, total loss: 90.890540
# total_train_accuracy: tensor(0.8690, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 932, total loss: 91.556447
# total_train_accuracy: tensor(0.8702, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 933, total loss: 91.437244
# total_train_accuracy: tensor(0.8666, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 934, total loss: 91.321636
# total_train_accuracy: tensor(0.8642, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 935, total loss: 91.890556
# total_train_accuracy: tensor(0.8810, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 936, total loss: 91.254744
# total_train_accuracy: tensor(0.8762, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 937, total loss: 91.061864
# total_train_accuracy: tensor(0.8834, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 938, total loss: 90.838121
# total_train_accuracy: tensor(0.8906, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 939, total loss: 90.887944
# total_train_accuracy: tensor(0.8714, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 940, total loss: 91.548025
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 941, total loss: 91.236889
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 942, total loss: 91.408100
# total_train_accuracy: tensor(0.8774, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 943, total loss: 91.269697
# total_train_accuracy: tensor(0.8630, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 944, total loss: 91.755290
# total_train_accuracy: tensor(0.8726, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 945, total loss: 91.448002
# total_train_accuracy: tensor(0.8714, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 946, total loss: 91.163801
# total_train_accuracy: tensor(0.8810, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 947, total loss: 91.105461
# total_train_accuracy: tensor(0.8606, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 948, total loss: 91.901685
# total_train_accuracy: tensor(0.8666, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 949, total loss: 91.367160
# total_train_accuracy: tensor(0.8810, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 950, total loss: 91.086906
# total_train_accuracy: tensor(0.8690, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 951, total loss: 91.364412
# total_train_accuracy: tensor(0.8714, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 952, total loss: 91.310907
# total_train_accuracy: tensor(0.8726, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5781, device='cuda:0')
# Training Epoch: 953, total loss: 91.436500
# total_train_accuracy: tensor(0.8798, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 954, total loss: 91.077000
# total_train_accuracy: tensor(0.8822, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 955, total loss: 91.195218
# total_train_accuracy: tensor(0.8834, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 956, total loss: 90.454921
# total_train_accuracy: tensor(0.8822, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5469, device='cuda:0')
# Training Epoch: 957, total loss: 90.629640
# total_train_accuracy: tensor(0.8846, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 958, total loss: 90.654350
# total_train_accuracy: tensor(0.8774, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 959, total loss: 90.972834
# total_train_accuracy: tensor(0.8834, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 960, total loss: 90.861808
# total_train_accuracy: tensor(0.8702, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 961, total loss: 91.426077
# total_train_accuracy: tensor(0.8954, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 962, total loss: 90.434683
# total_train_accuracy: tensor(0.8774, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 963, total loss: 90.984787
# total_train_accuracy: tensor(0.8762, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 964, total loss: 91.042019
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 965, total loss: 91.106728
# total_train_accuracy: tensor(0.8786, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 966, total loss: 91.083304
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 967, total loss: 91.151359
# total_train_accuracy: tensor(0.8834, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 968, total loss: 90.669224
# total_train_accuracy: tensor(0.8810, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 969, total loss: 90.868883
# total_train_accuracy: tensor(0.8810, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5781, device='cuda:0')
# Training Epoch: 970, total loss: 90.750983
# total_train_accuracy: tensor(0.8774, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 971, total loss: 90.970622
# total_train_accuracy: tensor(0.8942, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5625, device='cuda:0')
# Training Epoch: 972, total loss: 90.278662
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 973, total loss: 90.696452
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4219, device='cuda:0')
# Training Epoch: 974, total loss: 91.135660
# total_train_accuracy: tensor(0.8810, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4531, device='cuda:0')
# Training Epoch: 975, total loss: 90.861745
# total_train_accuracy: tensor(0.8678, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5625, device='cuda:0')
# Training Epoch: 976, total loss: 91.519174
# total_train_accuracy: tensor(0.8702, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3594, device='cuda:0')
# Training Epoch: 977, total loss: 91.305315
# total_train_accuracy: tensor(0.8894, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 978, total loss: 90.518381
# total_train_accuracy: tensor(0.8834, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5312, device='cuda:0')
# Training Epoch: 979, total loss: 91.019203
# total_train_accuracy: tensor(0.8786, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 980, total loss: 91.160893
# total_train_accuracy: tensor(0.8786, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5781, device='cuda:0')
# Training Epoch: 981, total loss: 91.013560
# total_train_accuracy: tensor(0.8654, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 982, total loss: 91.769290
# total_train_accuracy: tensor(0.8642, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 983, total loss: 91.790994
# total_train_accuracy: tensor(0.8738, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 984, total loss: 91.482371
# total_train_accuracy: tensor(0.8666, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4375, device='cuda:0')
# Training Epoch: 985, total loss: 91.321600
# total_train_accuracy: tensor(0.8822, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 986, total loss: 90.861774
# total_train_accuracy: tensor(0.8702, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 987, total loss: 91.582945
# total_train_accuracy: tensor(0.8714, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 988, total loss: 91.345509
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 989, total loss: 91.288017
# total_train_accuracy: tensor(0.8834, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4688, device='cuda:0')
# Training Epoch: 990, total loss: 90.871403
# total_train_accuracy: tensor(0.8882, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4062, device='cuda:0')
# Training Epoch: 991, total loss: 90.609352
# total_train_accuracy: tensor(0.8786, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 992, total loss: 91.090409
# total_train_accuracy: tensor(0.8654, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.3906, device='cuda:0')
# Training Epoch: 993, total loss: 91.610414
# total_train_accuracy: tensor(0.8846, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 994, total loss: 90.827988
# total_train_accuracy: tensor(0.8762, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5156, device='cuda:0')
# Training Epoch: 995, total loss: 91.243283
# total_train_accuracy: tensor(0.8774, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.4844, device='cuda:0')
# Training Epoch: 996, total loss: 91.053816
# total_train_accuracy: tensor(0.8894, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5625, device='cuda:0')
# Training Epoch: 997, total loss: 90.855867
# total_train_accuracy: tensor(0.8798, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.6094, device='cuda:0')
# Training Epoch: 998, total loss: 90.801959
# total_train_accuracy: tensor(0.8666, device='cuda:0')
# test
# test
# test
# test
# total_test_accuracy: tensor(0.5625, device='cuda:0')
# Training Epoch: 999, total loss: 91.860591
