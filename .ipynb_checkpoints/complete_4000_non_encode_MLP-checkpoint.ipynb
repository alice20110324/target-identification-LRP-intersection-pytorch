# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':1000,
    'linear_hidden':100,#线性模型输出层（隐层个数）
    'embed_input_dim':1001,#embed输入维度
    'embed_dim': 100, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    #'dnn_hidden_units': [100,11],#MLP隐层和输出层
    
    'dnn_hidden_units':[100,9],#MLP隐层
    'num_sparse_features_cols':4225,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 24,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'epoch':1000,
    'USE_MIXUP':True,
    'MIXUP_ALPHA': 0.5,#add mixup alpha ,用于beta分布
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    #'train_file':'data/xiaoqiu_gene_5000/train/final_5000_encode_100x.csv',
    'train_data':'dataset/xiaoguan/RF/RF_for_train/train_class_9/train/train_data.csv',
    'train_label':'dataset/xiaoguan/RF/RF_for_train/train_class_9/train/train_label.csv',
    'test_data':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_data.csv',
    'test_label':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_label.csv',
    #'title':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_data.csv',
    
    #'all':''
    #'title':'data/xiaoqiu_gene_5000/train/gene_5000_gene_name.csv',
    #'all':'data/xiaoqiu_gene_5000/train/gene_5000_label_name.csv'
}

# %%
#准备训练集

import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter

#import network
import config
import evaluate
import data_utils
import Trainer
#from utils import 
#准备训练集
#from new_dataset_processed import FMData
from dataset_process import FMData
def prepare_dataset(m_data,m_label,batch_size,n_class):
    m_dataset=FMData(m_data,m_label,n_class)
    m_dataloader=data.DataLoader(m_dataset, drop_last=True,batch_size=batch_size,shuffle=True,num_workers=4)
    
    return m_dataset,m_dataloader
# Out:
# [[190 220 490 ... 360 370 420]
#  [110 220 500 ... 340 260 420]
#  [100 300 500 ... 330 350 390]
#  ...
#  [450 360 500 ... 430 360 500]
#  [420 350 530 ... 440 370 500]
#  [420 360 540 ... 430 370 450]]

# %%
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics
def   train_data(model,train_loader,test_loader,batch_size,model_path):
    #train_accuracy=torchmetrics.Accuracy()
    #test_accuracy=torchmetrics.Accuracy()
    BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    total = 0
    
    #loss_func = torch.nn.BCELoss()
    loss_func=torch.nn.CrossEntropyLoss()
    #loss_func=nn.MultiLabelSoftMarginLoss()
    #loss_func=torch.nn.LogSoftmax()
    num=1000
    #model=nn.Softmax(nn.Linear(10149,16)).to(device)
    # 从DataLoader中获取小批量的id以及数据
    for epoch_id in range(1000):
        correct=0
        total=0
        total_test_acc=0
        
        for batch_idx, (x, labels) in enumerate(train_loader):
            x = Variable(x)
            labels = Variable(labels)
            
            
            #x = torch.tensor(x, dtype=torch.float)
            #x=x.clone().detach().requires_grad_(True)
            x=torch.tensor(x,dtype=torch.float)
            labels=torch.tensor(labels,dtype=torch.float)
            x, labels = x.cuda(), labels.cuda()
            labels_int=labels=torch.max(labels,1)[1]
            #labels_int.cuda()
            #print("labels:",labels)
            
            optimizer.zero_grad()
            y_predict = model(x)
            #print("y_predict:",y_predict)
            #loss = loss_func(y_predict.view(-1), labels)
            loss = loss_func(y_predict, labels)
            loss.backward()
            optimizer.step()
            
            loss = loss.item()
            #loss, predicted = self._train_single_batch(x, labels)

            total += loss
            
            
            #predicted = torch.max(y_predict.data,1)
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
            #predicted=predicted.detach().cpu().numpy()
            
            #labels=torch.max(labels,1)
            #print("labels:",labels)
            #labels=labels[1]
            #y_predict=y_predict.cuda()
            #labels=torch.max(labels,1)[1].cuda()
            #labels=labels.detach().cpu().numpy()
            #correct += (predicted == labels).sum()
            #print("correct:",correct)
            #correct=correct[0]
            #print("new_correct:",float(correct))
            #correct=float(correct)   
            #if batch_idx % 10 == 0:
            #print("batch_idx:",batch_idx)
            #print(correct/(BATCH_SIZE*(batch_idx+1)))
            batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
            #print('batch_train_acc:',batch_train_acc)
        #total_train_accuracy=torchmetrics.functional.compute_details()
        #print('total_train_accuracy:',total_train_accuracy)
        for i , (inputs , targets) in enumerate(test_loader):   
            # evaluate the model on the test set   
            #print(\ inputs:\  inputs)   
            #print(\ targets:\  targets)   
            inputs = Variable(inputs)   
            targets = Variable(targets)     
            #x = torch.tensor(x  dtype=torch.float)   
            #x=x.clone().detach().requires_grad_(True)   
            inputs=torch.tensor(inputs ,dtype=torch.float)   
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs , targets = inputs.cuda(),  targets.cuda()   
            yhat = model(inputs)  
            
            #yhat = torch.max(yhat.data,1)[1]
            #yhat=yhat.detach().cpu().numpy()
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
             #predicted = torch.max(y_predict.data,1)[1]
            
            
            targets=torch.max(targets,1)[1]
            #print("labels:",labels)
            #labels=labels[1]
            #targets=targets.detach().cpu().numpy()
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            #print("batch_test_acc:",batch_test_acc)
            total_test_acc+=batch_test_acc
            #total_test_accuracy=torchmetrics.functional.compute_details()
        print('total_test_accuracy:',total_test_acc/(i+1))
        
                    
                    
            
            #model.evaluate()
            #model.eval()
            #train_result = evaluate.metrics(model, train_loader)
            #valid_result = evaluate.metrics(model, valid_loader)
            #est_result = evaluate.metrics(model, test_loader)
            #acturals,predictions,acc_test=evaluate_model(test_loader,model)
            #print("acc_test:  %d  " %(acc_test))
            #print("Train_RMSE: {:.3f}, Valid_RMSE: {:.3f}, Test_RMSE: {:.3f}".format(
            #train_result, valid_result, test_result))
            # print('[Training Epoch: {}] Batch: {}, Loss: {}'.format(epoch_id, batch_id, loss))
        print("Training Epoch: %d, total loss: %f" % (epoch_id, total))
        #print("auc:",roc_auc_score)
    #功能：保存训练完的网络的各层参数（即weights和bias)
    #path='dataset/xiaoguan/RF/RF_for_train/train_class_9/model/gene_4000_NFM.pkl'
        if epoch_id %100==0:
            num=num+1
            path=os.path.join(model_path,'MLP'+str(num)+'.pkl')
            torch.save(model.state_dict(),path)

# %%
train_dataset,train_loader=prepare_dataset(nfm_config['train_data'],nfm_config['train_label'],nfm_config['batch_size'],nfm_config['n_class'])
test_dataset,test_loader=prepare_dataset(nfm_config['test_data'],nfm_config['test_label'],nfm_config['batch_size'],nfm_config['n_class'])
from MLP import MLP
#from new_nfm_network import NFM
model=MLP(4224,1000,100,9)
#model=NFM(nfm_config)
model.cuda()
print("MLP:",model)
train_data(model,train_loader,test_loader,nfm_config['batch_size'],'dataset/xiaoguan/RF/RF_for_train/train_class_9/model/MLP_no_encode/')

# %%
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。  
#原文链接：https://blog.csdn.net/jclian91/article/details/121708431#   
from torch.autograd import Variable   
from torch.utils.data import DataLoader   
from sklearn.metrics import roc_auc_score   
from sklearn.metrics import accuracy_score   
        
        
def evaluate_model(test_dl , model):   
    predictions,  actuals = [] , []   
    for i , (inputs , targets) in enumerate(test_dl):   
        # evaluate the model on the test set   
        #print(\ inputs:\  inputs)   
        #print(\ targets:\  targets)   
        inputs = Variable(inputs)   
        targets = Variable(targets)   
                    
                    
        #x = torch.tensor(x  dtype=torch.float)   
        #x=x.clone().detach().requires_grad_(True)   
        inputs=torch.tensor(inputs ,dtype=torch.float)   
        targets=torch.tensor(targets ,dtype=torch.float)   
        inputs , targets = inputs.cuda(),  targets.cuda()   
        yhat = model(inputs)   
        # retrieve numpy array   
        #yhat = yhat.detach().numpy()   
        yhat = yhat.detach().cpu().numpy()#转换到cpu   
        # yhat=yhat.argmax(axis=1)   
        #print(' yhat:',  yhat)   
        #print('yhat.shape:' ,yhat.shape)   
        actual = targets.detach().cpu().numpy()   
        actual=actual.round()   
        #print('actual:',  actual)   
        #print('actual.shape:', actual.shape)   
        #actual = actual.reshape(-1  1)   
        # round to class values   
        yhat = yhat.round()   
        # store   
        predictions.append(yhat)   
        actuals.append(actual)   
    #print('prediction:',  predictions)   
    #print('actuals:',  actuals)   
    predictions , actuals = np.vstack(predictions) , np.vstack(actuals)   
    #print('prediction:',  predictions)   
    #print('actuals:',  actuals)   
    # calculate accuracy   
    acc_test = accuracy_score(actuals , predictions)   
    return  actuals , predictions ,acc_test

# %%
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#import network
import config
import evaluate
import data_utils
import Trainer
import evaluate
import torchmetrics
def   train_data(model,train_loader,test_loader,batch_size,model_path):
    #train_accuracy=torchmetrics.Accuracy()
    #test_accuracy=torchmetrics.Accuracy()
    BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    total = 0
    #loss_func = torch.nn.BCELoss()
    loss_func=torch.nn.CrossEntropyLoss()
    #loss_func=nn.MultiLabelSoftMarginLoss()
    #loss_func=torch.nn.LogSoftmax()
    
    #model=nn.Softmax(nn.Linear(10149,16)).to(device)
    # 从DataLoader中获取小批量的id以及数据
    for epoch_id in range(1000):
        correct=0
        total=0
        total_test_acc=0
        for batch_idx, (x, labels) in enumerate(train_loader):
            x = Variable(x)
            labels = Variable(labels)
            
            
            #x = torch.tensor(x, dtype=torch.float)
            #x=x.clone().detach().requires_grad_(True)
            x=torch.tensor(x,dtype=torch.float)
            labels=torch.tensor(labels,dtype=torch.float)
            x, labels = x.cuda(), labels.cuda()
            labels_int=labels=torch.max(labels,1)[1]
            #labels_int.cuda()
            #print("labels:",labels)
            
            optimizer.zero_grad()
            y_predict = model(x)
            #print("y_predict:",y_predict)
            #loss = loss_func(y_predict.view(-1), labels)
            loss = loss_func(y_predict, labels)
            loss.backward()
            optimizer.step()
            
            loss = loss.item()
            #loss, predicted = self._train_single_batch(x, labels)

            total += loss
            
            
            #predicted = torch.max(y_predict.data,1)
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
            #predicted=predicted.detach().cpu().numpy()
            
            #labels=torch.max(labels,1)
            #print("labels:",labels)
            #labels=labels[1]
            #y_predict=y_predict.cuda()
            #labels=torch.max(labels,1)[1].cuda()
            #labels=labels.detach().cpu().numpy()
            #correct += (predicted == labels).sum()
            #print("correct:",correct)
            #correct=correct[0]
            #print("new_correct:",float(correct))
            #correct=float(correct)   
            #if batch_idx % 10 == 0:
            #print("batch_idx:",batch_idx)
            #print(correct/(BATCH_SIZE*(batch_idx+1)))
            batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
            #print('batch_train_acc:',batch_train_acc)
        #total_train_accuracy=torchmetrics.functional.compute_details()
        #print('total_train_accuracy:',total_train_accuracy)
        for i , (inputs , targets) in enumerate(test_loader):   
            # evaluate the model on the test set   
            #print(\ inputs:\  inputs)   
            #print(\ targets:\  targets)   
            inputs = Variable(inputs)   
            targets = Variable(targets)     
            #x = torch.tensor(x  dtype=torch.float)   
            #x=x.clone().detach().requires_grad_(True)   
            inputs=torch.tensor(inputs ,dtype=torch.float)   
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs , targets = inputs.cuda(),  targets.cuda()   
            yhat = model(inputs)  
            
            #yhat = torch.max(yhat.data,1)[1]
            #yhat=yhat.detach().cpu().numpy()
            #print("predicted:",predicted)
            #predicted = torch.max(y_predict.data,1)[1]
             #predicted = torch.max(y_predict.data,1)[1]
            
            
            targets=torch.max(targets,1)[1]
            #print("labels:",labels)
            #labels=labels[1]
            #targets=targets.detach().cpu().numpy()
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            #print("batch_test_acc:",batch_test_acc)
            total_test_acc+=batch_test_acc
            #total_test_accuracy=torchmetrics.functional.compute_details()
        print('total_test_accuracy:',total_test_acc/(i+1))
        
                    
                    
            
            #model.evaluate()
            #model.eval()
            #train_result = evaluate.metrics(model, train_loader)
            #valid_result = evaluate.metrics(model, valid_loader)
            #est_result = evaluate.metrics(model, test_loader)
            #acturals,predictions,acc_test=evaluate_model(test_loader,model)
            #print("acc_test:  %d  " %(acc_test))
            #print("Train_RMSE: {:.3f}, Valid_RMSE: {:.3f}, Test_RMSE: {:.3f}".format(
            #train_result, valid_result, test_result))
            # print('[Training Epoch: {}] Batch: {}, Loss: {}'.format(epoch_id, batch_id, loss))
        print("Training Epoch: %d, total loss: %f" % (epoch_id, total))
        #print("auc:",roc_auc_score)
    #功能：保存训练完的网络的各层参数（即weights和bias)
    #path='dataset/xiaoguan/RF/RF_for_train/train_class_9/model/gene_4000_NFM.pkl'
    
    torch.save(model.state_dict(),model_path)

# %%
train_dataset,train_loader=prepare_dataset(nfm_config['train_data'],nfm_config['train_label'],nfm_config['batch_size'],nfm_config['n_class'])
test_dataset,test_loader=prepare_dataset(nfm_config['test_data'],nfm_config['test_label'],nfm_config['batch_size'],nfm_config['n_class'])
from MLP import MLP
model=MLP(4224,1000,100,9)
model.cuda()
print("MLP:",model)
train_data(model,train_loader,test_loader,nfm_config['batch_size'],'dataset/xiaoguan/RF/RF_for_train/train_class_9/model/non_encode_gene_4000_MLP.pkl')
# Out:
# FMData
# FMData
# MLP: MLP(
#   (fc1): Linear(in_features=4224, out_features=1000, bias=True)
#   (bn1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=1000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:50: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_test_accuracy: tensor(0.3194, device='cuda:0')
# Training Epoch: 0, total loss: 53.187173
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:101: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:102: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_test_accuracy: tensor(0.2778, device='cuda:0')
# Training Epoch: 1, total loss: 52.489628
# total_test_accuracy: tensor(0.2639, device='cuda:0')
# Training Epoch: 2, total loss: 52.014929
# total_test_accuracy: tensor(0.3333, device='cuda:0')
# Training Epoch: 3, total loss: 51.445334
# total_test_accuracy: tensor(0.3056, device='cuda:0')
# Training Epoch: 4, total loss: 51.038609
# total_test_accuracy: tensor(0.3611, device='cuda:0')
# Training Epoch: 5, total loss: 50.965019
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 6, total loss: 50.861221
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 7, total loss: 50.345125
# total_test_accuracy: tensor(0.4583, device='cuda:0')
# Training Epoch: 8, total loss: 49.893160
# total_test_accuracy: tensor(0.3611, device='cuda:0')
# Training Epoch: 9, total loss: 49.846927
# total_test_accuracy: tensor(0.4722, device='cuda:0')
# Training Epoch: 10, total loss: 49.714162
# total_test_accuracy: tensor(0.4722, device='cuda:0')
# Training Epoch: 11, total loss: 49.158398
# total_test_accuracy: tensor(0.4444, device='cuda:0')
# Training Epoch: 12, total loss: 49.222057
# total_test_accuracy: tensor(0.4722, device='cuda:0')
# Training Epoch: 13, total loss: 48.637728
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 14, total loss: 48.719218
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 15, total loss: 48.795029
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 16, total loss: 48.503881
# total_test_accuracy: tensor(0.5000, device='cuda:0')
# Training Epoch: 17, total loss: 49.045734
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 18, total loss: 48.726856
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 19, total loss: 48.442868
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 20, total loss: 47.792806
# total_test_accuracy: tensor(0.6528, device='cuda:0')
# Training Epoch: 21, total loss: 48.293088
# total_test_accuracy: tensor(0.5278, device='cuda:0')
# Training Epoch: 22, total loss: 47.468069
# total_test_accuracy: tensor(0.6111, device='cuda:0')
# Training Epoch: 23, total loss: 47.408169
# total_test_accuracy: tensor(0.5417, device='cuda:0')
# Training Epoch: 24, total loss: 47.331470
# total_test_accuracy: tensor(0.6528, device='cuda:0')
# Training Epoch: 25, total loss: 47.054026
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 26, total loss: 46.746219
# total_test_accuracy: tensor(0.6389, device='cuda:0')
# Training Epoch: 27, total loss: 46.762237
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch:
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 991, total loss: 39.730293
# total_test_accuracy: tensor(0.6667, device='cuda:0')
# Training Epoch: 992, total loss: 39.806237
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 993, total loss: 40.323887
# total_test_accuracy: tensor(0.5972, device='cuda:0')
# Training Epoch: 994, total loss: 40.119053
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 995, total loss: 39.789808
# total_test_accuracy: tensor(0.4861, device='cuda:0')
# Training Epoch: 996, total loss: 39.519124
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 997, total loss: 40.019036
# total_test_accuracy: tensor(0.5694, device='cuda:0')
# Training Epoch: 998, total loss: 39.743292
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 999, total loss: 40.313471

# %%
torch.save(model.state_dict(),'dataset/xiaoguan/RF/RF_for_train/train_class_9/model/non_encode_gene_4000_MLP.pkl')

# %%
##测试集
#from new_nfm_network import NFM
#加载模型



from MLP import MLP
model=MLP(4224,1000,100,9)
#model.cuda()
path='dataset/xiaoguan/RF/RF_for_train/train_class_9/model/non_encode_gene_4000_MLP.pkl'
#nfm = NFM(nfm_config).cuda()
net=model.cuda()
#net=nfm
print(net)
#net = nn.DataParallel(net)
#net = net.to(device)
net.load_state_dict(torch.load(path),strict=False)
net.cuda()

optimizer = torch.optim.Adam(net.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
total = 0
#loss_func = torch.nn.BCELoss()
loss_func=torch.nn.CrossEntropyLoss()
# Out:
# MLP(
#   (fc1): Linear(in_features=4224, out_features=1000, bias=True)
#   (bn1): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=1000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )

# %%
#数据集准备测试
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter

#import network
import config
import evaluate
import data_utils
import Trainer
from dataset_process import FMData

'''  
test_dataset = FMData(nfm_config['test_data'],nfm_config['test_label'],nfm_config['n_class'])
test_loader = data.DataLoader(test_dataset, drop_last=True,batch_size=100,shuffle=True, num_workers=4)

'''
test_dataset,test_loader=prepare_dataset(nfm_config['test_data'],nfm_config['test_label'],nfm_config['batch_size'],nfm_config['n_class'])
# Out:
# row: 0 label: [0]
# row: 1 label: [0]
# row: 2 label: [0]
# row: 3 label: [0]
# row: 4 label: [0]
# row: 5 label: [0]
# row: 6 label: [0]
# row: 7 label: [0]
# row: 8 label: [0]
# row: 9 label: [0]
# row: 10 label: [0]
# row: 11 label: [0]
# row: 12 label: [1]
# row: 13 label: [1]
# row: 14 label: [1]
# row: 15 label: [1]
# row: 16 label: [1]
# row: 17 label: [1]
# row: 18 label: [1]
# row: 19 label: [1]
# row: 20 label: [1]
# row: 21 label: [1]
# row: 22 label: [1]
# row: 23 label: [1]
# row: 24 label: [1]
# row: 25 label: [2]
# row: 26 label: [2]
# row: 27 label: [2]
# row: 28 label: [3]
# row: 29 label: [3]
# row: 30 label: [3]
# row: 31 label: [4]
# row: 32 label: [4]
# row: 33 label: [5]
# row: 34 label: [5]
# row: 35 label: [6]
# row: 36 label: [6]
# row: 37 label: [6]
# row: 38 label: [6]
# row: 39 label: [6]
# row: 40 label: [6]
# row: 41 label: [6]
# row: 42 label: [6]
# row: 43 label: [6]
# row: 44 label: [6]
# row: 45 label: [6]
# row: 46 label: [6]
# row: 47 label: [6]
# row: 48 label: [6]
# row: 49 label: [6]
# row: 50 label: [6]
# row: 51 label: [6]
# row: 52 label: [6]
# row: 53 label: [6]
# row: 54 label: [6]
# row: 55 label: [6]
# row: 56 label: [6]
# row: 57 label: [6]
# row: 58 label: [6]
# row: 59 label: [6]
# row: 60 label: [7]
# row: 61 label: [7]
# row: 62 label: [7]
# row: 63 label: [7]
# row: 64 label: [8]
# row: 65 label: [8]
# row: 66 label: [8]
# row: 67 label: [8]
# row: 68 label: [8]
# row: 69 label: [8]
# row: 70 label: [8]
# row: 71 label: [8]
# row: 72 label: [8]
# row: 73 label: [8]
# row: 74 label: [8]
# row: 75 label: [8]
# row: 76 label: [8]
# label: [[0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.82222223 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.82222223 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.82222223 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.82222223 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.82222223 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.82222223 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.82222223 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.82222223 0.02222222 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.82222223 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.82222223 0.02222222
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.82222223
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.82222223
#   0.02222222 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.82222223 0.02222222 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.82222223 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.82222223 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.82222223 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.82222223 0.02222222]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]
#  [0.02222222 0.02222222 0.02222222 0.02222222 0.02222222 0.02222222
#   0.02222222 0.02222222 0.82222223]]
# features: [[4.77798555 5.86606602 3.45513157 ... 3.62210283 3.39090379 3.72185252]
#  [4.78629985 5.7960645  3.83144007 ... 4.19214932 3.45749937 3.64528141]
#  [4.88697927 5.72916363 3.43365027 ... 3.60494927 3.31709496 3.85617144]
#  ...
#  [6.84452032 6.01981194 2.72255183 ... 1.08743404 4.02330608 4.21967984]
#  [6.27573954 5.47979751 1.80126726 ... 1.8067708  3.86991325 4.72031271]
#  [6.25252267 6.60607204 1.21762219 ... 1.12281082 4.08252199 5.11631014]]

# %%
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。  
#原文链接：https://blog.csdn.net/jclian91/article/details/121708431#   
from torch.autograd import Variable   
from torch.utils.data import DataLoader   
from sklearn.metrics import roc_auc_score   
from sklearn.metrics import accuracy_score   
        
        
def evaluate_model(test_dl , model):   
    predictions,  actuals = [] , []   
    for i , (inputs , targets) in enumerate(test_dl):   
        # evaluate the model on the test set   
        #print(\ inputs:\  inputs)   
        #print(\ targets:\  targets)   
        inputs = Variable(inputs)   
        targets = Variable(targets)   
                    
                    
        #x = torch.tensor(x  dtype=torch.float)   
        #x=x.clone().detach().requires_grad_(True)   
        inputs=torch.tensor(inputs ,dtype=torch.float)   
        targets=torch.tensor(targets ,dtype=torch.float)   
        inputs , targets = inputs.cuda(),  targets.cuda()   
        yhat = model(inputs)   
        # retrieve numpy array   
        #yhat = yhat.detach().numpy()   
        yhat = yhat.detach().cpu().numpy()#转换到cpu   
        # yhat=yhat.argmax(axis=1)   
        #print(' yhat:',  yhat)   
        #print('yhat.shape:' ,yhat.shape)   
        actual = targets.detach().cpu().numpy()   
        actual=actual.round()   
        #print('actual:',  actual)   
        #print('actual.shape:', actual.shape)   
        #actual = actual.reshape(-1  1)   
        # round to class values   
        yhat = yhat.round()   
        # store   
        predictions.append(yhat)   
        actuals.append(actual)   
    #print('prediction:',  predictions)   
    #print('actuals:',  actuals)   
    predictions , actuals = np.vstack(predictions) , np.vstack(actuals)   
    #print('prediction:',  predictions)   
    #print('actuals:',  actuals)   
    # calculate accuracy   
    acc_test = accuracy_score(actuals , predictions)   
    return  actuals , predictions ,acc_test

# %%
actuals,predictions,acc_test=evaluate_model(test_loader,model)
print("acc_test",acc_test)
# Out:
# acc_test 0.5277777777777778
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
