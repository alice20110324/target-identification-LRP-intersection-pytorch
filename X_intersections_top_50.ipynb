# %%
#for 50_genes
import pandas as pd 
import numpy as np
mlp_20_path='results_genes/MLP/contri_k_names_df.csv'
nfm_layer_20_path='results_genes/NFM_layer_2/contri_k_names_df.csv'


mlp_20_df=pd.read_csv(mlp_20_path,sep=',')
nfm_layer_20_df=pd.read_csv(nfm_layer_20_path,sep=',')

#print(mlp_20_df)
mlp_20_df=mlp_20_df.iloc[:,1:]
nfm_layer_20_df=nfm_layer_20_df.iloc[:,1:]
#print(mlp_20_df.shape)
mlp_20_np=np.array(mlp_20_df)
nfm_layer_20_np=np.array(nfm_layer_20_df)

#print(mlp_20_np)


import csv
csv_filename = "results_genes/intersections/intersecions_50_df.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    #writer.writerow(result_list)

    #intersections_20_list=[]
    for i in range(9):
        mlp_data=mlp_20_np[i,:].tolist()
        nfm_data=nfm_layer_20_np[i,:].tolist()
    
        # 将列表转换为集合
        mlp_set = set(mlp_data)
        nfm_set = set(nfm_data)

        # 求交集
        intersection = mlp_set.intersection(nfm_set)

        # 将交集转换回列表
        intersection_list = list(intersection)
        print('intersecion_list:',intersection_list)
        writer.writerow(intersection_list)
        #intersections_20_list.append(intersection_list)
#print('len:',len(intersections_20_list))    
file.close()    
#intersections_20_np=np.array(intersections_20_list)  
#intersections_20_df=pd.DataFrame(intersections_20_np)
#intersections_20_df.to_csv('results_genes/intersections/intersecions_20_df.csv')
# Out:
# intersecion_list: ['EEF1AKMT3', 'KLF6', 'ACP6', 'BCR', 'DUSP6', 'RHOB', 'DEPTOR', 'GDF15', 'AHCYL1', 'PTP4A1', 'CHCHD3', 'CYP39A1', 'FOS', 'AUTS2', 'IFI6', 'LYPLA1', 'IFI44L', 'KLF9', 'UQCR10', 'TMEM100', 'ABLIM1', 'DENND1C', 'NUDT4', 'ATP6V1F', 'CFB', 'GPX3', 'ZNF195', 'JUNB', 'ABCB7', 'PCK1', 'CACNA1D', 'ALB', 'INSR', 'ADM2', 'NR0B2', 'ADPRM']
# intersecion_list: ['GPC5', 'RPS27L', 'MAB21L4', 'MST1L', 'BCR', 'CTSG', 'VAMP8', 'CYP2J2', 'DUSP6', 'DNAJB1', 'LGMN', 'ZNHIT1', 'CHODL', 'LHPP', 'HIRA', 'HERC5', 'TDP2', 'CAMLG', 'TESC', 'DZIP1', 'CHP1', 'IFI6', 'RGS5', 'UQCR10', 'TUBB2B', 'LRRC23', 'HKDC1', 'NDUFA13', 'MS4A4A', 'SLC3A2', 'GATC', 'AGL', 'AADAC', 'IFIT1', 'MAP3K1', 'CPVL', 'ADPRM', 'MEST']
# intersecion_list: ['TUBA4B', 'CASP8', 'CTTN', 'ACP6', 'ABCC3', 'TRA2A', 'PDE3B', 'TFAP2A', 'MRPS15', 'AHCYL1', 'VTCN1', 'EPM2AIP1', 'ISCU', 'TTC1', 'CAMLG', 'FBLN5', 'FOS', 'NEAT1', 'ACSBG2', 'METTL9', 'TTC3', 'NR1D2', 'COX15', 'PDE8A', 'ACTA2', 'SLC16A1', 'TAF4B', 'NONO', 'VDR', 'ACVR1B', 'AGPAT5', 'NDUFB5', 'CFLAR', 'ECH1', 'RPS24', 'MEST']
# intersecion_list: ['KLF6', 'BCR', 'VAMP8', 'GPX2', 'RHOB', 'FST', 'MNX1', 'CLDN4', 'WASHC4', 'MRPL44', 'ABCB4', 'ISCU', 'TESC', 'ZNF593', 'CYP21A2', 'IFI6', 'KLF9', 'PTMS', 'UQCR10', 'ATP6V1F', 'COL1A1', 'TYMP', 'SLC3A2', 'BCCIP', 'CD163', 'ENPP2', 'EGLN3', 'TRIM14', 'BHLHE40', 'ECH1', 'RPS24']
# intersecion_list: ['CRABP2', 'GLB1L', 'TRAPPC2L', 'MAB21L4', 'MST1L', 'BCR', 'VAMP8', 'ACAD10', 'MYO15B', 'AFP', 'FKBP4', 'AHCYL1', 'RPL38', 'FOS', 'COX15', 'ITGB3BP', 'ABLIM3', 'LYPLA1', 'EMX1', 'PEG10', 'ADORA3', 'TMEM100', 'NONO', 'WASHC3', 'ABCB7', 'UCHL1', 'RHBDL1', 'FCGBP', 'TARS2', 'IGHV3-23', 'L2HGDH', 'LARP1', 'ACE', 'ECH1', 'CPVL', 'WARS2', 'WDR12']
# intersecion_list: ['UBXN8', 'LGMN', 'DEPTOR', 'ATP5IF1', 'CHCHD3', 'EPM2AIP1', 'OVOL2', 'HERC5', 'NOS2', 'FBLN5', 'ACAT2', 'AUTS2', 'ITGB3BP', 'IFI6', 'LHX1', 'REN', 'PTMS', 'AMFR', 'LIPC', 'ZNF195', 'COL4A3BP', 'CTXND1', 'C1orf174', 'MRPS16', 'RHBDL1', 'ESRRA', 'SERPINA3', 'IFIT1', 'BHLHE40', 'RRM2', 'MAP3K1', 'ADM2', 'MRPL19', 'OLFML3', 'AIRE']
# intersecion_list: ['RPA3', 'OXCT1', 'ADI1', 'PLIN3', 'SERPINF1', 'ZNHIT1', 'ACAD10', 'HMGCS2', 'NINL', 'WASHC4', 'RGN', 'PTP4A1', 'NDUFB1', 'CAMLG', 'ABCD3', 'SPI1', 'CP', 'PDK3', 'ABLIM1', 'NUDT4', 'HKDC1', 'COL4A3BP', 'BDKRB2', 'NUBPL', 'NDUFA13', 'ABCB7', 'OSBPL1A', 'UCHL1', 'PLEKHA5', 'ATP6V0E2', 'WARS2', 'NPIPB15', 'CYP2E1', 'PTPN3', 'ABHD2']
# intersecion_list: ['RHOBTB1', 'PPP6R1', 'ABCC3', 'ADI1', 'UBXN8', 'GPX2', 'ELF3', 'ANKRD2', 'AHCYL1', 'IGLV2-14', 'LHPP', 'CASP5', 'LIPG', 'TTC1', 'SH3BP2', 'METTL1', 'MT2A', 'METTL9', 'NR1D2', 'IFI6', 'KLF9', 'CP', 'SLC16A1', 'UGDH', 'CGREF1', 'PDK3', 'FGFR2', 'ATP6V1F', 'CFB', 'GPX3', 'COL1A1', 'TYMP', 'CD163', 'BCCIP', 'SERPINA3', 'ALB', 'LARP1', 'CPVL', 'OLFML3']
# intersecion_list: ['TFAM', 'MAB21L4', 'ABCC3', 'VAMP8', 'FST', 'LGMN', 'DEPTOR', 'TFAP2A', 'AHCYL1', 'TTC1', 'HERC5', 'TDP2', 'AUTS2', 'IFI6', 'IFI44L', 'RGS5', 'ADORA3', 'UQCR10', 'ABLIM1', 'GEMIN6', 'DENND1C', 'CFB', 'GPX3', 'ZNF195', 'MRPS16', 'NDUFA13', 'MS4A4A', 'CD163', 'EGLN3', 'TRIM14', 'ALB', 'IFIT1', 'MAP3K1', 'CPVL', 'MRPL19', 'OLFML3']

# %%
#compute unions for  the intersections_20_df of every class 
#intersections_20_df=pd.read_csv('results_genes/intersections/intersecions_20_df.csv',sep=',')
#from chartGPT of the following code
#intersections_20_df=intersections_20_df.iloc[:,1:]
#print(intersections_20_df)
#intersections_20_np=np.array(intersections_20_df)


result = set()
import csv
csv_filename = "results_genes/intersections/intersecions_50_df.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='r', newline='') as csvfile:
    csv_reader = csv.reader(csvfile)
    # 逐行读取数据
    for row in csv_reader:
        row_set=set(row)
        result=result.union(row_set)
        
        

# 或者使用集合的union方法的更简洁写法，使用集合解析
# result = set().union(*list_of_lists)

# 或者使用 | 运算符
# result = set().union(*list_of_lists)

# 将结果转回列表
result_list = list(result)

print(len(result_list))

import csv
csv_filename = "results_genes/intersections/genes_intersections_50.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    writer.writerow(result_list)

#这将输出所有列表的并集，不包含重复的元素。在这个例子中，结果会是 [1, 2, 3, 4, 5, 6, 7]。你可以根据你的实际需求将这个结果转换为列表或者保留为集合，具体取决于你的应用场景。
#抽取训练集和测试集中的数据

#生成新选取元素的数据集
train_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/train_val_info.csv'
test_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info.csv'

train_df=pd.read_csv(train_path,sep=',')


train_df=train_df.iloc[:,1:]


columns=result_list
columns.append('label')
print('columns:',columns)


train_df2=train_df[columns]
print(train_df2.shape)
train_df2.to_csv('results_genes/intersections/dataset/50/train_val_info.csv')

test_df=pd.read_csv(test_path,sep=',')

test_df=test_df.iloc[:,1:]



test_df=test_df[columns]
print(test_df.shape)
test_df.to_csv('results_genes/intersections/dataset/50/test_info.csv')
# Out:
# 198
# columns: ['CRABP2', 'KLF6', 'RPA3', 'OXCT1', 'PPP6R1', 'TFAM', 'CTSG', 'PDE3B', 'MNX1', 'GDF15', 'HMGCS2', 'AFP', 'NINL', 'AHCYL1', 'LHPP', 'RGN', 'CYP39A1', 'TTC1', 'CAMLG', 'FOS', 'ACSBG2', 'ABLIM3', 'LYPLA1', 'LHX1', 'PEG10', 'PTMS', 'CP', 'ABLIM1', 'CFB', 'HKDC1', 'TYMP', 'EGLN3', 'UCHL1', 'RHBDL1', 'AGL', 'SERPINA3', 'ATP6V0E2', 'BHLHE40', 'L2HGDH', 'LARP1', 'ECH1', 'AIRE', 'ABHD2', 'EEF1AKMT3', 'TUBA4B', 'RHOBTB1', 'CTTN', 'BCR', 'ADI1', 'PLIN3', 'CYP2J2', 'DUSP6', 'FST', 'ELF3', 'DEPTOR', 'MYO15B', 'ATP5IF1', 'WASHC4', 'TFAP2A', 'MRPS15', 'PTP4A1', 'HIRA', 'ISCU', 'RPL38', 'NEAT1', 'ACAT2', 'SH3BP2', 'CYP21A2', 'NR1D2', 'IFI6', 'PDE8A', 'ACTA2', 'REN', 'KLF9', 'SPI1', 'RGS5', 'TMEM100', 'GEMIN6', 'DENND1C', 'COL1A1', 'GPX3', 'WASHC3', 'COL4A3BP', 'CTXND1', 'MRPS16', 'BCCIP', 'CD163', 'ABCB7', 'IGHV3-23', 'PLEKHA5', 'AGPAT5', 'TARS2', 'AADAC', 'IFIT1', 'RRM2', 'MAP3K1', 'CPVL', 'ADPRM', 'NPIPB15', 'CYP2E1', 'WDR12', 'MEST', 'GLB1L', 'GPC5', 'MST1L', 'GPX2', 'RHOB', 'SERPINF1', 'ANKRD2', 'ZNHIT1', 'FKBP4', 'MRPL44', 'CASP5', 'LIPG', 'FBLN5', 'CHP1', 'AUTS2', 'MT2A', 'SLC16A1', 'PDK3', 'NUDT4', 'ATP6V1F', 'TUBB2B', 'NONO', 'ZNF195', 'C1orf174', 'SLC3A2', 'MS4A4A', 'ESRRA', 'PCK1', 'ALB', 'NDUFB5', 'ADM2', 'MRPL19', 'WARS2', 'TRAPPC2L', 'CASP8', 'RPS27L', 'ACP6', 'MAB21L4', 'ABCC3', 'VAMP8', 'TRA2A', 'UBXN8', 'DNAJB1', 'LGMN', 'ACAD10', 'CLDN4', 'CHODL', 'IGLV2-14', 'VTCN1', 'CHCHD3', 'EPM2AIP1', 'ABCB4', 'OVOL2', 'NDUFB1', 'HERC5', 'TDP2', 'TESC', 'ZNF593', 'NOS2', 'DZIP1', 'METTL1', 'METTL9', 'TTC3', 'COX15', 'ITGB3BP', 'ABCD3', 'IFI44L', 'EMX1', 'AMFR', 'ADORA3', 'UQCR10', 'LIPC', 'UGDH', 'TAF4B', 'CGREF1', 'FGFR2', 'LRRC23', 'VDR', 'BDKRB2', 'NUBPL', 'NDUFA13', 'JUNB', 'GATC', 'ACVR1B', 'ENPP2', 'OSBPL1A', 'TRIM14', 'FCGBP', 'CACNA1D', 'INSR', 'ACE', 'CFLAR', 'NR0B2', 'RPS24', 'OLFML3', 'PTPN3', 'label']
# (549, 199)
# (138, 199)

# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':2000,
    #'linear_hidden':100,#线性模型输出层（隐层个数）
    #'embed_input_dim':1001,#embed输入维度
    #'embed_dim': 100, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    #'dnn_hidden_units': [100,11],#MLP隐层和输出层
    
    'dnn_hidden_units':[100,9],#MLP隐层
    'num_sparse_features_cols':10477,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 16,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'epoch':1000,
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    #'train_file':'data/xiaoqiu_gene_5000/train/final_5000_encode_100x.csv',
    #'train_data':'dataset/qiuguan/encode/encode_1000/train/train_encode_data_1000_new.csv',
    #'train_label':'dataset/qiuguan/non_code/train/train_label.csv',
    #'guan_test_data':'dataset/qiuguan/non_code/guan_test/guan_test_data.csv',
    #'guan_test_label':'dataset/qiuguan/non_code/guan_test/guan_test_label.csv',
    #'test_data':'dataset/qiuguan/encode/encode_1000/test/test_encode_data_1000_new.csv',
    #'test_label':'dataset/qiuguan/non_code/test/test_labels.csv',
    #'title':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_data.csv',
    
    #'all':''
    #'title':'data/xiaoqiu_gene_5000/train/gene_5000_gene_name.csv',
    #'all':'data/xiaoqiu_gene_5000/train/gene_5000_label_name.csv'
}

#model definition
import torch.nn as nn
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(3300)
        self.fc1 = nn.Linear(3300, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model = MLP().cuda()
print(model)

class MLP1(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(198)
        self.fc1 = nn.Linear(198, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model1 = MLP1().cuda()
print(model1)
class MLP2(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(93)
        self.fc1 = nn.Linear(93, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model2 = MLP2().cuda()
print(model2)
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import torch.nn.functional as F  # 激励函数的库
#import network
import config
import evaluate
import data_utils
#import Trainer



def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    #n = len(labels)
    n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output

def one_hot(labels, classes):
    n = len(labels)
    #eoff = label_smoothing / classes
    output = np.zeros((n, classes), dtype=np.float32)
    for row, label in enumerate(labels):
        output[row, label] = 1
        #print("row:",row,"label:",label)
    return output


def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    #n = len(labels)
    n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output

def one_hot(labels, classes):
    n = len(labels)
    #eoff = label_smoothing / classes
    output = np.zeros((n, classes), dtype=np.float32)
    for row, label in enumerate(labels):
        output[row, label] = 1
        #print("row:",row,"label:",label)
    return output



class KZDatasetPredict(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, df_list):
    
       
        self.data_info = self.get_data_info(df_list)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data,label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data,label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,df_list):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        print('data_info:',df_list[-1])
        #df=pd.read_csv(csv_path,sep=',')
        #df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        label=int(df_list[-1])
        labels.append(label)
        print('labels:',labels)
        data=df_list[:-1]
        #df_np=np.array(df_list)
        #print(rows,cols)
        
        #print('labels:',labels)
        labels=np.array(labels)
        print('labels.shape:',labels.shape)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        
           
        
        data=np.array(data)#
            
            
            
            
            
            
            
            
        data=torch.from_numpy(data)#
            
        labels=torch.from_numpy(labels)#
        #bi_data=embding_process(nfm_config,data)
        #print("bi_data.shape:",bi_data.shape)
            
            
        data_info.append((data,label))
        return data_info
class KZDatasetTest(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, csv_path):
    
       
        self.data_info = self.get_data_info(csv_path)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]
            data=data.astype(float)#
            data=np.array(data)#
            
            label=labels[i]
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            label=torch.from_numpy(label)#
            
            
            data_info.append((data,label))
        return data_info
import torch
import torch.nn as nn
from torch.utils.data.dataset import *
from PIL import Image
from torch.nn import functional as F
import random
from sklearn.model_selection import train_test_split
import ast
import torchvision


        

class KZDataset(Dataset):
    def __init__(self, csv_path, K,n_class,ki=0, typ='train', transform=None, rand=False):
       
        self.all_data_info = self.get_data_info(csv_path)
        
        if rand:
            random.seed(1)
            random.shuffle(self.all_data_info)
        leng = len(self.all_data_info)
        every_z_len = leng // K
        if typ == 'val':
            self.data_info = self.all_data_info[every_z_len * ki : every_z_len * (ki+1)]
        elif typ == 'train':
            self.data_info = self.all_data_info[: every_z_len * ki] + self.all_data_info[every_z_len * (ki+1) :]
            
        self.transform = transform
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, label

    def __len__(self):
        return len(self.data_info)
    
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        
        print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]
            data=data.astype(float)#
            data=np.array(data)#
            
            label=labels[i]
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            label=torch.from_numpy(label)#
            
            
            data_info.append((data,label))
        return data_info
            
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics

from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics


def train_epoch(model,train_loader,batch_size,optimizer,loss_func):
    BATCH_SIZE=batch_size
    total = 0
    correct=0
    total_loss=0
    #
    model.train()
    total_train_accuracy=0  
    for batch_idx, (x, labels) in enumerate(train_loader):
            
        labels = Variable(labels)
        x = Variable(x)
            
            
        x=torch.tensor(x,dtype=torch.float)
        labels=torch.tensor(labels,dtype=torch.float)
        x, labels = x.cuda(), labels.cuda()
        labels_int=labels=torch.max(labels,1)[1]
            
            
        optimizer.zero_grad()
        y_predict = model(x)
            
        loss = loss_func(y_predict, labels)
        loss.backward()
        optimizer.step()
            
        loss = loss.item()
           

        total_loss += loss
            
            
            
        batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
        total_train_accuracy+=batch_train_acc
            
    total_train_accuracy/=(batch_idx+1)
    print('total_train_accuracy:',total_train_accuracy)
    print("Training Epoch: %d, total loss: %f" % (epoch_id, total_loss))
    return total_loss,total_train_accuracy

def val_epoch(model,test_loader,batch_size,optimizer): 
    batch_size_num=0
    total_test_acc=0
    model.eval()
    for i , (inputs , targets) in enumerate(test_loader):   
            print("test")
            
            inputs = Variable(inputs)   
            targets = Variable(targets)     
           
            inputs=torch.tensor(inputs ,dtype=torch.float)   
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs , targets = inputs.cuda(),  targets.cuda()   
            yhat = model(inputs)  
            
            
            
            targets=torch.max(targets,1)[1]
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            
            total_test_acc+=batch_test_acc
            
            batch_size_num=i
    total_test_acc/=(batch_size_num+1)
        ###print('total_test_accuracy:',total_test_acc/(batch_size+1))
    print('total_test_accuracy:',total_test_acc)
        
                    
                    
            
            
    
        
   
    
    return total_test_acc


import numpy as np
import math
import matplotlib.pyplot as plt

def plotLoss(loss,epoch):
    plt.rcParams['font.sans-serif']=['SimHei']
    plt.rcParams['axes.unicode_minus'] = False
    plt.figure(figsize=(8, 5))
    x=[i for i in range(epoch)]
    #acc_train=acc_train.cpu()
    #acc_test=acc_test.cpu()
    plt.plot(x, loss, 'r-', mec='k', label='Logistic Loss', lw=2)
    #plt.plot(x,acc_train,'b-',mec='k',label='accuracy Train',lw=2)
    #plt.plot(x,acc_test,'g-',mec='k',label='accuracy Test',lw=2)
    #plt.plot(x, y_01, 'g-', mec='k', label='0/1 Loss', lw=2)
    #plt.plot(x, y_hinge, 'b-',mec='k', label='Hinge Loss', lw=2)
    #plt.plot(x, boost, 'm--',mec='k', label='Adaboost Loss',lw=2)
    plt.grid(True, ls='--')
    plt.legend(loc='upper right')
    plt.title('损失函数')
    plt.show()
# Out:
# MLP(
#   (bn0): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=3300, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP1(
#   (bn0): BatchNorm1d(198, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=198, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP2(
#   (bn0): BatchNorm1d(93, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=93, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )

# %%
#train model with new features of 94
model=model1
K=10
test_metrics=[]
train_loss_total_list=[]
for ki in range(K):
    trainset = KZDataset(csv_path='results_genes/intersections/dataset/50/train_val_info.csv',K=K, n_class=nfm_config['n_class'],ki=ki,  typ='train', transform=None, rand=True)
    valset = KZDataset(csv_path='results_genes/intersections/dataset/50/train_val_info.csv', K=K,n_class=nfm_config['n_class'],ki=ki,  typ='val', transform=None, rand=True)
    train_loader = data.DataLoader(
         dataset=trainset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size'],
         shuffle=True)
    val_loader = data.DataLoader(
         dataset=valset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
    
    model_path='results_genes/intersections/models/50/'
    #BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    #total = 0
    
    
    loss_func=torch.nn.CrossEntropyLoss()
    
    num=0
   
    
    epoches=101
    for epoch_id in range(epoches):
          
        
        
        train_loss_total,acc_train=train_epoch(model,train_loader,nfm_config['batch_size'],optimizer,loss_func)
        train_loss_total_list.append(train_loss_total)#
        if epoch_id %20==0:
            num=num+1
            #path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pkl')
            #torch.save(model.state_dict(),path)
            # 保存模型
            
            path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pt')##################pt
            torch.save(model.state_dict(),path)
            #torch.save(model.state_dict(),path)
    print("the ",ki," epoch ends")
    plotLoss(train_loss_total_list,epoches)
    train_loss_total_list=[]
    acc_test=val_epoch(model,val_loader,nfm_config['batch_size'],optimizer)
    print("acc_test_each_k:",acc_test)
    test_metrics.append(acc_test)

print(test_metrics)
#test_metrics=test_metrics.tolist()
test_metrics=[x.cpu().detach().numpy() for x in test_metrics]
print(test_metrics)
acc_test_metrics=np.mean(test_metrics) 
print("acc_test_metrics:",acc_test_metrics)
# Out:
# 549 199
# 549 199
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:450: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:451: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.2625, device='cuda:0')
# Training Epoch: 0, total loss: 64.204114
# total_train_accuracy: tensor(0.5500, device='cuda:0')
# Training Epoch: 1, total loss: 60.161712
# total_train_accuracy: tensor(0.6229, device='cuda:0')
# Training Epoch: 2, total loss: 58.589393
# total_train_accuracy: tensor(0.6833, device='cuda:0')
# Training Epoch: 3, total loss: 57.147403
# total_train_accuracy: tensor(0.7146, device='cuda:0')
# Training Epoch: 4, total loss: 56.424986
# total_train_accuracy: tensor(0.7729, device='cuda:0')
# Training Epoch: 5, total loss: 55.505944
# total_train_accuracy: tensor(0.7458, device='cuda:0')
# Training Epoch: 6, total loss: 55.530683
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 7, total loss: 54.198019
# total_train_accuracy: tensor(0.8229, device='cuda:0')
# Training Epoch: 8, total loss: 53.477774
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 9, total loss: 52.583436
# total_train_accuracy: tensor(0.8271, device='cuda:0')
# Training Epoch: 10, total loss: 52.624353
# total_train_accuracy: tensor(0.8417, device='cuda:0')
# Training Epoch: 11, total loss: 52.121024
# total_train_accuracy: tensor(0.8333, device='cuda:0')
# Training Epoch: 12, total loss: 51.993474
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 13, total loss: 51.725671
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 14, total loss: 51.780821
# total_train_accuracy: tensor(0.8479, device='cuda:0')
# Training Epoch: 15, total loss: 51.720601
# total_train_accuracy: tensor(0.8438, device='cuda:0')
# Training Epoch: 16, total loss: 51.615375
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 17, total loss: 50.441866
# total_train_accuracy: tensor(0.8604, device='cuda:0')
# Training Epoch: 18, total loss: 50.564806
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 19, total loss: 49.958529
# total_train_accuracy: tensor(0.8667, device='cuda:0')
# Training Epoch: 20, total loss: 50.138384
# total_train_accuracy: tensor(0.8688, device='cuda:0')
# Training Epoch: 21, total loss: 50.406807
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 22, total loss: 49.569573
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 23, total loss: 49.832078
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 24, total loss: 49.624163
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 25, total loss: 49.314399
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 26, total loss: 48.751971
# total_train_accuracy: tensor(0.9063, device='cuda:0')
# Training Epoch: 27, total loss: 48.749439
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 28, total loss: 49.163483
# total_train_accuracy: tensor(0.9063, device='cuda:0')
# Training Epoch: 29, total loss: 48.453068
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 30, total loss: 48.278935
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 31, total loss: 48.230731
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 32, total loss: 48.678319
# total_train_accuracy: tensor(0.8646, device='cuda:0')
# Training Epoch: 33, total loss: 49.023663
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 34, total loss: 48.023540
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 35, total loss: 48.764047
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 36, total loss: 48.030308
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 37, total loss: 48.824898
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 38, total loss: 48.264994
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 39, total loss: 47.316642
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 40, total loss: 48.051377
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 41, total loss: 47.496108
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 42, total loss: 47.740504
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 43, total loss: 47.551662
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 44, total loss: 47.056459
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 45, total loss: 47.608075
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 46, total loss: 47.173482
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 47, total loss: 47.183461
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 48, total loss: 47.091707
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 49, total loss: 46.825818
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 50, total loss: 46.766004
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 51, total loss: 46.848218
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 52, total loss: 46.998265
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 53, total loss: 46.669549
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 54, total loss: 47.221140
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 55, total loss: 46.927836
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 56, total loss: 46.732802
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 57, total loss: 46.474860
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 58, total loss: 45.928731
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 59, total loss: 45.915006
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 60, total loss: 46.751212
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 61, total loss: 46.214921
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 62, total loss: 46.115597
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 63, total loss: 46.284937
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 64, total loss: 46.550575
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 65, total loss: 45.747864
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 66, total loss: 45.863778
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 67, total loss: 46.156741
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 68, total loss: 46.154425
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 69, total loss: 45.612893
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 70, total loss: 46.074276
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 71, total loss: 45.642414
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 72, total loss: 45.990476
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 73, total loss: 45.879086
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 74, total loss: 45.330021
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 75, total loss: 45.528078
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 76, total loss: 45.401218
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 77, total loss: 45.659930
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 78, total loss: 45.798753
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 79, total loss: 45.657338
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 80, total loss: 45.192127
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 81, total loss: 45.453731
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 82, total loss: 45.491986
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 83, total loss: 44.708192
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 84, total loss: 45.339176
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 85, total loss: 44.891325
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 86, total loss: 45.408423
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 87, total loss: 45.758980
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 88, total loss: 45.292521
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 89, total loss: 45.315982
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 90, total loss: 45.335773
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 91, total loss: 44.635417
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 92, total loss: 44.919502
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 93, total loss: 45.498205
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 94, total loss: 45.028175
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 95, total loss: 44.923760
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 96, total loss: 45.127384
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 97, total loss: 44.633274
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 98, total loss: 44.288718
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 99, total loss: 44.605093
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 100, total loss: 45.243706
# the  0  epoch ends
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:488: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:489: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# test
# test
# test
# total_test_accuracy: tensor(0.8542, device='cuda:0')
# acc_test_each_k: tensor(0.8542, device='cuda:0')
# 549 199
# 549 199
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 0, total loss: 45.442831
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 1, total loss: 46.069012
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 2, total loss: 44.845253
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 3, total loss: 44.742928
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 4, total loss: 45.282867
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 5, total loss: 45.437202
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 6, total loss: 44.676139
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 7, total loss: 45.005347
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 8, total loss: 44.829548
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 9, total loss: 45.141427
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 10, total loss: 45.128449
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 11, total loss: 44.710838
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 12, total loss: 44.678597
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 13, total loss: 44.811537
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 14, total loss: 44.185694
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 15, total loss: 43.965119
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 16, total loss: 44.430596
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 17, total loss: 44.373579
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 18, total loss: 44.734085
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 19, total loss: 44.284021
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 20, total loss: 44.708439
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 21, total loss: 44.311499
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 22, total loss: 44.297217
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 23, total loss: 44.444167
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 24, total loss: 44.513741
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 25, total loss: 44.138071
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 26, total loss: 44.428159
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 27, total loss: 44.553986
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 28, total loss: 44.141426
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 29, total loss: 44.195844
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 30, total loss: 44.736477
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 31, total loss: 43.678079
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 32, total loss: 44.529511
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 33, total loss: 43.705511
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 34, total loss: 43.526069
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 35, total loss: 44.418471
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 36, total loss: 44.185699
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 37, total loss: 44.137847
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 38, total loss: 44.142339
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 39, total loss: 44.315542
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 40, total loss: 43.959441
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 41, total loss: 43.950301
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 42, total loss: 44.057859
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 43, total loss: 44.043400
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 44, total loss: 44.095975
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 45, total loss: 43.888259
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 46, total loss: 44.073350
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 47, total loss: 43.982338
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 48, total loss: 43.747409
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 49, total loss: 43.644354
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 50, total loss: 44.502326
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 51, total loss: 43.923755
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 52, total loss: 43.568046
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 53, total loss: 43.963794
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 54, total loss: 44.034465
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 55, total loss: 43.514284
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 56, total loss: 43.690814
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 57, total loss: 43.998221
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 58, total loss: 44.284908
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 59, total loss: 44.071494
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 60, total loss: 43.751525
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 61, total loss: 43.925979
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 62, total loss: 43.758103
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 63, total loss: 43.776656
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 64, total loss: 43.306764
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 65, total loss: 43.797232
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 66, total loss: 44.406685
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 67, total loss: 43.861547
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 68, total loss: 43.957530
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 69, total loss: 43.691363
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 70, total loss: 43.610774
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 71, total loss: 43.434557
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 72, total loss: 44.036270
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 73, total loss: 43.160999
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 74, total loss: 43.651929
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 75, total loss: 43.435290
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 76, total loss: 43.542394
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 77, total loss: 42.942762
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 78, total loss: 43.219122
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 79, total loss: 43.617829
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 80, total loss: 43.242779
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 81, total loss: 44.005447
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 82, total loss: 43.431063
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 83, total loss: 43.506683
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 84, total loss: 43.676183
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 85, total loss: 43.637856
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 86, total loss: 43.396582
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 87, total loss: 43.282785
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 88, total loss: 43.664169
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 89, total loss: 43.567567
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 90, total loss: 43.566105
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 91, total loss: 43.556062
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 92, total loss: 43.104946
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 93, total loss: 43.060356
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 94, total loss: 43.274405
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 95, total loss: 43.231519
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 96, total loss: 43.164901
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 97, total loss: 43.298476
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 98, total loss: 43.107247
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 99, total loss: 43.389057
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 100, total loss: 44.008283
# the  1  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(0.9375, device='cuda:0')
# acc_test_each_k: tensor(0.9375, device='cuda:0')
# 549 199
# 549 199
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 0, total loss: 44.227380
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 1, total loss: 43.799941
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 2, total loss: 43.440982
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 3, total loss: 43.412163
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 4, total loss: 43.195376
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 5, total loss: 43.411374
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 6, total loss: 44.245128
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 7, total loss: 43.283039
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 8, total loss: 43.117524
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 9, total loss: 43.558881
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 10, total loss: 43.364882
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 11, total loss: 43.258701
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 12, total loss: 43.126541
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 13, total loss: 43.181438
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 14, total loss: 43.566786
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 15, total loss: 43.206896
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 16, total loss: 43.720093
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 17, total loss: 42.917137
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 18, total loss: 43.378744
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 19, total loss: 43.139579
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 20, total loss: 43.623832
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 21, total loss: 43.055704
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 22, total loss: 43.443843
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 23, total loss: 43.239783
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 24, total loss: 44.198055
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 25, total loss: 43.880488
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 26, total loss: 43.296318
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 27, total loss: 43.317021
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 28, total loss: 42.929817
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 29, total loss: 43.357597
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 30, total loss: 43.162819
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 31, total loss: 43.746373
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 32, total loss: 44.045899
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 33, total loss: 43.388662
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 34, total loss: 43.218042
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 35, total loss: 43.042202
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 36, total loss: 43.398041
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 37, total loss: 42.952821
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 38, total loss: 43.514524
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 39, total loss: 43.720290
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 40, total loss: 43.096120
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 41, total loss: 43.660166
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 42, total loss: 43.331034
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 43, total loss: 43.145136
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 44, total loss: 43.023122
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 45, total loss: 43.204542
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 46, total loss: 43.165871
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 47, total loss: 42.684365
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 48, total loss: 43.183587
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 49, total loss: 43.004099
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 50, total loss: 42.965112
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 51, total loss: 43.106439
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 52, total loss: 43.474088
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 53, total loss: 43.340985
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 54, total loss: 43.098023
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 55, total loss: 43.132270
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 56, total loss: 43.002460
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 57, total loss: 43.060933
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 58, total loss: 43.286194
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 59, total loss: 43.494257
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 60, total loss: 43.075866
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 61, total loss: 43.718162
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 62, total loss: 43.470701
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 63, total loss: 42.878024
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 64, total loss: 43.545979
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 65, total loss: 43.550108
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 66, total loss: 43.074470
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 67, total loss: 43.031806
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 68, total loss: 42.892398
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 69, total loss: 42.983125
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 70, total loss: 43.416087
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 71, total loss: 42.992710
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 72, total loss: 43.168311
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 73, total loss: 43.030533
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 74, total loss: 42.901249
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 75, total loss: 43.422306
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 76, total loss: 42.617742
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 77, total loss: 43.068766
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 78, total loss: 43.203760
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 79, total loss: 42.998165
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 80, total loss: 43.777763
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 81, total loss: 42.927531
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 82, total loss: 43.011890
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 83, total loss: 42.993290
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 84, total loss: 42.811211
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 85, total loss: 42.819050
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 86, total loss: 43.101407
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 87, total loss: 43.163317
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 88, total loss: 42.755292
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 89, total loss: 42.411917
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 90, total loss: 43.749208
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 91, total loss: 42.553671
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 92, total loss: 43.319312
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 93, total loss: 42.785780
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 94, total loss: 42.971403
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 95, total loss: 43.179500
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 96, total loss: 42.533000
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 97, total loss: 42.697762
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 98, total loss: 43.013942
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 99, total loss: 42.744054
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 100, total loss: 42.961992
# the  2  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(0.9792, device='cuda:0')
# acc_test_each_k: tensor(0.9792, device='cuda:0')
# 549 199
# 549 199
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 0, total loss: 43.266797
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 1, total loss: 43.011121
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 2, total loss: 43.116652
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 3, total loss: 43.520336
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 4, total loss: 43.181828
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 5, total loss: 43.089626
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 6, total loss: 42.870169
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 7, total loss: 43.380909
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 8, total loss: 43.003195
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 9, total loss: 42.555735
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 10, total loss: 42.571349
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 11, total loss: 42.857868
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 12, total loss: 43.019911
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 13, total loss: 42.355781
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 14, total loss: 42.754911
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 15, total loss: 42.950418
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 16, total loss: 42.973953
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 17, total loss: 42.986786
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 18, total loss: 42.716615
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 19, total loss: 42.864422
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 20, total loss: 42.542561
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 21, total loss: 43.004515
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 22, total loss: 42.727413
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 23, total loss: 42.928714
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 24, total loss: 42.907821
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 25, total loss: 42.252781
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 26, total loss: 43.026435
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 27, total loss: 43.197343
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 28, total loss: 42.887066
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 29, total loss: 42.819745
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 30, total loss: 42.900841
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 31, total loss: 42.901983
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 32, total loss: 42.821326
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 33, total loss: 42.717311
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 34, total loss: 42.916264
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 35, total loss: 42.901493
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 36, total loss: 43.149652
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 37, total loss: 42.537891
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 38, total loss: 43.079795
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 39, total loss: 42.830918
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 40, total loss: 42.811037
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 41, total loss: 42.919354
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 42, total loss: 42.517922
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 43, total loss: 42.681573
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 44, total loss: 43.283159
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 45, total loss: 42.671805
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 46, total loss: 43.005821
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 47, total loss: 43.157122
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 48, total loss: 42.598148
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 49, total loss: 42.760993
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 50, total loss: 42.687108
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 51, total loss: 42.858907
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 52, total loss: 42.838432
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 53, total loss: 43.196416
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 54, total loss: 42.654771
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 55, total loss: 42.210107
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 56, total loss: 42.604567
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 57, total loss: 43.046991
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 58, total loss: 42.834628
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 59, total loss: 42.903969
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 60, total loss: 42.750646
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 61, total loss: 42.776812
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 62, total loss: 42.837834
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 63, total loss: 43.085225
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 64, total loss: 42.899334
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 65, total loss: 42.794216
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 66, total loss: 42.728031
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 67, total loss: 42.354554
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 68, total loss: 42.323873
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 69, total loss: 42.399241
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 70, total loss: 42.905550
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 71, total loss: 42.846277
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 72, total loss: 42.727631
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 73, total loss: 42.560583
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 74, total loss: 42.640242
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 75, total loss: 42.888958
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 76, total loss: 42.657169
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 77, total loss: 42.826616
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 78, total loss: 42.861973
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 79, total loss: 42.831350
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 80, total loss: 42.993228
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 81, total loss: 42.512456
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 82, total loss: 42.635806
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 83, total loss: 42.686950
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 84, total loss: 43.019282
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 85, total loss: 42.436172
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 86, total loss: 42.702103
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 87, total loss: 42.391213
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 88, total loss: 42.918374
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 89, total loss: 42.988273
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 90, total loss: 43.084695
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 91, total loss: 42.479178
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 92, total loss: 42.877345
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 93, total loss: 42.722919
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 94, total loss: 42.899713
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 95, total loss: 42.720478
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 96, total loss: 42.400551
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 97, total loss: 42.742814
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 98, total loss: 43.045063
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 99, total loss: 42.556165
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 100, total loss: 42.673755
# the  3  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(0.9583, device='cuda:0')
# acc_test_each_k: tensor(0.9583, device='cuda:0')
# 549 199
# 549 199
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 0, total loss: 42.891718
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 1, total loss: 42.507786
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 2, total loss: 42.637483
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 3, total loss: 42.852122
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 4, total loss: 43.201053
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 5, total loss: 42.975209
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 6, total loss: 42.503062
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 7, total loss: 42.523980
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 8, total loss: 42.661032
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 9, total loss: 42.699283
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 10, total loss: 42.665376
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 11, total loss: 42.684539
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 12, total loss: 42.715469
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 13, total loss: 42.695062
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 14, total loss: 42.705160
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 15, total loss: 42.889926
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 16, total loss: 42.312263
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 17, total loss: 42.403998
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 18, total loss: 42.492013
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 19, total loss: 42.537110
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 20, total loss: 42.906610
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 21, total loss: 42.664269
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 22, total loss: 42.508422
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 23, total loss: 42.454722
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 24, total loss: 42.540110
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 25, total loss: 42.529655
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 26, total loss: 42.833271
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 27, total loss: 42.706539
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 28, total loss: 42.519879
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 29, total loss: 42.513618
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 30, total loss: 42.705064
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 31, total loss: 42.549740
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 32, total loss: 42.868860
# total_train_accuracy: tensor(0.9896, device='cuda:0')
# Training Epoch: 33, total loss: 42.145424
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 34, total loss: 42.438370
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 35, total loss: 42.609587
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 36, total loss: 42.396295
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 37, total loss: 42.791412
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 38, total loss: 42.520169
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 39, total loss: 42.319391
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 40, total loss: 42.437773
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 41, total loss: 42.600466
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 42, total loss: 42.446439
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 43, total loss: 42.391951
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 44, total loss: 42.695541
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 45, total loss: 42.610085
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 46, total loss: 42.358924
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 47, total loss: 42.893724
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 48, total loss: 42.441579
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 49, total loss: 42.640874
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 50, total loss: 42.251491
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 51, total loss: 42.535724
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 52, total loss: 42.406428
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 53, total loss: 42.812076
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 54, total loss: 42.914294
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 55, total loss: 42.794523
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 56, total loss: 43.143109
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 57, total loss: 42.287497
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 58, total loss: 42.887860
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 59, total loss: 42.927781
# ...
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 45, total loss: 42.628945
# total_train_accuracy: tensor(0.9896, device='cuda:0')
# Training Epoch: 46, total loss: 41.892702
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 47, total loss: 42.809669
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 48, total loss: 42.416828
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 49, total loss: 42.456323
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 50, total loss: 42.107106
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 51, total loss: 42.148226
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 52, total loss: 42.422972
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 53, total loss: 42.538775
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 54, total loss: 42.404272
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 55, total loss: 42.716171
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 56, total loss: 42.389375
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 57, total loss: 42.457007
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 58, total loss: 42.423232
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 59, total loss: 42.737429
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 60, total loss: 42.670159
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 61, total loss: 42.078162
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 62, total loss: 42.169953
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 63, total loss: 42.743289
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 64, total loss: 42.797338
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 65, total loss: 42.556910
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 66, total loss: 42.454124
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 67, total loss: 42.490187
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 68, total loss: 42.296679
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 69, total loss: 42.319381
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 70, total loss: 42.377279
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 71, total loss: 42.620948
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 72, total loss: 42.313758
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 73, total loss: 42.332195
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 74, total loss: 42.490700
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 75, total loss: 42.532042
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 76, total loss: 42.508653
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 77, total loss: 42.648855
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 78, total loss: 42.130569
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 79, total loss: 42.385996
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 80, total loss: 42.145609
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 81, total loss: 42.277150
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 82, total loss: 41.916329
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 83, total loss: 42.323525
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 84, total loss: 42.475506
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 85, total loss: 42.406974
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 86, total loss: 42.483400
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 87, total loss: 42.184205
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 88, total loss: 42.445655
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 89, total loss: 42.079654
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 90, total loss: 42.481678
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 91, total loss: 42.398782
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 92, total loss: 42.069155
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 93, total loss: 43.160964
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 94, total loss: 42.448222
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 95, total loss: 41.977600
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 96, total loss: 42.273309
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 97, total loss: 42.542937
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 98, total loss: 41.970678
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 99, total loss: 42.197745
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 100, total loss: 42.300918
# the  8  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# acc_test_each_k: tensor(1., device='cuda:0')
# 549 199
# 549 199
# total_train_accuracy: tensor(0.9896, device='cuda:0')
# Training Epoch: 0, total loss: 42.136547
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 1, total loss: 42.236988
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 2, total loss: 42.861276
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 3, total loss: 42.521108
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 4, total loss: 42.682143
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 5, total loss: 42.350552
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 6, total loss: 42.518701
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 7, total loss: 42.388699
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 8, total loss: 41.934546
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 9, total loss: 42.427566
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 10, total loss: 42.264420
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 11, total loss: 42.432203
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 12, total loss: 42.460269
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 13, total loss: 42.082096
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 14, total loss: 42.329948
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 15, total loss: 42.449494
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 16, total loss: 42.113641
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 17, total loss: 42.423297
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 18, total loss: 42.153378
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 19, total loss: 42.415210
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 20, total loss: 42.663711
# total_train_accuracy: tensor(0.9896, device='cuda:0')
# Training Epoch: 21, total loss: 41.747903
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 22, total loss: 42.054305
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 23, total loss: 42.032165
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 24, total loss: 41.954370
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 25, total loss: 42.031816
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 26, total loss: 42.615145
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 27, total loss: 42.366406
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 28, total loss: 42.265111
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 29, total loss: 42.624975
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 30, total loss: 42.577610
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 31, total loss: 42.193177
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 32, total loss: 42.640187
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 33, total loss: 42.389785
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 34, total loss: 42.475824
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 35, total loss: 42.489986
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 36, total loss: 42.242067
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 37, total loss: 42.432138
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 38, total loss: 42.467836
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 39, total loss: 42.150783
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 40, total loss: 42.790174
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 41, total loss: 42.309323
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 42, total loss: 42.323087
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 43, total loss: 42.499427
# total_train_accuracy: tensor(0.9938, device='cuda:0')
# Training Epoch: 44, total loss: 41.975540
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 45, total loss: 42.255726
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 46, total loss: 42.152075
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 47, total loss: 42.224397
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 48, total loss: 42.332243
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 49, total loss: 42.518324
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 50, total loss: 42.415335
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 51, total loss: 42.117626
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 52, total loss: 42.396685
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 53, total loss: 42.152802
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 54, total loss: 41.970387
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 55, total loss: 41.918453
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 56, total loss: 42.255659
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 57, total loss: 42.434336
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 58, total loss: 42.476555
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 59, total loss: 42.594721
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 60, total loss: 42.536604
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 61, total loss: 42.728971
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 62, total loss: 42.384763
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 63, total loss: 42.291769
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 64, total loss: 42.332817
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 65, total loss: 42.163481
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 66, total loss: 42.665301
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 67, total loss: 42.493119
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 68, total loss: 42.807808
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 69, total loss: 42.259798
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 70, total loss: 42.114761
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 71, total loss: 42.190894
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 72, total loss: 42.501774
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 73, total loss: 42.267551
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 74, total loss: 42.400915
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 75, total loss: 42.305848
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 76, total loss: 42.548831
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 77, total loss: 42.601024
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 78, total loss: 42.060520
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 79, total loss: 42.432751
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 80, total loss: 42.273931
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 81, total loss: 42.314388
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 82, total loss: 42.033678
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 83, total loss: 42.263242
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 84, total loss: 42.252048
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 85, total loss: 42.023685
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 86, total loss: 41.892823
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 87, total loss: 42.187744
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 88, total loss: 42.227901
# total_train_accuracy: tensor(0.9917, device='cuda:0')
# Training Epoch: 89, total loss: 42.116141
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 90, total loss: 42.333875
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 91, total loss: 42.083911
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 92, total loss: 42.339476
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 93, total loss: 42.188062
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 94, total loss: 42.300943
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 95, total loss: 42.316902
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 96, total loss: 42.190183
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 97, total loss: 41.991973
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 98, total loss: 42.434674
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 99, total loss: 42.377637
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 100, total loss: 42.103714
# the  9  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# acc_test_each_k: tensor(1., device='cuda:0')
# [tensor(0.8542, device='cuda:0'), tensor(0.9375, device='cuda:0'), tensor(0.9792, device='cuda:0'), tensor(0.9583, device='cuda:0'), tensor(0.9583, device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0')]
# [array(0.8541667, dtype=float32), array(0.9375, dtype=float32), array(0.9791667, dtype=float32), array(0.9583334, dtype=float32), array(0.9583334, dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(1., dtype=float32)]
# acc_test_metrics: 0.96875

# %%
import torch

#功能：加载保存到path中的各层参数到神经网络

#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP610.pkl'
#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP9110.pkl'
path='results_genes/intersections/models/50/MLP610.pt'
#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP10910.pkl'
#nfm=NFM(nfm_config)
mlp=MLP1()
#print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
mlp.load_state_dict(torch.load(path),strict=False)
mlp.cuda()

print(mlp)




mlp_params = list(mlp.named_parameters())
#print(nfm_params)
net=mlp


testset = KZDatasetTest(csv_path='results_genes/intersections/dataset/50/test_info.csv')
   
test_loader = data.DataLoader(
         dataset=testset,
         #transform=torchvision.transforms.ToTensor(),
         
         batch_size=nfm_config['batch_size']
        
     )
#———————————————— 
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/jclian91/article/details/121708431# 
from torch.autograd import Variable 
from torch.utils.data import DataLoader 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import accuracy_score 
 
def evaluate_model(test_dl, model): 
    model.eval()#测试数据稳定
    predictions, actuals = [], [] 
    for i, (inputs, targets) in enumerate(test_dl): 
        # evaluate the model on the test set 
        #print(\ inputs:\ ,inputs) 
        #print(\ targets:\ ,targets) 
        inputs = Variable(inputs) 
        targets = Variable(targets) 
                 
                 
        #x = torch.tensor(x, dtype=torch.float) 
        #x=x.clone().detach().requires_grad_(True) 
        inputs=torch.tensor(inputs,dtype=torch.float) 
        targets=torch.tensor(targets,dtype=torch.float) 
        inputs, targets = inputs.cuda(), targets.cuda() 
        yhat = model(inputs) 
        yhat=(yhat==torch.max(yhat,1,keepdim=True)[0]).to(dtype=torch.int32)
        # retrieve numpy array 
        #yhat = yhat.detach().numpy() 
        yhat = yhat.detach().cpu().numpy()#转换到cpu 
        # yhat=yhat.argmax(axis=1) 
        #print(yhat:\ ,yhat) 
        #print('yhat.shape:',yhat.shape) 
        actual = targets.detach().cpu().numpy() 
        actual=actual.round() 
        #print(\ actual:\ ,actual) 
        #print('actual.shape:',actual.shape
        #predictions.appe) 
        #actual = actual.reshape(-1, 1) 
        # round to class values 
        yhat = yhat.round() 
        # store nd(yhat) 
        actuals.append(actual) 
        predictions.append(yhat)
    #print("prediction:" ,predictions) 
    #print("actuals:",actuals) 
    predictions, actuals = np.vstack(predictions), np.vstack(actuals) 
    #print("prediction:" ,predictions) 
    #print("actuals:" ,actuals) 
    # calculate accuracy 
    acc_test = accuracy_score(actuals, predictions) 
    return  actuals, predictions,acc_test 

import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 
target_list=actuals 
pred_list=predictions 
      
y_true=target_list 
y_pred=pred_list 
      
f1=f1_score(y_true=target_list, y_pred=pred_list, average='macro') # 也可以指定micro模式 
acc_score=accuracy_score(y_true=target_list, y_pred=pred_list) 
rec_score=recall_score(y_true=target_list,y_pred=pred_list,average='macro') # 也可以指定micro模式 
pre_recall=precision_score(y_true=target_list,y_pred=pred_list,average='macro') 
print("f1_score:  %.4f" ,f1) 
print("accuracy_score:" ,acc_score) 
print("recall_score:",rec_score) 
print("pre_recall:" ,pre_recall)



auc_curve = roc_auc_score(y_true, y_pred, multi_class='ovo')
#———————————————— 
#版权声明：本文为CSDN博主「农民小飞侠」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/w5688414/article/details/106595892 
PM_y=y_pred 
true_y=y_true 
n_classes=PM_y.shape[1] 
      
print("n_classes:",n_classes) 
fpr = dict() 
tpr = dict() 
roc_auc = dict() 
for i in range(n_classes): 
    fpr[i], tpr[i], _ = roc_curve(true_y[:, i], PM_y[:, i]) 
    roc_auc[i] = auc(fpr[i], tpr[i]) 
    #print(i) 
    #print(fpr) 
    #print(tpr) 
    
    
    
#计算macro auc 
from scipy import interp 
# First aggregate all false positive rates 
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)])) 
       
# Then interpolate all ROC curves at this points 
mean_tpr = np.zeros_like(all_fpr) 
for i in range(n_classes): 
    mean_tpr += interp(all_fpr, fpr[i], tpr[i]) 
       
    # Finally average it and compute AUC 
    mean_tpr /= n_classes 
       
    fpr["macro"] = all_fpr 
    tpr["macro"] = mean_tpr 
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    
    
    
#画图 
      
import matplotlib.pyplot as plt 
from itertools import cycle 
from matplotlib.ticker import FuncFormatter 
lw = 2 
# Plot all ROC curves 
plt.figure() 
labels=['Con(0)','DN(1)','FSGS(2)','HT(3)','IgA(4)','MCD(5)','MGN(6)','RPGN(7)','SLE(8)'] 

'''
plt.plot(fpr["macro"], tpr["macro"], 
              label='macro-average ROC curve (area = {0:0.4f})' 
                    ''.format(roc_auc["macro"]), 
              color='navy', linestyle=':', linewidth=4) 
'''

       
colors = cycle(['aqua', 'darkorange', 'cornflowerblue','blue','yellow','burlywood','cornsilk','darkblue','goldenrod','greenyellow','maroon']) 
for i, color in zip(range(n_classes), colors): 
    plt.plot(fpr[i], tpr[i], color=color, lw=lw, 
                  label=labels[i]+'(area = {0:0.4f})'.format(roc_auc[i])) 
       
    plt.plot([0, 1], [0, 1], 'k--', lw=lw) 
    plt.xlim([0.0, 1.0]) 
    plt.ylim([0.0, 1.05]) 
      
      
    plt.xlabel('1-Specificity (%)') 
    plt.ylabel('Sensitivity (%)') 
    #plt.title('testing on kidney tubules with F800 without augment') 
    plt.title('testing on kidney tubules with F800 \n without augment')   

        
def to_percent(temp, position): 
    return '%1.0f'%(100*temp) 
      
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.legend(loc="lower right" ) 
      
plt.show()
# Out:
# MLP1(
#   (bn0): BatchNorm1d(198, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=198, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# 138 199
# f1_score:  %.4f 0.9211082149428014
# accuracy_score: 0.9202898550724637
# recall_score: 0.9235164835164835
# pre_recall: 0.929987004548408
# n_classes: 9
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:151: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
