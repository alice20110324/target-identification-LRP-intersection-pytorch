# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':800,#线性模型输出层（隐层个数）
    'embed_input_dim':101,#embed输入维度##########################20,101,1001
    'embed_dim': 10, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    'dnn_hidden_units': [50,9],#MLP隐层和输出层
    'num_sparse_features_cols':3300,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 24,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'train_label': 'dataset/gene_247/train/guan_train_label.csv',
    'train_data':'dataset/gene_247/train/guan_train_data.csv',
    'test_label':'dataset/gene_247/test/qiu_test_label.csv',
    'test_data':'dataset/gene_247/test/qiu_test_data.csv',
    'gene_name':'dataset/qiuguan/origin_800/gene_name.csv',
    'label_name':'dataset/qiuguan/origin_800/gene_label.csv'
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
}

nfm_config1 = \
{
    'n_class':9,
    'linear_hidden1':800,#线性模型输出层（隐层个数）
    'embed_input_dim':20,#embed输入维度
    'embed_dim': 10, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    'dnn_hidden_units': [50,9],#MLP隐层和输出层
    'num_sparse_features_cols':266,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 24,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'train_label': 'dataset/gene_247/train/guan_train_label.csv',
    'train_data':'dataset/gene_247/train/guan_train_data.csv',
    'test_label':'dataset/gene_247/test/qiu_test_label.csv',
    'test_data':'dataset/gene_247/test/qiu_test_data.csv',
    'gene_name':'dataset/qiuguan/origin_800/gene_name.csv',
    'label_name':'dataset/qiuguan/origin_800/gene_label.csv'
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
}
nfm_config2 = \
{
    'n_class':9,
    'linear_hidden1':800,#线性模型输出层（隐层个数）
    'embed_input_dim':20,#embed输入维度
    'embed_dim': 10, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    'dnn_hidden_units': [50,9],#MLP隐层和输出层
    'num_sparse_features_cols':133,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 24,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'train_label': 'dataset/gene_247/train/guan_train_label.csv',
    'train_data':'dataset/gene_247/train/guan_train_data.csv',
    'test_label':'dataset/gene_247/test/qiu_test_label.csv',
    'test_data':'dataset/gene_247/test/qiu_test_data.csv',
    'gene_name':'dataset/qiuguan/origin_800/gene_name.csv',
    'label_name':'dataset/qiuguan/origin_800/gene_label.csv'
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
}


import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import torch.nn.functional as F  # 激励函数的库
#import network
import config
import evaluate
import data_utils
#import Trainer



def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    #n = len(labels)
    n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output

def one_hot(labels, classes):
    n = len(labels)
    #eoff = label_smoothing / classes
    output = np.zeros((n, classes), dtype=np.float32)
    for row, label in enumerate(labels):
        output[row, label] = 1
        #print("row:",row,"label:",label)
    return output

class KZDatasetPredict(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, df_list):
    
       
        self.data_info = self.get_data_info(df_list)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, bi_data,label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, bi_data,label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,df_list):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        print('data_info:',df_list[-1])
        #df=pd.read_csv(csv_path,sep=',')
        #df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        label=int(df_list[-1])
        labels.append(label)
        print('labels:',labels)
        data=df_list[:-1]
        #df_np=np.array(df_list)
        #print(rows,cols)
        
        #print('labels:',labels)
        labels=np.array(labels)
        print('labels.shape:',labels.shape)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        
           
        
        data=np.array(data)#
            
            
            
            
            
            
            
            
        data=torch.from_numpy(data)#
            
        labels=torch.from_numpy(labels)#
        bi_data=embding_process(nfm_config,data)
        #print("bi_data.shape:",bi_data.shape)
            
            
        data_info.append((data,bi_data,label))
        return data_info
    
class KZDatasetTest(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, csv_path):
    
       
        self.data_info = self.get_data_info(csv_path)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, bi_data,label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, bi_data,label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        #print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]#data
            data=data.astype(float)#
            data=np.array(data)#
            
            
            #data=torch.from_numpy(data)
            
            
            
            
            label=labels[i]#label
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            #print("data.shape:",data.shape)
            label=torch.from_numpy(label)#
            bi_data=embding_process(nfm_config,data)
            #print("bi_data.shape:",bi_data.shape)
            
            
            data_info.append((data,bi_data,label))
        return data_info
    
    
    
import torch
import torch.nn as nn
from torch.utils.data.dataset import *
from PIL import Image
from torch.nn import functional as F
import random
from sklearn.model_selection import train_test_split
import ast
import torchvision


        

class KZDataset(Dataset):
    def __init__(self, csv_path, K,n_class,ki=0, typ='train', transform=None, rand=False):
        
        self.all_data_info = self.get_data_info(csv_path)
        
        if rand:
            random.seed(1)
            random.shuffle(self.all_data_info)
        leng = len(self.all_data_info)
        every_z_len = leng // K
        if typ == 'val':
            self.data_info = self.all_data_info[every_z_len * ki : every_z_len * (ki+1)]
        elif typ == 'train':
            self.data_info = self.all_data_info[: every_z_len * ki] + self.all_data_info[every_z_len * (ki+1) :]
            
        self.transform = transform
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, bi_data,label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, bi_data,label

    def __len__(self):
        return len(self.data_info)
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        #print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]#data
            data=data.astype(float)#
            data=np.array(data)#
            
            
            #data=torch.from_numpy(data)
            
            
            
            
            label=labels[i]#label
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            #print("data.shape:",data.shape)
            label=torch.from_numpy(label)#
            bi_data=embding_process(nfm_config,data)
            #print("bi_data.shape:",bi_data.shape)
           
            
            data_info.append((data,bi_data,label))
        return data_info
            

import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn


import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics
#import network
import config
import evaluate
import data_utils
import Trainer
#from utils import 
#准备训练集
#from new_dataset_processed import FMData
#from dataset_process import FMData
def train_epoch(model,train_loader,batch_size,optimizer,loss_func):
    BATCH_SIZE=batch_size
    total = 0
    correct=0
    total_loss=0
    #
    total_train_accuracy=0  
    model.train()
    for batch_idx, (x, bi_x,labels) in enumerate(train_loader):
            
        x = Variable(x)
        bi_x=Variable(bi_x)
        labels = Variable(labels)
            
            
        #x = torch.tensor(x, dtype=torch.float)
        #x=x.clone().detach().requires_grad_(True)
        x=torch.tensor(x,dtype=torch.float)
        bi_x=torch.tensor(bi_x,dtype=torch.long)
        labels=torch.tensor(labels,dtype=torch.float)
        x, bi_x,labels = x.cuda(), bi_x.cuda(),labels.cuda()
        labels_int=labels=torch.max(labels,1)[1]
            
        optimizer.zero_grad()
        y_predict = model(x,bi_x)
            
        loss = loss_func(y_predict, labels)
        loss.backward()
        optimizer.step()
            
        loss = loss.item()
           

        total_loss += loss
            
            
            
        batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
        total_train_accuracy+=batch_train_acc
            
    total_train_accuracy/=(batch_idx+1)
    print('total_train_accuracy:',total_train_accuracy)
    print("Training Epoch: %d, total loss: %f" % (epoch_id, total_loss))
    return total_loss,total_train_accuracy



def val_epoch(model,test_loader,batch_size,optimizer): 
    batch_size_num=0
    total_test_acc=0
    model.eval()
    for i , (inputs ,bi_inputs, targets) in enumerate(test_loader):   
            print("test")
            # evaluate the model on the test set   
            #print(\ inputs:\  inputs)   
            #print(\ targets:\  targets)   
            inputs = Variable(inputs)   
            bi_inputs=Variable(bi_inputs)
            targets = Variable(targets)     
            #x = torch.tensor(x  dtype=torch.float)   
            #x=x.clone().detach().requires_grad_(True)   
            inputs=torch.tensor(inputs ,dtype=torch.float)  
            bi_inputs=torch.tensor(bi_inputs,dtype=torch.float)
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs ,bi_inputs,targets = inputs.cuda(),bi_inputs.cuda(), targets.cuda()   
            yhat = model(inputs,bi_inputs)   
            
            
            
            targets=torch.max(targets,1)[1]
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            
            total_test_acc+=batch_test_acc
            
            batch_size_num=i
    total_test_acc/=(batch_size_num+1)
        ###print('total_test_accuracy:',total_test_acc/(batch_size+1))
    print('total_test_accuracy:',total_test_acc)
        
    return total_test_acc




import torch.nn as nn
class BiInteractionPooling(nn.Module):
    """Bi-Interaction Layer used in Neural FM,compress the
      pairwise element-wise product of features into one single vector.
      Input shape
        - A 3D tensor with shape:``(batch_size,field_size,embedding_size)``.
      Output shape
    http://127.0.0.1:3000/notebooks/NFM-pyorch-master/NFM-pyorch-master/%E6%9C%AA%E5%91%BD%E5%90%8D5.ipynb?kernel_name=python3#    - 3D tensor with shape: ``(batch_size,1,embedding_size)``.
    """
    def __init__(self):
        super(BiInteractionPooling, self).__init__()

    def forward(self, inputs):
        concated_embeds_value = inputs
        square_of_sum = torch.pow(
            torch.sum(concated_embeds_value, dim=1, keepdim=True), 2)
        sum_of_square = torch.sum(
            concated_embeds_value * concated_embeds_value, dim=1, keepdim=True)
        cross_term = 0.5 * (square_of_sum - sum_of_square)
        return cross_term

import torch.nn as nn
class BiInteractionPooling(nn.Module):
    """Bi-Interaction Layer used in Neural FM,compress the
      pairwise element-wise product of features into one single vector.
      Input shape
        - A 3D tensor with shape:``(batch_size,field_size,embedding_size)``.
      Output shape
    http://127.0.0.1:3000/notebooks/NFM-pyorch-master/NFM-pyorch-master/%E6%9C%AA%E5%91%BD%E5%90%8D5.ipynb?kernel_name=python3#    - 3D tensor with shape: ``(batch_size,1,embedding_size)``.
    """
    def __init__(self):
        super(BiInteractionPooling, self).__init__()

    def forward(self, inputs):
        concated_embeds_value = inputs
        #print("bi_interaction compute:")
        #print("inputs:",inputs.shape)
        square_of_sum = torch.pow(
            torch.sum(concated_embeds_value, dim=1, keepdim=True), 2)
        #print("square_of_sum：",square_of_sum.shape)
        sum_of_square = torch.sum(
            concated_embeds_value * concated_embeds_value, dim=1, keepdim=True)
        #print("sum_of_square:",sum_of_square.shape)
        cross_term = 0.5 * (square_of_sum - sum_of_square)
        #print("cross_term:",cross_term.shape)
        return cross_term
    
    
def embding_process(config,sparse_inputs):
    #sparse_inputs=torch.tensor(sparse_inputs)
    #sparse_inputs=torch.tensor(sparse_inputs,dtype=torch.int8)
    sparse_inputs=sparse_inputs.int()
    embedding_layers=nn.Embedding(config['embed_input_dim'],config['embed_dim'])
    #print("sparse_inputs:",sparse_inputs.shape)   
    # B-Interaction 层
    bi_pooling = BiInteractionPooling()
    bi_dropout = config['bi_dropout']
    if bi_dropout > 0:
        dropout = nn.Dropout(bi_dropout)
            
    num_sparse_feature=config['num_sparse_features_cols']
    
   
    
    
    
    
        
        
    sparse_embeds = embedding_layers(sparse_inputs) 
    #sparse_embeds=np.array(sparse_embeds)
    #print('sparse_embeds.shape:',sparse_embeds.shape)
    sparse_embeds=sparse_embeds.detach().numpy()
    sparse_embeds=sparse_embeds.T
    sparse_embeds=torch.from_numpy(sparse_embeds)
    #sparse_embeds =[ torch.cat((sparse_embeds[i]), axis=0) for i  in range(sparse_embeds.shape[0])]
    #print("sparse_embeds:",sparse_embeds)
    #print("sparse_numpy.T.shape:",sparse_embeds.shape)
    
    #BN_bi = nn.BatchNorm1d(config['embed_dim'])
    # 送入B-Interaction层
    #fm_input = sparse_embeds.view(-1, num_sparse_feature, config['embed_dim'])#整理成n行m列
    fm_input=sparse_embeds
    # print(fm_input)
    # print(fm_input.shape)
    #print("fm_input:",fm_input)

    bi_out = bi_pooling(fm_input)
    
    #print("bi_out.shape:",bi_out.shape)
    bi_out=bi_out.detach().numpy()
    bi_out=bi_out.T
    bi_out=torch.from_numpy(bi_out)
    #print("bi_out.T.shape:",bi_out.shape)
    
    bi_out = bi_out.view(-1)###
    if bi_dropout:
        bi_out = dropout(bi_out)
    #bi_out = bi_out.unsqueeze(0)
    #
    #print("bi_out_view.shape:",bi_out.shape)
    #bi_out=BN_bi(bi_out)########
    
    
    return bi_out


import torch
import torch.nn as nn
from basemodel import BaseModel
import torch.nn.functional as F



    



class NFM(BaseModel):
    def __init__(self, config, dense_features_cols=[]):#=[]为新增
    #def __init__(self, config, dense_features_cols, sparse_features_cols):
        super(NFM, self).__init__(config)
        # 稠密和稀疏特征的数量
        #self.num_dense_feature = dense_features_cols.__len__()
        self.num_dense_feature = 0#修改
        self.num_sparse_feature = config['num_sparse_features_cols']
        #self.num_sparse_feature = 0##修改
        self.__config=config
        
        self.bi_BN=nn.BatchNorm1d(nfm_config['embed_dim'])
        
        self.BN_num=nn.BatchNorm1d(self.num_sparse_feature)
        self.linear1=nn.Linear(config['num_sparse_features_cols'],config['linear_hidden1'])
        self.bn1=nn.BatchNorm1d(config['linear_hidden1'])
        self.drop1=nn.Dropout(0.5)
        self.relu1=nn.ReLU()
        
        self.linear2=nn.Linear(config['linear_hidden1']+config['embed_dim'],config['dnn_hidden_units'][0])
        self.bn2=nn.BatchNorm1d(config['dnn_hidden_units'][0])
        self.drop2=nn.Dropout(0.5)
        self.relu2=nn.ReLU()
        
        self.linear3=nn.Linear(config['dnn_hidden_units'][0],config['dnn_hidden_units'][1])
        self.bn3=nn.BatchNorm1d(config['dnn_hidden_units'][1])
        #self.drop3=nn.Dropout(0.3)
        self.relu3=nn.ReLU()
        
        #self.embedding_layers=nn.Embedding(config['embed_input_dim'],config['embed_dim'])
        
        
            
            
        
        
        
        #self.dnn_softmax=nn.Softmax(dim=1) # 按列SoftMax,列和为1  #注意nn.softmax的定义和调用
        #self.dnn_softmax_=F.softmax(dim=1)
        #self.dnn_hidden_units=config['dnn_hidden_units']
    def forward(self, x,bi_x):
        # 先区分出稀疏特征和稠密特征，这里是按照列来划分的，即所有的行都要进行筛选
        #bi_x=bi_x.long()
        #print(x.dtype)
        # 求出线性部分
        #x=F.relu(self.drop(self.BN_linear1(self.linear_model1(self.BN_num(x))))
        #x=F.relu(self.drop(self.BN_linear1(self.linear_model1(x))))
        #print("x,,bi_x",x.shape,bi_x.shape)
        x=self.BN_num(x)#####
        #print("x_BN:",bi_x.shape)
        #x=self.linear_model1(x)
        
        #x1=torch.cat((x,bi_x),dim=1)
        #print("linear_output:",linear_output)
        #linear_output=linear_output.view(-1,self.__config['linear_hidden1'])
        #linear_output=self.drop(linear_output)
        #linear_output=self.BN_linear(linear_output)
        # 求出稀疏特征的embedding向量
        
        
        #print('bi_out.shape:',bi_out.shape)
        #print(x.dtype)
        #print(bi_out.dtype)
        
        #input=x,bi_x#不能是list，必须是tensor
        #x1,x2=input
        y1=self.relu1(self.drop1(self.bn1(self.linear1(x))))
        bi_x=torch.tensor(bi_x,dtype=torch.float)#######
        bi_x=self.bi_BN(bi_x)####
        x2=torch.cat((y1,bi_x),dim=1)
        #print('y1.shape:',y1.shape)
        y2=self.relu2(self.drop2(self.bn2(self.linear2(x2))))
        #x3=torch.cat((y2,bi_x),dim=1)
        #print('y2.shape:',y2.linear3(y2)))
        #print('y3.shape:',y3.shape)
        y3=self.relu3(self.bn3(self.linear3(y2)))
        y=F.softmax(y3,dim=1)
        #x3=torch.cat((y2,bi_x),dim=1)
        #x3=torch.cat((y2,bi_x),dim=1)
        #print('x3.shape:',x3.shape)
        
        
        y_pred=y
        #y_pred=self.dnn_softmax(dnn_output)#增加
        #y_pred=F.softmax(dnn_output,dim=0)
        # Final
        #output = linear_output + y_pred#修改
        #y_pred = self.dnn_softmax(output,dim=0)

        return y_pred
    
nfm = NFM(nfm_config).cuda()
nfm.cuda()
nfm_params = list(nfm.named_parameters())
#print(nfm_params[1])
nfm1 = NFM(nfm_config1).cuda()
nfm1.cuda()
nfm_params1 = list(nfm1.named_parameters())
nfm2 = NFM(nfm_config2).cuda()
nfm2.cuda()
nfm_params2 = list(nfm2.named_parameters())
import numpy as np
import math
import matplotlib.pyplot as plt

def plotLoss(loss,epoch):
    plt.rcParams['font.sans-serif']=['SimHei']
    plt.rcParams['axes.unicode_minus'] = False
    plt.figure(figsize=(8, 5))
    x=[i for i in range(epoch)]
    #acc_train=acc_train.cpu()
    #acc_test=acc_test.cpu()
    plt.plot(x, loss, 'r-', mec='k', label='Logistic Loss', lw=2)
    #plt.plot(x,acc_train,'b-',mec='k',label='accuracy Train',lw=2)
    #plt.plot(x,acc_test,'g-',mec='k',label='accuracy Test',lw=2)
    #plt.plot(x, y_01, 'g-', mec='k', label='0/1 Loss', lw=2)
    #plt.plot(x, y_hinge, 'b-',mec='k', label='Hinge Loss', lw=2)
    #plt.plot(x, boost, 'm--',mec='k', label='Adaboost Loss',lw=2)
    plt.grid(True, ls='--')
    plt.legend(loc='upper right')
    plt.title('损失函数')
    plt.show()

# %%
model=nfm
K=10
test_metrics=[]
train_loss_total_list=[]
for ki in range(K):
    trainset = KZDataset(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/train_val_info.csv',K=K, n_class=nfm_config['n_class'],ki=ki,  typ='train', transform=None, rand=True)
    valset = KZDataset(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/train_val_info.csv', K=K,n_class=nfm_config['n_class'],ki=ki,  typ='val', transform=None, rand=True)
    #trainset = KZDataset(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/encode_100/train_val_info.csv',K=K, n_class=nfm_config['n_class'],ki=ki,  typ='train', transform=None, rand=True)
    #valset = KZDataset(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/encode_100/train_val_info.csv', K=K,n_class=nfm_config['n_class'],ki=ki,  typ='val', transform=None, rand=True)
    
    train_loader = data.DataLoader(
         dataset=trainset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size'],
         shuffle=True)
    val_loader = data.DataLoader(
         dataset=valset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
    
    model_path='models/NFM_layer_2/'
    #BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    #total = 0
    
    
    loss_func=torch.nn.CrossEntropyLoss()
    
    num=0
   
    
    epoches=101
    for epoch_id in range(epoches):
          
        
        
        train_loss_total,acc_train=train_epoch(model,train_loader,nfm_config['batch_size'],optimizer,loss_func)
        train_loss_total_list.append(train_loss_total)#
        if epoch_id %20==0:
            num=num+1
            #path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pkl')
            #torch.save(model.state_dict(),path)
            # 保存模型
            
            path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pt')##################pt
            torch.save(model.state_dict(),path)
            #torch.save(model.state_dict(),path)
    print("the ",ki," epoch ends")
    plotLoss(train_loss_total_list,epoches)
    train_loss_total_list=[]
    acc_test=val_epoch(model,val_loader,nfm_config['batch_size'],optimizer)
    print("acc_test_each_k:",acc_test)
    test_metrics.append(acc_test)

print(test_metrics)
#test_metrics=test_metrics.tolist()
test_metrics=[x.cpu().detach().numpy() for x in test_metrics]
print(test_metrics)
acc_test_metrics=np.mean(test_metrics) 
print("acc_test_metrics:",acc_test_metrics)

# %%
import torch

#功能：加载保存到path中的各层参数到神经网络

#path='models/NFM_layer_2/MLP610.pkl'
#path='models/NFM_layer_2/MLP610.pt'
path='models/NFM_layer_2/MLP610.pt'
nfm=NFM(nfm_config)
#mlp=MLP()
print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
nfm.load_state_dict(torch.load(path),strict=False)
nfm.cuda()

print(nfm)




nfm_params = list(nfm.named_parameters())
#print(nfm_params)
net=nfm


#testset = KZDatasetTest(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info.csv')
testset = KZDatasetTest(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info.csv')   
test_loader = data.DataLoader(
         dataset=testset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
#———————————————— 
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/jclian91/article/details/121708431# 
from torch.autograd import Variable 
from torch.utils.data import DataLoader 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import accuracy_score 
 
def evaluate_model(test_dl, model): 
    model.eval()#测试数据稳定
    predictions, actuals = [], [] 
    for i, (inputs,bi_inputs ,targets) in enumerate(test_dl): 
        # evaluate the model on the test set 
        #print(\ inputs:\ ,inputs) 
        #print(\ targets:\ ,targets) 
        inputs = Variable(inputs) 
        bi_inputs=Variable(bi_inputs)
        targets = Variable(targets) 
                 
                 
        #x = torch.tensor(x, dtype=torch.float) 
        #x=x.clone().detach().requires_grad_(True) 
        inputs=torch.tensor(inputs,dtype=torch.float) 
        bi_inputs=torch.tensor(bi_inputs,dtype=torch.float)
        targets=torch.tensor(targets,dtype=torch.float) 
        inputs,bi_inputs, targets = inputs.cuda(), bi_inputs.cuda(),targets.cuda() 
        yhat = model(inputs,bi_inputs) 
        # retrieve numpy array 
        #yhat = yhat.detach().numpy() 
        yhat = yhat.detach().cpu().numpy()#转换到cpu 
        # yhat=yhat.argmax(axis=1) 
        #print(yhat:\ ,yhat) 
        #print('yhat.shape:',yhat.shape) 
        actual = targets.detach().cpu().numpy() 
        actual=actual.round() 
        #print(\ actual:\ ,actual) 
        #print('actual.shape:',actual.shape
        #predictions.appe) 
        #actual = actual.reshape(-1, 1) 
        # round to class values 
        yhat = yhat.round() 
        # store nd(yhat) 
        actuals.append(actual) 
        predictions.append(yhat)
    #print("prediction:" ,predictions) 
    #print("actuals:",actuals) 
    predictions, actuals = np.vstack(predictions), np.vstack(actuals) 
    #print("prediction:" ,predictions) 
    #print("actuals:" ,actuals) 
    # calculate accuracy 
    acc_test = accuracy_score(actuals, predictions) 
    return  actuals, predictions,acc_test 

import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch

#功能：加载保存到path中的各层参数到神经网络






import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 
target_list=actuals 
pred_list=predictions 
      
y_true=target_list 
y_pred=pred_list 
      
f1=f1_score(y_true=target_list, y_pred=pred_list, average='macro') # 也可以指定micro模式 
acc_score=accuracy_score(y_true=target_list, y_pred=pred_list) 
rec_score=recall_score(y_true=target_list,y_pred=pred_list,average='macro') # 也可以指定micro模式 
pre_recall=precision_score(y_true=target_list,y_pred=pred_list,average='macro') 
print("f1_score:  %.4f" ,f1) 
print("accuracy_score:" ,acc_score) 
print("recall_score:",rec_score) 
print("pre_recall:" ,pre_recall)



auc_curve = roc_auc_score(y_true, y_pred, multi_class='ovo')
#———————————————— 
#版权声明：本文为CSDN博主「农民小飞侠」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/w5688414/article/details/106595892 
PM_y=y_pred 
true_y=y_true 
n_classes=PM_y.shape[1] 
      
print("n_classes:",n_classes) 
fpr = dict() 
tpr = dict() 
roc_auc = dict() 
for i in range(n_classes): 
    fpr[i], tpr[i], _ = roc_curve(true_y[:, i], PM_y[:, i]) 
    roc_auc[i] = auc(fpr[i], tpr[i]) 
    #print(i) 
    #print(fpr) 
    #print(tpr) 
    
    
    
#计算macro auc 
from scipy import interp 
# First aggregate all false positive rates 
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)])) 
       
# Then interpolate all ROC curves at this points 
mean_tpr = np.zeros_like(all_fpr) 
for i in range(n_classes): 
    mean_tpr += interp(all_fpr, fpr[i], tpr[i]) 
       
    # Finally average it and compute AUC 
    mean_tpr /= n_classes 
       
    fpr["macro"] = all_fpr 
    tpr["macro"] = mean_tpr 
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    
    
    
#画图 
      
import matplotlib.pyplot as plt 
from itertools import cycle 
from matplotlib.ticker import FuncFormatter 
lw = 2 
# Plot all ROC curves 
plt.figure() 
labels=['Con(0)','DN(1)','FSGS(2)','HT(3)','IgA(4)','MCD(5)','MGN(6)','RPGN(7)','SLE(8)'] 

'''
plt.plot(fpr["macro"], tpr["macro"], 
              label='macro-average ROC curve (area = {0:0.4f})' 
                    ''.format(roc_auc["macro"]), 
              color='navy', linestyle=':', linewidth=4) 
'''

       
colors = cycle(['aqua', 'darkorange', 'cornflowerblue','blue','yellow','burlywood','cornsilk','darkblue','goldenrod','greenyellow','maroon']) 
for i, color in zip(range(n_classes), colors): 
    plt.plot(fpr[i], tpr[i], color=color, lw=lw, 
                  label=labels[i]+'(area = {0:0.4f})'.format(roc_auc[i])) 
       
    plt.plot([0, 1], [0, 1], 'k--', lw=lw) 
    plt.xlim([0.0, 1.0]) 
    plt.ylim([0.0, 1.05]) 
      
      
    plt.xlabel('1-Specificity (%)') 
    plt.ylabel('Sensitivity (%)') 
    plt.title('NFM_layer_2_non_encode') 
      

        
def to_percent(temp, position): 
    return '%1.0f'%(100*temp) 
      
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.legend(loc="lower right" ) 
      
plt.show() 



#———————————————— 
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/jclian91/article/details/103074506/ 
      
from sklearn.metrics import confusion_matrix 
import matplotlib.pyplot as plt 
import matplotlib as mpl 
      
# 支持中文字体显示, 使用于Mac系统 
#zhfont=mpl.font_manager.FontProperties(fname=\ /Library/Fonts/Songti.ttc\ ) 
      
y_true=actuals# = ['北京', '上海', '成都', '成都', '上海', '北京', '上海', '成都', '北京', '上海'] 
y_pred=predictions #= ['北京', '上海', '成都', '上海', '成都', '成都', '上海', '成都', '北京', '上海'] 
      
#ValueError: multilabel-indicator is not supported 
      
classes = [0,1,2,3,4,5,6,7,8] 
#confusion = confusion_matrix(y_true, y_pred)#ValueError: multilabel-indicator is not supported 
      
confusion = confusion_matrix(y_true.argmax(axis=1), y_pred.argmax(axis=1)) 
# 绘制热度图 
plt.imshow(confusion, cmap=plt.cm.Greens) 
indices = range(len(confusion)) 
#plt.xticks(indices, classes, fontproperties=zhfont) 
#plt.yticks(indices, classes, fontproperties=zhfont) 
      
plt.xticks(indices, classes) 
plt.yticks(indices, classes) 
plt.colorbar() 
plt.xlabel('y_pred') 
plt.ylabel('y_true') 
      
# 显示数据 
for first_index in range(len(confusion)): 
    for second_index in range(len(confusion[first_index])): 
        plt.text(first_index, second_index, confusion[first_index][second_index]) 
      
# 显示图片 
plt.show()
# Out:
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=3300, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=3300, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:699: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:699: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:160: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# f1_score:  %.4f 0.9337584035258454
# accuracy_score: 0.9083333333333333
# recall_score: 0.9182071339966077
# pre_recall: 0.9569624819624819
# n_classes: 9

# %%
#find the maxs for the predicted correctly
from torch.autograd import Variable 
from torch.utils.data import DataLoader 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import accuracy_score 
 
def max_predict_model(test_dl, model): 
    model.eval()#测试数据稳定
    error_dataset=torch.tensor([0])
    error_dataset=error_dataset.view(1,1)
    predictions, actuals = [], [] 
    num=0
    for i, (inputs,bi_inputs ,targets) in enumerate(test_dl): 
        # evaluate the model on the test set 
        #print(\ inputs:\ ,inputs) 
        #print(\ targets:\ ,targets) 
        inputs = Variable(inputs) 
        bi_inputs=Variable(bi_inputs)
        targets = Variable(targets) 
        #print(targets)
        #print('targets:',targets.shape)        
        #targets=targets.argmax(axis=1)  
        #print('targets:',targets.shape)
        #x = torch.tensor(x, dtype=torch.float) 
        #x=x.clone().detach().requires_grad_(True) 
        inputs=torch.tensor(inputs,dtype=torch.float) 
        bi_inputs=torch.tensor(bi_inputs,dtype=torch.float)
        targets=torch.tensor(targets,dtype=torch.float) 
        inputs,bi_inputs, targets = inputs.cuda(), bi_inputs.cuda(),targets.cuda() 
        yhat = model(inputs,bi_inputs)
        max_yhat=torch.max(yhat)
        yhats=yhat.argmax(axis=1)
        print('yhat:',yhat.shape)
        
        if targets==max_yhat:
            return True,max_yhat
        else:
            return False,max_yhat
#return the mark of whether the sample predicted correctly and predicted value#find the maxs for the predicted correctly
from torch.autograd import Variable 
from torch.utils.data import DataLoader 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import accuracy_score 
 
def max_predict_model(test_dl, model): 
    model.eval()#测试数据稳定
    error_dataset=torch.tensor([0])
    error_dataset=error_dataset.view(1,1)
    predictions, actuals = [], [] 
    num=0
    for i, (inputs,bi_inputs ,targets) in enumerate(test_dl): 
        # evaluate the model on the test set 
        #print(\ inputs:\ ,inputs) 
        #print(\ targets:\ ,targets) 
        inputs = Variable(inputs) 
        bi_inputs=Variable(bi_inputs)
        targets = Variable(targets) 
        #print(targets)
        #print('targets:',targets.shape)        
        #targets=targets.argmax(axis=1)  
        #print('targets:',targets.shape)
        #x = torch.tensor(x, dtype=torch.float) 
        #x=x.clone().detach().requires_grad_(True) 
        inputs=torch.tensor(inputs,dtype=torch.float) 
        bi_inputs=torch.tensor(bi_inputs,dtype=torch.float)
        targets=torch.tensor(targets,dtype=torch.float) 
        inputs,bi_inputs, targets = inputs.cuda(), bi_inputs.cuda(),targets.cuda() 
        yhat = model(inputs,bi_inputs) 
        max_yhat=torch.max(yhat)
        yhats=yhat.argmax(axis=1)
        print('yhat:',yhat.shape)
        
        if targets==max_yhat:
            return True,max_yhat
        else:
            return False,max_yhat
#return the mark of whether the sample predicted correctly and predicted value

# %%
#find the samples that predicted correctly for max
import pandas as pd 
test_df=pd.read_csv('dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info1.csv',sep=',')
test_df=test_df.iloc[:,1:]

columns=test_df.columns
rows,cols=test_df.shape
print(rows,cols)
import torch

#功能：加载保存到path中的各层参数到神经网络
nfm=NFM(nfm_config)
path='models/NFM_layer_2/MLP610.pt'

#nfm=NFM(nfm_config)
#mlp=MLP()
#print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
model=nfm
model.load_state_dict(torch.load(path),strict=False)
model.cuda()

print(model)




model_params = list(model.named_parameters())
#print(nfm_params)
net=model


#testset = KZDatasetPredict(test_df)
''''
test_loader = data.DataLoader(
         dataset=testset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
'''
max_value=0
max_sample=[]
max_mask=0
for i in range(rows):
    df_list=test_df.iloc[i,:].tolist()
    print(type(df_list))
    print('df_list:',df_list[-1])
    #print(data_set)
    print('this is data_set')
    data_set = KZDatasetPredict(df_list)
    data_test_loader=data.DataLoader(dataset=data_set,
                                    batch_size=1)
    print(data_test_loader)
    bool_index, yhat=max_predict_model(data_test_loader,model)
    
    if bool_index==True and yhat>max_value:
        max_value=yhat
        max_mask=i
        
max_sample=test_df.iloc[max_mask,:].tolist()

import csv
csv_filename = "dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/NFM/test_info4_from_max.csv"

# 使用CSV模块保存列表为CSV文件
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(columns)
    writer.writerow(max_sample)
# Out:
# 138 3301
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=3300, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# <class 'list'>
# df_list: 5.0
# this is data_set
# data_info: 5.0
# labels: [5]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b14e5f8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 5.0
# this is data_set
# data_info: 5.0
# labels: [5]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7a20>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7860>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d76a0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d74a8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7588>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7748>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7908>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7ac8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7c88>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 0.0
# this is data_set
# data_info: 0.0
# labels: [0]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7e48>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b148400>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b1484a8>
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:64: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:65: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:66: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:699: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7cc0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7b00>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 0.0
# this is data_set
# data_info: 0.0
# labels: [0]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7940>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7780>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 0.0
# this is data_set
# data_info: 0.0
# labels: [0]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d75c0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 5.0
# this is data_set
# data_info: 5.0
# labels: [5]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7518>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7668>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7828>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d79e8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 0.0
# this is data_set
# data_info: 0.0
# labels: [0]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7ba8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7d68>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 5.0
# this is data_set
# data_info: 5.0
# labels: [5]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7c88>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b148400>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b148358>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e20f0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e21d0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e22b0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0bb13128>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7f28>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b14e5f8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 0.0
# this is data_set
# data_info: 0.0
# labels: [0]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d78d0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7710>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7470>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7550>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d76d8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7898>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7a58>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7c18>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7ba8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7c88>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b148358>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b1486d8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2128>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2208>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e22e8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e23c8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e24a8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2588>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7c50>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d75f8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7d30>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7b00>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7940>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7780>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d75c0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 5.0
# this is data_set
# data_info: 5.0
# labels: [5]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7518>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7668>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7828>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7dd8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7c88>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b1484e0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b148358>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e20b8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2198>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2278>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2358>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2438>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 5.0
# this is data_set
# data_info: 5.0
# labels: [5]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2518>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e25f8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e26d8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7be0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7e48>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7da0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7a20>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7860>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d76a0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d74a8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7588>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7748>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 0.0
# this is data_set
# data_info: 0.0
# labels: [0]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7908>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7828>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7c88>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b148fd0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 5.0
# this is data_set
# data_info: 5.0
# labels: [5]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b148048>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e20f0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e21d0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e22b0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2390>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7f28>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 0.0
# this is data_set
# data_info: 0.0
# labels: [0]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7630>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7c50>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 0.0
# this is data_set
# data_info: 0.0
# labels: [0]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d75f8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7d30>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7b00>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7940>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7780>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d75c0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7518>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7ba8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7c88>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b148fd0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b1486d8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e20b8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 5.0
# this is data_set
# data_info: 5.0
# labels: [5]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2198>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2278>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2358>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2438>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2518>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e25f8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e26d8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 0.0
# this is data_set
# data_info: 0.0
# labels: [0]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7e10>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d77b8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 5.0
# this is data_set
# data_info: 5.0
# labels: [5]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7978>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7b38>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 5.0
# this is data_set
# data_info: 5.0
# labels: [5]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7cf8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7eb8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7ac8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d79e8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7d68>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7a58>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 1.0
# this is data_set
# data_info: 1.0
# labels: [1]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7518>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7c88>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b148400>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b148048>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e20f0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e21d0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e22b0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2390>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 8.0
# this is data_set
# data_info: 8.0
# labels: [8]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b2e2470>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 3.0
# this is data_set
# data_info: 3.0
# labels: [3]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b1563c8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 4.0
# this is data_set
# data_info: 4.0
# labels: [4]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d77f0>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 6.0
# this is data_set
# data_info: 6.0
# labels: [6]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7f60>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 2.0
# this is data_set
# data_info: 2.0
# labels: [2]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7e10>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d77b8>
# yhat: torch.Size([1, 9])
# <class 'list'>
# df_list: 7.0
# this is data_set
# data_info: 7.0
# labels: [7]
# labels.shape: (1,)
# <torch.utils.data.dataloader.DataLoader object at 0x7f9f0b4d7978>
# yhat: torch.Size([1, 9])

# %%
#compute mean value of all the correctly predicted samples:
#topk=20
#compute mean value of all the correctly predicted samples:
import pandas as pd 
import torch
import numpy as np
test_df=pd.read_csv('dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/NFM/test_info4_from_max.csv',sep=',')
test_df=test_df.iloc[:,1:]
#print(test_df)
##
columns=test_df.columns
row_max_np=np.array(test_df)
print(row_max_np)

rows,cols=test_df.shape
print(rows,cols)

print(row_max_np)
row_max_tensor=torch.from_numpy(row_max_np).cuda()
row_max_tensor=torch.tensor(row_max_tensor,dtype=torch.float)
print('row_max_tensor:',row_max_tensor.shape)
#去掉行




#compute contribution using the Equ.
import torch

#功能：加载保存到path中的各层参数到神经网络

import torch

#功能：加载保存到path中的各层参数到神经网络

import torch

#功能：加载保存到path中的各层参数到神经网络

import torch

#功能：加载保存到path中的各层参数到神经网络

import torch

#功能：加载保存到path中的各层参数到神经网络

path='models/NFM_layer_2/MLP610.pt'

#nfm=NFM(nfm_config)
nfm=NFM(nfm_config)
#print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
nfm.load_state_dict(torch.load(path),strict=False)
nfm.cuda()

print(nfm)




nfm_params = list(nfm.named_parameters())
#print(nfm_params)
net=nfm



weight={}
for name,parameters in net.named_parameters():
    print(name,':',parameters.size())
    #names.append(name)
    weight[name]=parameters
#print("weight:",weight)
#q
'''
bi_BN.weight : torch.Size([10])
bi_BN.bias : torch.Size([10])
BN_num.weight : torch.Size([3300])
BN_num.bias : torch.Size([3300])
linear1.weight : torch.Size([800, 3300])
linear1.bias : torch.Size([800])
bn1.weight : torch.Size([800])
bn1.bias : torch.Size([800])
linear2.weight : torch.Size([50, 810])
linear2.bias : torch.Size([50])
bn2.weight : torch.Size([50])
bn2.bias : torch.Size([50])
linear3.weight : torch.Size([9, 50])
linear3.bias : torch.Size([9])
bn3.weight : torch.Size([9])
bn3.bias : torch.Size([9])
import pandas as pd 
import numpy as np
'''








def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    n = len(labels)
    #n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output







l3=torch.mm(weight['linear3.weight'],weight['linear2.weight'][:,:800])
print('l3:',l3.shape)
l2=torch.mm(l3,weight['linear1.weight'])
print('l2:',l2.shape)
contri_k=[]
contri_k_names=[]
for i in range(nfm_config['n_class']):
    l1=torch.mm(l2,row_max_tensor.T)
    uu=l2[i,:]*row_max_tensor.reshape(3300)
    print(uu.shape)
    top_k=torch.topk(uu,20,largest=True)######################K==50
    print('top_k:',top_k)
    
    contri_k.append(top_k)
    top_k_indices=top_k.indices.cpu().detach().numpy().tolist()
    print('top_k_indices:',top_k_indices)
    top_k_names=[columns[j] for j in top_k_indices]
    print(top_k_names)
    contri_k_names.append(top_k_names)

contri_k_names_np=np.array(contri_k_names)
print(contri_k_names_np.shape)

contri_k_names_df=pd.DataFrame(contri_k_names_np)
contri_k_names_df.to_csv('results_genes/NFM_layer_2/contri_20_names_df_max.csv')
#from chartGPT of the following code
result = set()
for sublist in contri_k_names:
    result = result.union(sublist)

# 或者使用集合的union方法的更简洁写法，使用集合解析
# result = set().union(*list_of_lists)

# 或者使用 | 运算符
# result = set().union(*list_of_lists)

# 将结果转回列表
result_list = list(result)

print(result_list)

import csv
csv_filename = "results_genes/NFM_layer_2/genes_20_max.csv"

# 使用CSV模块保存列表为CSV文件
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    writer.writerow(result_list)

#这将输出所有列表的并集，不包含重复的元素。在这个例子中，结果会是 [1, 2, 3, 4, 5, 6, 7]。你可以根据你的实际需求将这个结果转换为列表或者保留为集合，具体取决于你的应用场景。
#抽取训练集和测试集中的数据

#生成新选取元素的数据集
train_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/train_val_info.csv'
test_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info.csv'

train_df=pd.read_csv(train_path,sep=',')
train_df1=train_df
print(train_df1.columns)
train_df=train_df.iloc[:,1:]
train_df1=train_df1.iloc[:,1:-1]

columns=result_list
columns.append('label')
print(columns)


train_df2=train_df[columns]
print(train_df2.shape)
train_df2.to_csv('dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/NFM_layer_2_20/max_train_val_info.csv')

test_df=pd.read_csv(test_path,sep=',')

test_df=test_df.iloc[:,1:]



test_df=test_df[columns]
print(test_df.shape)
test_df.to_csv('dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/NFM_layer_2_20/max_test_info.csv')
# Out:
# [[6.20620106 9.83624556 7.03888594 ... 6.60749236 5.08499007 5.        ]]
# 1 3300
# [[6.20620106 9.83624556 7.03888594 ... 6.60749236 5.08499007 5.        ]]
# row_max_tensor: torch.Size([1, 3300])
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=3300, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# bi_BN.weight : torch.Size([10])
# bi_BN.bias : torch.Size([10])
# BN_num.weight : torch.Size([3300])
# BN_num.bias : torch.Size([3300])
# linear1.weight : torch.Size([800, 3300])
# linear1.bias : torch.Size([800])
# bn1.weight : torch.Size([800])
# bn1.bias : torch.Size([800])
# linear2.weight : torch.Size([50, 810])
# linear2.bias : torch.Size([50])
# bn2.weight : torch.Size([50])
# bn2.bias : torch.Size([50])
# linear3.weight : torch.Size([9, 50])
# linear3.bias : torch.Size([9])
# bn3.weight : torch.Size([9])
# bn3.bias : torch.Size([9])
# l3: torch.Size([9, 800])
# l2: torch.Size([9, 3300])
# torch.Size([3300])
# top_k: torch.return_types.topk(
# values=tensor([14.8897, 11.1089, 10.9703, 10.3978, 10.1277,  9.7058,  9.6419,  9.4452,
#          9.1586,  9.1096,  9.0530,  8.5981,  8.5030,  7.6138,  6.8724,  6.7644,
#          6.6570,  6.6559,  6.6556,  6.5076], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([ 989, 2662, 1171, 2010,  914,  142, 1116,  103, 1333, 1768, 2093,  510,
#          699, 2755,  726, 3268,  746, 2652, 2489,  956], device='cuda:0'))
# top_k_indices: [989, 2662, 1171, 2010, 914, 142, 1116, 103, 1333, 1768, 2093, 510, 699, 2755, 726, 3268, 746, 2652, 2489, 956]
# ['ATP6V0E2', 'MVP', 'CLIC4', 'MFSD11', 'PPFIBP2', 'PAPSS1', 'HMBS', 'SEPHS1', 'SNRPA', 'CRYL1', 'NNAT', 'ABCB8', 'ADRA2B', 'APBB2', 'AGMAT', 'COX7B', 'AHCYL2', 'POLR3B', 'ELF4', 'NHLH1']
# torch.Size([3300])
# top_k: torch.return_types.topk(
# values=tensor([19.7878, 18.7620, 11.9067, 11.0279, 10.5672,  9.6331,  9.4844,  9.3781,
#          9.2694,  8.7226,  8.6540,  8.5870,  8.4978,  8.4762,  8.4543,  8.3598,
#          8.3449,  8.3420,  8.1741,  7.8931], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([1150,  726, 2332, 3288,  987,  823, 1609, 1880,  257,  487, 1111, 3268,
#         2330,  103, 3238, 1467, 3125, 1154, 1919,  593], device='cuda:0'))
# top_k_indices: [1150, 726, 2332, 3288, 987, 823, 1609, 1880, 257, 487, 1111, 3268, 2330, 103, 3238, 1467, 3125, 1154, 1919, 593]
# ['RHOC', 'AGMAT', 'HIGD1A', 'MAB21L4', 'PSMB1', 'PCF11', 'CREB3L2', 'ATP6V1F', 'ASNS', 'AAGAB', 'ZBTB7B', 'COX7B', 'LASP1', 'SEPHS1', 'LINC01565', 'SMO', 'GATM', 'RGN', 'DAD1', 'ACSF2']
# torch.Size([3300])
# top_k: torch.return_types.topk(
# values=tensor([31.0015, 21.0531, 19.4079, 18.3989, 17.1471, 16.5233, 15.9839, 15.5574,
#         14.7545, 13.7875, 13.3500, 12.6378, 12.2753, 11.7226, 11.5977, 11.2048,
#         11.1880, 10.9987, 10.6329, 10.5141], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([2344,  601, 2472,  624, 2124, 1184,  593, 1467, 2141, 2947, 2210,  716,
#         1786,  335,   89, 1854, 2418,  303, 1585,  589], device='cuda:0'))
# top_k_indices: [2344, 601, 2472, 624, 2124, 1184, 593, 1467, 2141, 2947, 2210, 716, 1786, 335, 89, 1854, 2418, 303, 1585, 589]
# ['LDHB', 'ACTB', 'PSMB5', 'ACVR2A', 'XPO6', 'EBP', 'ACSF2', 'SMO', 'FADS2', 'KIF1B', 'CACNA1F', 'AFTPH', 'CSF1', 'SETDB1', 'MED18', 'FBXO9', 'PIK3C2B', 'CD2AP', 'ASXL2', 'ACPP']
# torch.Size([3300])
# top_k: torch.return_types.topk(
# values=tensor([25.8561, 17.7029, 16.7553, 16.1007, 14.3770, 14.2004, 12.4568, 12.1138,
#         11.0542, 10.2145, 10.0796,  9.2654,  8.8754,  8.7283,  8.4081,  7.9153,
#          7.8975,  7.5517,  7.2460,  7.2449], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([2303, 3125,  882, 2429, 2036, 1449, 2332, 1740,  989, 1422, 2312, 2150,
#          975,  796, 1768,  508, 1971, 2496, 1713, 1524], device='cuda:0'))
# top_k_indices: [2303, 3125, 882, 2429, 2036, 1449, 2332, 1740, 989, 1422, 2312, 2150, 975, 796, 1768, 508, 1971, 2496, 1713, 1524]
# ['GPX3', 'GATM', 'RPL5', 'SDC4', 'PIGH', 'VTI1B', 'HIGD1A', 'PSMC5', 'ATP6V0E2', 'SSR1', 'NDUFAF3', 'MYL6', 'RHCG', 'ALCAM', 'CRYL1', 'ABCB6', 'ZCCHC14', 'THRA', 'PCMT1', 'FSTL1']
# torch.Size([3300])
# top_k: torch.return_types.topk(
# values=tensor([19.1835, 17.2140, 14.0793, 12.5996, 12.2537, 11.7635, 11.7583, 11.3255,
#         11.1417, 10.9164, 10.2409, 10.0581,  9.9747,  9.9635,  9.8936,  9.8336,
#          9.7688,  9.7138,  9.6806,  9.5012], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([ 716,  569, 2303, 1526, 1333, 2363, 2010, 3289,   14,  696, 1426,  556,
#         2818, 1176,  370, 3249, 2438,  460,  838, 1585], device='cuda:0'))
# top_k_indices: [716, 569, 2303, 1526, 1333, 2363, 2010, 3289, 14, 696, 1426, 556, 2818, 1176, 370, 3249, 2438, 460, 838, 1585]
# ['AFTPH', 'ACE2', 'GPX3', 'PLA2G2A', 'SNRPA', 'CCNC', 'MFSD11', 'GLB1L', 'SGF29', 'ADPGK', 'STX17', 'ACAD8', 'PSMD9', 'LAMB2', 'DAPK2', 'RAB3IL1', 'CHAF1A', 'SLC25A36', 'TNS1', 'ASXL2']
# torch.Size([3300])
# top_k: torch.return_types.topk(
# values=tensor([13.1854, 12.3708, 10.8033, 10.3310, 10.2220, 10.1653, 10.0490, 10.0256,
#          8.8849,  8.8812,  8.8538,  8.7419,  8.7117,  8.6380,  8.5711,  8.4872,
#          8.3385,  8.3032,  8.2476,  7.7017], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([3055,  575, 1152, 1171,  417,  239,  103, 2947,  349, 2061, 3289,  551,
#         2438, 1639, 3017, 2295, 2492, 2207, 2657, 1753], device='cuda:0'))
# top_k_indices: [3055, 575, 1152, 1171, 417, 239, 103, 2947, 349, 2061, 3289, 551, 2438, 1639, 3017, 2295, 2492, 2207, 2657, 1753]
# ['GM2A', 'ACO1', 'IFT20', 'CLIC4', 'FSCN3', 'TADA3', 'SEPHS1', 'KIF1B', 'HP', 'TSPAN15', 'GLB1L', 'ACAA1', 'CHAF1A', 'PLCD1', 'MKRN2', 'SMIM8', 'RPL8', 'GYPC', 'ZPR1', 'CFHR2']
# torch.Size([3300])
# top_k: torch.return_types.topk(
# values=tensor([15.0550, 14.8495, 14.8160, 13.8957, 13.0441, 12.3457, 12.3420, 11.9679,
#         11.7265, 10.9434, 10.7877,  9.5458,  8.9902,  8.9872,  8.8360,  8.7477,
#          8.5351,  8.4038,  8.3527,  8.1534], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([2066,  535, 3060,  460, 2666, 2116, 1106, 3256,  556, 1289,  925,  684,
#          987,  545, 2251, 1145, 1792, 3085,   52, 2018], device='cuda:0'))
# top_k_indices: [2066, 535, 3060, 460, 2666, 2116, 1106, 3256, 556, 1289, 925, 684, 987, 545, 2251, 1145, 1792, 3085, 52, 2018]
# ['PDGFC', 'ABHD3', 'FDX1', 'SLC25A36', 'METTL22', 'PPP6R3', 'ENTR1', 'SLCO4C1', 'ACAD8', 'TIMM13', 'HAO2', 'ADIPOR1', 'PSMB1', 'ABLIM3', 'MRPL13', 'KNOP1', 'RPS21', 'TSPYL5', 'PFKP', 'SCARB2']
# torch.Size([3300])
# top_k: torch.return_types.topk(
# values=tensor([20.3362, 19.0716, 16.0168, 14.3472, 13.8257, 13.6637, 13.0124, 12.7191,
#         12.2356, 12.1577, 12.0776, 11.8946, 11.3333, 11.1231, 11.0613, 10.9813,
#         10.5154, 10.4278, 10.1173,  9.9452], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([ 165,  210,  975, 1209,  103, 1896, 2496,   52, 1270, 2429, 1880, 2326,
#          385,  937, 2138, 2312, 2818,  516, 1150, 3069], device='cuda:0'))
# top_k_indices: [165, 210, 975, 1209, 103, 1896, 2496, 52, 1270, 2429, 1880, 2326, 385, 937, 2138, 2312, 2818, 516, 1150, 3069]
# ['YARS', 'ADH5', 'RHCG', 'PSMB9', 'SEPHS1', 'UBE2Z', 'THRA', 'PFKP', 'DLG1', 'SDC4', 'ATP6V1F', 'ANGEL2', 'DNASE1L3', 'SLC39A1', 'C1orf56', 'NDUFAF3', 'PSMD9', 'ABCC4', 'RHOC', 'HNRNPD']
# torch.Size([3300])
# top_k: torch.return_types.topk(
# values=tensor([30.8441, 30.4266, 20.7008, 19.2427, 16.7560, 15.9678, 15.9640, 14.1419,
#         13.5485, 13.2553, 13.1676, 12.9379, 12.6306, 12.5955, 12.5737, 12.3217,
#         11.6773, 11.6562, 11.3717, 11.2130], device='cuda:0',
#        grad_fn=<TopkBackward0>),
# indices=tensor([ 103, 1449, 1171, 2303, 1111,  796,  290, 3238,  124, 2141,  987, 1152,
#         2207, 1010, 1713, 3289,  516, 1768, 2602,  545], device='cuda:0'))
# top_k_indices: [103, 1449, 1171, 2303, 1111, 796, 290, 3238, 124, 2141, 987, 1152, 2207, 1010, 1713, 3289, 516, 1768, 2602, 545]
# ['SEPHS1', 'VTI1B', 'CLIC4', 'GPX3', 'ZBTB7B', 'ALCAM', 'UBR5', 'LINC01565', 'SOX21', 'FADS2', 'PSMB1', 'IFT20', 'GYPC', 'SLC39A14', 'PCMT1', 'GLB1L', 'ABCC4', 'CRYL1', 'DRC3', 'ABLIM3']
# (9, 20)
# ['RPL5', 'RHCG', 'ACPP', 'ABCC4', 'NHLH1', 'CHAF1A', 'YARS', 'FADS2', 'MFSD11', 'KNOP1', 'PIK3C2B', 'FSTL1', 'NNAT', 'UBE2Z', 'ABLIM3', 'RPS21', 'FSCN3', 'FBXO9', 'SLC25A36', 'DNASE1L3', 'LDHB', 'TSPAN15', 'SLC39A1', 'AHCYL2', 'GLB1L', 'PSMB5', 'HMBS', 'PDGFC', 'PSMB1', 'PSMC5', 'MYL6', 'SMO', 'SGF29', 'ACAD8', 'C1orf56', 'PCF11', 'SNRPA', 'SLCO4C1', 'ATP6V1F', 'ANGEL2', 'RGN', 'LINC01565', 'MVP', 'SDC4', 'PLCD1', 'AAGAB', 'PPP6R3', 'LASP1', 'ABHD3', 'ZCCHC14', 'PSMD9', 'PIGH', 'CACNA1F', 'ABCB6', 'DRC3', 'MAB21L4', 'CCNC', 'COX7B', 'TADA3', 'XPO6', 'TNS1', 'MED18', 'ZPR1', 'ENTR1', 'ADPGK', 'ALCAM', 'CFHR2', 'ASNS', 'GYPC', 'DAPK2', 'PSMB9', 'ADIPOR1', 'CREB3L2', 'ACSF2', 'HP', 'PAPSS1', 'METTL22', 'APBB2', 'MKRN2', 'ACTB', 'FDX1', 'HNRNPD', 'DLG1', 'HIGD1A', 'RAB3IL1', 'ACE2', 'CRYL1', 'LAMB2', 'DAD1', 'NDUFAF3', 'SSR1', 'IFT20', 'GM2A', 'RHOC', 'TSPYL5', 'POLR3B', 'STX17', 'GPX3', 'SOX21', 'ABCB8', 'GATM', 'PCMT1', 'ATP6V0E2', 'ADH5', 'MRPL13', 'ZBTB7B', 'TIMM13', 'ASXL2', 'VTI1B', 'SLC39A14', 'PFKP', 'SEPHS1', 'PLA2G2A', 'ACAA1', 'ADRA2B', 'PPFIBP2', 'THRA', 'UBR5', 'CLIC4', 'HAO2', 'RPL8', 'KIF1B', 'EBP', 'SETDB1', 'AFTPH', 'ACO1', 'AGMAT', 'ELF4', 'ACVR2A', 'CD2AP', 'CSF1', 'SMIM8', 'SCARB2']
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Index(['Unnamed: 0', 'RHOA', 'STX2', 'CISD1', 'WDR11', 'SCYL2', 'MGC2889',
#        'CCDC47', 'KLF8', 'CCL1',
#        ...
#        'PLAC4', 'NRBP1', 'LRRC23', 'SPHK2', 'KIAA0513', 'SULT1A1', 'AMOT',
#        'CA1', 'GPR35', 'label'],
#       dtype='object', length=3302)
# ['RPL5', 'RHCG', 'ACPP', 'ABCC4', 'NHLH1', 'CHAF1A', 'YARS', 'FADS2', 'MFSD11', 'KNOP1', 'PIK3C2B', 'FSTL1', 'NNAT', 'UBE2Z', 'ABLIM3', 'RPS21', 'FSCN3', 'FBXO9', 'SLC25A36', 'DNASE1L3', 'LDHB', 'TSPAN15', 'SLC39A1', 'AHCYL2', 'GLB1L', 'PSMB5', 'HMBS', 'PDGFC', 'PSMB1', 'PSMC5', 'MYL6', 'SMO', 'SGF29', 'ACAD8', 'C1orf56', 'PCF11', 'SNRPA', 'SLCO4C1', 'ATP6V1F', 'ANGEL2', 'RGN', 'LINC01565', 'MVP', 'SDC4', 'PLCD1', 'AAGAB', 'PPP6R3', 'LASP1', 'ABHD3', 'ZCCHC14', 'PSMD9', 'PIGH', 'CACNA1F', 'ABCB6', 'DRC3', 'MAB21L4', 'CCNC', 'COX7B', 'TADA3', 'XPO6', 'TNS1', 'MED18', 'ZPR1', 'ENTR1', 'ADPGK', 'ALCAM', 'CFHR2', 'ASNS', 'GYPC', 'DAPK2', 'PSMB9', 'ADIPOR1', 'CREB3L2', 'ACSF2', 'HP', 'PAPSS1', 'METTL22', 'APBB2', 'MKRN2', 'ACTB', 'FDX1', 'HNRNPD', 'DLG1', 'HIGD1A', 'RAB3IL1', 'ACE2', 'CRYL1', 'LAMB2', 'DAD1', 'NDUFAF3', 'SSR1', 'IFT20', 'GM2A', 'RHOC', 'TSPYL5', 'POLR3B', 'STX17', 'GPX3', 'SOX21', 'ABCB8', 'GATM', 'PCMT1', 'ATP6V0E2', 'ADH5', 'MRPL13', 'ZBTB7B', 'TIMM13', 'ASXL2', 'VTI1B', 'SLC39A14', 'PFKP', 'SEPHS1', 'PLA2G2A', 'ACAA1', 'ADRA2B', 'PPFIBP2', 'THRA', 'UBR5', 'CLIC4', 'HAO2', 'RPL8', 'KIF1B', 'EBP', 'SETDB1', 'AFTPH', 'ACO1', 'AGMAT', 'ELF4', 'ACVR2A', 'CD2AP', 'CSF1', 'SMIM8', 'SCARB2', 'label']
# (549, 134)
# (138, 134)

# %%
model=nfm2
K=10
test_metrics=[]
train_loss_total_list=[]
for ki in range(K):
    trainset = KZDataset(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/NFM_layer_2_20/max_train_val_info.csv',K=K, n_class=nfm_config['n_class'],ki=ki,  typ='train', transform=None, rand=True)
    valset = KZDataset(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/NFM_layer_2_20/max_train_val_info.csv', K=K,n_class=nfm_config['n_class'],ki=ki,  typ='val', transform=None, rand=True)
    train_loader = data.DataLoader(
         dataset=trainset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size'],
         shuffle=True)
    val_loader = data.DataLoader(
         dataset=valset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
    
    model_path='models/NFM_layer_2_20/max/'
    #BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    #total = 0
    
    
    loss_func=torch.nn.CrossEntropyLoss()
    
    num=0
   
    
    epoches=101
    for epoch_id in range(epoches):
          
        
        
        train_loss_total,acc_train=train_epoch(model,train_loader,nfm_config['batch_size'],optimizer,loss_func)
        train_loss_total_list.append(train_loss_total)#
        if epoch_id %20==0:
            num=num+1
            #path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pkl')
            #torch.save(model.state_dict(),path)
            # 保存模型
            
            path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pt')##################pt
            torch.save(model.state_dict(),path)
            #torch.save(model.state_dict(),path)
    print("the ",ki," epoch ends")
    plotLoss(train_loss_total_list,epoches)
    train_loss_total_list=[]
    acc_test=val_epoch(model,val_loader,nfm_config['batch_size'],optimizer)
    print("acc_test_each_k:",acc_test)
    test_metrics.append(acc_test)

print(test_metrics)
#test_metrics=test_metrics.tolist()
test_metrics=[x.cpu().detach().numpy() for x in test_metrics]
print(test_metrics)
acc_test_metrics=np.mean(test_metrics) 
print("acc_test_metrics:",acc_test_metrics)
       
model=model2
K=10
test_metrics=[]
train_loss_total_list=[]
for ki in range(K):
    trainset = KZDataset(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/NFM_layer_2_20/max_train_val_info.csv',K=K, n_class=nfm_config['n_class'],ki=ki,  typ='train', transform=None, rand=True)
    valset = KZDataset(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/NFM_layer_2_20/max_train_val_info.csv', K=K,n_class=nfm_config['n_class'],ki=ki,  typ='val', transform=None, rand=True)
    train_loader = data.DataLoader(
         dataset=trainset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size'],
         shuffle=True)
    val_loader = data.DataLoader(
         dataset=valset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
    
    model_path='models/NFM_layer_2_20/max/'
    #BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    #total = 0
    
    
    loss_func=torch.nn.CrossEntropyLoss()
    
    num=0
   
    
    epoches=101
    for epoch_id in range(epoches):
          
        
        
        train_loss_total,acc_train=train_epoch(model,train_loader,nfm_config['batch_size'],optimizer,loss_func)
        train_loss_total_list.append(train_loss_total)#
        if epoch_id %20==0:
            num=num+1
            #path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pkl')
            #torch.save(model.state_dict(),path)
            # 保存模型
            
            path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pt')##################pt
            torch.save(model.state_dict(),path)
            #torch.save(model.state_dict(),path)
    print("the ",ki," epoch ends")
    plotLoss(train_loss_total_list,epoches)
    train_loss_total_list=[]
    acc_test=val_epoch(model,val_loader,nfm_config['batch_size'],optimizer)
    print("acc_test_each_k:",acc_test)
    test_metrics.append(acc_test)

print(test_metrics)
#test_metrics=test_metrics.tolist()
test_metrics=[x.cpu().detach().numpy() for x in test_metrics]
print(test_metrics)
acc_test_metrics=np.mean(test_metrics) 
print("acc_test_metrics:",acc_test_metrics)
# Out:
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:444: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:445: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:446: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:699: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.1125, device='cuda:0')
# Training Epoch: 0, total loss: 43.929333
# total_train_accuracy: tensor(0.1896, device='cuda:0')
# Training Epoch: 1, total loss: 43.344322
# total_train_accuracy: tensor(0.2333, device='cuda:0')
# Training Epoch: 2, total loss: 43.054347
# total_train_accuracy: tensor(0.2833, device='cuda:0')
# Training Epoch: 3, total loss: 42.666553
# total_train_accuracy: tensor(0.3333, device='cuda:0')
# Training Epoch: 4, total loss: 42.341272
# total_train_accuracy: tensor(0.3354, device='cuda:0')
# Training Epoch: 5, total loss: 42.298920
# total_train_accuracy: tensor(0.3833, device='cuda:0')
# Training Epoch: 6, total loss: 41.862330
# total_train_accuracy: tensor(0.4042, device='cuda:0')
# Training Epoch: 7, total loss: 41.664736
# total_train_accuracy: tensor(0.4000, device='cuda:0')
# Training Epoch: 8, total loss: 41.368582
# total_train_accuracy: tensor(0.4333, device='cuda:0')
# Training Epoch: 9, total loss: 41.211482
# total_train_accuracy: tensor(0.4333, device='cuda:0')
# Training Epoch: 10, total loss: 41.237048
# total_train_accuracy: tensor(0.4938, device='cuda:0')
# Training Epoch: 11, total loss: 40.640303
# total_train_accuracy: tensor(0.4833, device='cuda:0')
# Training Epoch: 12, total loss: 40.361859
# total_train_accuracy: tensor(0.4854, device='cuda:0')
# Training Epoch: 13, total loss: 40.520542
# total_train_accuracy: tensor(0.4917, device='cuda:0')
# Training Epoch: 14, total loss: 40.389148
# total_train_accuracy: tensor(0.4708, device='cuda:0')
# Training Epoch: 15, total loss: 40.307074
# total_train_accuracy: tensor(0.4833, device='cuda:0')
# Training Epoch: 16, total loss: 39.988067
# total_train_accuracy: tensor(0.5083, device='cuda:0')
# Training Epoch: 17, total loss: 39.648123
# total_train_accuracy: tensor(0.5354, device='cuda:0')
# Training Epoch: 18, total loss: 39.440314
# total_train_accuracy: tensor(0.5375, device='cuda:0')
# Training Epoch: 19, total loss: 39.364771
# total_train_accuracy: tensor(0.5729, device='cuda:0')
# Training Epoch: 20, total loss: 38.860193
# total_train_accuracy: tensor(0.5750, device='cuda:0')
# Training Epoch: 21, total loss: 38.882471
# total_train_accuracy: tensor(0.5625, device='cuda:0')
# Training Epoch: 22, total loss: 38.786580
# total_train_accuracy: tensor(0.5146, device='cuda:0')
# Training Epoch: 23, total loss: 39.023666
# total_train_accuracy: tensor(0.5813, device='cuda:0')
# Training Epoch: 24, total loss: 38.536196
# total_train_accuracy: tensor(0.5729, device='cuda:0')
# Training Epoch: 25, total loss: 38.485861
# total_train_accuracy: tensor(0.5667, device='cuda:0')
# Training Epoch: 26, total loss: 38.273447
# total_train_accuracy: tensor(0.5833, device='cuda:0')
# Training Epoch: 27, total loss: 38.056487
# total_train_accuracy: tensor(0.5792, device='cuda:0')
# Training Epoch: 28, total loss: 38.251177
# total_train_accuracy: tensor(0.6229, device='cuda:0')
# Training Epoch: 29, total loss: 37.621643
# total_train_accuracy: tensor(0.5729, device='cuda:0')
# Training Epoch: 30, total loss: 37.960902
# total_train_accuracy: tensor(0.5854, device='cuda:0')
# Training Epoch: 31, total loss: 37.841784
# total_train_accuracy: tensor(0.6104, device='cuda:0')
# Training Epoch: 32, total loss: 37.509955
# total_train_accuracy: tensor(0.6417, device='cuda:0')
# Training Epoch: 33, total loss: 37.192741
# total_train_accuracy: tensor(0.5917, device='cuda:0')
# Training Epoch: 34, total loss: 37.778181
# total_train_accuracy: tensor(0.6146, device='cuda:0')
# Training Epoch: 35, total loss: 37.426163
# total_train_accuracy: tensor(0.6438, device='cuda:0')
# Training Epoch: 36, total loss: 37.180717
# total_train_accuracy: tensor(0.6229, device='cuda:0')
# Training Epoch: 37, total loss: 37.189212
# total_train_accuracy: tensor(0.6042, device='cuda:0')
# Training Epoch: 38, total loss: 37.430484
# total_train_accuracy: tensor(0.6375, device='cuda:0')
# Training Epoch: 39, total loss: 36.834249
# total_train_accuracy: tensor(0.6125, device='cuda:0')
# Training Epoch: 40, total loss: 37.171388
# total_train_accuracy: tensor(0.6521, device='cuda:0')
# Training Epoch: 41, total loss: 36.297525
# total_train_accuracy: tensor(0.6667, device='cuda:0')
# Training Epoch: 42, total loss: 36.561345
# total_train_accuracy: tensor(0.6750, device='cuda:0')
# Training Epoch: 43, total loss: 36.340490
# total_train_accuracy: tensor(0.6396, device='cuda:0')
# Training Epoch: 44, total loss: 36.545766
# total_train_accuracy: tensor(0.6521, device='cuda:0')
# Training Epoch: 45, total loss: 36.501732
# total_train_accuracy: tensor(0.6833, device='cuda:0')
# Training Epoch: 46, total loss: 36.107102
# total_train_accuracy: tensor(0.6562, device='cuda:0')
# Training Epoch: 47, total loss: 36.407308
# total_train_accuracy: tensor(0.6854, device='cuda:0')
# Training Epoch: 48, total loss: 35.755947
# total_train_accuracy: tensor(0.6646, device='cuda:0')
# Training Epoch: 49, total loss: 36.163595
# total_train_accuracy: tensor(0.6396, device='cuda:0')
# Training Epoch: 50, total loss: 36.433117
# total_train_accuracy: tensor(0.6542, device='cuda:0')
# Training Epoch: 51, total loss: 36.168127
# total_train_accuracy: tensor(0.7021, device='cuda:0')
# Training Epoch: 52, total loss: 35.858865
# total_train_accuracy: tensor(0.6667, device='cuda:0')
# Training Epoch: 53, total loss: 36.201616
# total_train_accuracy: tensor(0.6667, device='cuda:0')
# Training Epoch: 54, total loss: 35.910846
# total_train_accuracy: tensor(0.6583, device='cuda:0')
# Training Epoch: 55, total loss: 35.906948
# total_train_accuracy: tensor(0.6813, device='cuda:0')
# Training Epoch: 56, total loss: 35.813292
# total_train_accuracy: tensor(0.6667, device='cuda:0')
# Training Epoch: 57, total loss: 35.828579
# total_train_accuracy: tensor(0.6688, device='cuda:0')
# Training Epoch: 58, total loss: 35.932892
# total_train_accuracy: tensor(0.6687, device='cuda:0')
# Training Epoch: 59, total loss: 35.859218
# total_train_accuracy: tensor(0.6583, device='cuda:0')
# Training Epoch: 60, total loss: 35.962673
# total_train_accuracy: tensor(0.7125, device='cuda:0')
# Training Epoch: 61, total loss: 35.413802
# total_train_accuracy: tensor(0.6833, device='cuda:0')
# Training Epoch: 62, total loss: 35.663118
# total_train_accuracy: tensor(0.6625, device='cuda:0')
# Training Epoch: 63, total loss: 35.697852
# total_train_accuracy: tensor(0.6896, device='cuda:0')
# Training Epoch: 64, total loss: 35.279849
# total_train_accuracy: tensor(0.6771, device='cuda:0')
# Training Epoch: 65, total loss: 35.471602
# total_train_accuracy: tensor(0.6500, device='cuda:0')
# Training Epoch: 66, total loss: 35.729708
# total_train_accuracy: tensor(0.7292, device='cuda:0')
# Training Epoch: 67, total loss: 34.977934
# total_train_accuracy: tensor(0.6979, device='cuda:0')
# Training Epoch: 68, total loss: 35.444671
# total_train_accuracy: tensor(0.6854, device='cuda:0')
# Training Epoch: 69, total loss: 35.324657
# total_train_accuracy: tensor(0.7042, device='cuda:0')
# Training Epoch: 70, total loss: 35.086075
# total_train_accuracy: tensor(0.6958, device='cuda:0')
# Training Epoch: 71, total loss: 35.273874
# total_train_accuracy: tensor(0.7187, device='cuda:0')
# Training Epoch: 72, total loss: 34.713300
# total_train_accuracy: tensor(0.7083, device='cuda:0')
# Training Epoch: 73, total loss: 34.898546
# total_train_accuracy: tensor(0.6917, device='cuda:0')
# Training Epoch: 74, total loss: 35.257041
# total_train_accuracy: tensor(0.7125, device='cuda:0')
# Training Epoch: 75, total loss: 34.956547
# total_train_accuracy: tensor(0.7167, device='cuda:0')
# Training Epoch: 76, total loss: 34.839440
# total_train_accuracy: tensor(0.6979, device='cuda:0')
# Training Epoch: 77, total loss: 35.276768
# total_train_accuracy: tensor(0.7333, device='cuda:0')
# Training Epoch: 78, total loss: 34.516847
# total_train_accuracy: tensor(0.7312, device='cuda:0')
# Training Epoch: 79, total loss: 34.451765
# total_train_accuracy: tensor(0.7458, device='cuda:0')
# Training Epoch: 80, total loss: 34.421285
# total_train_accuracy: tensor(0.7312, device='cuda:0')
# Training Epoch: 81, total loss: 34.638618
# total_train_accuracy: tensor(0.7417, device='cuda:0')
# Training Epoch: 82, total loss: 34.626146
# total_train_accuracy: tensor(0.6979, device='cuda:0')
# Training Epoch: 83, total loss: 34.778236
# total_train_accuracy: tensor(0.7062, device='cuda:0')
# Training Epoch: 84, total loss: 34.755461
# total_train_accuracy: tensor(0.7354, device='cuda:0')
# Training Epoch: 85, total loss: 34.303411
# total_train_accuracy: tensor(0.7104, device='cuda:0')
# Training Epoch: 86, total loss: 34.922180
# total_train_accuracy: tensor(0.7062, device='cuda:0')
# Training Epoch: 87, total loss: 34.599533
# total_train_accuracy: tensor(0.7021, device='cuda:0')
# Training Epoch: 88, total loss: 34.334728
# total_train_accuracy: tensor(0.7563, device='cuda:0')
# Training Epoch: 89, total loss: 34.150870
# total_train_accuracy: tensor(0.7417, device='cuda:0')
# Training Epoch: 90, total loss: 34.170039
# total_train_accuracy: tensor(0.7396, device='cuda:0')
# Training Epoch: 91, total loss: 34.304909
# total_train_accuracy: tensor(0.7479, device='cuda:0')
# Training Epoch: 92, total loss: 34.171776
# total_train_accuracy: tensor(0.7312, device='cuda:0')
# Training Epoch: 93, total loss: 34.174237
# total_train_accuracy: tensor(0.7271, device='cuda:0')
# Training Epoch: 94, total loss: 34.386147
# total_train_accuracy: tensor(0.7250, device='cuda:0')
# Training Epoch: 95, total loss: 34.375697
# total_train_accuracy: tensor(0.7125, device='cuda:0')
# Training Epoch: 96, total loss: 34.590372
# total_train_accuracy: tensor(0.7479, device='cuda:0')
# Training Epoch: 97, total loss: 33.883529
# total_train_accuracy: tensor(0.7083, device='cuda:0')
# Training Epoch: 98, total loss: 34.450654
# total_train_accuracy: tensor(0.7604, device='cuda:0')
# Training Epoch: 99, total loss: 33.805961
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# total_train_accuracy: tensor(0.7375, device='cuda:0')
# Training Epoch: 100, total loss: 34.060454
# the  0  epoch ends
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:488: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:489: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:490: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# test
# test
# total_test_accuracy: tensor(0.5833, device='cuda:0')
# acc_test_each_k: tensor(0.5833, device='cuda:0')
# total_train_accuracy: tensor(0.6958, device='cuda:0')
# Training Epoch: 0, total loss: 34.561474
# total_train_accuracy: tensor(0.6979, device='cuda:0')
# Training Epoch: 1, total loss: 34.507093
# total_train_accuracy: tensor(0.6792, device='cuda:0')
# Training Epoch: 2, total loss: 35.052065
# total_train_accuracy: tensor(0.7354, device='cuda:0')
# Training Epoch: 3, total loss: 33.979206
# total_train_accuracy: tensor(0.6917, device='cuda:0')
# Training Epoch: 4, total loss: 34.974417
# total_train_accuracy: tensor(0.7021, device='cuda:0')
# Training Epoch: 5, total loss: 34.654332
# total_train_accuracy: tensor(0.7167, device='cuda:0')
# Training Epoch: 6, total loss: 34.479112
# total_train_accuracy: tensor(0.7000, device='cuda:0')
# Training Epoch: 7, total loss: 34.705492
# total_train_accuracy: tensor(0.7167, device='cuda:0')
# Training Epoch: 8, total loss: 34.264921
# total_train_accuracy: tensor(0.7542, device='cuda:0')
# Training Epoch: 9, total loss: 33.949827
# total_train_accuracy: tensor(0.7021, device='cuda:0')
# Training Epoch: 10, total loss: 34.255911
# total_train_accuracy: tensor(0.7125, device='cuda:0')
# Training Epoch: 11, total loss: 34.316052
# total_train_accuracy: tensor(0.7313, device='cuda:0')
# Training Epoch: 12, total loss: 33.917341
# total_train_accuracy: tensor(0.7375, device='cuda:0')
# Training Epoch: 13, total loss: 34.047842
# total_train_accuracy: tensor(0.7625, device='cuda:0')
# Training Epoch: 14, total loss: 33.817026
# total_train_accuracy: tensor(0.7604, device='cuda:0')
# Training Epoch: 15, total loss: 33.709016
# total_train_accuracy: tensor(0.7229, device='cuda:0')
# Training Epoch: 16, total loss: 34.108309
# total_train_accuracy: tensor(0.7604, device='cuda:0')
# Training Epoch: 17, total loss: 33.535828
# total_train_accuracy: tensor(0.7167, device='cuda:0')
# Training Epoch: 18, total loss: 34.208002
# total_train_accuracy: tensor(0.7292, device='cuda:0')
# Training Epoch: 19, total loss: 33.809090
# total_train_accuracy: tensor(0.7688, device='cuda:0')
# Training Epoch: 20, total loss: 33.221586
# total_train_accuracy: tensor(0.7375, device='cuda:0')
# Training Epoch: 21, total loss: 33.822519
# total_train_accuracy: tensor(0.7667, device='cuda:0')
# Training Epoch: 22, total loss: 33.670013
# total_train_accuracy: tensor(0.7479, device='cuda:0')
# Training Epoch: 23, total loss: 33.673031
# total_train_accuracy: tensor(0.7208, device='cuda:0')
# Training Epoch: 24, total loss: 34.107370
# total_train_accuracy: tensor(0.7708, device='cuda:0')
# Training Epoch: 25, total loss: 33.325262
# total_train_accuracy: tensor(0.7438, device='cuda:0')
# Training Epoch: 26, total loss: 33.560677
# total_train_accuracy: tensor(0.7375, device='cuda:0')
# Training Epoch: 27, total loss: 33.663972
# total_train_accuracy: tensor(0.7563, device='cuda:0')
# Training Epoch: 28, total loss: 33.576644
# total_train_accuracy: tensor(0.7625, device='cuda:0')
# Training Epoch: 29, total loss: 33.424053
# total_train_accuracy: tensor(0.7729, device='cuda:0')
# Training Epoch: 30, total loss: 33.374432
# total_train_accuracy: tensor(0.7229, device='cuda:0')
# Training Epoch: 31, total loss: 33.981469
# total_train_accuracy: tensor(0.7146, device='cuda:0')
# Training Epoch: 32, total loss: 34.134094
# total_train_accuracy: tensor(0.7729, device='cuda:0')
# Training Epoch: 33, total loss: 33.224996
# total_train_accuracy: tensor(0.7854, device='cuda:0')
# Training Epoch: 34, total loss: 33.060417
# total_train_accuracy: tensor(0.7896, device='cuda:0')
# Training Epoch: 35, total loss: 32.993523
# total_train_accuracy: tensor(0.7542, device='cuda:0')
# Training Epoch: 36, total loss: 33.389270
# total_train_accuracy: tensor(0.7417, device='cuda:0')
# Training Epoch: 37, total loss: 33.552523
# total_train_accuracy: tensor(0.7833, device='cuda:0')
# Training Epoch: 38, total loss: 32.808728
# total_train_accuracy: tensor(0.7438, device='cuda:0')
# Training Epoch: 39, total loss: 33.418698
# total_train_accuracy: tensor(0.7500, device='cuda:0')
# Training Epoch: 40, total loss: 33.541976
# total_train_accuracy: tensor(0.7396, device='cuda:0')
# Training Epoch: 41, total loss: 33.731488
# total_train_accuracy: tensor(0.7854, device='cuda:0')
# Training Epoch: 42, total loss: 33.135819
# total_train_accuracy: tensor(0.7500, device='cuda:0')
# Training Epoch: 43, total loss: 33.691476
# total_train_accuracy: tensor(0.7646, device='cuda:0')
# Training Epoch: 44, total loss: 33.453803
# total_train_accuracy: tensor(0.7542, device='cuda:0')
# Training Epoch: 45, total loss: 33.443360
# total_train_accuracy: tensor(0.7271, device='cuda:0')
# Training Epoch: 46, total loss: 33.608547
# total_train_accuracy: tensor(0.7771, device='cuda:0')
# Training Epoch: 47, total loss: 33.175657
# total_train_accuracy: tensor(0.7563, device='cuda:0')
# Training Epoch: 48, total loss: 33.379020
# total_train_accuracy: tensor(0.7771, device='cuda:0')
# Training Epoch: 49, total loss: 33.016371
# total_train_accuracy: tensor(0.7708, device='cuda:0')
# Training Epoch: 50, total loss: 33.110208
# total_train_accuracy: tensor(0.7688, device='cuda:0')
# Training Epoch: 51, total loss: 33.032391
# total_train_accuracy: tensor(0.7583, device='cuda:0')
# Training Epoch: 52, total loss: 33.494240
# total_train_accuracy: tensor(0.7708, device='cuda:0')
# Training Epoch: 53, total loss: 32.901285
# total_train_accuracy: tensor(0.7938, device='cuda:0')
# Training Epoch: 54, total loss: 33.035158
# total_train_accuracy: tensor(0.7479, device='cuda:0')
# Training Epoch: 55, total loss: 33.483623
# total_train_accuracy: tensor(0.7812, device='cuda:0')
# Training Epoch: 56, total loss: 33.043495
# total_train_accuracy: tensor(0.7812, device='cuda:0')
# Training Epoch: 57, total loss: 32.931452
# total_train_accuracy: tensor(0.7750, device='cuda:0')
# Training Epoch: 58, total loss: 32.940772
# total_train_accuracy: tensor(0.7833, device='cuda:0')
# Training Epoch: 59, total loss: 32.633243
# total_train_accuracy: tensor(0.7479, device='cuda:0')
# Training Epoch: 60, total loss: 33.203396
# total_train_accuracy: tensor(0.7813, device='cuda:0')
# Training Epoch: 61, total loss: 33.001854
# total_train_accuracy: tensor(0.7979, device='cuda:0')
# Training Epoch: 62, total loss: 32.814610
# total_train_accuracy: tensor(0.7833, device='cuda:0')
# Training Epoch: 63, total loss: 33.209799
# total_train_accuracy: tensor(0.7500, device='cuda:0')
# Training Epoch: 64, total loss: 33.416937
# total_train_accuracy: tensor(0.7500, device='cuda:0')
# Training Epoch: 65, total loss: 33.263335
# total_train_accuracy: tensor(0.7604, device='cuda:0')
# Training Epoch: 66, total loss: 33.168297
# total_train_accuracy: tensor(0.7437, device='cuda:0')
# Training Epoch: 67, total loss: 33.085804
# total_train_accuracy: tensor(0.8042, device='cuda:0')
# Training Epoch: 68, total loss: 32.558468
# total_train_accuracy: tensor(0.7750, device='cuda:0')
# Training Epoch: 69, total loss: 33.008387
# total_train_accuracy: tensor(0.8000, device='cuda:0')
# Training Epoch: 70, total loss: 32.477278
# total_train_accuracy: tensor(0.8042, device='cuda:0')
# Training Epoch: 71, total loss: 32.493502
# total_train_accuracy: tensor(0.8021, device='cuda:0')
# Training Epoch: 72, total loss: 32.721328
# total_train_accuracy: tensor(0.7729, device='cuda:0')
# Training Epoch: 73, total loss: 33.049729
# total_train_accuracy: tensor(0.7771, device='cuda:0')
# Training Epoch: 74, total loss: 32.970066
# total_train_accuracy: tensor(0.7958, device='cuda:0')
# Training Epoch: 75, total loss: 32.437008
# total_train_accuracy: tensor(0.7292, device='cuda:0')
# Training Epoch: 76, total loss: 33.397770
# total_train_accuracy: tensor(0.7771, device='cuda:0')
# Training Epoch: 77, total loss: 32.782138
# total_train_accuracy: tensor(0.7833, device='cuda:0')
# Training Epoch: 78, total loss: 32.544059
# total_train_accuracy: tensor(0.8021, device='cuda:0')
# Training Epoch: 79, total loss: 32.393565
# total_train_accuracy: tensor(0.7583, device='cuda:0')
# Training Epoch: 80, total loss: 33.082470
# total_train_accuracy: tensor(0.8000, device='cuda:0')
# Training Epoch: 81, total loss: 32.564075
# total_train_accuracy: tensor(0.8000, device='cuda:0')
# Training Epoch: 82, total loss: 32.624146
# total_train_accuracy: tensor(0.7708, device='cuda:0')
# Training Epoch: 83, total loss: 33.018038
# total_train_accuracy: tensor(0.7542, device='cuda:0')
# Training Epoch: 84, total loss: 33.478474
# total_train_accuracy: tensor(0.7813, device='cuda:0')
# Training Epoch: 85, total loss: 32.754923
# total_train_accuracy: tensor(0.8083, device='cuda:0')
# Training Epoch: 86, total loss: 32.427608
# total_train_accuracy: tensor(0.7708, device='cuda:0')
# Training Epoch: 87, total loss: 32.797529
# total_train_accuracy: tensor(0.7896, device='cuda:0')
# Training Epoch: 88, total loss: 32.627651
# total_train_accuracy: tensor(0.7875, device='cuda:0')
# Training Epoch: 89, total loss: 32.453627
# total_train_accuracy: tensor(0.8083, device='cuda:0')
# Training Epoch: 90, total loss: 32.416298
# total_train_accuracy: tensor(0.7958, device='cuda:0')
# Training Epoch: 91, total loss: 32.515340
# total_train_accuracy: tensor(0.8062, device='cuda:0')
# Training Epoch: 92, total loss: 32.168433
# total_train_accuracy: tensor(0.7958, device='cuda:0')
# Training Epoch: 93, total loss: 32.576915
# total_train_accuracy: tensor(0.8188, device='cuda:0')
# Training Epoch: 94, total loss: 32.112078
# total_train_accuracy: tensor(0.7854, device='cuda:0')
# Training Epoch: 95, total loss: 32.610226
# total_train_accuracy: tensor(0.7875, device='cuda:0')
# Training Epoch: 96, total loss: 32.599007
# total_train_accuracy: tensor(0.7750, device='cuda:0')
# Training Epoch: 97, total loss: 32.681000
# total_train_accuracy: tensor(0.7750, device='cuda:0')
# Training Epoch: 98, total loss: 32.513881
# total_train_accuracy: tensor(0.7708, device='cuda:0')
# Training Epoch: 99, total loss: 32.987787
# total_train_accuracy: tensor(0.7646, device='cuda:0')
# Training Epoch: 100, total loss: 32.855865
# the  1  epoch ends
# test
# test
# total_test_accuracy: tensor(0.7708, device='cuda:0')
# acc_test_each_k: tensor(0.7708, device='cuda:0')
# total_train_accuracy: tensor(0.7458, device='cuda:0')
# Training Epoch: 0, total loss: 33.466355
# total_train_accuracy: tensor(0.7937, device='cuda:0')
# Training Epoch: 1, total loss: 32.460455
# total_train_accuracy: tensor(0.7792, device='cuda:0')
# Training Epoch: 2, total loss: 32.736184
# total_train_accuracy: tensor(0.8063, device='cuda:0')
# Training Epoch: 3, total loss: 32.249090
# total_train_accuracy: tensor(0.7896, device='cuda:0')
# Training Epoch: 4, total loss: 32.585376
# total_train_accuracy: tensor(0.7875, device='cuda:0')
# Training Epoch: 5, total loss: 32.493965
# total_train_accuracy: tensor(0.8021, device='cuda:0')
# Training Epoch: 6, total loss: 32.246225
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 7, total loss: 32.044919
# total_train_accuracy: tensor(0.7917, device='cuda:0')
# Training Epoch: 8, total loss: 32.472848
# total_train_accuracy: tensor(0.7958, device='cuda:0')
# Training Epoch: 9, total loss: 32.608522
# total_train_accuracy: tensor(0.7958, device='cuda:0')
# Training Epoch: 10, total loss: 32.462938
# total_train_accuracy: tensor(0.7917, device='cuda:0')
# Training Epoch: 11, total loss: 32.518264
# total_train_accuracy: tensor(0.7979, device='cuda:0')
# Training Epoch: 12, total loss: 32.331040
# total_train_accuracy: tensor(0.7854, device='cuda:0')
# Training Epoch: 13, total loss: 32.631255
# total_train_accuracy: tensor(0.7750, device='cuda:0')
# Training Epoch: 14, total loss: 32.522235
# total_train_accuracy: tensor(0.7833, device='cuda:0')
# Training Epoch: 15, total loss: 32.477613
# total_train_accuracy: tensor(0.7833, device='cuda:0')
# Training Epoch: 16, total loss: 32.666378
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# Training Epoch: 17, total loss: 32.178725
# total_train_accuracy: tensor(0.8042, device='cuda:0')
# Training Epoch: 18, total loss: 32.193922
# total_train_accuracy: tensor(0.7729, device='cuda:0')
# Training Epoch: 19, total loss: 32.707429
# total_train_accuracy: tensor(0.7979, device='cuda:0')
# Training Epoch: 20, total loss: 32.148745
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 21, total loss: 32.127920
# total_train_accuracy: tensor(0.8000, device='cuda:0')
# Training Epoch: 22, total loss: 32.086220
# total_train_accuracy: tensor(0.7813, device='cuda:0')
# Training Epoch: 23, total loss: 32.774035
# total_train_accuracy: tensor(0.7854, device='cuda:0')
# Training Epoch: 24, total loss: 32.561090
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 25, total loss: 32.093787
# total_train_accuracy: tensor(0.7958, device='cuda:0')
# Training Epoch: 26, total loss: 32.221840
# total_train_accuracy: tensor(0.7875, device='cuda:0')
# Training Epoch: 27, total loss: 32.452020
# total_train_accuracy: tensor(0.8229, device='cuda:0')
# Training Epoch: 28, total loss: 31.870920
# total_train_accuracy: tensor(0.7979, device='cuda:0')
# Training Epoch: 29, total loss: 32.265208
# total_train_accuracy: tensor(0.8354, device='cuda:0')
# Training Epoch: 30, total loss: 31.941840
# total_train_accuracy: tensor(0.7979, device='cuda:0')
# Training Epoch: 31, total loss: 32.155826
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 32, total loss: 31.942602
# total_train_accuracy: tensor(0.8333, device='cuda:0')
# Training Epoch: 33, total loss: 31.749877
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 34, total loss: 32.245316
# total_train_accuracy: tensor(0.8208, device='cuda:0')
# Training Epoch: 35, total loss: 31.893437
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 36, total loss: 31.951875
# total_train_accuracy: tensor(0.8229, device='cuda:0')
# Training Epoch: 37, total loss: 31.765284
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 38, total loss: 32.010608
# total_train_accuracy: tensor(0.7771, device='cuda:0')
# Training Epoch: 39, total loss: 32.441803
# total_train_accuracy: tensor(0.8021, device='cuda:0')
# Training Epoch: 40, total loss: 31.986056
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 41, total loss: 31.893326
# total_train_accuracy: tensor(0.8437, device='cuda:0')
# Training Epoch: 42, total loss: 31.780370
# total_train_accuracy: tensor(0.7938, device='cuda:0')
# Training Epoch: 43, total loss: 32.331245
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 44, total loss: 31.936936
# total_train_accuracy: tensor(0.8229, device='cuda:0')
# Training Epoch: 45, total loss: 31.833000
# total_train_accuracy: tensor(0.8042, device='cuda:0')
# Training Epoch: 46, total loss: 32.131930
# total_train_accuracy: tensor(0.8083, device='cuda:0')
# Training Epoch: 47, total loss: 32.028980
# total_train_accuracy: tensor(0.7833, device='cuda:0')
# Training Epoch: 48, total loss: 32.275035
# total_train_accuracy: tensor(0.8208, device='cuda:0')
# Training Epoch: 49, total loss: 31.834616
# total_train_accuracy: tensor(0.8354, device='cuda:0')
# Training Epoch: 50, total loss: 31.624346
# total_train_accuracy: tensor(0.8250, device='cuda:0')
# Training Epoch: 51, total loss: 31.799701
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 52, total loss: 32.130727
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 53, total loss: 31.839231
# total_train_accuracy: tensor(0.8083, device='cuda:0')
# Training Epoch: 54, total loss: 32.009318
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 55, total loss: 32.061037
# total_train_accuracy: tensor(0.8417, device='cuda:0')
# Training Epoch: 56, total loss: 31.533060
# total_train_accuracy: tensor(0.8188, device='cuda:0')
# Training Epoch: 57, total loss: 31.810671
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 58, total loss: 31.672080
# total_train_accuracy: tensor(0.8063, device='cuda:0')
# Training Epoch: 59, total loss: 31.948936
# total_train_accuracy: tensor(0.8063, device='cuda:0')
# Training Epoch: 60, total loss: 32.052793
# total_train_accuracy: tensor(0.8313, device='cuda:0')
# Training Epoch: 61, total loss: 31.789649
# total_train_accuracy: tensor(0.8562, device='cuda:0')
# Training Epoch: 62, total loss: 31.115098
# total_train_accuracy: tensor(0.8021, device='cuda:0')
# Training Epoch: 63, total loss: 32.066198
# total_train_accuracy: tensor(0.7958, device='cuda:0')
# Training Epoch: 64, total loss: 32.240159
# total_train_accuracy: tensor(0.8188, device='cuda:0')
# Training Epoch: 65, total loss: 31.805913
# total_train_accuracy: tensor(0.8021, device='cuda:0')
# Training Epoch: 66, total loss: 32.087593
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# Training Epoch: 67, total loss: 31.824390
# total_train_accuracy: tensor(0.7979, device='cuda:0')
# Training Epoch: 68, total loss: 32.022830
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 69, total loss: 31.533037
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 70, total loss: 31.955976
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 71, total loss: 31.990089
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 72, total loss: 31.707029
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 73, total loss: 31.510527
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 74, total loss: 31.777054
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 75, total loss: 32.049642
# total_train_accuracy: tensor(0.8292, device='cuda:0')
# Training Epoch: 76, total loss: 31.558220
# total_train_accuracy: tensor(0.8188, device='cuda:0')
# Training Epoch: 77, total loss: 31.847014
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 78, total loss: 31.387870
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 79, total loss: 31.378695
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 80, total loss: 31.299287
# total_train_accuracy: tensor(0.8667, device='cuda:0')
# Training Epoch: 81, total loss: 31.313624
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 82, total loss: 31.482237
# total_train_accuracy: tensor(0.8542, device='cuda:0')
# Training Epoch: 83, total loss: 31.270393
# total_train_accuracy: tensor(0.8250, device='cuda:0')
# Training Epoch: 84, total loss: 31.839249
# total_train_accuracy: tensor(0.8208, device='cuda:0')
# Training Epoch: 85, total loss: 31.702235
# total_train_accuracy: tensor(0.8229, device='cuda:0')
# Training Epoch: 86, total loss: 31.865361
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 87, total loss: 31.189101
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 88, total loss: 31.134802
# total_train_accuracy: tensor(0.8479, device='cuda:0')
# Training Epoch: 89, total loss: 31.172761
# total_train_accuracy: tensor(0.8333, device='cuda:0')
# Training Epoch: 90, total loss: 31.442672
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 91, total loss: 31.590769
# total_train_accuracy: tensor(0.8042, device='cuda:0')
# Training Epoch: 92, total loss: 31.964257
# total_train_accuracy: tensor(0.8188, device='cuda:0')
# Training Epoch: 93, total loss: 31.699437
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 94, total loss: 31.451288
# total_train_accuracy: tensor(0.8417, device='cuda:0')
# Training Epoch: 95, total loss: 31.410990
# total_train_accuracy: tensor(0.8229, device='cuda:0')
# Training Epoch: 96, total loss: 31.431412
# total_train_accuracy: tensor(0.8354, device='cuda:0')
# Training Epoch: 97, total loss: 31.526074
# total_train_accuracy: tensor(0.8521, device='cuda:0')
# Training Epoch: 98, total loss: 31.144206
# total_train_accuracy: tensor(0.8521, device='cuda:0')
# Training Epoch: 99, total loss: 31.302423
# total_train_accuracy: tensor(0.8479, device='cuda:0')
# Training Epoch: 100, total loss: 31.274952
# the  2  epoch ends
# test
# test
# total_test_accuracy: tensor(0.8125, device='cuda:0')
# acc_test_each_k: tensor(0.8125, device='cuda:0')
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# Training Epoch: 0, total loss: 31.770958
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 1, total loss: 31.444055
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 2, total loss: 31.249400
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 3, total loss: 31.153447
# total_train_accuracy: tensor(0.8250, device='cuda:0')
# Training Epoch: 4, total loss: 31.637257
# total_train_accuracy: tensor(0.8125, device='cuda:0')
# Training Epoch: 5, total loss: 32.051815
# total_train_accuracy: tensor(0.8438, device='cuda:0')
# Training Epoch: 6, total loss: 31.363823
# total_train_accuracy: tensor(0.8271, device='cuda:0')
# Training Epoch: 7, total loss: 31.703679
# total_train_accuracy: tensor(0.8438, device='cuda:0')
# Training Epoch: 8, total loss: 31.311355
# total_train_accuracy: tensor(0.8250, device='cuda:0')
# Training Epoch: 9, total loss: 31.670811
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 10, total loss: 31.565094
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# Training Epoch: 11, total loss: 31.725549
# total_train_accuracy: tensor(0.8313, device='cuda:0')
# Training Epoch: 12, total loss: 31.559131
# total_train_accuracy: tensor(0.7896, device='cuda:0')
# Training Epoch: 13, total loss: 32.045199
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 14, total loss: 31.504059
# total_train_accuracy: tensor(0.8292, device='cuda:0')
# Training Epoch: 15, total loss: 31.655998
# total_train_accuracy: tensor(0.8292, device='cuda:0')
# Training Epoch: 16, total loss: 31.448858
# total_train_accuracy: tensor(0.8292, device='cuda:0')
# Training Epoch: 17, total loss: 31.600152
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 18, total loss: 31.204241
# total_train_accuracy: tensor(0.8271, device='cuda:0')
# Training Epoch: 19, total loss: 31.656363
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 20, total loss: 31.252926
# total_train_accuracy: tensor(0.8521, device='cuda:0')
# Training Epoch: 21, total loss: 31.166438
# total_train_accuracy: tensor(0.8042, device='cuda:0')
# Training Epoch: 22, total loss: 31.985394
# total_train_accuracy: tensor(0.8250, device='cuda:0')
# Training Epoch: 23, total loss: 31.429596
# total_train_accuracy: tensor(0.8208, device='cuda:0')
# Training Epoch: 24, total loss: 31.703712
# total_train_accuracy: tensor(0.8354, device='cuda:0')
# Training Epoch: 25, total loss: 31.308803
# total_train_accuracy: tensor(0.8083, device='cuda:0')
# Training Epoch: 26, total loss: 31.860848
# total_train_accuracy: tensor(0.8250, device='cuda:0')
# Training Epoch: 27, total loss: 31.495664
# total_train_accuracy: tensor(0.8417, device='cuda:0')
# Training Epoch: 28, total loss: 31.178558
# total_train_accuracy: tensor(0.8604, device='cuda:0')
# Training Epoch: 29, total loss: 31.042164
# total_train_accuracy: tensor(0.8292, device='cuda:0')
# Training Epoch: 30, total loss: 31.589222
# total_train_accuracy: tensor(0.8354, device='cuda:0')
# Training Epoch: 31, total loss: 31.356436
# total_train_accuracy: tensor(0.8250, device='cuda:0')
# Training Epoch: 32, total loss: 31.736140
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 33, total loss: 31.254283
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# Training Epoch: 34, total loss: 31.646995
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 35, total loss: 31.209275
# total_train_accuracy: tensor(0.8562, device='cuda:0')
# Training Epoch: 36, total loss: 31.198583
# total_train_accuracy: tensor(0.8250, device='cuda:0')
# Training Epoch: 37, total loss: 31.512775
# total_train_accuracy: tensor(0.8625, device='cuda:0')
# Training Epoch: 38, total loss: 31.086166
# total_train_accuracy: tensor(0.8208, device='cuda:0')
# Training Epoch: 39, total loss: 31.669747
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 40, total loss: 30.814369
# total_train_accuracy: tensor(0.8354, device='cuda:0')
# Training Epoch: 41, total loss: 31.463135
# total_train_accuracy: tensor(0.8354, device='cuda:0')
# Training Epoch: 42, total loss: 31.233555
# total_train_accuracy: tensor(0.8417, device='cuda:0')
# Training Epoch: 43, total loss: 31.261574
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 44, total loss: 31.117948
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 45, total loss: 31.268017
# total_train_accuracy: tensor(0.8562, device='cuda:0')
# Training Epoch: 46, total loss: 31.147038
# total_train_accuracy: tensor(0.8625, device='cuda:0')
# Training Epoch: 47, total loss: 30.859819
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 48, total loss: 31.884129
# total_train_accuracy: tensor(0.8688, device='cuda:0')
# Training Epoch: 49, total loss: 31.058774
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 50, total loss: 31.341723
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 51, total loss: 31.373441
# total_train_accuracy: tensor(0.8188, device='cuda:0')
# Training Epoch: 52, total loss: 31.671474
# total_train_accuracy: tensor(0.8333, device='cuda:0')
# Training Epoch: 53, total loss: 31.407917
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 54, total loss: 31.138817
# total_train_accuracy: tensor(0.8417, device='cuda:0')
# Training Epoch: 55, total loss: 31.160225
# total_train_accuracy: tensor(0.8604, device='cuda:0')
# Training Epoch: 56, total loss: 30.842385
# total_train_accuracy: tensor(0.8333, device='cuda:0')
# Training Epoch: 57, total loss: 31.439094
# total_train_accuracy: tensor(0.8354, device='cuda:0')
# Training Epoch: 58, total loss: 31.364988
# total_train_accuracy: tensor(0.8271, device='cuda:0')
# Training Epoch: 59, total loss: 31.493318
# total_train_accuracy: tensor(0.8646, device='cuda:0')
# Training Epoch: 60, total loss: 31.001042
# total_train_accuracy: tensor(0.8437, device='cuda:0')
# Training Epoch: 61, total loss: 31.332094
# total_train_accuracy: tensor(0.8625, device='cuda:0')
# Training Epoch: 62, total loss: 30.989563
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 63, total loss: 30.854305
# total_train_accuracy: tensor(0.8292, device='cuda:0')
# Training Epoch: 64, total loss: 31.507616
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 65, total loss: 30.868966
# total_train_accuracy: tensor(0.8313, device='cuda:0')
# Training Epoch: 66, total loss: 31.443405
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 67, total loss: 31.084317
# total_train_accuracy: tensor(0.8229, device='cuda:0')
# Training Epoch: 68, total loss: 31.593465
# total_train_accuracy: tensor(0.8521, device='cuda:0')
# Training Epoch: 69, total loss: 31.039307
# total_train_accuracy: tensor(0.8271, device='cuda:0')
# Training Epoch: 70, total loss: 31.524512
# total_train_accuracy: tensor(0.8313, device='cuda:0')
# Training Epoch: 71, total loss: 31.446016
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 72, total loss: 30.903296
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 73, total loss: 31.160880
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 74, total loss: 31.083170
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 75, total loss: 31.122327
# total_train_accuracy: tensor(0.8563, device='cuda:0')
# Training Epoch: 76, total loss: 30.969441
# total_train_accuracy: tensor(0.8292, device='cuda:0')
# Training Epoch: 77, total loss: 31.314739
# total_train_accuracy: tensor(0.8625, device='cuda:0')
# Training Epoch: 78, total loss: 30.931361
# total_train_accuracy: tensor(0.8646, device='cuda:0')
# Training Epoch: 79, total loss: 30.637568
# total_train_accuracy: tensor(0.8729, device='cuda:0')
# Training Epoch: 80, total loss: 30.740339
# total_train_accuracy: tensor(0.8646, device='cuda:0')
# Training Epoch: 81, total loss: 30.810429
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 82, total loss: 30.449688
# total_train_accuracy: tensor(0.8687, device='cuda:0')
# Training Epoch: 83, total loss: 30.801786
# total_train_accuracy: tensor(0.8542, device='cuda:0')
# Training Epoch: 84, total loss: 31.029001
# total_train_accuracy: tensor(0.8708, device='cuda:0')
# Training Epoch: 85, total loss: 30.676893
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 86, total loss: 31.100736
# total_train_accuracy: tensor(0.8854, device='cuda:0')
# Training Epoch: 87, total loss: 30.623938
# total_train_accuracy: tensor(0.8479, device='cuda:0')
# Training Epoch: 88, total loss: 31.180451
# total_train_accuracy: tensor(0.8646, device='cuda:0')
# Training Epoch: 89, total loss: 30.865842
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 90, total loss: 30.549506
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 91, total loss: 30.403403
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 92, total loss: 30.376133
# total_train_accuracy: tensor(0.8479, device='cuda:0')
# Training Epoch: 93, total loss: 31.104385
# total_train_accuracy: tensor(0.8437, device='cuda:0')
# Training Epoch: 94, total loss: 31.321307
# total_train_accuracy: tensor(0.8479, device='cuda:0')
# Training Epoch: 95, total loss: 31.149460
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 96, total loss: 31.116624
# total_train_accuracy: tensor(0.8708, device='cuda:0')
# Training Epoch: 97, total loss: 30.663558
# total_train_accuracy: tensor(0.8708, device='cuda:0')
# Training Epoch: 98, total loss: 30.755677
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 99, total loss: 31.020422
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 100, total loss: 31.060557
# the  3  epoch ends
# test
# test
# total_test_accuracy: tensor(0.9375, device='cuda:0')
# acc_test_each_k: tensor(0.9375, device='cuda:0')
# total_train_accuracy: tensor(0.8312, device='cuda:0')
# Training Epoch: 0, total loss: 31.317128
# total_train_accuracy: tensor(0.8146, device='cuda:0')
# Training Epoch: 1, total loss: 31.800307
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 2, total loss: 31.182853
# total_train_accuracy: tensor(0.8729, device='cuda:0')
# Training Epoch: 3, total loss: 30.727766
# total_train_accuracy: tensor(0.8542, device='cuda:0')
# Training Epoch: 4, total loss: 30.964671
# total_train_accuracy: tensor(0.8292, device='cuda:0')
# Training Epoch: 5, total loss: 31.531354
# total_train_accuracy: tensor(0.8646, device='cuda:0')
# Training Epoch: 6, total loss: 30.837625
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 7, total loss: 30.947802
# total_train_accuracy: tensor(0.8687, device='cuda:0')
# Training Epoch: 8, total loss: 30.947683
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 9, total loss: 30.118919
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 10, total loss: 30.689241
# total_train_accuracy: tensor(0.8479, device='cuda:0')
# Training Epoch: 11, total loss: 31.125728
# total_train_accuracy: tensor(0.8312, device='cuda:0')
# Training Epoch: 12, total loss: 31.222482
# total_train_accuracy: tensor(0.8625, device='cuda:0')
# Training Epoch: 13, total loss: 31.102140
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 14, total loss: 31.307937
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 15, total loss: 31.146625
# total_train_accuracy: tensor(0.8562, device='cuda:0')
# Training Epoch: 16, total loss: 31.178205
# total_train_accuracy: tensor(0.8687, device='cuda:0')
# Training Epoch: 17, total loss: 30.808076
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 18, total loss: 30.315830
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 19, total loss: 30.616529
# total_train_accuracy: tensor(0.8604, device='cuda:0')
# Training Epoch: 20, total loss: 31.071658
# total_train_accuracy: tensor(0.8521, device='cuda:0')
# Training Epoch: 21, total loss: 30.997720
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 22, total loss: 30.555746
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 23, total loss: 30.826846
# total_train_accuracy: tensor(0.8625, device='cuda:0')
# Training Epoch: 24, total loss: 30.776518
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 25, total loss: 31.320192
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 26, total loss: 31.245979
# total_train_accuracy: tensor(0.8542, device='cuda:0')
# Training Epoch: 27, total loss: 31.035353
# total_train_accuracy: tensor(0.8625, device='cuda:0')
# Training Epoch: 28, total loss: 30.828870
# total_train_accuracy: tensor(0.8604, device='cuda:0')
# Training Epoch: 29, total loss: 30.646441
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 30, total loss: 30.624064
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 31, total loss: 30.388270
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 32, total loss: 30.523614
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 33, total loss: 30.266511
# total_train_accuracy: tensor(0.8750, device='cuda:0')
# Training Epoch: 34, total loss: 30.731105
# total_train_accuracy: tensor(0.8625, device='cuda:0')
# Training Epoch: 35, total loss: 30.843538
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 36, total loss: 30.663562
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 37, total loss: 30.575841
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 38, total loss: 30.420517
# total_train_accuracy: tensor(0.8854, device='cuda:0')
# Training Epoch: 39, total loss: 30.257013
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 40, total loss: 30.185854
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 41, total loss: 30.067388
# total_train_accuracy: tensor(0.8604, device='cuda:0')
# Training Epoch: 42, total loss: 30.778977
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 43, total loss: 29.774509
# total_train_accuracy: tensor(0.8562, device='cuda:0')
# Training Epoch: 44, total loss: 30.846200
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 45, total loss: 30.540330
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 46, total loss: 30.111400
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 47, total loss: 30.204137
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 48, total loss: 30.396553
# total_train_accuracy: tensor(0.8729, device='cuda:0')
# Training Epoch: 49, total loss: 30.592473
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 50, total loss: 30.589519
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 51, total loss: 30.223491
# total_train_accuracy: tensor(0.8937, device='cuda:0')
# ...
# Training Epoch: 48, total loss: 29.752354
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 49, total loss: 29.979687
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 50, total loss: 29.773324
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 51, total loss: 30.106747
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 52, total loss: 30.049932
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 53, total loss: 29.757024
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 54, total loss: 29.731601
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 55, total loss: 29.608972
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 56, total loss: 29.734986
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 57, total loss: 29.621292
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 58, total loss: 29.552184
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 59, total loss: 30.029241
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 60, total loss: 29.814626
# total_train_accuracy: tensor(0.8813, device='cuda:0')
# Training Epoch: 61, total loss: 30.248157
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 62, total loss: 29.447235
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 63, total loss: 29.833794
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 64, total loss: 29.679774
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 65, total loss: 29.694496
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 66, total loss: 29.715236
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 67, total loss: 29.578021
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 68, total loss: 29.832605
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 69, total loss: 29.976249
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 70, total loss: 29.403776
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 71, total loss: 30.082950
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 72, total loss: 30.106676
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 73, total loss: 29.717677
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 74, total loss: 29.264918
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 75, total loss: 29.736923
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 76, total loss: 29.682848
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 77, total loss: 29.781456
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 78, total loss: 29.631613
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 79, total loss: 29.810677
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 80, total loss: 29.590897
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 81, total loss: 29.384483
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 82, total loss: 29.531818
# total_train_accuracy: tensor(0.9062, device='cuda:0')
# Training Epoch: 83, total loss: 29.725184
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 84, total loss: 29.881317
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 85, total loss: 29.662059
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 86, total loss: 29.606593
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 87, total loss: 29.556601
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 88, total loss: 29.231157
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 89, total loss: 30.009727
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 90, total loss: 29.559871
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 91, total loss: 29.440498
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 92, total loss: 29.640979
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 93, total loss: 30.000656
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 94, total loss: 29.838841
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 95, total loss: 29.355001
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 96, total loss: 29.325804
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 97, total loss: 29.477640
# total_train_accuracy: tensor(0.8854, device='cuda:0')
# Training Epoch: 98, total loss: 29.963221
# total_train_accuracy: tensor(0.9062, device='cuda:0')
# Training Epoch: 99, total loss: 29.836406
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 100, total loss: 30.122327
# the  8  epoch ends
# test
# test
# total_test_accuracy: tensor(0.9792, device='cuda:0')
# acc_test_each_k: tensor(0.9792, device='cuda:0')
# total_train_accuracy: tensor(0.8854, device='cuda:0')
# Training Epoch: 0, total loss: 30.195002
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 1, total loss: 29.938281
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 2, total loss: 30.130793
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 3, total loss: 29.872570
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 4, total loss: 29.749538
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 5, total loss: 29.480579
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 6, total loss: 29.212284
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 7, total loss: 29.754297
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 8, total loss: 29.960327
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 9, total loss: 30.009834
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 10, total loss: 30.268757
# total_train_accuracy: tensor(0.8854, device='cuda:0')
# Training Epoch: 11, total loss: 30.219903
# total_train_accuracy: tensor(0.9063, device='cuda:0')
# Training Epoch: 12, total loss: 29.835908
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 13, total loss: 29.840519
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 14, total loss: 29.911518
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 15, total loss: 30.078088
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 16, total loss: 30.166433
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 17, total loss: 29.988114
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 18, total loss: 29.703439
# total_train_accuracy: tensor(0.9062, device='cuda:0')
# Training Epoch: 19, total loss: 29.653678
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 20, total loss: 29.980098
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 21, total loss: 29.669792
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 22, total loss: 29.714317
# total_train_accuracy: tensor(0.8542, device='cuda:0')
# Training Epoch: 23, total loss: 30.646336
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 24, total loss: 29.633560
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 25, total loss: 29.981667
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 26, total loss: 30.155646
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 27, total loss: 29.597471
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 28, total loss: 29.830499
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 29, total loss: 30.160555
# total_train_accuracy: tensor(0.9187, device='cuda:0')
# Training Epoch: 30, total loss: 29.671255
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 31, total loss: 29.792809
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 32, total loss: 29.746572
# total_train_accuracy: tensor(0.9187, device='cuda:0')
# Training Epoch: 33, total loss: 29.400686
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 34, total loss: 29.871551
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 35, total loss: 30.084899
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 36, total loss: 29.911733
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 37, total loss: 29.519933
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 38, total loss: 30.017420
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 39, total loss: 29.702743
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 40, total loss: 29.954585
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 41, total loss: 29.677245
# total_train_accuracy: tensor(0.8854, device='cuda:0')
# Training Epoch: 42, total loss: 30.021386
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 43, total loss: 29.825235
# total_train_accuracy: tensor(0.8813, device='cuda:0')
# Training Epoch: 44, total loss: 30.322025
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 45, total loss: 29.552866
# total_train_accuracy: tensor(0.8667, device='cuda:0')
# Training Epoch: 46, total loss: 30.415555
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 47, total loss: 29.879909
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 48, total loss: 29.470571
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 49, total loss: 29.811485
# total_train_accuracy: tensor(0.9187, device='cuda:0')
# Training Epoch: 50, total loss: 29.627567
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 51, total loss: 29.672607
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 52, total loss: 29.567120
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 53, total loss: 29.740173
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 54, total loss: 29.947852
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 55, total loss: 29.835945
# total_train_accuracy: tensor(0.9063, device='cuda:0')
# Training Epoch: 56, total loss: 29.524865
# total_train_accuracy: tensor(0.9062, device='cuda:0')
# Training Epoch: 57, total loss: 29.786728
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 58, total loss: 29.835325
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 59, total loss: 29.645648
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 60, total loss: 29.473632
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 61, total loss: 29.944513
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 62, total loss: 29.801208
# total_train_accuracy: tensor(0.9062, device='cuda:0')
# Training Epoch: 63, total loss: 29.752440
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 64, total loss: 29.723584
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 65, total loss: 29.715372
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 66, total loss: 29.986593
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 67, total loss: 29.592259
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 68, total loss: 29.534049
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 69, total loss: 29.659824
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 70, total loss: 30.187010
# total_train_accuracy: tensor(0.8854, device='cuda:0')
# Training Epoch: 71, total loss: 30.160863
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 72, total loss: 29.564552
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 73, total loss: 29.461912
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 74, total loss: 29.744060
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 75, total loss: 29.555862
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 76, total loss: 29.240360
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 77, total loss: 29.522347
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 78, total loss: 29.577875
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 79, total loss: 29.587859
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 80, total loss: 29.652053
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 81, total loss: 29.478003
# total_train_accuracy: tensor(0.8813, device='cuda:0')
# Training Epoch: 82, total loss: 30.252824
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 83, total loss: 29.817580
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 84, total loss: 30.179126
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 85, total loss: 29.730383
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 86, total loss: 29.578256
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 87, total loss: 29.856883
# total_train_accuracy: tensor(0.9000, device='cuda:0')
# Training Epoch: 88, total loss: 30.055251
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 89, total loss: 29.977178
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 90, total loss: 29.769024
# total_train_accuracy: tensor(0.9062, device='cuda:0')
# Training Epoch: 91, total loss: 29.664975
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 92, total loss: 30.162509
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 93, total loss: 30.131983
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 94, total loss: 29.772173
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 95, total loss: 30.141228
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 96, total loss: 29.674353
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 97, total loss: 30.012001
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 98, total loss: 29.607021
# total_train_accuracy: tensor(0.8854, device='cuda:0')
# Training Epoch: 99, total loss: 29.948995
# total_train_accuracy: tensor(0.8583, device='cuda:0')
# Training Epoch: 100, total loss: 30.344548
# the  9  epoch ends
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# acc_test_each_k: tensor(1., device='cuda:0')
# [tensor(0.5833, device='cuda:0'), tensor(0.7708, device='cuda:0'), tensor(0.8125, device='cuda:0'), tensor(0.9375, device='cuda:0'), tensor(0.9375, device='cuda:0'), tensor(0.9792, device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(0.9792, device='cuda:0'), tensor(1., device='cuda:0')]
# [array(0.5833334, dtype=float32), array(0.7708334, dtype=float32), array(0.8125, dtype=float32), array(0.9375, dtype=float32), array(0.9375, dtype=float32), array(0.9791666, dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(0.9791666, dtype=float32), array(1., dtype=float32)]
# acc_test_metrics: 0.9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-98666d7df805> in <module>
#      61 print("acc_test_metrics:",acc_test_metrics)
#      62
# ---> 63 model=model2
#      64 K=10
#      65 test_metrics=[]
#
# NameError: name 'model2' is not defined

# %%
import torch

#功能：加载保存到path中的各层参数到神经网络

#path='models/NFM_layer_2/MLP610.pkl'
path='models/NFM_layer_2_20/max/MLP610.pt'
nfm2=NFM(nfm_config2)
#mlp=MLP()
print(nfm2)
#net = nn.DataParallel(net)
#net = net.to(device)
nfm2.load_state_dict(torch.load(path),strict=False)
nfm2.cuda()

print(nfm2)




nfm_params2 = list(nfm2.named_parameters())
#print(nfm_params)
net=nfm2


testset = KZDatasetTest(csv_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/NFM_layer_2_20/max_test_info.csv')
   
test_loader = data.DataLoader(
         dataset=testset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config1['batch_size']
        
     )
#———————————————— 
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/jclian91/article/details/121708431# 
from torch.autograd import Variable 
from torch.utils.data import DataLoader 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import accuracy_score 
 
def evaluate_model(test_dl, model): 
    model.eval()#测试数据稳定
    predictions, actuals = [], [] 
    for i, (inputs,bi_inputs ,targets) in enumerate(test_dl): 
        # evaluate the model on the test set 
        #print(\ inputs:\ ,inputs) 
        #print(\ targets:\ ,targets) 
        inputs = Variable(inputs) 
        bi_inputs=Variable(bi_inputs)
        targets = Variable(targets) 
                 
                 
        #x = torch.tensor(x, dtype=torch.float) 
        #x=x.clone().detach().requires_grad_(True) 
        inputs=torch.tensor(inputs,dtype=torch.float) 
        bi_inputs=torch.tensor(bi_inputs,dtype=torch.float)
        targets=torch.tensor(targets,dtype=torch.float) 
        inputs,bi_inputs, targets = inputs.cuda(), bi_inputs.cuda(),targets.cuda() 
        yhat = model(inputs,bi_inputs) 
        # retrieve numpy array 
        #yhat = yhat.detach().numpy() 
        yhat = yhat.detach().cpu().numpy()#转换到cpu 
        # yhat=yhat.argmax(axis=1) 
        #print(yhat:\ ,yhat) 
        #print('yhat.shape:',yhat.shape) 
        actual = targets.detach().cpu().numpy() 
        actual=actual.round() 
        #print(\ actual:\ ,actual) 
        #print('actual.shape:',actual.shape
        #predictions.appe) 
        #actual = actual.reshape(-1, 1) 
        # round to class values 
        yhat = yhat.round() 
        # store nd(yhat) 
        actuals.append(actual) 
        predictions.append(yhat)
    #print("prediction:" ,predictions) 
    #print("actuals:",actuals) 
    predictions, actuals = np.vstack(predictions), np.vstack(actuals) 
    #print("prediction:" ,predictions) 
    #print("actuals:" ,actuals) 
    # calculate accuracy 
    acc_test = accuracy_score(actuals, predictions) 
    return  actuals, predictions,acc_test 

import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch

#功能：加载保存到path中的各层参数到神经网络






import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 
target_list=actuals 
pred_list=predictions 
      
y_true=target_list 
y_pred=pred_list 
      
f1=f1_score(y_true=target_list, y_pred=pred_list, average='macro') # 也可以指定micro模式 
acc_score=accuracy_score(y_true=target_list, y_pred=pred_list) 
rec_score=recall_score(y_true=target_list,y_pred=pred_list,average='macro') # 也可以指定micro模式 
pre_recall=precision_score(y_true=target_list,y_pred=pred_list,average='macro') 
print("f1_score:  %.4f" ,f1) 
print("accuracy_score:" ,acc_score) 
print("recall_score:",rec_score) 
print("pre_recall:" ,pre_recall)



auc_curve = roc_auc_score(y_true, y_pred, multi_class='ovo')
#———————————————— 
#版权声明：本文为CSDN博主「农民小飞侠」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/w5688414/article/details/106595892 
PM_y=y_pred 
true_y=y_true 
n_classes=PM_y.shape[1] 
      
print("n_classes:",n_classes) 
fpr = dict() 
tpr = dict() 
roc_auc = dict() 
for i in range(n_classes): 
    fpr[i], tpr[i], _ = roc_curve(true_y[:, i], PM_y[:, i]) 
    roc_auc[i] = auc(fpr[i], tpr[i]) 
    #print(i) 
    #print(fpr) 
    #print(tpr) 
    
    
    
#计算macro auc 
from scipy import interp 
# First aggregate all false positive rates 
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)])) 
       
# Then interpolate all ROC curves at this points 
mean_tpr = np.zeros_like(all_fpr) 
for i in range(n_classes): 
    mean_tpr += interp(all_fpr, fpr[i], tpr[i]) 
       
    # Finally average it and compute AUC 
    mean_tpr /= n_classes 
       
    fpr["macro"] = all_fpr 
    tpr["macro"] = mean_tpr 
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    
    
    
#画图 
      
import matplotlib.pyplot as plt 
from itertools import cycle 
from matplotlib.ticker import FuncFormatter 
lw = 2 
# Plot all ROC curves 
plt.figure() 
labels=['Con(0)','DN(1)','FSGS(2)','HT(3)','IgA(4)','MCD(5)','MGN(6)','RPGN(7)','SLE(8)'] 

'''
plt.plot(fpr["macro"], tpr["macro"], 
              label='macro-average ROC curve (area = {0:0.4f})' 
                    ''.format(roc_auc["macro"]), 
              color='navy', linestyle=':', linewidth=4) 
'''

       
colors = cycle(['aqua', 'darkorange', 'cornflowerblue','blue','yellow','burlywood','cornsilk','darkblue','goldenrod','greenyellow','maroon']) 
for i, color in zip(range(n_classes), colors): 
    plt.plot(fpr[i], tpr[i], color=color, lw=lw, 
                  label=labels[i]+'(area = {0:0.4f})'.format(roc_auc[i])) 
       
    plt.plot([0, 1], [0, 1], 'k--', lw=lw) 
    plt.xlim([0.0, 1.0]) 
    plt.ylim([0.0, 1.05]) 
      
      
    plt.xlabel('1-Specificity (%)') 
    plt.ylabel('Sensitivity (%)') 
    plt.title('NFM_layer_2_non_encode') 
      

        
def to_percent(temp, position): 
    return '%1.0f'%(100*temp) 
      
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.legend(loc="lower right" ) 
      
plt.show() 



#———————————————— 
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/jclian91/article/details/103074506/ 
      
from sklearn.metrics import confusion_matrix 
import matplotlib.pyplot as plt 
import matplotlib as mpl 
      
# 支持中文字体显示, 使用于Mac系统 
#zhfont=mpl.font_manager.FontProperties(fname=\ /Library/Fonts/Songti.ttc\ ) 
      
y_true=actuals# = ['北京', '上海', '成都', '成都', '上海', '北京', '上海', '成都', '北京', '上海'] 
y_pred=predictions #= ['北京', '上海', '成都', '上海', '成都', '成都', '上海', '成都', '北京', '上海'] 
      
#ValueError: multilabel-indicator is not supported 
      
classes = [0,1,2,3,4,5,6,7,8] 
#confusion = confusion_matrix(y_true, y_pred)#ValueError: multilabel-indicator is not supported 
      
confusion = confusion_matrix(y_true.argmax(axis=1), y_pred.argmax(axis=1)) 
# 绘制热度图 
plt.imshow(confusion, cmap=plt.cm.Greens) 
indices = range(len(confusion)) 
#plt.xticks(indices, classes, fontproperties=zhfont) 
#plt.yticks(indices, classes, fontproperties=zhfont) 
      
plt.xticks(indices, classes) 
plt.yticks(indices, classes) 
plt.colorbar() 
plt.xlabel('y_pred') 
plt.ylabel('y_true') 
      
# 显示数据 
for first_index in range(len(confusion)): 
    for second_index in range(len(confusion[first_index])): 
        plt.text(first_index, second_index, confusion[first_index][second_index]) 
      
# 显示图片 
plt.show()
# Out:
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(133, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=133, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# NFM(
#   (bi_BN): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_num): BatchNorm1d(133, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear1): Linear(in_features=133, out_features=800, bias=True)
#   (bn1): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop1): Dropout(p=0.5, inplace=False)
#   (relu1): ReLU()
#   (linear2): Linear(in_features=810, out_features=50, bias=True)
#   (bn2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop2): Dropout(p=0.5, inplace=False)
#   (relu2): ReLU()
#   (linear3): Linear(in_features=50, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
# )
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:56: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:699: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:56: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:699: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:159: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# f1_score:  %.4f 0.8777558085218882
# accuracy_score: 0.85
# recall_score: 0.8561099718994456
# pre_recall: 0.9180825528864744
# n_classes: 9
