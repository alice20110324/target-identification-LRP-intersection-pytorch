# %%
#for 20_genes
import pandas as pd 
import numpy as np
mlp_20_path='results_genes/MLP/contri_20_names_df_all_samples.csv'
nfm_layer_20_path='results_genes/NFM_layer_2/contri_20_names_df_all_samples.csv'


mlp_20_df=pd.read_csv(mlp_20_path,sep=',')
nfm_layer_20_df=pd.read_csv(nfm_layer_20_path,sep=',')

#print(mlp_20_df)
mlp_20_df=mlp_20_df.iloc[:,1:]
nfm_layer_20_df=nfm_layer_20_df.iloc[:,1:]
#print(mlp_20_df.shape)
mlp_20_np=np.array(mlp_20_df)
nfm_layer_20_np=np.array(nfm_layer_20_df)

#print(mlp_20_np)


import csv
csv_filename = "results_genes/intersections/intersecions_20_df_all_samples.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    #writer.writerow(result_list)

    #intersections_20_list=[]
    for i in range(9):
        mlp_data=mlp_20_np[i,:].tolist()
        nfm_data=nfm_layer_20_np[i,:].tolist()
    
        # 将列表转换为集合
        mlp_set = set(mlp_data)
        nfm_set = set(nfm_data)

        # 求交集
        intersection = mlp_set.intersection(nfm_set)

        # 将交集转换回列表
        intersection_list = list(intersection)
        print('intersecion_list:',intersection_list)
        writer.writerow(intersection_list)
        #intersections_20_list.append(intersection_list)
#print('len:',len(intersections_20_list))    
file.close()    
#intersections_20_np=np.array(intersections_20_list)  
#intersections_20_df=pd.DataFrame(intersections_20_np)
#intersections_20_df.to_csv('results_genes/intersections/intersecions_20_df.csv')
# Out:
# intersecion_list: ['GPX3', 'IFI6', 'PTP4A1', 'GDF15', 'LYPLA1', 'RHOB', 'AHCYL1', 'PCK1', 'KLF6', 'CYP39A1', 'ABCB7', 'ADPRM']
# intersecion_list: ['IFI6', 'LHPP', 'RGS5', 'CHP1', 'CTSG', 'ZNHIT1', 'MEST', 'AGL', 'LGMN', 'RPS27L', 'CYP2J2', 'NDUFA13', 'MST1L', 'CPVL']
# intersecion_list: ['EPM2AIP1', 'ACVR1B', 'TFAP2A', 'ACTA2', 'ACP6', 'NEAT1', 'TRA2A', 'MRPS15', 'CAMLG', 'ISCU', 'MEST', 'METTL9', 'VTCN1', 'VDR', 'TUBA4B', 'CFLAR']
# intersecion_list: ['TESC', 'FST', 'SLC3A2', 'BHLHE40', 'KLF9', 'ATP6V1F', 'BCCIP', 'TYMP']
# intersecion_list: ['WASHC3', 'COX15', 'LYPLA1', 'ABLIM3', 'TMEM100', 'ITGB3BP', 'RPL38', 'LARP1', 'GLB1L', 'FKBP4', 'WDR12']
# intersecion_list: ['IFI6', 'IFIT1', 'BHLHE40', 'DEPTOR', 'LIPC', 'RRM2', 'OLFML3', 'LGMN', 'PTMS', 'COL4A3BP', 'MRPS16', 'ATP5IF1']
# intersecion_list: ['NDUFB1', 'SERPINF1', 'PTP4A1', 'PLIN3', 'UCHL1', 'SPI1', 'ABLIM1', 'BDKRB2', 'ADI1', 'CAMLG', 'ZNHIT1', 'ABHD2', 'ACAD10', 'RGN', 'WASHC4']
# intersecion_list: ['IFI6', 'CGREF1', 'GPX2', 'CFB', 'CD163', 'IGLV2-14', 'KLF9', 'ABCC3', 'SH3BP2', 'UGDH', 'METTL9', 'SERPINA3', 'ATP6V1F', 'BCCIP', 'CPVL']
# intersecion_list: ['TFAM', 'GPX3', 'ALB', 'IFI6', 'TRIM14', 'MS4A4A', 'IFIT1', 'ABLIM1', 'DEPTOR', 'LGMN', 'MAP3K1', 'MRPS16', 'NDUFA13', 'CPVL']

# %%
#compute unions for  the intersections_20_df of every class 
#intersections_20_df=pd.read_csv('results_genes/intersections/intersecions_20_df.csv',sep=',')
#from chartGPT of the following code
#intersections_20_df=intersections_20_df.iloc[:,1:]
#print(intersections_20_df)
#intersections_20_np=np.array(intersections_20_df)


result = set()
import csv
csv_filename = "results_genes/intersections/intersecions_20_df_all_samples.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='r', newline='') as csvfile:
    csv_reader = csv.reader(csvfile)
    # 逐行读取数据
    for row in csv_reader:
        row_set=set(row)
        result=result.union(row_set)
        
        

# 或者使用集合的union方法的更简洁写法，使用集合解析
# result = set().union(*list_of_lists)

# 或者使用 | 运算符
# result = set().union(*list_of_lists)

# 将结果转回列表
result_list = list(result)

print(len(result_list))

import csv
csv_filename = "results_genes/intersections/genes_intersections_20_all_samples.csv"

# 使用CSV模块保存列表为CSV文件#妙
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    writer.writerow(result_list)

#这将输出所有列表的并集，不包含重复的元素。在这个例子中，结果会是 [1, 2, 3, 4, 5, 6, 7]。你可以根据你的实际需求将这个结果转换为列表或者保留为集合，具体取决于你的应用场景。
#抽取训练集和测试集中的数据

#生成新选取元素的数据集
train_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/train_val_info.csv'
test_path='dataset/qiuguan/origin_800/xiaoqiu_xiaoguan/test_info.csv'

train_df=pd.read_csv(train_path,sep=',')


train_df=train_df.iloc[:,1:]


columns=result_list
columns.append('label')
print('columns:',columns)


train_df2=train_df[columns]
print(train_df2.shape)
train_df2.to_csv('results_genes/intersections/dataset/train_val_info_all_samples.csv')

test_df=pd.read_csv(test_path,sep=',')

test_df=test_df.iloc[:,1:]



test_df=test_df[columns]
print(test_df.shape)
test_df.to_csv('results_genes/intersections/dataset/test_info_all_samples.csv')
# Out:
# 93
# columns: ['ACVR1B', 'ACP6', 'UCHL1', 'ABLIM1', 'ITGB3BP', 'ADI1', 'WASHC4', 'FST', 'GPX3', 'LHPP', 'GDF15', 'CD163', 'ZNHIT1', 'ISCU', 'METTL9', 'ABHD2', 'VDR', 'UGDH', 'ATP5IF1', 'CGREF1', 'TFAP2A', 'IGLV2-14', 'PCK1', 'DEPTOR', 'OLFML3', 'CYP39A1', 'GLB1L', 'BCCIP', 'SLC3A2', 'FKBP4', 'EPM2AIP1', 'COX15', 'AHCYL1', 'BHLHE40', 'BDKRB2', 'CHP1', 'LGMN', 'CYP2J2', 'NDUFB1', 'SERPINF1', 'ALB', 'MS4A4A', 'TRIM14', 'LYPLA1', 'SPI1', 'LIPC', 'CTSG', 'RPL38', 'SH3BP2', 'ABCB7', 'ADPRM', 'TUBA4B', 'RGN', 'NDUFA13', 'PTP4A1', 'ACTA2', 'IFIT1', 'RGS5', 'ABLIM3', 'MAP3K1', 'COL4A3BP', 'RPS27L', 'MRPS16', 'ACAD10', 'ATP6V1F', 'WDR12', 'SERPINA3', 'CPVL', 'TESC', 'TFAM', 'WASHC3', 'GPX2', 'RHOB', 'RRM2', 'KLF9', 'ABCC3', 'KLF6', 'MRPS15', 'VTCN1', 'TYMP', 'IFI6', 'PLIN3', 'CFB', 'TMEM100', 'NEAT1', 'TRA2A', 'CAMLG', 'MEST', 'AGL', 'CFLAR', 'PTMS', 'LARP1', 'MST1L', 'label']
# (549, 94)
# (138, 94)

# %%
import torch
import Trainer
from network import NFM
import torch.utils.data as Data
from Utils.criteo_loader import getTestData, getTrainData

nfm_config = \
{
    'n_class':9,
    'linear_hidden1':2000,
    #'linear_hidden':100,#线性模型输出层（隐层个数）
    #'embed_input_dim':1001,#embed输入维度
    #'embed_dim': 100, # 用于控制稀疏特征经过Embedding层后的稠密特征大小，embed输出维度
    #'dnn_hidden_units': [100,11],#MLP隐层和输出层
    
    'dnn_hidden_units':[100,9],#MLP隐层
    'num_sparse_features_cols':10477,#the number of the gene columns
    'num_dense_features': 0,#dense features number
    'bi_dropout': 0.5,#Bi-Interaction 的dropout
    'num_epoch': 500,#训练epoch次数
    'batch_size': 16,#batch_size
    'lr': 1e-3,
    'l2_regularization': 1e-4,
    'device_id': 0,
    'use_cuda': False,
    'epoch':1000,
    
    #'train_file': '../Data/criteo/processed_data/train_set.csv',
    #'fea_file': '../Data/criteo/processed_data/fea_col.npy',
    #'validate_file': '../Data/criteo/processed_data/val_set.csv',
    #'test_file': '../Data/criteo/processed_data/test_set.csv',
    #'model_name': '../TrainedModels/NFM.model'
    #'train_file':'data/xiaoqiu_gene_5000/train/final_5000_encode_100x.csv',
    #'train_data':'dataset/qiuguan/encode/encode_1000/train/train_encode_data_1000_new.csv',
    #'train_label':'dataset/qiuguan/non_code/train/train_label.csv',
    #'guan_test_data':'dataset/qiuguan/non_code/guan_test/guan_test_data.csv',
    #'guan_test_label':'dataset/qiuguan/non_code/guan_test/guan_test_label.csv',
    #'test_data':'dataset/qiuguan/encode/encode_1000/test/test_encode_data_1000_new.csv',
    #'test_label':'dataset/qiuguan/non_code/test/test_labels.csv',
    #'title':'dataset/xiaoguan/RF/RF_for_train/train_class_9/test/test_data.csv',
    
    #'all':''
    #'title':'data/xiaoqiu_gene_5000/train/gene_5000_gene_name.csv',
    #'all':'data/xiaoqiu_gene_5000/train/gene_5000_label_name.csv'
}

#model definition
import torch.nn as nn
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(3300)
        self.fc1 = nn.Linear(3300, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model = MLP().cuda()
print(model)

class MLP1(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(237)
        self.fc1 = nn.Linear(237, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model1 = MLP1().cuda()
print(model1)
class MLP2(nn.Module):
    def __init__(self):
        super().__init__()
        self.bn0=nn.BatchNorm1d(93)
        self.fc1 = nn.Linear(93, 2000)
        self.bn1= nn.BatchNorm1d(2000)
        self.fc2 = nn.Linear(2000, 100)
        self.bn2=nn.BatchNorm1d(100)
        self.fc3=nn.Linear(100,9)
        self.bn3=nn.BatchNorm1d(9)
        
        self.drop=nn.Dropout(0.5)
    def forward(self, x):
        x=self.bn0(x)
        x = F.relu(self.drop(self.bn1(self.fc1(x))))
        x = F.relu(self.drop(self.bn2(self.fc2(x))))
        return F.softmax(self.bn3(self.fc3(x)), dim=1)
model2 = MLP2().cuda()
print(model2)
import os
import time
import argparse
import numpy as np
import pandas as pd 

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import torch.nn.functional as F  # 激励函数的库
#import network
import config
import evaluate
import data_utils
#import Trainer



def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    #n = len(labels)
    n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output

def one_hot(labels, classes):
    n = len(labels)
    #eoff = label_smoothing / classes
    output = np.zeros((n, classes), dtype=np.float32)
    for row, label in enumerate(labels):
        output[row, label] = 1
        #print("row:",row,"label:",label)
    return output


def one_hot_smoothing(labels, classes, label_smoothing=0.2):
    #n = len(labels)
    n=labels.shape[0]
    eoff = label_smoothing / classes
    output = np.ones((n, classes), dtype=np.float32) * eoff
    for row, label in enumerate(labels):
        output[row, label] = 1 - label_smoothing + eoff
        #print("row:",row,"label:",label)
    return output

def one_hot(labels, classes):
    n = len(labels)
    #eoff = label_smoothing / classes
    output = np.zeros((n, classes), dtype=np.float32)
    for row, label in enumerate(labels):
        output[row, label] = 1
        #print("row:",row,"label:",label)
    return output



class KZDatasetPredict(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, df_list):
    
       
        self.data_info = self.get_data_info(df_list)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data,label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data,label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,df_list):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        print('data_info:',df_list[-1])
        #df=pd.read_csv(csv_path,sep=',')
        #df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        label=int(df_list[-1])
        labels.append(label)
        print('labels:',labels)
        data=df_list[:-1]
        #df_np=np.array(df_list)
        #print(rows,cols)
        
        #print('labels:',labels)
        labels=np.array(labels)
        print('labels.shape:',labels.shape)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        
           
        
        data=np.array(data)#
            
            
            
            
            
            
            
            
        data=torch.from_numpy(data)#
            
        labels=torch.from_numpy(labels)#
        #bi_data=embding_process(nfm_config,data)
        #print("bi_data.shape:",bi_data.shape)
            
            
        data_info.append((data,label))
        return data_info
class KZDatasetTest(data.Dataset):
    """ Construct the FM pytorch dataset. """
    #def __init__(self, file,label_file, feature_map,n_class=16):
    def __init__(self, csv_path):
    
       
        self.data_info = self.get_data_info(csv_path)
        
        
            
        
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, label

    def __len__(self):
        return len(self.data_info)
   
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]
            data=data.astype(float)#
            data=np.array(data)#
            
            label=labels[i]
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            label=torch.from_numpy(label)#
            
            
            data_info.append((data,label))
        return data_info
import torch
import torch.nn as nn
from torch.utils.data.dataset import *
from PIL import Image
from torch.nn import functional as F
import random
from sklearn.model_selection import train_test_split
import ast
import torchvision


        

class KZDataset(Dataset):
    def __init__(self, csv_path, K,n_class,ki=0, typ='train', transform=None, rand=False):
       
        self.all_data_info = self.get_data_info(csv_path)
        
        if rand:
            random.seed(1)
            random.shuffle(self.all_data_info)
        leng = len(self.all_data_info)
        every_z_len = leng // K
        if typ == 'val':
            self.data_info = self.all_data_info[every_z_len * ki : every_z_len * (ki+1)]
        elif typ == 'train':
            self.data_info = self.all_data_info[: every_z_len * ki] + self.all_data_info[every_z_len * (ki+1) :]
            
        self.transform = transform
        
        

    def __getitem__(self, index):
        # Dataset读取图片的函数
        data, label = self.data_info[index]
        #img = Image.open(img_pth).convert('RGB')
        
        return data, label

    def __len__(self):
        return len(self.data_info)
    
    
    
    def get_data_info(self,csv_path):
        #解析路径
        #转为一维list存储，每一位为【图片路径，图片类别】
        labels=[]
        data_info=[]
        df=pd.read_csv(csv_path,sep=',')
        df=df.iloc[:,1:]
        
        #print(df.iloc[:,-1])
        #df=df.applymap(ast.literal_eval)
        rows,cols=df.shape
        
        print(rows,cols)
        for i in df.iloc[:,-1]:
            #print(i)
            labels.append(int(i))
        #print('labels:',labels)
        labels=np.array(labels)
        #print('labels:',labels)
        #labels=np.array(labels)
        labels=one_hot_smoothing(labels,nfm_config['n_class'])
        #print(labels)
        for i in range(rows):
            data=df.iloc[i,:-1]
            data=data.astype(float)#
            data=np.array(data)#
            
            label=labels[i]
            #print(data.shape)
            #print(label.shape)
            #label=label.tolist()
            data=torch.from_numpy(data)#
            label=torch.from_numpy(label)#
            
            
            data_info.append((data,label))
        return data_info
            
from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics

from torch.autograd import Variable
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score
from new_nfm_network import NFM
import os
import time
import argparse
import numpy as np
import pandas as pd 
import sys

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
import torch.backends.cudnn as cudnn
#3from tensorboardX import SummaryWriter
import sys 
#import network
import config
import evaluate
import data_utils
import Trainer
import torchmetrics


def train_epoch(model,train_loader,batch_size,optimizer,loss_func):
    BATCH_SIZE=batch_size
    total = 0
    correct=0
    total_loss=0
    #
    model.train()
    total_train_accuracy=0  
    for batch_idx, (x, labels) in enumerate(train_loader):
            
        labels = Variable(labels)
        x = Variable(x)
            
            
        x=torch.tensor(x,dtype=torch.float)
        labels=torch.tensor(labels,dtype=torch.float)
        x, labels = x.cuda(), labels.cuda()
        labels_int=labels=torch.max(labels,1)[1]
            
            
        optimizer.zero_grad()
        y_predict = model(x)
            
        loss = loss_func(y_predict, labels)
        loss.backward()
        optimizer.step()
            
        loss = loss.item()
           

        total_loss += loss
            
            
            
        batch_train_acc=torchmetrics.functional.accuracy(y_predict,labels_int)
        total_train_accuracy+=batch_train_acc
            
    total_train_accuracy/=(batch_idx+1)
    print('total_train_accuracy:',total_train_accuracy)
    print("Training Epoch: %d, total loss: %f" % (epoch_id, total_loss))
    return total_loss,total_train_accuracy

def val_epoch(model,test_loader,batch_size,optimizer): 
    batch_size_num=0
    total_test_acc=0
    model.eval()
    for i , (inputs , targets) in enumerate(test_loader):   
            print("test")
            
            inputs = Variable(inputs)   
            targets = Variable(targets)     
           
            inputs=torch.tensor(inputs ,dtype=torch.float)   
            targets=torch.tensor(targets ,dtype=torch.float)   
            inputs , targets = inputs.cuda(),  targets.cuda()   
            yhat = model(inputs)  
            
            
            
            targets=torch.max(targets,1)[1]
            
            
            
            batch_test_acc=torchmetrics.functional.accuracy(yhat,targets)
            
            total_test_acc+=batch_test_acc
            
            batch_size_num=i
    total_test_acc/=(batch_size_num+1)
        ###print('total_test_accuracy:',total_test_acc/(batch_size+1))
    print('total_test_accuracy:',total_test_acc)
        
                    
                    
            
            
    
        
   
    
    return total_test_acc


import numpy as np
import math
import matplotlib.pyplot as plt

def plotLoss(loss,epoch):
    plt.rcParams['font.sans-serif']=['SimHei']
    plt.rcParams['axes.unicode_minus'] = False
    plt.figure(figsize=(8, 5))
    x=[i for i in range(epoch)]
    #acc_train=acc_train.cpu()
    #acc_test=acc_test.cpu()
    plt.plot(x, loss, 'r-', mec='k', label='Logistic Loss', lw=2)
    #plt.plot(x,acc_train,'b-',mec='k',label='accuracy Train',lw=2)
    #plt.plot(x,acc_test,'g-',mec='k',label='accuracy Test',lw=2)
    #plt.plot(x, y_01, 'g-', mec='k', label='0/1 Loss', lw=2)
    #plt.plot(x, y_hinge, 'b-',mec='k', label='Hinge Loss', lw=2)
    #plt.plot(x, boost, 'm--',mec='k', label='Adaboost Loss',lw=2)
    plt.grid(True, ls='--')
    plt.legend(loc='upper right')
    plt.title('损失函数')
    plt.show()
# Out:
# MLP(
#   (bn0): BatchNorm1d(3300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=3300, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP1(
#   (bn0): BatchNorm1d(237, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=237, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# MLP2(
#   (bn0): BatchNorm1d(93, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=93, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )

# %%
#train model with new features of 94
model=model2
K=10
test_metrics=[]
train_loss_total_list=[]
for ki in range(K):
    trainset = KZDataset(csv_path='results_genes/intersections/dataset/train_val_info_all_samples.csv',K=K, n_class=nfm_config['n_class'],ki=ki,  typ='train', transform=None, rand=True)
    valset = KZDataset(csv_path='results_genes/intersections/dataset/train_val_info_all_samples.csv', K=K,n_class=nfm_config['n_class'],ki=ki,  typ='val', transform=None, rand=True)
    train_loader = data.DataLoader(
         dataset=trainset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size'],
         shuffle=True)
    val_loader = data.DataLoader(
         dataset=valset,
         #transform=torchvision.transforms.ToTensor(),
         drop_last=True,
         batch_size=nfm_config['batch_size']
        
     )
    
    model_path='results_genes/intersections/models/all_samples/'
    #BATCH_SIZE=batch_size
    optimizer = torch.optim.Adam(model.parameters(), lr=nfm_config['lr'], weight_decay=nfm_config['l2_regularization'])
    #total = 0
    
    
    loss_func=torch.nn.CrossEntropyLoss()
    
    num=0
   
    
    epoches=101
    for epoch_id in range(epoches):
          
        
        
        train_loss_total,acc_train=train_epoch(model,train_loader,nfm_config['batch_size'],optimizer,loss_func)
        train_loss_total_list.append(train_loss_total)#
        if epoch_id %20==0:
            num=num+1
            #path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pkl')
            #torch.save(model.state_dict(),path)
            # 保存模型
            
            path=os.path.join(model_path,'MLP'+str(num)+str(K)+'.pt')##################pt
            torch.save(model.state_dict(),path)
            #torch.save(model.state_dict(),path)
    print("the ",ki," epoch ends")
    plotLoss(train_loss_total_list,epoches)
    train_loss_total_list=[]
    acc_test=val_epoch(model,val_loader,nfm_config['batch_size'],optimizer)
    print("acc_test_each_k:",acc_test)
    test_metrics.append(acc_test)

print(test_metrics)
#test_metrics=test_metrics.tolist()
test_metrics=[x.cpu().detach().numpy() for x in test_metrics]
print(test_metrics)
acc_test_metrics=np.mean(test_metrics) 
print("acc_test_metrics:",acc_test_metrics)
# Out:
# 549 94
# 549 94
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:450: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:451: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# total_train_accuracy: tensor(0.2708, device='cuda:0')
# Training Epoch: 0, total loss: 63.668788
# total_train_accuracy: tensor(0.4708, device='cuda:0')
# Training Epoch: 1, total loss: 60.912796
# total_train_accuracy: tensor(0.5958, device='cuda:0')
# Training Epoch: 2, total loss: 59.166575
# total_train_accuracy: tensor(0.6500, device='cuda:0')
# Training Epoch: 3, total loss: 57.893565
# total_train_accuracy: tensor(0.6833, device='cuda:0')
# Training Epoch: 4, total loss: 57.037323
# total_train_accuracy: tensor(0.7125, device='cuda:0')
# Training Epoch: 5, total loss: 56.396883
# total_train_accuracy: tensor(0.7521, device='cuda:0')
# Training Epoch: 6, total loss: 55.221956
# total_train_accuracy: tensor(0.7479, device='cuda:0')
# Training Epoch: 7, total loss: 55.256394
# total_train_accuracy: tensor(0.7938, device='cuda:0')
# Training Epoch: 8, total loss: 54.404666
# total_train_accuracy: tensor(0.7833, device='cuda:0')
# Training Epoch: 9, total loss: 54.124977
# total_train_accuracy: tensor(0.8000, device='cuda:0')
# Training Epoch: 10, total loss: 53.810310
# total_train_accuracy: tensor(0.7958, device='cuda:0')
# Training Epoch: 11, total loss: 52.924653
# total_train_accuracy: tensor(0.7750, device='cuda:0')
# Training Epoch: 12, total loss: 53.587236
# total_train_accuracy: tensor(0.8104, device='cuda:0')
# Training Epoch: 13, total loss: 52.958915
# total_train_accuracy: tensor(0.8354, device='cuda:0')
# Training Epoch: 14, total loss: 52.104620
# total_train_accuracy: tensor(0.8271, device='cuda:0')
# Training Epoch: 15, total loss: 52.281665
# total_train_accuracy: tensor(0.8229, device='cuda:0')
# Training Epoch: 16, total loss: 51.890497
# total_train_accuracy: tensor(0.8167, device='cuda:0')
# Training Epoch: 17, total loss: 52.032637
# total_train_accuracy: tensor(0.8500, device='cuda:0')
# Training Epoch: 18, total loss: 51.798894
# total_train_accuracy: tensor(0.8396, device='cuda:0')
# Training Epoch: 19, total loss: 51.141573
# total_train_accuracy: tensor(0.8375, device='cuda:0')
# Training Epoch: 20, total loss: 51.139336
# total_train_accuracy: tensor(0.8604, device='cuda:0')
# Training Epoch: 21, total loss: 50.748201
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 22, total loss: 50.228982
# total_train_accuracy: tensor(0.8521, device='cuda:0')
# Training Epoch: 23, total loss: 50.575328
# total_train_accuracy: tensor(0.8438, device='cuda:0')
# Training Epoch: 24, total loss: 50.316640
# total_train_accuracy: tensor(0.8604, device='cuda:0')
# Training Epoch: 25, total loss: 50.109068
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 26, total loss: 49.625121
# total_train_accuracy: tensor(0.8604, device='cuda:0')
# Training Epoch: 27, total loss: 49.737994
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 28, total loss: 48.865958
# total_train_accuracy: tensor(0.8458, device='cuda:0')
# Training Epoch: 29, total loss: 49.717264
# total_train_accuracy: tensor(0.8729, device='cuda:0')
# Training Epoch: 30, total loss: 49.117323
# total_train_accuracy: tensor(0.8688, device='cuda:0')
# Training Epoch: 31, total loss: 48.816710
# total_train_accuracy: tensor(0.8667, device='cuda:0')
# Training Epoch: 32, total loss: 49.616431
# total_train_accuracy: tensor(0.8938, device='cuda:0')
# Training Epoch: 33, total loss: 48.764185
# total_train_accuracy: tensor(0.9021, device='cuda:0')
# Training Epoch: 34, total loss: 48.575072
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 35, total loss: 47.982584
# total_train_accuracy: tensor(0.8792, device='cuda:0')
# Training Epoch: 36, total loss: 48.542944
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 37, total loss: 48.598801
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 38, total loss: 48.124212
# total_train_accuracy: tensor(0.8833, device='cuda:0')
# Training Epoch: 39, total loss: 48.377193
# total_train_accuracy: tensor(0.8896, device='cuda:0')
# Training Epoch: 40, total loss: 48.407288
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 41, total loss: 48.112159
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 42, total loss: 48.262894
# total_train_accuracy: tensor(0.8854, device='cuda:0')
# Training Epoch: 43, total loss: 48.060442
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 44, total loss: 47.927466
# total_train_accuracy: tensor(0.8813, device='cuda:0')
# Training Epoch: 45, total loss: 47.943278
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 46, total loss: 47.609962
# total_train_accuracy: tensor(0.8813, device='cuda:0')
# Training Epoch: 47, total loss: 48.124492
# total_train_accuracy: tensor(0.8708, device='cuda:0')
# Training Epoch: 48, total loss: 48.152838
# total_train_accuracy: tensor(0.9104, device='cuda:0')
# Training Epoch: 49, total loss: 47.442882
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 50, total loss: 47.510626
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 51, total loss: 47.766870
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 52, total loss: 46.777849
# total_train_accuracy: tensor(0.8771, device='cuda:0')
# Training Epoch: 53, total loss: 47.751825
# total_train_accuracy: tensor(0.8958, device='cuda:0')
# Training Epoch: 54, total loss: 47.314674
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 55, total loss: 47.131610
# total_train_accuracy: tensor(0.8979, device='cuda:0')
# Training Epoch: 56, total loss: 47.075884
# total_train_accuracy: tensor(0.9063, device='cuda:0')
# Training Epoch: 57, total loss: 46.960584
# total_train_accuracy: tensor(0.8875, device='cuda:0')
# Training Epoch: 58, total loss: 47.382318
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 59, total loss: 46.616833
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 60, total loss: 46.898966
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 61, total loss: 46.336779
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 62, total loss: 46.548499
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 63, total loss: 46.556707
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 64, total loss: 46.101594
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 65, total loss: 46.628130
# total_train_accuracy: tensor(0.8917, device='cuda:0')
# Training Epoch: 66, total loss: 47.037809
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 67, total loss: 45.984188
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 68, total loss: 46.259841
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 69, total loss: 45.652521
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 70, total loss: 46.187880
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 71, total loss: 46.578352
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 72, total loss: 46.089281
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 73, total loss: 46.916754
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 74, total loss: 46.487284
# total_train_accuracy: tensor(0.9271, device='cuda:0')
# Training Epoch: 75, total loss: 45.557052
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 76, total loss: 45.575134
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 77, total loss: 45.528799
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 78, total loss: 45.105785
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 79, total loss: 45.491849
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 80, total loss: 46.265003
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 81, total loss: 46.076831
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 82, total loss: 45.659155
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 83, total loss: 45.830791
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 84, total loss: 45.807028
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 85, total loss: 45.915931
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 86, total loss: 45.284552
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 87, total loss: 46.433739
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 88, total loss: 45.384309
# total_train_accuracy: tensor(0.9167, device='cuda:0')
# Training Epoch: 89, total loss: 45.905650
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 90, total loss: 45.393330
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 91, total loss: 45.705415
# total_train_accuracy: tensor(0.9250, device='cuda:0')
# Training Epoch: 92, total loss: 45.709970
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 93, total loss: 45.116596
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 94, total loss: 45.434382
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 95, total loss: 45.291493
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 96, total loss: 45.514322
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 97, total loss: 44.793976
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 98, total loss: 45.708052
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 99, total loss: 44.879140
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 100, total loss: 44.540814
# the  0  epoch ends
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25439 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22833 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/anaconda3/envs/new_pytorch/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:488: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:489: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# test
# test
# test
# total_test_accuracy: tensor(0.8750, device='cuda:0')
# acc_test_each_k: tensor(0.8750, device='cuda:0')
# 549 94
# 549 94
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 0, total loss: 45.575938
# total_train_accuracy: tensor(0.9042, device='cuda:0')
# Training Epoch: 1, total loss: 46.195501
# total_train_accuracy: tensor(0.9083, device='cuda:0')
# Training Epoch: 2, total loss: 45.794076
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 3, total loss: 45.199595
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 4, total loss: 45.686677
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 5, total loss: 44.856549
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 6, total loss: 45.358136
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 7, total loss: 45.598533
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 8, total loss: 45.093125
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 9, total loss: 45.006022
# total_train_accuracy: tensor(0.9229, device='cuda:0')
# Training Epoch: 10, total loss: 45.502516
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 11, total loss: 44.967153
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 12, total loss: 44.926749
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 13, total loss: 45.134528
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 14, total loss: 44.829862
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 15, total loss: 44.356400
# total_train_accuracy: tensor(0.9292, device='cuda:0')
# Training Epoch: 16, total loss: 45.143611
# total_train_accuracy: tensor(0.9125, device='cuda:0')
# Training Epoch: 17, total loss: 45.471129
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 18, total loss: 44.747218
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 19, total loss: 44.690389
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 20, total loss: 44.571028
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 21, total loss: 44.965438
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 22, total loss: 44.748419
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 23, total loss: 45.119392
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 24, total loss: 44.685722
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 25, total loss: 44.717327
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 26, total loss: 44.407727
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 27, total loss: 44.734329
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 28, total loss: 44.260700
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 29, total loss: 44.181481
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 30, total loss: 44.609299
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 31, total loss: 44.014770
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 32, total loss: 44.395237
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 33, total loss: 44.125452
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 34, total loss: 44.737617
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 35, total loss: 44.182851
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 36, total loss: 44.291008
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 37, total loss: 44.431517
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 38, total loss: 44.432488
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 39, total loss: 44.729933
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 40, total loss: 44.221802
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 41, total loss: 44.073106
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 42, total loss: 43.813007
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 43, total loss: 44.518801
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 44, total loss: 44.019427
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 45, total loss: 44.827870
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 46, total loss: 43.967475
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 47, total loss: 43.686856
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 48, total loss: 44.036219
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 49, total loss: 43.897760
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 50, total loss: 43.873447
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 51, total loss: 44.011550
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 52, total loss: 44.550998
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 53, total loss: 44.264487
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 54, total loss: 44.356442
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 55, total loss: 44.011054
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 56, total loss: 43.494153
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 57, total loss: 43.841972
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 58, total loss: 44.313859
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 59, total loss: 43.921059
# total_train_accuracy: tensor(0.9313, device='cuda:0')
# Training Epoch: 60, total loss: 44.689884
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 61, total loss: 43.758348
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 62, total loss: 43.569943
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 63, total loss: 43.799628
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 64, total loss: 43.797809
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 65, total loss: 44.332339
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 66, total loss: 43.761231
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 67, total loss: 44.309152
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 68, total loss: 43.689103
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 69, total loss: 43.609178
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 70, total loss: 44.149343
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 71, total loss: 43.437096
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 72, total loss: 44.309721
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 73, total loss: 43.843989
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 74, total loss: 43.799330
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 75, total loss: 43.727666
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 76, total loss: 43.416260
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 77, total loss: 43.528383
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 78, total loss: 43.566289
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 79, total loss: 43.869317
# total_train_accuracy: tensor(0.9188, device='cuda:0')
# Training Epoch: 80, total loss: 44.591314
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 81, total loss: 44.098633
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 82, total loss: 43.472089
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 83, total loss: 43.904641
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 84, total loss: 43.222971
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 85, total loss: 43.354138
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 86, total loss: 43.022797
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 87, total loss: 43.699638
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 88, total loss: 43.848430
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 89, total loss: 43.519967
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 90, total loss: 43.637677
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 91, total loss: 43.443272
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 92, total loss: 43.659990
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 93, total loss: 43.373761
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 94, total loss: 43.374063
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 95, total loss: 43.435109
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 96, total loss: 43.258408
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 97, total loss: 44.392097
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 98, total loss: 44.091960
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 99, total loss: 43.968781
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 100, total loss: 44.039553
# the  1  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(0.9583, device='cuda:0')
# acc_test_each_k: tensor(0.9583, device='cuda:0')
# 549 94
# 549 94
# total_train_accuracy: tensor(0.9375, device='cuda:0')
# Training Epoch: 0, total loss: 44.157577
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 1, total loss: 43.852978
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 2, total loss: 44.095510
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 3, total loss: 43.804460
# total_train_accuracy: tensor(0.9208, device='cuda:0')
# Training Epoch: 4, total loss: 44.456156
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 5, total loss: 43.207760
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 6, total loss: 43.609808
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 7, total loss: 43.286813
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 8, total loss: 43.307094
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 9, total loss: 43.538794
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 10, total loss: 43.406003
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 11, total loss: 43.493485
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 12, total loss: 43.272608
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 13, total loss: 43.763335
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 14, total loss: 43.884713
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 15, total loss: 43.081048
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 16, total loss: 43.782334
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 17, total loss: 44.122056
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 18, total loss: 43.047999
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 19, total loss: 43.968899
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 20, total loss: 43.342582
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 21, total loss: 43.062531
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 22, total loss: 43.345309
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 23, total loss: 43.414964
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 24, total loss: 43.114602
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 25, total loss: 43.149655
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 26, total loss: 43.699022
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 27, total loss: 43.244381
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 28, total loss: 43.281672
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 29, total loss: 43.697545
# total_train_accuracy: tensor(0.9146, device='cuda:0')
# Training Epoch: 30, total loss: 44.534692
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 31, total loss: 43.483028
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 32, total loss: 43.019459
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 33, total loss: 43.362804
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 34, total loss: 43.691406
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 35, total loss: 43.001326
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 36, total loss: 43.357262
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 37, total loss: 42.975919
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 38, total loss: 43.398317
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 39, total loss: 43.049396
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 40, total loss: 42.953165
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 41, total loss: 42.881819
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 42, total loss: 43.029381
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 43, total loss: 43.305201
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 44, total loss: 43.172128
# total_train_accuracy: tensor(0.9396, device='cuda:0')
# Training Epoch: 45, total loss: 43.649909
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 46, total loss: 42.835787
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 47, total loss: 43.030249
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 48, total loss: 43.064801
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 49, total loss: 43.365848
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 50, total loss: 43.064029
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 51, total loss: 43.332244
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 52, total loss: 42.802373
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 53, total loss: 43.423373
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 54, total loss: 43.393376
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 55, total loss: 43.389416
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 56, total loss: 43.434080
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 57, total loss: 43.110365
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 58, total loss: 42.842088
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 59, total loss: 42.876091
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 60, total loss: 43.427286
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 61, total loss: 42.772927
# total_train_accuracy: tensor(0.9333, device='cuda:0')
# Training Epoch: 62, total loss: 43.859877
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 63, total loss: 43.075071
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 64, total loss: 42.863200
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 65, total loss: 43.049960
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 66, total loss: 42.689591
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 67, total loss: 43.003153
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 68, total loss: 43.751004
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 69, total loss: 43.006252
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 70, total loss: 42.946469
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 71, total loss: 43.123459
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 72, total loss: 42.953749
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 73, total loss: 43.264590
# total_train_accuracy: tensor(0.9417, device='cuda:0')
# Training Epoch: 74, total loss: 43.721530
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 75, total loss: 42.951043
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 76, total loss: 42.912155
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 77, total loss: 42.999730
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 78, total loss: 43.396640
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 79, total loss: 43.484668
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 80, total loss: 42.802971
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 81, total loss: 43.207796
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 82, total loss: 43.411752
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 83, total loss: 43.514718
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 84, total loss: 43.634706
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 85, total loss: 42.819293
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 86, total loss: 42.930171
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 87, total loss: 43.141289
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 88, total loss: 43.509032
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 89, total loss: 42.739703
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 90, total loss: 43.537761
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 91, total loss: 43.270866
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 92, total loss: 42.935894
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 93, total loss: 42.754410
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 94, total loss: 43.881065
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 95, total loss: 42.753255
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 96, total loss: 43.161952
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 97, total loss: 42.655299
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 98, total loss: 42.921458
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 99, total loss: 43.010418
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 100, total loss: 42.640602
# the  2  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# acc_test_each_k: tensor(1., device='cuda:0')
# 549 94
# 549 94
# total_train_accuracy: tensor(0.9354, device='cuda:0')
# Training Epoch: 0, total loss: 43.866783
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 1, total loss: 43.166543
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 2, total loss: 43.162059
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 3, total loss: 43.159852
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 4, total loss: 43.305540
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 5, total loss: 42.608329
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 6, total loss: 43.260588
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 7, total loss: 43.220803
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 8, total loss: 43.215997
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 9, total loss: 43.278903
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 10, total loss: 42.606869
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 11, total loss: 42.866955
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 12, total loss: 42.457844
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 13, total loss: 42.805539
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 14, total loss: 43.145680
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 15, total loss: 43.224615
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 16, total loss: 43.403894
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 17, total loss: 43.192951
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 18, total loss: 43.081865
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 19, total loss: 42.974791
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 20, total loss: 42.695047
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 21, total loss: 43.130709
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 22, total loss: 43.165299
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 23, total loss: 43.137289
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 24, total loss: 42.635812
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 25, total loss: 42.941874
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 26, total loss: 42.795655
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 27, total loss: 43.217106
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 28, total loss: 42.993258
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 29, total loss: 42.906770
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 30, total loss: 42.875575
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 31, total loss: 43.248365
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 32, total loss: 42.959707
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 33, total loss: 43.299848
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 34, total loss: 42.775453
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 35, total loss: 43.058049
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 36, total loss: 42.771574
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 37, total loss: 43.041083
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 38, total loss: 43.013995
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 39, total loss: 43.386238
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 40, total loss: 43.248532
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 41, total loss: 43.090373
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 42, total loss: 43.047216
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 43, total loss: 43.082212
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 44, total loss: 43.180005
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 45, total loss: 42.505712
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 46, total loss: 42.852280
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 47, total loss: 42.697601
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 48, total loss: 42.901459
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 49, total loss: 42.866666
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 50, total loss: 43.015733
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 51, total loss: 42.940514
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 52, total loss: 42.754809
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 53, total loss: 43.309270
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 54, total loss: 42.697284
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 55, total loss: 42.779188
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 56, total loss: 42.348876
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 57, total loss: 42.360100
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 58, total loss: 43.039516
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 59, total loss: 43.149779
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 60, total loss: 43.016653
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 61, total loss: 42.639515
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 62, total loss: 42.715390
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 63, total loss: 42.926371
# total_train_accuracy: tensor(0.9438, device='cuda:0')
# Training Epoch: 64, total loss: 43.631716
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 65, total loss: 42.975996
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 66, total loss: 43.154058
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 67, total loss: 42.672631
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 68, total loss: 42.808321
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 69, total loss: 42.873580
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 70, total loss: 42.929979
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 71, total loss: 42.672891
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 72, total loss: 42.645877
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 73, total loss: 43.032485
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 74, total loss: 43.191263
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 75, total loss: 42.904693
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 76, total loss: 42.895132
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 77, total loss: 42.971753
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 78, total loss: 42.649591
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 79, total loss: 42.882753
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 80, total loss: 43.182413
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 81, total loss: 43.246898
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 82, total loss: 42.711927
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 83, total loss: 42.851437
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 84, total loss: 42.907307
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 85, total loss: 42.773217
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 86, total loss: 42.990520
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 87, total loss: 42.593598
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 88, total loss: 43.035994
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 89, total loss: 42.825458
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 90, total loss: 42.948586
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 91, total loss: 42.842249
# total_train_accuracy: tensor(0.9479, device='cuda:0')
# Training Epoch: 92, total loss: 43.124328
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 93, total loss: 42.986278
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 94, total loss: 42.897129
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 95, total loss: 42.975611
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 96, total loss: 42.778384
# total_train_accuracy: tensor(0.9958, device='cuda:0')
# Training Epoch: 97, total loss: 41.996678
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 98, total loss: 42.855746
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 99, total loss: 43.095981
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 100, total loss: 42.273107
# the  3  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# acc_test_each_k: tensor(1., device='cuda:0')
# 549 94
# 549 94
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 0, total loss: 42.731940
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 1, total loss: 42.982205
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 2, total loss: 42.789626
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 3, total loss: 42.917300
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 4, total loss: 42.259773
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 5, total loss: 42.565490
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 6, total loss: 42.641341
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 7, total loss: 42.628530
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 8, total loss: 42.610658
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 9, total loss: 42.866049
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 10, total loss: 42.836346
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 11, total loss: 43.021374
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 12, total loss: 42.951159
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 13, total loss: 42.388778
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 14, total loss: 43.132267
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 15, total loss: 42.482116
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 16, total loss: 43.135850
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 17, total loss: 42.938594
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 18, total loss: 42.525343
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 19, total loss: 43.083714
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 20, total loss: 42.754252
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 21, total loss: 42.749094
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 22, total loss: 42.615247
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 23, total loss: 42.421748
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 24, total loss: 42.795756
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 25, total loss: 42.646402
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 26, total loss: 42.525159
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 27, total loss: 42.415178
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 28, total loss: 42.726491
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 29, total loss: 43.304024
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 30, total loss: 42.863693
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 31, total loss: 42.797902
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 32, total loss: 42.993363
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 33, total loss: 42.789220
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 34, total loss: 42.943068
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 35, total loss: 42.883106
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 36, total loss: 42.865358
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 37, total loss: 42.717942
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 38, total loss: 42.633353
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 39, total loss: 42.546018
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 40, total loss: 42.328267
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 41, total loss: 42.350162
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 42, total loss: 42.657582
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 43, total loss: 42.909157
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 44, total loss: 42.682142
# total_train_accuracy: tensor(0.9521, device='cuda:0')
# Training Epoch: 45, total loss: 43.057188
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 46, total loss: 42.772017
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 47, total loss: 42.580336
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 48, total loss: 42.759456
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 49, total loss: 42.455222
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 50, total loss: 42.722890
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 51, total loss: 42.754868
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 52, total loss: 42.484681
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 53, total loss: 42.730047
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 54, total loss: 42.870979
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 55, total loss: 42.849628
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 56, total loss: 43.028641
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 57, total loss: 42.641844
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 58, total loss: 42.587200
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 59, total loss: 43.208203
# ...
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 45, total loss: 42.504387
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 46, total loss: 42.901278
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 47, total loss: 42.221220
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 48, total loss: 42.426922
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 49, total loss: 42.891909
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 50, total loss: 42.266913
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 51, total loss: 42.396244
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 52, total loss: 42.451068
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 53, total loss: 42.293199
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 54, total loss: 42.428043
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 55, total loss: 42.300995
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 56, total loss: 42.882299
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 57, total loss: 42.387235
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 58, total loss: 42.688871
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 59, total loss: 42.669445
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 60, total loss: 42.550383
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 61, total loss: 43.181494
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 62, total loss: 42.489002
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 63, total loss: 42.362576
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 64, total loss: 42.569861
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 65, total loss: 42.693336
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 66, total loss: 42.003295
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 67, total loss: 42.434542
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 68, total loss: 42.448719
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 69, total loss: 42.214516
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 70, total loss: 42.576944
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 71, total loss: 42.660070
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 72, total loss: 42.346438
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 73, total loss: 42.771680
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 74, total loss: 42.567417
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 75, total loss: 42.188486
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 76, total loss: 42.638735
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 77, total loss: 42.577363
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 78, total loss: 42.596730
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 79, total loss: 42.295984
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 80, total loss: 42.186570
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 81, total loss: 42.216091
# total_train_accuracy: tensor(0.9542, device='cuda:0')
# Training Epoch: 82, total loss: 42.717940
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 83, total loss: 42.502951
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 84, total loss: 41.943517
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 85, total loss: 42.177615
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 86, total loss: 41.924087
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 87, total loss: 42.308440
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 88, total loss: 42.631197
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 89, total loss: 42.349103
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 90, total loss: 42.484532
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 91, total loss: 42.255122
# total_train_accuracy: tensor(0.9500, device='cuda:0')
# Training Epoch: 92, total loss: 43.070059
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 93, total loss: 42.399306
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 94, total loss: 42.089235
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 95, total loss: 42.208663
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 96, total loss: 41.872980
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 97, total loss: 42.257688
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 98, total loss: 42.609611
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 99, total loss: 42.353629
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 100, total loss: 42.541798
# the  8  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(1., device='cuda:0')
# acc_test_each_k: tensor(1., device='cuda:0')
# 549 94
# 549 94
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 0, total loss: 42.030627
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 1, total loss: 42.868248
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 2, total loss: 42.389047
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 3, total loss: 42.393721
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 4, total loss: 42.755668
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 5, total loss: 42.177287
# total_train_accuracy: tensor(0.9583, device='cuda:0')
# Training Epoch: 6, total loss: 42.746679
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 7, total loss: 42.723714
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 8, total loss: 42.127072
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 9, total loss: 42.320076
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 10, total loss: 42.312261
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 11, total loss: 42.229162
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 12, total loss: 42.550052
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 13, total loss: 42.451051
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 14, total loss: 42.282885
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 15, total loss: 42.457819
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 16, total loss: 42.213612
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 17, total loss: 42.624657
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 18, total loss: 42.461680
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 19, total loss: 42.494588
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 20, total loss: 42.421188
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 21, total loss: 42.263954
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 22, total loss: 42.327452
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 23, total loss: 42.423266
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 24, total loss: 42.199536
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 25, total loss: 42.342775
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 26, total loss: 42.744728
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 27, total loss: 42.713280
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 28, total loss: 42.490739
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 29, total loss: 42.246763
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 30, total loss: 42.540053
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 31, total loss: 42.384144
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 32, total loss: 42.553369
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 33, total loss: 42.439883
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 34, total loss: 42.345570
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 35, total loss: 42.250913
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 36, total loss: 42.389771
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 37, total loss: 42.205788
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 38, total loss: 42.589257
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 39, total loss: 42.649429
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 40, total loss: 42.490142
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 41, total loss: 42.522519
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 42, total loss: 42.703430
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 43, total loss: 42.544034
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 44, total loss: 42.521411
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 45, total loss: 42.154718
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 46, total loss: 42.278703
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 47, total loss: 42.450589
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 48, total loss: 42.299538
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 49, total loss: 42.256048
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 50, total loss: 42.378997
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 51, total loss: 42.277841
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 52, total loss: 42.061969
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 53, total loss: 42.243221
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 54, total loss: 42.283335
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 55, total loss: 42.512693
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 56, total loss: 42.503777
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 57, total loss: 42.552613
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 58, total loss: 42.676329
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 59, total loss: 42.648267
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 60, total loss: 42.443454
# total_train_accuracy: tensor(0.9833, device='cuda:0')
# Training Epoch: 61, total loss: 42.085279
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 62, total loss: 42.645826
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 63, total loss: 42.751488
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 64, total loss: 42.463458
# total_train_accuracy: tensor(0.9875, device='cuda:0')
# Training Epoch: 65, total loss: 41.991089
# total_train_accuracy: tensor(0.9896, device='cuda:0')
# Training Epoch: 66, total loss: 41.904405
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 67, total loss: 42.297129
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 68, total loss: 42.408373
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 69, total loss: 42.535907
# total_train_accuracy: tensor(0.9625, device='cuda:0')
# Training Epoch: 70, total loss: 43.006894
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 71, total loss: 42.352260
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 72, total loss: 42.044660
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 73, total loss: 42.452705
# total_train_accuracy: tensor(0.9771, device='cuda:0')
# Training Epoch: 74, total loss: 42.355910
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 75, total loss: 42.532068
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 76, total loss: 42.471185
# total_train_accuracy: tensor(0.9854, device='cuda:0')
# Training Epoch: 77, total loss: 42.072873
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 78, total loss: 42.575183
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 79, total loss: 42.451073
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 80, total loss: 42.456945
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 81, total loss: 42.216994
# total_train_accuracy: tensor(0.9667, device='cuda:0')
# Training Epoch: 82, total loss: 42.651054
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 83, total loss: 42.469183
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 84, total loss: 42.441402
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 85, total loss: 42.477254
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 86, total loss: 42.494747
# total_train_accuracy: tensor(0.9729, device='cuda:0')
# Training Epoch: 87, total loss: 42.345723
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 88, total loss: 42.446208
# total_train_accuracy: tensor(0.9646, device='cuda:0')
# Training Epoch: 89, total loss: 42.675999
# total_train_accuracy: tensor(0.9604, device='cuda:0')
# Training Epoch: 90, total loss: 42.795340
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 91, total loss: 42.495980
# total_train_accuracy: tensor(0.9750, device='cuda:0')
# Training Epoch: 92, total loss: 42.522733
# total_train_accuracy: tensor(0.9458, device='cuda:0')
# Training Epoch: 93, total loss: 43.082018
# total_train_accuracy: tensor(0.9563, device='cuda:0')
# Training Epoch: 94, total loss: 42.793665
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 95, total loss: 42.378053
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 96, total loss: 42.051497
# total_train_accuracy: tensor(0.9792, device='cuda:0')
# Training Epoch: 97, total loss: 42.115818
# total_train_accuracy: tensor(0.9813, device='cuda:0')
# Training Epoch: 98, total loss: 42.155878
# total_train_accuracy: tensor(0.9708, device='cuda:0')
# Training Epoch: 99, total loss: 42.390541
# total_train_accuracy: tensor(0.9688, device='cuda:0')
# Training Epoch: 100, total loss: 42.583862
# the  9  epoch ends
# test
# test
# test
# total_test_accuracy: tensor(0.9792, device='cuda:0')
# acc_test_each_k: tensor(0.9792, device='cuda:0')
# [tensor(0.8750, device='cuda:0'), tensor(0.9583, device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(0.9792, device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(1., device='cuda:0'), tensor(0.9792, device='cuda:0')]
# [array(0.875, dtype=float32), array(0.9583334, dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(0.9791667, dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(1., dtype=float32), array(0.9791667, dtype=float32)]
# acc_test_metrics: 0.9791667

# %%
import torch

#功能：加载保存到path中的各层参数到神经网络

#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP610.pkl'
#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP9110.pkl'
path='results_genes/intersections/models/all_samples/MLP610.pt'
#path='dataset/qiuguan/model_new_K_fold_RandomTree/MLP_non_encode/MLP10910.pkl'
#nfm=NFM(nfm_config)
mlp=MLP2()
#print(nfm)
#net = nn.DataParallel(net)
#net = net.to(device)
mlp.load_state_dict(torch.load(path),strict=False)
mlp.cuda()

print(mlp)




mlp_params = list(mlp.named_parameters())
#print(nfm_params)
net=mlp


testset = KZDatasetTest(csv_path='results_genes/intersections/dataset/test_info_all_samples.csv')
   
test_loader = data.DataLoader(
         dataset=testset,
         #transform=torchvision.transforms.ToTensor(),
         
         batch_size=nfm_config['batch_size']
        
     )
#———————————————— 
#版权声明：本文为CSDN博主「山阴少年」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/jclian91/article/details/121708431# 
from torch.autograd import Variable 
from torch.utils.data import DataLoader 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import accuracy_score 
 
def evaluate_model(test_dl, model): 
    model.eval()#测试数据稳定
    predictions, actuals = [], [] 
    for i, (inputs, targets) in enumerate(test_dl): 
        # evaluate the model on the test set 
        #print(\ inputs:\ ,inputs) 
        #print(\ targets:\ ,targets) 
        inputs = Variable(inputs) 
        targets = Variable(targets) 
                 
                 
        #x = torch.tensor(x, dtype=torch.float) 
        #x=x.clone().detach().requires_grad_(True) 
        inputs=torch.tensor(inputs,dtype=torch.float) 
        targets=torch.tensor(targets,dtype=torch.float) 
        inputs, targets = inputs.cuda(), targets.cuda() 
        yhat = model(inputs) 
        yhat=(yhat==torch.max(yhat,1,keepdim=True)[0]).to(dtype=torch.int32)
        # retrieve numpy array 
        #yhat = yhat.detach().numpy() 
        yhat = yhat.detach().cpu().numpy()#转换到cpu 
        # yhat=yhat.argmax(axis=1) 
        #print(yhat:\ ,yhat) 
        #print('yhat.shape:',yhat.shape) 
        actual = targets.detach().cpu().numpy() 
        actual=actual.round() 
        #print(\ actual:\ ,actual) 
        #print('actual.shape:',actual.shape
        #predictions.appe) 
        #actual = actual.reshape(-1, 1) 
        # round to class values 
        yhat = yhat.round() 
        # store nd(yhat) 
        actuals.append(actual) 
        predictions.append(yhat)
    #print("prediction:" ,predictions) 
    #print("actuals:",actuals) 
    predictions, actuals = np.vstack(predictions), np.vstack(actuals) 
    #print("prediction:" ,predictions) 
    #print("actuals:" ,actuals) 
    # calculate accuracy 
    acc_test = accuracy_score(actuals, predictions) 
    return  actuals, predictions,acc_test 

import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch.nn.functional as F 
from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 

import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


import torch.nn.functional as F 

actuals,predictions,acc_test=evaluate_model(test_loader,net)


from sklearn.metrics import precision_recall_curve, average_precision_score,roc_curve, auc, precision_score, recall_score, f1_score, confusion_matrix, accuracy_score 
target_list=actuals 
pred_list=predictions 
      
y_true=target_list 
y_pred=pred_list 
      
f1=f1_score(y_true=target_list, y_pred=pred_list, average='macro') # 也可以指定micro模式 
acc_score=accuracy_score(y_true=target_list, y_pred=pred_list) 
rec_score=recall_score(y_true=target_list,y_pred=pred_list,average='macro') # 也可以指定micro模式 
pre_recall=precision_score(y_true=target_list,y_pred=pred_list,average='macro') 
print("f1_score:  %.4f" ,f1) 
print("accuracy_score:" ,acc_score) 
print("recall_score:",rec_score) 
print("pre_recall:" ,pre_recall)



auc_curve = roc_auc_score(y_true, y_pred, multi_class='ovo')
#———————————————— 
#版权声明：本文为CSDN博主「农民小飞侠」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。 
#原文链接：https://blog.csdn.net/w5688414/article/details/106595892 
PM_y=y_pred 
true_y=y_true 
n_classes=PM_y.shape[1] 
      
print("n_classes:",n_classes) 
fpr = dict() 
tpr = dict() 
roc_auc = dict() 
for i in range(n_classes): 
    fpr[i], tpr[i], _ = roc_curve(true_y[:, i], PM_y[:, i]) 
    roc_auc[i] = auc(fpr[i], tpr[i]) 
    #print(i) 
    #print(fpr) 
    #print(tpr) 
    
    
    
#计算macro auc 
from scipy import interp 
# First aggregate all false positive rates 
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)])) 
       
# Then interpolate all ROC curves at this points 
mean_tpr = np.zeros_like(all_fpr) 
for i in range(n_classes): 
    mean_tpr += interp(all_fpr, fpr[i], tpr[i]) 
       
    # Finally average it and compute AUC 
    mean_tpr /= n_classes 
       
    fpr["macro"] = all_fpr 
    tpr["macro"] = mean_tpr 
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    
    
    
#画图 
      
import matplotlib.pyplot as plt 
from itertools import cycle 
from matplotlib.ticker import FuncFormatter 
lw = 2 
# Plot all ROC curves 
plt.figure() 
labels=['Con(0)','DN(1)','FSGS(2)','HT(3)','IgA(4)','MCD(5)','MGN(6)','RPGN(7)','SLE(8)'] 

'''
plt.plot(fpr["macro"], tpr["macro"], 
              label='macro-average ROC curve (area = {0:0.4f})' 
                    ''.format(roc_auc["macro"]), 
              color='navy', linestyle=':', linewidth=4) 
'''

       
colors = cycle(['aqua', 'darkorange', 'cornflowerblue','blue','yellow','burlywood','cornsilk','darkblue','goldenrod','greenyellow','maroon']) 
for i, color in zip(range(n_classes), colors): 
    plt.plot(fpr[i], tpr[i], color=color, lw=lw, 
                  label=labels[i]+'(area = {0:0.4f})'.format(roc_auc[i])) 
       
    plt.plot([0, 1], [0, 1], 'k--', lw=lw) 
    plt.xlim([0.0, 1.0]) 
    plt.ylim([0.0, 1.05]) 
      
      
    plt.xlabel('1-Specificity (%)') 
    plt.ylabel('Sensitivity (%)') 
    #plt.title('testing on kidney tubules with F800 without augment') 
    plt.title('evaluation with MLP model on top 20 genes\n  based on mean of all samples ')   

        
def to_percent(temp, position): 
    return '%1.0f'%(100*temp) 
      
plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.gca().xaxis.set_major_formatter(FuncFormatter(to_percent)) 
plt.legend(loc="lower right" ) 
      
plt.show()
# Out:
# MLP2(
#   (bn0): BatchNorm1d(93, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=93, out_features=2000, bias=True)
#   (bn1): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=2000, out_features=100, bias=True)
#   (bn2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3): Linear(in_features=100, out_features=9, bias=True)
#   (bn3): BatchNorm1d(9, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=False)
# )
# 138 94
# f1_score:  %.4f 0.8972002864331725
# accuracy_score: 0.8985507246376812
# recall_score: 0.9066666666666667
# pre_recall: 0.8945822695822696
# n_classes: 9
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /home/zhengfang/.local/lib/python3.6/site-packages/ipykernel_launcher.py:151: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
